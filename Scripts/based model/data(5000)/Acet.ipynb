# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\5k\Acet_5k')
    epoch = 300
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\NEDD')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 45/45 - 5s - loss: 0.6974 - accuracy: 0.5092 - val_loss: 0.6927 - val_accuracy: 0.5016
#
# Epoch 00001: val_loss improved from inf to 0.69271, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 2/300
# 45/45 - 1s - loss: 0.6908 - accuracy: 0.5267 - val_loss: 0.6887 - val_accuracy: 0.5328
#
# Epoch 00002: val_loss improved from 0.69271 to 0.68875, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 3/300
# 45/45 - 0s - loss: 0.6845 - accuracy: 0.5515 - val_loss: 0.6864 - val_accuracy: 0.5449
#
# Epoch 00003: val_loss improved from 0.68875 to 0.68644, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 4/300
# 45/45 - 0s - loss: 0.6824 - accuracy: 0.5590 - val_loss: 0.6857 - val_accuracy: 0.5433
#
# Epoch 00004: val_loss improved from 0.68644 to 0.68573, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 5/300
# 45/45 - 0s - loss: 0.6796 - accuracy: 0.5621 - val_loss: 0.6809 - val_accuracy: 0.5574
#
# Epoch 00005: val_loss improved from 0.68573 to 0.68087, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 6/300
# 45/45 - 0s - loss: 0.6756 - accuracy: 0.5736 - val_loss: 0.6824 - val_accuracy: 0.5376
#
# Epoch 00006: val_loss did not improve from 0.68087
# Epoch 7/300
# 45/45 - 0s - loss: 0.6710 - accuracy: 0.5813 - val_loss: 0.6694 - val_accuracy: 0.5894
#
# Epoch 00007: val_loss improved from 0.68087 to 0.66936, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 8/300
# 45/45 - 0s - loss: 0.6616 - accuracy: 0.6020 - val_loss: 0.6633 - val_accuracy: 0.6032
#
# Epoch 00008: val_loss improved from 0.66936 to 0.66333, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 9/300
# 45/45 - 0s - loss: 0.6553 - accuracy: 0.6080 - val_loss: 0.6541 - val_accuracy: 0.6218
#
# Epoch 00009: val_loss improved from 0.66333 to 0.65412, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 10/300
# 45/45 - 0s - loss: 0.6494 - accuracy: 0.6192 - val_loss: 0.6488 - val_accuracy: 0.6278
#
# Epoch 00010: val_loss improved from 0.65412 to 0.64878, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 11/300
# 45/45 - 0s - loss: 0.6391 - accuracy: 0.6295 - val_loss: 0.6431 - val_accuracy: 0.6197
#
# Epoch 00011: val_loss improved from 0.64878 to 0.64312, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 12/300
# 45/45 - 0s - loss: 0.6345 - accuracy: 0.6402 - val_loss: 0.6599 - val_accuracy: 0.5943
#
# Epoch 00012: val_loss did not improve from 0.64312
# Epoch 13/300
# 45/45 - 0s - loss: 0.6283 - accuracy: 0.6477 - val_loss: 0.6488 - val_accuracy: 0.6149
#
# Epoch 00013: val_loss did not improve from 0.64312
# Epoch 14/300
# 45/45 - 0s - loss: 0.6275 - accuracy: 0.6489 - val_loss: 0.6557 - val_accuracy: 0.5922
#
# Epoch 00014: val_loss did not improve from 0.64312
# Epoch 15/300
# 45/45 - 0s - loss: 0.6221 - accuracy: 0.6517 - val_loss: 0.6397 - val_accuracy: 0.6294
#
# Epoch 00015: val_loss improved from 0.64312 to 0.63973, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 16/300
# 45/45 - 0s - loss: 0.6166 - accuracy: 0.6592 - val_loss: 0.6375 - val_accuracy: 0.6282
#
# Epoch 00016: val_loss improved from 0.63973 to 0.63747, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 17/300
# 45/45 - 0s - loss: 0.6151 - accuracy: 0.6628 - val_loss: 0.6296 - val_accuracy: 0.6367
#
# Epoch 00017: val_loss improved from 0.63747 to 0.62957, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 18/300
# 45/45 - 0s - loss: 0.6101 - accuracy: 0.6695 - val_loss: 0.6444 - val_accuracy: 0.6230
#
# Epoch 00018: val_loss did not improve from 0.62957
# Epoch 19/300
# 45/45 - 0s - loss: 0.6082 - accuracy: 0.6690 - val_loss: 0.6463 - val_accuracy: 0.6185
#
# Epoch 00019: val_loss did not improve from 0.62957
# Epoch 20/300
# 45/45 - 0s - loss: 0.6053 - accuracy: 0.6717 - val_loss: 0.6283 - val_accuracy: 0.6489
#
# Epoch 00020: val_loss improved from 0.62957 to 0.62828, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 21/300
# 45/45 - 0s - loss: 0.6030 - accuracy: 0.6704 - val_loss: 0.6332 - val_accuracy: 0.6404
#
# Epoch 00021: val_loss did not improve from 0.62828
# Epoch 22/300
# 45/45 - 0s - loss: 0.6022 - accuracy: 0.6747 - val_loss: 0.6259 - val_accuracy: 0.6428
#
# Epoch 00022: val_loss improved from 0.62828 to 0.62595, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 23/300
# 45/45 - 0s - loss: 0.5991 - accuracy: 0.6812 - val_loss: 0.6305 - val_accuracy: 0.6420
#
# Epoch 00023: val_loss did not improve from 0.62595
# Epoch 24/300
# 45/45 - 0s - loss: 0.6005 - accuracy: 0.6762 - val_loss: 0.6292 - val_accuracy: 0.6420
#
# Epoch 00024: val_loss did not improve from 0.62595
# Epoch 25/300
# 45/45 - 0s - loss: 0.5938 - accuracy: 0.6841 - val_loss: 0.6248 - val_accuracy: 0.6493
#
# Epoch 00025: val_loss improved from 0.62595 to 0.62476, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 26/300
# 45/45 - 0s - loss: 0.5928 - accuracy: 0.6819 - val_loss: 0.6223 - val_accuracy: 0.6456
#
# Epoch 00026: val_loss improved from 0.62476 to 0.62233, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 27/300
# 45/45 - 0s - loss: 0.5897 - accuracy: 0.6843 - val_loss: 0.6332 - val_accuracy: 0.6392
#
# Epoch 00027: val_loss did not improve from 0.62233
# Epoch 28/300
# 45/45 - 0s - loss: 0.5871 - accuracy: 0.6910 - val_loss: 0.6241 - val_accuracy: 0.6440
#
# Epoch 00028: val_loss did not improve from 0.62233
# Epoch 29/300
# 45/45 - 0s - loss: 0.5828 - accuracy: 0.6939 - val_loss: 0.6229 - val_accuracy: 0.6416
# Epoch 00029: val_loss did not improve from 0.62233
# Epoch 30/300
# 45/45 - 0s - loss: 0.5829 - accuracy: 0.6948 - val_loss: 0.6362 - val_accuracy: 0.6161
#
# Epoch 00030: val_loss did not improve from 0.62233
# Epoch 31/300
# 45/45 - 0s - loss: 0.5841 - accuracy: 0.6924 - val_loss: 0.6288 - val_accuracy: 0.6319
#
# Epoch 00031: val_loss did not improve from 0.62233
# Epoch 32/300
# 45/45 - 0s - loss: 0.5812 - accuracy: 0.6962 - val_loss: 0.6234 - val_accuracy: 0.6408
#
# Epoch 00032: val_loss did not improve from 0.62233
# Epoch 33/300
# 45/45 - 0s - loss: 0.5739 - accuracy: 0.7017 - val_loss: 0.6379 - val_accuracy: 0.6137
#
# Epoch 00033: val_loss did not improve from 0.62233
# Epoch 34/300
# 45/45 - 0s - loss: 0.5739 - accuracy: 0.7019 - val_loss: 0.6336 - val_accuracy: 0.6226
#
# Epoch 00034: val_loss did not improve from 0.62233
# Epoch 35/300
# 45/45 - 0s - loss: 0.5733 - accuracy: 0.7010 - val_loss: 0.6536 - val_accuracy: 0.6032
#
# Epoch 00035: val_loss did not improve from 0.62233
# Epoch 36/300
# 45/45 - 0s - loss: 0.5765 - accuracy: 0.6981 - val_loss: 0.6177 - val_accuracy: 0.6505
#
# Epoch 00036: val_loss improved from 0.62233 to 0.61774, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 37/300
# 45/45 - 0s - loss: 0.5735 - accuracy: 0.6953 - val_loss: 0.6221 - val_accuracy: 0.6521
#
# Epoch 00037: val_loss did not improve from 0.61774
# Epoch 38/300
# 45/45 - 0s - loss: 0.5666 - accuracy: 0.7075 - val_loss: 0.6326 - val_accuracy: 0.6294
#
# Epoch 00038: val_loss did not improve from 0.61774
# Epoch 39/300
# 45/45 - 0s - loss: 0.5717 - accuracy: 0.7020 - val_loss: 0.6203 - val_accuracy: 0.6456
#
# Epoch 00039: val_loss did not improve from 0.61774
# Epoch 40/300
# 45/45 - 0s - loss: 0.5650 - accuracy: 0.7079 - val_loss: 0.6310 - val_accuracy: 0.6351
#
# Epoch 00040: val_loss did not improve from 0.61774
# Epoch 41/300
# 45/45 - 0s - loss: 0.5664 - accuracy: 0.7039 - val_loss: 0.6292 - val_accuracy: 0.6339
#
# Epoch 00041: val_loss did not improve from 0.61774
# Epoch 42/300
# 45/45 - 0s - loss: 0.5674 - accuracy: 0.7047 - val_loss: 0.6291 - val_accuracy: 0.6363
#
# Epoch 00042: val_loss did not improve from 0.61774
# Epoch 43/300
# 45/45 - 0s - loss: 0.5577 - accuracy: 0.7130 - val_loss: 0.6247 - val_accuracy: 0.6436
#
# Epoch 00043: val_loss did not improve from 0.61774
# Epoch 44/300
# 45/45 - 0s - loss: 0.5581 - accuracy: 0.7097 - val_loss: 0.6219 - val_accuracy: 0.6485
#
# Epoch 00044: val_loss did not improve from 0.61774
# Epoch 45/300
# 45/45 - 0s - loss: 0.5553 - accuracy: 0.7142 - val_loss: 0.6163 - val_accuracy: 0.6561
#
# Epoch 00045: val_loss improved from 0.61774 to 0.61634, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 46/300
# 45/45 - 0s - loss: 0.5575 - accuracy: 0.7165 - val_loss: 0.6216 - val_accuracy: 0.6489
#
# Epoch 00046: val_loss did not improve from 0.61634
# Epoch 47/300
# 45/45 - 0s - loss: 0.5552 - accuracy: 0.7148 - val_loss: 0.6227 - val_accuracy: 0.6493
#
# Epoch 00047: val_loss did not improve from 0.61634
# Epoch 48/300
# 45/45 - 0s - loss: 0.5490 - accuracy: 0.7207 - val_loss: 0.6290 - val_accuracy: 0.6359
#
# Epoch 00048: val_loss did not improve from 0.61634
# Epoch 49/300
# 45/45 - 0s - loss: 0.5528 - accuracy: 0.7177 - val_loss: 0.6156 - val_accuracy: 0.6493
#
# Epoch 00049: val_loss improved from 0.61634 to 0.61562, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 50/300
# 45/45 - 0s - loss: 0.5502 - accuracy: 0.7157 - val_loss: 0.6361 - val_accuracy: 0.6278
#
# Epoch 00050: val_loss did not improve from 0.61562
# Epoch 51/300
# 45/45 - 0s - loss: 0.5447 - accuracy: 0.7229 - val_loss: 0.6214 - val_accuracy: 0.6517
#
# Epoch 00051: val_loss did not improve from 0.61562
# Epoch 52/300
# 45/45 - 0s - loss: 0.5498 - accuracy: 0.7196 - val_loss: 0.6264 - val_accuracy: 0.6590
#
# Epoch 00052: val_loss did not improve from 0.61562
# Epoch 53/300
# 45/45 - 0s - loss: 0.5432 - accuracy: 0.7243 - val_loss: 0.6199 - val_accuracy: 0.6513
#
# Epoch 00053: val_loss did not improve from 0.61562
# Epoch 54/300
# 45/45 - 0s - loss: 0.5431 - accuracy: 0.7238 - val_loss: 0.6204 - val_accuracy: 0.6513
#
# Epoch 00054: val_loss did not improve from 0.61562
# Epoch 55/300
# 45/45 - 0s - loss: 0.5453 - accuracy: 0.7226 - val_loss: 0.6199 - val_accuracy: 0.6521
#
# Epoch 00055: val_loss did not improve from 0.61562
# Epoch 56/300
# 45/45 - 0s - loss: 0.5385 - accuracy: 0.7264 - val_loss: 0.6169 - val_accuracy: 0.6574
#
# Epoch 00056: val_loss did not improve from 0.61562
# Epoch 57/300
# 45/45 - 0s - loss: 0.5349 - accuracy: 0.7261 - val_loss: 0.6204 - val_accuracy: 0.6541
#
# Epoch 00057: val_loss did not improve from 0.61562
# Epoch 58/300
# 45/45 - 0s - loss: 0.5349 - accuracy: 0.7308 - val_loss: 0.6160 - val_accuracy: 0.6529
#
# Epoch 00058: val_loss did not improve from 0.61562
# Epoch 59/300
# 45/45 - 0s - loss: 0.5316 - accuracy: 0.7306 - val_loss: 0.6128 - val_accuracy: 0.6650
#
# Epoch 00059: val_loss improved from 0.61562 to 0.61285, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 60/300
# 45/45 - 0s - loss: 0.5326 - accuracy: 0.7339 - val_loss: 0.6180 - val_accuracy: 0.6590
#
# Epoch 00060: val_loss did not improve from 0.61285
# Epoch 61/300
# 45/45 - 0s - loss: 0.5337 - accuracy: 0.7301 - val_loss: 0.6236 - val_accuracy: 0.6452
#
# Epoch 00061: val_loss did not improve from 0.61285
# Epoch 62/300
# 45/45 - 0s - loss: 0.5262 - accuracy: 0.7316 - val_loss: 0.6255 - val_accuracy: 0.6408
#
# Epoch 00062: val_loss did not improve from 0.61285
# Epoch 63/300
# 45/45 - 0s - loss: 0.5320 - accuracy: 0.7310 - val_loss: 0.6172 - val_accuracy: 0.6586
#
# Epoch 00063: val_loss did not improve from 0.61285
# Epoch 64/300
# 45/45 - 0s - loss: 0.5270 - accuracy: 0.7358 - val_loss: 0.6139 - val_accuracy: 0.6590
#
# Epoch 00064: val_loss did not improve from 0.61285
# Epoch 65/300
# 45/45 - 0s - loss: 0.5280 - accuracy: 0.7321 - val_loss: 0.6205 - val_accuracy: 0.6505
#
# Epoch 00065: val_loss did not improve from 0.61285
# Epoch 66/300
# 45/45 - 0s - loss: 0.5250 - accuracy: 0.7341 - val_loss: 0.6257 - val_accuracy: 0.6464
#
# Epoch 00066: val_loss did not improve from 0.61285
# Epoch 67/300
# 45/45 - 0s - loss: 0.5242 - accuracy: 0.7348 - val_loss: 0.6162 - val_accuracy: 0.6501
#
# Epoch 00067: val_loss did not improve from 0.61285
# Epoch 68/300
# 45/45 - 0s - loss: 0.5200 - accuracy: 0.7363 - val_loss: 0.6166 - val_accuracy: 0.6570
#
# Epoch 00068: val_loss did not improve from 0.61285
# Epoch 69/300
# 45/45 - 0s - loss: 0.5187 - accuracy: 0.7405 - val_loss: 0.6157 - val_accuracy: 0.6497
#
# Epoch 00069: val_loss did not improve from 0.61285
# Epoch 70/300
# 45/45 - 0s - loss: 0.5153 - accuracy: 0.7435 - val_loss: 0.6428 - val_accuracy: 0.6343
#
# Epoch 00070: val_loss did not improve from 0.61285
# Epoch 71/300
# 45/45 - 0s - loss: 0.5218 - accuracy: 0.7380 - val_loss: 0.6187 - val_accuracy: 0.6610
#
# Epoch 00071: val_loss did not improve from 0.61285
# Epoch 72/300
# 45/45 - 0s - loss: 0.5183 - accuracy: 0.7387 - val_loss: 0.6167 - val_accuracy: 0.6493
#
# Epoch 00072: val_loss did not improve from 0.61285
# Epoch 73/300
# 45/45 - 0s - loss: 0.5139 - accuracy: 0.7436 - val_loss: 0.6165 - val_accuracy: 0.6525
#
# Epoch 00073: val_loss did not improve from 0.61285
# Epoch 74/300
# 45/45 - 0s - loss: 0.5127 - accuracy: 0.7448 - val_loss: 0.6125 - val_accuracy: 0.6646
#
# Epoch 00074: val_loss improved from 0.61285 to 0.61247, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5
# Epoch 75/300
# 45/45 - 0s - loss: 0.5093 - accuracy: 0.7482 - val_loss: 0.6219 - val_accuracy: 0.6517
#
# Epoch 00075: val_loss did not improve from 0.61247
# Epoch 76/300
# 45/45 - 0s - loss: 0.5127 - accuracy: 0.7443 - val_loss: 0.6195 - val_accuracy: 0.6549
#
# Epoch 00076: val_loss did not improve from 0.61247
# Epoch 77/300
# 45/45 - 0s - loss: 0.5135 - accuracy: 0.7424 - val_loss: 0.6309 - val_accuracy: 0.6404
#
# Epoch 00077: val_loss did not improve from 0.61247
# Epoch 78/300
# 45/45 - 0s - loss: 0.5068 - accuracy: 0.7494 - val_loss: 0.6194 - val_accuracy: 0.6549
#
# Epoch 00078: val_loss did not improve from 0.61247
# Epoch 79/300
# 45/45 - 0s - loss: 0.5018 - accuracy: 0.7507 - val_loss: 0.6241 - val_accuracy: 0.6513
#
# Epoch 00079: val_loss did not improve from 0.61247
# Epoch 80/300
# 45/45 - 0s - loss: 0.5031 - accuracy: 0.7527 - val_loss: 0.6328 - val_accuracy: 0.6392
#
# Epoch 00080: val_loss did not improve from 0.61247
# Epoch 81/300
# 45/45 - 0s - loss: 0.5003 - accuracy: 0.7512 - val_loss: 0.6216 - val_accuracy: 0.6485
#
# Epoch 00081: val_loss did not improve from 0.61247
# Epoch 82/300
# 45/45 - 0s - loss: 0.5069 - accuracy: 0.7476 - val_loss: 0.6215 - val_accuracy: 0.6545
#
# Epoch 00082: val_loss did not improve from 0.61247
# Epoch 83/300
# 45/45 - 0s - loss: 0.4994 - accuracy: 0.7528 - val_loss: 0.6238 - val_accuracy: 0.6497
#
# Epoch 00083: val_loss did not improve from 0.61247
# Epoch 84/300
# 45/45 - 0s - loss: 0.5043 - accuracy: 0.7444 - val_loss: 0.6156 - val_accuracy: 0.6561
#
# Epoch 00084: val_loss did not improve from 0.61247
# Epoch 85/300
# 45/45 - 0s - loss: 0.5004 - accuracy: 0.7508 - val_loss: 0.6215 - val_accuracy: 0.6570
#
# Epoch 00085: val_loss did not improve from 0.61247
# Epoch 86/300
# 45/45 - 0s - loss: 0.4907 - accuracy: 0.7568 - val_loss: 0.6182 - val_accuracy: 0.6521
#
# Epoch 00086: val_loss did not improve from 0.61247
# Epoch 87/300
# 45/45 - 0s - loss: 0.4951 - accuracy: 0.7566 - val_loss: 0.6367 - val_accuracy: 0.6363
#
# Epoch 00087: val_loss did not improve from 0.61247
# Epoch 88/300
# 45/45 - 0s - loss: 0.5011 - accuracy: 0.7519 - val_loss: 0.6207 - val_accuracy: 0.6537
#
# Epoch 00088: val_loss did not improve from 0.61247
# Epoch 89/300
# 45/45 - 0s - loss: 0.4958 - accuracy: 0.7540 - val_loss: 0.6179 - val_accuracy: 0.6570
#
# Epoch 00089: val_loss did not improve from 0.61247
# Epoch 90/300
# 45/45 - 0s - loss: 0.4877 - accuracy: 0.7627 - val_loss: 0.6167 - val_accuracy: 0.6598
#
# Epoch 00090: val_loss did not improve from 0.61247
# Epoch 91/300
# 45/45 - 0s - loss: 0.4930 - accuracy: 0.7556 - val_loss: 0.6206 - val_accuracy: 0.6582
#
# Epoch 00091: val_loss did not improve from 0.61247
# Epoch 92/300
# 45/45 - 0s - loss: 0.4853 - accuracy: 0.7621 - val_loss: 0.6209 - val_accuracy: 0.6566
#
# Epoch 00092: val_loss did not improve from 0.61247
# Epoch 93/300
# 45/45 - 0s - loss: 0.4854 - accuracy: 0.7634 - val_loss: 0.6211 - val_accuracy: 0.6505
#
# Epoch 00093: val_loss did not improve from 0.61247
# Epoch 94/300
# 45/45 - 0s - loss: 0.4922 - accuracy: 0.7551 - val_loss: 0.6215 - val_accuracy: 0.6533
#
# Epoch 00094: val_loss did not improve from 0.61247
# Epoch 95/300
# 45/45 - 0s - loss: 0.4881 - accuracy: 0.7635 - val_loss: 0.6203 - val_accuracy: 0.6557
#
# Epoch 00095: val_loss did not improve from 0.61247
# Epoch 96/300
# 45/45 - 0s - loss: 0.4827 - accuracy: 0.7641 - val_loss: 0.6194 - val_accuracy: 0.6553
#
# Epoch 00096: val_loss did not improve from 0.61247
# Epoch 97/300
# 45/45 - 0s - loss: 0.4825 - accuracy: 0.7653 - val_loss: 0.6225 - val_accuracy: 0.6529
#
# Epoch 00097: val_loss did not improve from 0.61247
# Epoch 98/300
# 45/45 - 0s - loss: 0.4838 - accuracy: 0.7628 - val_loss: 0.6362 - val_accuracy: 0.6347
#
# Epoch 00098: val_loss did not improve from 0.61247
# Epoch 99/300
# 45/45 - 0s - loss: 0.4746 - accuracy: 0.7675 - val_loss: 0.6209 - val_accuracy: 0.6493
#
# Epoch 00099: val_loss did not improve from 0.61247
# Epoch 100/300
# 45/45 - 0s - loss: 0.4767 - accuracy: 0.7692 - val_loss: 0.6263 - val_accuracy: 0.6440
#
# Epoch 00100: val_loss did not improve from 0.61247
# Epoch 101/300
# 45/45 - 0s - loss: 0.4737 - accuracy: 0.7691 - val_loss: 0.6220 - val_accuracy: 0.6493
#
# Epoch 00101: val_loss did not improve from 0.61247
# Epoch 102/300
# 45/45 - 0s - loss: 0.4747 - accuracy: 0.7694 - val_loss: 0.6162 - val_accuracy: 0.6582
#
# Epoch 00102: val_loss did not improve from 0.61247
# Epoch 103/300
# 45/45 - 0s - loss: 0.4721 - accuracy: 0.7721 - val_loss: 0.6152 - val_accuracy: 0.6630
#
# Epoch 00103: val_loss did not improve from 0.61247
# Epoch 104/300
# 45/45 - 0s - loss: 0.4723 - accuracy: 0.7707 - val_loss: 0.6171 - val_accuracy: 0.6545
#
# Epoch 00104: val_loss did not improve from 0.61247
# Epoch 105/300
# 45/45 - 0s - loss: 0.4725 - accuracy: 0.7718 - val_loss: 0.6227 - val_accuracy: 0.6493
#
# Epoch 00105: val_loss did not improve from 0.61247
# Epoch 106/300
# 45/45 - 0s - loss: 0.4737 - accuracy: 0.7693 - val_loss: 0.6166 - val_accuracy: 0.6614
#
# Epoch 00106: val_loss did not improve from 0.61247
# Epoch 107/300
# 45/45 - 0s - loss: 0.4727 - accuracy: 0.7682 - val_loss: 0.6210 - val_accuracy: 0.6525
#
# Epoch 00107: val_loss did not improve from 0.61247
# Epoch 108/300
# 45/45 - 0s - loss: 0.4674 - accuracy: 0.7779 - val_loss: 0.6240 - val_accuracy: 0.6509
#
# Epoch 00108: val_loss did not improve from 0.61247
# Epoch 109/300
# 45/45 - 0s - loss: 0.4650 - accuracy: 0.7750 - val_loss: 0.6182 - val_accuracy: 0.6505
#
# Epoch 00109: val_loss did not improve from 0.61247
# Epoch 110/300
# 45/45 - 0s - loss: 0.4701 - accuracy: 0.7710 - val_loss: 0.6198 - val_accuracy: 0.6509
#
# Epoch 00110: val_loss did not improve from 0.61247
# Epoch 111/300
# 45/45 - 0s - loss: 0.4672 - accuracy: 0.7743 - val_loss: 0.6325 - val_accuracy: 0.6359
#
# Epoch 00111: val_loss did not improve from 0.61247
# Epoch 112/300
# 45/45 - 0s - loss: 0.4623 - accuracy: 0.7726 - val_loss: 0.6225 - val_accuracy: 0.6509
#
# Epoch 00112: val_loss did not improve from 0.61247
# Epoch 113/300
# 45/45 - 0s - loss: 0.4689 - accuracy: 0.7771 - val_loss: 0.6229 - val_accuracy: 0.6456
#
# Epoch 00113: val_loss did not improve from 0.61247
# Epoch 114/300
# 45/45 - 0s - loss: 0.4677 - accuracy: 0.7721 - val_loss: 0.6191 - val_accuracy: 0.6525
#
# Epoch 00114: val_loss did not improve from 0.61247
# Epoch 115/300
# 45/45 - 0s - loss: 0.4594 - accuracy: 0.7771 - val_loss: 0.6245 - val_accuracy: 0.6416
#
# Epoch 00115: val_loss did not improve from 0.61247
# Epoch 116/300
# 45/45 - 0s - loss: 0.4625 - accuracy: 0.7778 - val_loss: 0.6256 - val_accuracy: 0.6497
#
# Epoch 00116: val_loss did not improve from 0.61247
# Epoch 117/300
# 45/45 - 0s - loss: 0.4648 - accuracy: 0.7792 - val_loss: 0.6280 - val_accuracy: 0.6472
#
# Epoch 00117: val_loss did not improve from 0.61247
# Epoch 118/300
# 45/45 - 0s - loss: 0.4675 - accuracy: 0.7706 - val_loss: 0.6242 - val_accuracy: 0.6460
#
# Epoch 00118: val_loss did not improve from 0.61247
# Epoch 119/300
# 45/45 - 0s - loss: 0.4571 - accuracy: 0.7841 - val_loss: 0.6206 - val_accuracy: 0.6590
#
# Epoch 00119: val_loss did not improve from 0.61247
# Epoch 120/300
# 45/45 - 0s - loss: 0.4587 - accuracy: 0.7823 - val_loss: 0.6223 - val_accuracy: 0.6537
#
# Epoch 00120: val_loss did not improve from 0.61247
# Epoch 121/300
# 45/45 - 0s - loss: 0.4552 - accuracy: 0.7854 - val_loss: 0.6193 - val_accuracy: 0.6521
#
# Epoch 00121: val_loss did not improve from 0.61247
# Epoch 122/300
# 45/45 - 0s - loss: 0.4537 - accuracy: 0.7830 - val_loss: 0.6205 - val_accuracy: 0.6513
#
# Epoch 00122: val_loss did not improve from 0.61247
# Epoch 123/300
# 45/45 - 0s - loss: 0.4490 - accuracy: 0.7897 - val_loss: 0.6208 - val_accuracy: 0.6570
#
# Epoch 00123: val_loss did not improve from 0.61247
# Epoch 124/300
# 45/45 - 0s - loss: 0.4539 - accuracy: 0.7863 - val_loss: 0.6251 - val_accuracy: 0.6501
#
# Epoch 00124: val_loss did not improve from 0.61247
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6251 - accuracy: 0.6501
# Independent test: [0.6251025795936584, 0.6500809192657471]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.5760517799352751,
#  'SP': 0.7241100323624595,
#  'ACC': 0.6500809061488673,
#  'MCC': 0.30350687023821216,
#  'Recall': 0.5760517799352751,
#  'Precision': 0.6761633428300095,
#  'F1-score': 0.6221057230231543,
#  'Cutoff': 0.5}
