# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    #network.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\based\5k\K_5k')
    epoch = 300
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\based\NEDD')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 45/45 - 6s - loss: 0.6957 - accuracy: 0.5140 - val_loss: 0.6955 - val_accuracy: 0.5004
#
# Epoch 00001: val_loss improved from inf to 0.69552, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 2/300
# 45/45 - 1s - loss: 0.6907 - accuracy: 0.5244 - val_loss: 0.6888 - val_accuracy: 0.5413
#
# Epoch 00002: val_loss improved from 0.69552 to 0.68885, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 3/300
# 45/45 - 0s - loss: 0.6840 - accuracy: 0.5496 - val_loss: 0.6858 - val_accuracy: 0.5469
#
# Epoch 00003: val_loss improved from 0.68885 to 0.68584, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 4/300
# 45/45 - 0s - loss: 0.6812 - accuracy: 0.5592 - val_loss: 0.6839 - val_accuracy: 0.5372
#
# Epoch 00004: val_loss improved from 0.68584 to 0.68386, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 5/300
# 45/45 - 0s - loss: 0.6822 - accuracy: 0.5595 - val_loss: 0.6806 - val_accuracy: 0.5542
#
# Epoch 00005: val_loss improved from 0.68386 to 0.68061, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 6/300
# 45/45 - 0s - loss: 0.6787 - accuracy: 0.5612 - val_loss: 0.6793 - val_accuracy: 0.5611
#
# Epoch 00006: val_loss improved from 0.68061 to 0.67933, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 7/300
# 45/45 - 0s - loss: 0.6754 - accuracy: 0.5678 - val_loss: 0.6784 - val_accuracy: 0.5607
#
# Epoch 00007: val_loss improved from 0.67933 to 0.67840, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 8/300
# 45/45 - 0s - loss: 0.6730 - accuracy: 0.5782 - val_loss: 0.6711 - val_accuracy: 0.5781
#
# Epoch 00008: val_loss improved from 0.67840 to 0.67108, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 9/300
# 45/45 - 0s - loss: 0.6703 - accuracy: 0.5841 - val_loss: 0.6684 - val_accuracy: 0.5777
#
# Epoch 00009: val_loss improved from 0.67108 to 0.66838, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 10/300
# 45/45 - 0s - loss: 0.6661 - accuracy: 0.5957 - val_loss: 0.6621 - val_accuracy: 0.5995
#
# Epoch 00010: val_loss improved from 0.66838 to 0.66213, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 11/300
# 45/45 - 0s - loss: 0.6575 - accuracy: 0.6044 - val_loss: 0.6609 - val_accuracy: 0.6048
#
# Epoch 00011: val_loss improved from 0.66213 to 0.66095, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 12/300
# 45/45 - 0s - loss: 0.6585 - accuracy: 0.6050 - val_loss: 0.6591 - val_accuracy: 0.6129
#
# Epoch 00012: val_loss improved from 0.66095 to 0.65911, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 13/300
# 45/45 - 0s - loss: 0.6526 - accuracy: 0.6165 - val_loss: 0.6770 - val_accuracy: 0.5663
#
# Epoch 00013: val_loss did not improve from 0.65911
# Epoch 14/300
# 45/45 - 0s - loss: 0.6521 - accuracy: 0.6176 - val_loss: 0.6457 - val_accuracy: 0.6375
#
# Epoch 00014: val_loss improved from 0.65911 to 0.64571, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 15/300
# 45/45 - 0s - loss: 0.6483 - accuracy: 0.6219 - val_loss: 0.6529 - val_accuracy: 0.6214
#
# Epoch 00015: val_loss did not improve from 0.64571
# Epoch 16/300
# 45/45 - 0s - loss: 0.6465 - accuracy: 0.6221 - val_loss: 0.6446 - val_accuracy: 0.6383
#
# Epoch 00016: val_loss improved from 0.64571 to 0.64464, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 17/300
# 45/45 - 0s - loss: 0.6407 - accuracy: 0.6323 - val_loss: 0.6476 - val_accuracy: 0.6412
#
# Epoch 00017: val_loss did not improve from 0.64464
# Epoch 18/300
# 45/45 - 0s - loss: 0.6395 - accuracy: 0.6329 - val_loss: 0.6441 - val_accuracy: 0.6311
#
# Epoch 00018: val_loss improved from 0.64464 to 0.64406, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 19/300
# 45/45 - 0s - loss: 0.6380 - accuracy: 0.6309 - val_loss: 0.6450 - val_accuracy: 0.6335
#
# Epoch 00019: val_loss did not improve from 0.64406
# Epoch 20/300
# 45/45 - 0s - loss: 0.6363 - accuracy: 0.6387 - val_loss: 0.6428 - val_accuracy: 0.6383
#
# Epoch 00020: val_loss improved from 0.64406 to 0.64282, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 21/300
# 45/45 - 0s - loss: 0.6319 - accuracy: 0.6414 - val_loss: 0.6381 - val_accuracy: 0.6557
#
# Epoch 00021: val_loss improved from 0.64282 to 0.63808, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 22/300
# 45/45 - 0s - loss: 0.6343 - accuracy: 0.6415 - val_loss: 0.6519 - val_accuracy: 0.6242
#
# Epoch 00022: val_loss did not improve from 0.63808
# Epoch 23/300
# 45/45 - 0s - loss: 0.6288 - accuracy: 0.6449 - val_loss: 0.6321 - val_accuracy: 0.6448
#
# Epoch 00023: val_loss improved from 0.63808 to 0.63205, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 24/300
# 45/45 - 0s - loss: 0.6278 - accuracy: 0.6464 - val_loss: 0.6611 - val_accuracy: 0.6096
#
# Epoch 00024: val_loss did not improve from 0.63205
# Epoch 25/300
# 45/45 - 0s - loss: 0.6244 - accuracy: 0.6532 - val_loss: 0.6291 - val_accuracy: 0.6614
#
# Epoch 00025: val_loss improved from 0.63205 to 0.62913, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 26/300
# 45/45 - 0s - loss: 0.6222 - accuracy: 0.6540 - val_loss: 0.6324 - val_accuracy: 0.6456
#
# Epoch 00026: val_loss did not improve from 0.62913
# Epoch 27/300
# 45/45 - 0s - loss: 0.6243 - accuracy: 0.6504 - val_loss: 0.6256 - val_accuracy: 0.6691
# Epoch 00027: val_loss improved from 0.62913 to 0.62557, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 28/300
# 45/45 - 0s - loss: 0.6192 - accuracy: 0.6570 - val_loss: 0.6248 - val_accuracy: 0.6602
#
# Epoch 00028: val_loss improved from 0.62557 to 0.62480, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 29/300
# 45/45 - 0s - loss: 0.6140 - accuracy: 0.6654 - val_loss: 0.6227 - val_accuracy: 0.6586
#
# Epoch 00029: val_loss improved from 0.62480 to 0.62274, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 30/300
# 45/45 - 0s - loss: 0.6161 - accuracy: 0.6562 - val_loss: 0.6336 - val_accuracy: 0.6242
#
# Epoch 00030: val_loss did not improve from 0.62274
# Epoch 31/300
# 45/45 - 0s - loss: 0.6153 - accuracy: 0.6616 - val_loss: 0.6439 - val_accuracy: 0.6258
#
# Epoch 00031: val_loss did not improve from 0.62274
# Epoch 32/300
# 45/45 - 0s - loss: 0.6126 - accuracy: 0.6647 - val_loss: 0.6218 - val_accuracy: 0.6659
#
# Epoch 00032: val_loss improved from 0.62274 to 0.62182, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 33/300
# 45/45 - 0s - loss: 0.6134 - accuracy: 0.6681 - val_loss: 0.6362 - val_accuracy: 0.6335
#
# Epoch 00033: val_loss did not improve from 0.62182
# Epoch 34/300
# 45/45 - 0s - loss: 0.6103 - accuracy: 0.6678 - val_loss: 0.6259 - val_accuracy: 0.6699
#
# Epoch 00034: val_loss did not improve from 0.62182
# Epoch 35/300
# 45/45 - 0s - loss: 0.6090 - accuracy: 0.6651 - val_loss: 0.6259 - val_accuracy: 0.6691
#
# Epoch 00035: val_loss did not improve from 0.62182
# Epoch 36/300
# 45/45 - 0s - loss: 0.6045 - accuracy: 0.6706 - val_loss: 0.6281 - val_accuracy: 0.6606
#
# Epoch 00036: val_loss did not improve from 0.62182
# Epoch 37/300
# 45/45 - 0s - loss: 0.6077 - accuracy: 0.6668 - val_loss: 0.6293 - val_accuracy: 0.6566
#
# Epoch 00037: val_loss did not improve from 0.62182
# Epoch 38/300
# 45/45 - 0s - loss: 0.6000 - accuracy: 0.6773 - val_loss: 0.6164 - val_accuracy: 0.6675
#
# Epoch 00038: val_loss improved from 0.62182 to 0.61637, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 39/300
# 45/45 - 0s - loss: 0.6016 - accuracy: 0.6771 - val_loss: 0.6380 - val_accuracy: 0.6517
#
# Epoch 00039: val_loss did not improve from 0.61637
# Epoch 40/300
# 45/45 - 0s - loss: 0.5983 - accuracy: 0.6744 - val_loss: 0.6220 - val_accuracy: 0.6586
#
# Epoch 00040: val_loss did not improve from 0.61637
# Epoch 41/300
# 45/45 - 0s - loss: 0.6021 - accuracy: 0.6730 - val_loss: 0.6180 - val_accuracy: 0.6748
#
# Epoch 00041: val_loss did not improve from 0.61637
# Epoch 42/300
# 45/45 - 0s - loss: 0.5961 - accuracy: 0.6789 - val_loss: 0.6189 - val_accuracy: 0.6687
#
# Epoch 00042: val_loss did not improve from 0.61637
# Epoch 43/300
# 45/45 - 0s - loss: 0.5920 - accuracy: 0.6863 - val_loss: 0.6252 - val_accuracy: 0.6590
#
# Epoch 00043: val_loss did not improve from 0.61637
# Epoch 44/300
# 45/45 - 0s - loss: 0.5921 - accuracy: 0.6874 - val_loss: 0.6183 - val_accuracy: 0.6497
#
# Epoch 00044: val_loss did not improve from 0.61637
# Epoch 45/300
# 45/45 - 0s - loss: 0.5924 - accuracy: 0.6871 - val_loss: 0.6241 - val_accuracy: 0.6634
#
# Epoch 00045: val_loss did not improve from 0.61637
# Epoch 46/300
# 45/45 - 0s - loss: 0.5897 - accuracy: 0.6867 - val_loss: 0.6163 - val_accuracy: 0.6545
#
# Epoch 00046: val_loss improved from 0.61637 to 0.61629, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 47/300
# 45/45 - 0s - loss: 0.5861 - accuracy: 0.6890 - val_loss: 0.6154 - val_accuracy: 0.6731
#
# Epoch 00047: val_loss improved from 0.61629 to 0.61545, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 48/300
# 45/45 - 0s - loss: 0.5889 - accuracy: 0.6852 - val_loss: 0.6570 - val_accuracy: 0.6165
#
# Epoch 00048: val_loss did not improve from 0.61545
# Epoch 49/300
# 45/45 - 0s - loss: 0.5834 - accuracy: 0.6919 - val_loss: 0.6144 - val_accuracy: 0.6671
#
# Epoch 00049: val_loss improved from 0.61545 to 0.61439, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 50/300
# 45/45 - 0s - loss: 0.5831 - accuracy: 0.6868 - val_loss: 0.6186 - val_accuracy: 0.6655
#
# Epoch 00050: val_loss did not improve from 0.61439
# Epoch 51/300
# 45/45 - 0s - loss: 0.5815 - accuracy: 0.6910 - val_loss: 0.6043 - val_accuracy: 0.6816
#
# Epoch 00051: val_loss improved from 0.61439 to 0.60430, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 52/300
# 45/45 - 0s - loss: 0.5827 - accuracy: 0.6884 - val_loss: 0.6153 - val_accuracy: 0.6788
#
# Epoch 00052: val_loss did not improve from 0.60430
# Epoch 53/300
# 45/45 - 0s - loss: 0.5794 - accuracy: 0.6937 - val_loss: 0.6152 - val_accuracy: 0.6796
#
# Epoch 00053: val_loss did not improve from 0.60430
# Epoch 54/300
# 45/45 - 0s - loss: 0.5717 - accuracy: 0.7064 - val_loss: 0.6238 - val_accuracy: 0.6594
#
# Epoch 00054: val_loss did not improve from 0.60430
# Epoch 55/300
# 45/45 - 0s - loss: 0.5723 - accuracy: 0.6974 - val_loss: 0.6166 - val_accuracy: 0.6622
#
# Epoch 00055: val_loss did not improve from 0.60430
# Epoch 56/300
# 45/45 - 0s - loss: 0.5725 - accuracy: 0.6992 - val_loss: 0.6128 - val_accuracy: 0.6683
#
# Epoch 00056: val_loss did not improve from 0.60430
# Epoch 57/300
# 45/45 - 0s - loss: 0.5672 - accuracy: 0.7033 - val_loss: 0.6640 - val_accuracy: 0.6214
#
# Epoch 00057: val_loss did not improve from 0.60430
# Epoch 58/300
# 45/45 - 0s - loss: 0.5724 - accuracy: 0.6989 - val_loss: 0.6317 - val_accuracy: 0.6501
#
# Epoch 00058: val_loss did not improve from 0.60430
# Epoch 59/300
# 45/45 - 0s - loss: 0.5733 - accuracy: 0.6962 - val_loss: 0.6085 - val_accuracy: 0.6824
#
# Epoch 00059: val_loss did not improve from 0.60430
# Epoch 60/300
# 45/45 - 0s - loss: 0.5670 - accuracy: 0.7060 - val_loss: 0.6065 - val_accuracy: 0.6796
#
# Epoch 00060: val_loss did not improve from 0.60430
# Epoch 61/300
# 45/45 - 0s - loss: 0.5631 - accuracy: 0.7093 - val_loss: 0.6054 - val_accuracy: 0.6853
#
# Epoch 00061: val_loss did not improve from 0.60430
# Epoch 62/300
# 45/45 - 0s - loss: 0.5581 - accuracy: 0.7125 - val_loss: 0.6127 - val_accuracy: 0.6715
#
# Epoch 00062: val_loss did not improve from 0.60430
# Epoch 63/300
# 45/45 - 0s - loss: 0.5580 - accuracy: 0.7085 - val_loss: 0.6054 - val_accuracy: 0.6780
#
# Epoch 00063: val_loss did not improve from 0.60430
# Epoch 64/300
# 45/45 - 0s - loss: 0.5616 - accuracy: 0.7057 - val_loss: 0.6278 - val_accuracy: 0.6517
#
# Epoch 00064: val_loss did not improve from 0.60430
# Epoch 65/300
# 45/45 - 0s - loss: 0.5600 - accuracy: 0.7079 - val_loss: 0.6223 - val_accuracy: 0.6489
#
# Epoch 00065: val_loss did not improve from 0.60430
# Epoch 66/300
# 45/45 - 0s - loss: 0.5571 - accuracy: 0.7125 - val_loss: 0.6099 - val_accuracy: 0.6727
#
# Epoch 00066: val_loss did not improve from 0.60430
# Epoch 67/300
# 45/45 - 0s - loss: 0.5506 - accuracy: 0.7218 - val_loss: 0.6352 - val_accuracy: 0.6525
#
# Epoch 00067: val_loss did not improve from 0.60430
# Epoch 68/300
# 45/45 - 0s - loss: 0.5512 - accuracy: 0.7175 - val_loss: 0.6109 - val_accuracy: 0.6683
#
# Epoch 00068: val_loss did not improve from 0.60430
# Epoch 69/300
# 45/45 - 0s - loss: 0.5456 - accuracy: 0.7181 - val_loss: 0.6060 - val_accuracy: 0.6776
#
# Epoch 00069: val_loss did not improve from 0.60430
# Epoch 70/300
# 45/45 - 0s - loss: 0.5477 - accuracy: 0.7157 - val_loss: 0.6171 - val_accuracy: 0.6650
#
# Epoch 00070: val_loss did not improve from 0.60430
# Epoch 71/300
# 45/45 - 0s - loss: 0.5460 - accuracy: 0.7180 - val_loss: 0.6098 - val_accuracy: 0.6784
#
# Epoch 00071: val_loss did not improve from 0.60430
# Epoch 72/300
# 45/45 - 0s - loss: 0.5539 - accuracy: 0.7190 - val_loss: 0.6116 - val_accuracy: 0.6849
#
# Epoch 00072: val_loss did not improve from 0.60430
# Epoch 73/300
# 45/45 - 0s - loss: 0.5509 - accuracy: 0.7115 - val_loss: 0.6197 - val_accuracy: 0.6638
#
# Epoch 00073: val_loss did not improve from 0.60430
# Epoch 74/300
# 45/45 - 0s - loss: 0.5426 - accuracy: 0.7252 - val_loss: 0.6094 - val_accuracy: 0.6707
# Epoch 00074: val_loss did not improve from 0.60430
# Epoch 75/300
# 45/45 - 0s - loss: 0.5418 - accuracy: 0.7258 - val_loss: 0.6134 - val_accuracy: 0.6715
#
# Epoch 00075: val_loss did not improve from 0.60430
# Epoch 76/300
# 45/45 - 0s - loss: 0.5372 - accuracy: 0.7270 - val_loss: 0.6090 - val_accuracy: 0.6808
#
# Epoch 00076: val_loss did not improve from 0.60430
# Epoch 77/300
# 45/45 - 0s - loss: 0.5458 - accuracy: 0.7185 - val_loss: 0.6220 - val_accuracy: 0.6614
#
# Epoch 00077: val_loss did not improve from 0.60430
# Epoch 78/300
# 45/45 - 0s - loss: 0.5423 - accuracy: 0.7183 - val_loss: 0.6133 - val_accuracy: 0.6739
#
# Epoch 00078: val_loss did not improve from 0.60430
# Epoch 79/300
# 45/45 - 0s - loss: 0.5375 - accuracy: 0.7274 - val_loss: 0.6146 - val_accuracy: 0.6703
#
# Epoch 00079: val_loss did not improve from 0.60430
# Epoch 80/300
# 45/45 - 0s - loss: 0.5343 - accuracy: 0.7279 - val_loss: 0.6052 - val_accuracy: 0.6764
#
# Epoch 00080: val_loss did not improve from 0.60430
# Epoch 81/300
# 45/45 - 0s - loss: 0.5345 - accuracy: 0.7322 - val_loss: 0.6080 - val_accuracy: 0.6816
#
# Epoch 00081: val_loss did not improve from 0.60430
# Epoch 82/300
# 45/45 - 0s - loss: 0.5260 - accuracy: 0.7387 - val_loss: 0.6178 - val_accuracy: 0.6557
#
# Epoch 00082: val_loss did not improve from 0.60430
# Epoch 83/300
# 45/45 - 0s - loss: 0.5315 - accuracy: 0.7318 - val_loss: 0.6083 - val_accuracy: 0.6800
#
# Epoch 00083: val_loss did not improve from 0.60430
# Epoch 84/300
# 45/45 - 0s - loss: 0.5268 - accuracy: 0.7299 - val_loss: 0.6166 - val_accuracy: 0.6594
#
# Epoch 00084: val_loss did not improve from 0.60430
# Epoch 85/300
# 45/45 - 0s - loss: 0.5281 - accuracy: 0.7310 - val_loss: 0.6099 - val_accuracy: 0.6780
#
# Epoch 00085: val_loss did not improve from 0.60430
# Epoch 86/300
# 45/45 - 0s - loss: 0.5239 - accuracy: 0.7386 - val_loss: 0.6122 - val_accuracy: 0.6780
#
# Epoch 00086: val_loss did not improve from 0.60430
# Epoch 87/300
# 45/45 - 0s - loss: 0.5314 - accuracy: 0.7329 - val_loss: 0.6094 - val_accuracy: 0.6703
#
# Epoch 00087: val_loss did not improve from 0.60430
# Epoch 88/300
# 45/45 - 0s - loss: 0.5158 - accuracy: 0.7462 - val_loss: 0.6283 - val_accuracy: 0.6594
#
# Epoch 00088: val_loss did not improve from 0.60430
# Epoch 89/300
# 45/45 - 0s - loss: 0.5261 - accuracy: 0.7371 - val_loss: 0.6077 - val_accuracy: 0.6756
#
# Epoch 00089: val_loss did not improve from 0.60430
# Epoch 90/300
# 45/45 - 0s - loss: 0.5167 - accuracy: 0.7403 - val_loss: 0.6080 - val_accuracy: 0.6752
#
# Epoch 00090: val_loss did not improve from 0.60430
# Epoch 91/300
# 45/45 - 0s - loss: 0.5152 - accuracy: 0.7451 - val_loss: 0.6148 - val_accuracy: 0.6671
#
# Epoch 00091: val_loss did not improve from 0.60430
# Epoch 92/300
# 45/45 - 0s - loss: 0.5132 - accuracy: 0.7450 - val_loss: 0.6118 - val_accuracy: 0.6752
#
# Epoch 00092: val_loss did not improve from 0.60430
# Epoch 93/300
# 45/45 - 0s - loss: 0.5145 - accuracy: 0.7479 - val_loss: 0.6114 - val_accuracy: 0.6788
#
# Epoch 00093: val_loss did not improve from 0.60430
# Epoch 94/300
# 45/45 - 0s - loss: 0.5140 - accuracy: 0.7430 - val_loss: 0.6099 - val_accuracy: 0.6784
#
# Epoch 00094: val_loss did not improve from 0.60430
# Epoch 95/300
# 45/45 - 0s - loss: 0.5177 - accuracy: 0.7378 - val_loss: 0.6146 - val_accuracy: 0.6719
#
# Epoch 00095: val_loss did not improve from 0.60430
# Epoch 96/300
# 45/45 - 0s - loss: 0.5166 - accuracy: 0.7413 - val_loss: 0.6137 - val_accuracy: 0.6744
#
# Epoch 00096: val_loss did not improve from 0.60430
# Epoch 97/300
# 45/45 - 0s - loss: 0.5087 - accuracy: 0.7430 - val_loss: 0.6136 - val_accuracy: 0.6760
#
# Epoch 00097: val_loss did not improve from 0.60430
# Epoch 98/300
# 45/45 - 0s - loss: 0.5136 - accuracy: 0.7445 - val_loss: 0.6173 - val_accuracy: 0.6707
#
# Epoch 00098: val_loss did not improve from 0.60430
# Epoch 99/300
# 45/45 - 0s - loss: 0.5081 - accuracy: 0.7489 - val_loss: 0.6045 - val_accuracy: 0.6820
#
# Epoch 00099: val_loss did not improve from 0.60430
# Epoch 100/300
# 45/45 - 0s - loss: 0.5073 - accuracy: 0.7523 - val_loss: 0.6042 - val_accuracy: 0.6828
#
# Epoch 00100: val_loss improved from 0.60430 to 0.60420, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 101/300
# 45/45 - 0s - loss: 0.4999 - accuracy: 0.7558 - val_loss: 0.6089 - val_accuracy: 0.6744
#
# Epoch 00101: val_loss did not improve from 0.60420
# Epoch 102/300
# 45/45 - 0s - loss: 0.5059 - accuracy: 0.7519 - val_loss: 0.6066 - val_accuracy: 0.6824
#
# Epoch 00102: val_loss did not improve from 0.60420
# Epoch 103/300
# 45/45 - 0s - loss: 0.5020 - accuracy: 0.7518 - val_loss: 0.6214 - val_accuracy: 0.6614
#
# Epoch 00103: val_loss did not improve from 0.60420
# Epoch 104/300
# 45/45 - 0s - loss: 0.5083 - accuracy: 0.7509 - val_loss: 0.6066 - val_accuracy: 0.6752
#
# Epoch 00104: val_loss did not improve from 0.60420
# Epoch 105/300
# 45/45 - 0s - loss: 0.5010 - accuracy: 0.7537 - val_loss: 0.6093 - val_accuracy: 0.6711
#
# Epoch 00105: val_loss did not improve from 0.60420
# Epoch 106/300
# 45/45 - 0s - loss: 0.4952 - accuracy: 0.7539 - val_loss: 0.6117 - val_accuracy: 0.6671
#
# Epoch 00106: val_loss did not improve from 0.60420
# Epoch 107/300
# 45/45 - 0s - loss: 0.4971 - accuracy: 0.7551 - val_loss: 0.6103 - val_accuracy: 0.6683
#
# Epoch 00107: val_loss did not improve from 0.60420
# Epoch 108/300
# 45/45 - 0s - loss: 0.5073 - accuracy: 0.7507 - val_loss: 0.6080 - val_accuracy: 0.6731
#
# Epoch 00108: val_loss did not improve from 0.60420
# Epoch 109/300
# 45/45 - 0s - loss: 0.4984 - accuracy: 0.7551 - val_loss: 0.6123 - val_accuracy: 0.6723
#
# Epoch 00109: val_loss did not improve from 0.60420
# Epoch 110/300
# 45/45 - 0s - loss: 0.5023 - accuracy: 0.7520 - val_loss: 0.6070 - val_accuracy: 0.6748
#
# Epoch 00110: val_loss did not improve from 0.60420
# Epoch 111/300
# 45/45 - 0s - loss: 0.4909 - accuracy: 0.7636 - val_loss: 0.6106 - val_accuracy: 0.6768
#
# Epoch 00111: val_loss did not improve from 0.60420
# Epoch 112/300
# 45/45 - 0s - loss: 0.4901 - accuracy: 0.7642 - val_loss: 0.6084 - val_accuracy: 0.6707
#
# Epoch 00112: val_loss did not improve from 0.60420
# Epoch 113/300
# 45/45 - 0s - loss: 0.4996 - accuracy: 0.7489 - val_loss: 0.6136 - val_accuracy: 0.6699
#
# Epoch 00113: val_loss did not improve from 0.60420
# Epoch 114/300
# 45/45 - 0s - loss: 0.4900 - accuracy: 0.7602 - val_loss: 0.6102 - val_accuracy: 0.6723
#
# Epoch 00114: val_loss did not improve from 0.60420
# Epoch 115/300
# 45/45 - 0s - loss: 0.4885 - accuracy: 0.7603 - val_loss: 0.6141 - val_accuracy: 0.6650
#
# Epoch 00115: val_loss did not improve from 0.60420
# Epoch 116/300
# 45/45 - 0s - loss: 0.4939 - accuracy: 0.7563 - val_loss: 0.6092 - val_accuracy: 0.6739
#
# Epoch 00116: val_loss did not improve from 0.60420
# Epoch 117/300
# 45/45 - 0s - loss: 0.4906 - accuracy: 0.7615 - val_loss: 0.6109 - val_accuracy: 0.6687
#
# Epoch 00117: val_loss did not improve from 0.60420
# Epoch 118/300
# 45/45 - 0s - loss: 0.4890 - accuracy: 0.7615 - val_loss: 0.6135 - val_accuracy: 0.6723
#
# Epoch 00118: val_loss did not improve from 0.60420
# Epoch 119/300
# 45/45 - 0s - loss: 0.4880 - accuracy: 0.7651 - val_loss: 0.6085 - val_accuracy: 0.6788
#
# Epoch 00119: val_loss did not improve from 0.60420
# Epoch 120/300
# 45/45 - 0s - loss: 0.4833 - accuracy: 0.7675 - val_loss: 0.6118 - val_accuracy: 0.6691
#
# Epoch 00120: val_loss did not improve from 0.60420
# Epoch 121/300
# 45/45 - 0s - loss: 0.4769 - accuracy: 0.7679 - val_loss: 0.6091 - val_accuracy: 0.6845
#
# Epoch 00121: val_loss did not improve from 0.60420
# Epoch 122/300
# 45/45 - 0s - loss: 0.4749 - accuracy: 0.7709 - val_loss: 0.6102 - val_accuracy: 0.6772
#
# Epoch 00122: val_loss did not improve from 0.60420
# Epoch 123/300
# 45/45 - 0s - loss: 0.4829 - accuracy: 0.7632 - val_loss: 0.6129 - val_accuracy: 0.6752
#
# Epoch 00123: val_loss did not improve from 0.60420
# Epoch 124/300
# 45/45 - 0s - loss: 0.4787 - accuracy: 0.7619 - val_loss: 0.6152 - val_accuracy: 0.6723
#
# Epoch 00124: val_loss did not improve from 0.60420
# Epoch 125/300
# 45/45 - 0s - loss: 0.4819 - accuracy: 0.7637 - val_loss: 0.6129 - val_accuracy: 0.6683
#
# Epoch 00125: val_loss did not improve from 0.60420
# Epoch 126/300
# 45/45 - 0s - loss: 0.4857 - accuracy: 0.7608 - val_loss: 0.6100 - val_accuracy: 0.6723
#
# Epoch 00126: val_loss did not improve from 0.60420
# Epoch 127/300
# 45/45 - 0s - loss: 0.4771 - accuracy: 0.7697 - val_loss: 0.6123 - val_accuracy: 0.6703
# Epoch 00127: val_loss did not improve from 0.60420
# Epoch 128/300
# 45/45 - 0s - loss: 0.4818 - accuracy: 0.7687 - val_loss: 0.6099 - val_accuracy: 0.6748
#
# Epoch 00128: val_loss did not improve from 0.60420
# Epoch 129/300
# 45/45 - 0s - loss: 0.4712 - accuracy: 0.7750 - val_loss: 0.6115 - val_accuracy: 0.6748
#
# Epoch 00129: val_loss did not improve from 0.60420
# Epoch 130/300
# 45/45 - 0s - loss: 0.4694 - accuracy: 0.7709 - val_loss: 0.6101 - val_accuracy: 0.6719
#
# Epoch 00130: val_loss did not improve from 0.60420
# Epoch 131/300
# 45/45 - 0s - loss: 0.4697 - accuracy: 0.7745 - val_loss: 0.6153 - val_accuracy: 0.6602
#
# Epoch 00131: val_loss did not improve from 0.60420
# Epoch 132/300
# 45/45 - 0s - loss: 0.4768 - accuracy: 0.7690 - val_loss: 0.6168 - val_accuracy: 0.6650
#
# Epoch 00132: val_loss did not improve from 0.60420
# Epoch 133/300
# 45/45 - 0s - loss: 0.4702 - accuracy: 0.7695 - val_loss: 0.6085 - val_accuracy: 0.6703
#
# Epoch 00133: val_loss did not improve from 0.60420
# Epoch 134/300
# 45/45 - 0s - loss: 0.4754 - accuracy: 0.7710 - val_loss: 0.6113 - val_accuracy: 0.6650
#
# Epoch 00134: val_loss did not improve from 0.60420
# Epoch 135/300
# 45/45 - 0s - loss: 0.4691 - accuracy: 0.7742 - val_loss: 0.6095 - val_accuracy: 0.6703
#
# Epoch 00135: val_loss did not improve from 0.60420
# Epoch 136/300
# 45/45 - 0s - loss: 0.4676 - accuracy: 0.7749 - val_loss: 0.6116 - val_accuracy: 0.6691
#
# Epoch 00136: val_loss did not improve from 0.60420
# Epoch 137/300
# 45/45 - 0s - loss: 0.4770 - accuracy: 0.7712 - val_loss: 0.6090 - val_accuracy: 0.6788
#
# Epoch 00137: val_loss did not improve from 0.60420
# Epoch 138/300
# 45/45 - 0s - loss: 0.4724 - accuracy: 0.7715 - val_loss: 0.6143 - val_accuracy: 0.6667
#
# Epoch 00138: val_loss did not improve from 0.60420
# Epoch 139/300
# 45/45 - 0s - loss: 0.4688 - accuracy: 0.7740 - val_loss: 0.6148 - val_accuracy: 0.6691
#
# Epoch 00139: val_loss did not improve from 0.60420
# Epoch 140/300
# 45/45 - 0s - loss: 0.4618 - accuracy: 0.7781 - val_loss: 0.6126 - val_accuracy: 0.6723
#
# Epoch 00140: val_loss did not improve from 0.60420
# Epoch 141/300
# 45/45 - 0s - loss: 0.4668 - accuracy: 0.7762 - val_loss: 0.6065 - val_accuracy: 0.6707
#
# Epoch 00141: val_loss did not improve from 0.60420
# Epoch 142/300
# 45/45 - 0s - loss: 0.4678 - accuracy: 0.7755 - val_loss: 0.6150 - val_accuracy: 0.6699
#
# Epoch 00142: val_loss did not improve from 0.60420
# Epoch 143/300
# 45/45 - 0s - loss: 0.4639 - accuracy: 0.7756 - val_loss: 0.6100 - val_accuracy: 0.6707
#
# Epoch 00143: val_loss did not improve from 0.60420
# Epoch 144/300
# 45/45 - 0s - loss: 0.4614 - accuracy: 0.7812 - val_loss: 0.6180 - val_accuracy: 0.6650
#
# Epoch 00144: val_loss did not improve from 0.60420
# Epoch 145/300
# 45/45 - 0s - loss: 0.4585 - accuracy: 0.7827 - val_loss: 0.6144 - val_accuracy: 0.6675
#
# Epoch 00145: val_loss did not improve from 0.60420
# Epoch 146/300
# 45/45 - 0s - loss: 0.4564 - accuracy: 0.7821 - val_loss: 0.6118 - val_accuracy: 0.6683
#
# Epoch 00146: val_loss did not improve from 0.60420
# Epoch 147/300
# 45/45 - 0s - loss: 0.4572 - accuracy: 0.7821 - val_loss: 0.6099 - val_accuracy: 0.6760
#
# Epoch 00147: val_loss did not improve from 0.60420
# Epoch 148/300
# 45/45 - 0s - loss: 0.4520 - accuracy: 0.7859 - val_loss: 0.6158 - val_accuracy: 0.6727
#
# Epoch 00148: val_loss did not improve from 0.60420
# Epoch 149/300
# 45/45 - 0s - loss: 0.4563 - accuracy: 0.7817 - val_loss: 0.6092 - val_accuracy: 0.6719
#
# Epoch 00149: val_loss did not improve from 0.60420
# Epoch 150/300
# 45/45 - 0s - loss: 0.4522 - accuracy: 0.7870 - val_loss: 0.6108 - val_accuracy: 0.6752
#
# Epoch 00150: val_loss did not improve from 0.60420
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6108 - accuracy: 0.6752
# Independent test: [0.6108034253120422, 0.6751618385314941]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.6496763754045307,
#  'SP': 0.7006472491909385,
#  'ACC': 0.6751618122977346,
#  'MCC': 0.3507795888834843,
#  'Recall': 0.6496763754045307,
#  'Precision': 0.6845694799658995,
#  'F1-score': 0.6666666666666666,
#  'Cutoff': 0.5}
