# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-983277e31b6e> in <module>
#       4 config = ConfigProto()
#       5 config.gpu_options.allow_growth = True
# ----> 6 session = InteractiveSession(config=config)
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\client\session.py in __init__(self, target, graph, config)
#    1756     config.graph_options.place_pruned_graph = True
#    1757
# -> 1758     super(InteractiveSession, self).__init__(target, graph, config)
#    1759     with InteractiveSession._count_lock:
#    1760       if InteractiveSession._active_session_count > 0:
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\client\session.py in __init__(self, target, graph, config)
#     709     try:
#     710       # pylint: disable=protected-access
# --> 711       self._session = tf_session.TF_NewSessionRef(self._graph._c_graph, opts)
#     712       # pylint: enable=protected-access
#     713     finally:
#
# InternalError: CUDA runtime implicit initialization on GPU:0 failed. Status: out of memory

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\5k\Ubi_5k')
    epoch = 300
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\NEDD')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 45/45 - 8s - loss: 0.6955 - accuracy: 0.5192 - val_loss: 0.6917 - val_accuracy: 0.4976
#
# Epoch 00001: val_loss improved from inf to 0.69169, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 2/300
# 45/45 - 1s - loss: 0.6872 - accuracy: 0.5450 - val_loss: 0.6894 - val_accuracy: 0.5227
#
# Epoch 00002: val_loss improved from 0.69169 to 0.68938, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 3/300
# 45/45 - 0s - loss: 0.6793 - accuracy: 0.5615 - val_loss: 0.6861 - val_accuracy: 0.5433
#
# Epoch 00003: val_loss improved from 0.68938 to 0.68613, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 4/300
# 45/45 - 0s - loss: 0.6738 - accuracy: 0.5758 - val_loss: 0.7195 - val_accuracy: 0.4895
#
# Epoch 00004: val_loss did not improve from 0.68613
# Epoch 5/300
# 45/45 - 0s - loss: 0.6711 - accuracy: 0.5796 - val_loss: 0.6869 - val_accuracy: 0.5380
#
# Epoch 00005: val_loss did not improve from 0.68613
# Epoch 6/300
# 45/45 - 0s - loss: 0.6709 - accuracy: 0.5826 - val_loss: 0.6823 - val_accuracy: 0.5587
#
# Epoch 00006: val_loss improved from 0.68613 to 0.68230, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 7/300
# 45/45 - 0s - loss: 0.6673 - accuracy: 0.5852 - val_loss: 0.6814 - val_accuracy: 0.5591
#
# Epoch 00007: val_loss improved from 0.68230 to 0.68139, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 8/300
# 45/45 - 0s - loss: 0.6649 - accuracy: 0.5908 - val_loss: 0.6797 - val_accuracy: 0.5526
#
# Epoch 00008: val_loss improved from 0.68139 to 0.67971, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 9/300
# 45/45 - 0s - loss: 0.6638 - accuracy: 0.5886 - val_loss: 0.6793 - val_accuracy: 0.5647
#
# Epoch 00009: val_loss improved from 0.67971 to 0.67932, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 10/300
# 45/45 - 0s - loss: 0.6606 - accuracy: 0.5937 - val_loss: 0.6738 - val_accuracy: 0.5651
#
# Epoch 00010: val_loss improved from 0.67932 to 0.67377, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 11/300
# 45/45 - 0s - loss: 0.6600 - accuracy: 0.5971 - val_loss: 0.6786 - val_accuracy: 0.5655
#
# Epoch 00011: val_loss did not improve from 0.67377
# Epoch 12/300
# 45/45 - 0s - loss: 0.6524 - accuracy: 0.6094 - val_loss: 0.6640 - val_accuracy: 0.5801
#
# Epoch 00012: val_loss improved from 0.67377 to 0.66396, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 13/300
# 45/45 - 0s - loss: 0.6506 - accuracy: 0.6183 - val_loss: 0.6669 - val_accuracy: 0.5578
#
# Epoch 00013: val_loss did not improve from 0.66396
# Epoch 14/300
# 45/45 - 0s - loss: 0.6454 - accuracy: 0.6218 - val_loss: 0.6675 - val_accuracy: 0.5890
#
# Epoch 00014: val_loss did not improve from 0.66396
# Epoch 15/300
# 45/45 - 0s - loss: 0.6427 - accuracy: 0.6263 - val_loss: 0.6541 - val_accuracy: 0.5987
#
# Epoch 00015: val_loss improved from 0.66396 to 0.65408, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 16/300
# 45/45 - 0s - loss: 0.6382 - accuracy: 0.6293 - val_loss: 0.6645 - val_accuracy: 0.5939
#
# Epoch 00016: val_loss did not improve from 0.65408
# Epoch 17/300
# 45/45 - 0s - loss: 0.6370 - accuracy: 0.6346 - val_loss: 0.6580 - val_accuracy: 0.6133
#
# Epoch 00017: val_loss did not improve from 0.65408
# Epoch 18/300
# 45/45 - 0s - loss: 0.6358 - accuracy: 0.6406 - val_loss: 0.6499 - val_accuracy: 0.6258
#
# Epoch 00018: val_loss improved from 0.65408 to 0.64991, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 19/300
# 45/45 - 0s - loss: 0.6271 - accuracy: 0.6459 - val_loss: 0.6646 - val_accuracy: 0.5639
#
# Epoch 00019: val_loss did not improve from 0.64991
# Epoch 20/300
# 45/45 - 0s - loss: 0.6283 - accuracy: 0.6376 - val_loss: 0.6509 - val_accuracy: 0.5959
#
# Epoch 00020: val_loss did not improve from 0.64991
# Epoch 21/300
# 45/45 - 0s - loss: 0.6288 - accuracy: 0.6422 - val_loss: 0.6478 - val_accuracy: 0.5926
#
# Epoch 00021: val_loss improved from 0.64991 to 0.64784, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 22/300
# 45/45 - 0s - loss: 0.6243 - accuracy: 0.6520 - val_loss: 0.6431 - val_accuracy: 0.6424
#
# Epoch 00022: val_loss improved from 0.64784 to 0.64312, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 23/300
# 45/45 - 0s - loss: 0.6182 - accuracy: 0.6578 - val_loss: 0.6399 - val_accuracy: 0.6408
#
# Epoch 00023: val_loss improved from 0.64312 to 0.63986, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 24/300
# 45/45 - 0s - loss: 0.6164 - accuracy: 0.6643 - val_loss: 0.6464 - val_accuracy: 0.6278
#
# Epoch 00024: val_loss did not improve from 0.63986
# Epoch 25/300
# 45/45 - 0s - loss: 0.6131 - accuracy: 0.6595 - val_loss: 0.6325 - val_accuracy: 0.6452
#
# Epoch 00025: val_loss improved from 0.63986 to 0.63250, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 26/300
# 45/45 - 0s - loss: 0.6136 - accuracy: 0.6677 - val_loss: 0.6434 - val_accuracy: 0.6028
#
# Epoch 00026: val_loss did not improve from 0.63250
# Epoch 27/300
# 45/45 - 0s - loss: 0.6100 - accuracy: 0.6687 - val_loss: 0.6387 - val_accuracy: 0.6076
#
# Epoch 00027: val_loss did not improve from 0.63250
# Epoch 28/300
# 45/45 - 0s - loss: 0.6126 - accuracy: 0.6679 - val_loss: 0.6377 - val_accuracy: 0.6468
#
# Epoch 00028: val_loss did not improve from 0.63250
# Epoch 29/300
# 45/45 - 0s - loss: 0.6077 - accuracy: 0.6663 - val_loss: 0.6328 - val_accuracy: 0.6464
#
# Epoch 00029: val_loss did not improve from 0.63250
# Epoch 30/300
# 45/45 - 0s - loss: 0.6086 - accuracy: 0.6659 - val_loss: 0.6302 - val_accuracy: 0.6533
#
# Epoch 00030: val_loss improved from 0.63250 to 0.63016, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 31/300
# 45/45 - 0s - loss: 0.6085 - accuracy: 0.6670 - val_loss: 0.6290 - val_accuracy: 0.6493
#
# Epoch 00031: val_loss improved from 0.63016 to 0.62898, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 32/300
# 45/45 - 0s - loss: 0.6025 - accuracy: 0.6665 - val_loss: 0.6237 - val_accuracy: 0.6610
#
# Epoch 00032: val_loss improved from 0.62898 to 0.62369, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 33/300
# 45/45 - 0s - loss: 0.6051 - accuracy: 0.6699 - val_loss: 0.6206 - val_accuracy: 0.6671
#
# Epoch 00033: val_loss improved from 0.62369 to 0.62058, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 34/300
# 45/45 - 0s - loss: 0.5943 - accuracy: 0.6825 - val_loss: 0.6509 - val_accuracy: 0.5999
#
# Epoch 00034: val_loss did not improve from 0.62058
# Epoch 35/300
# 45/45 - 0s - loss: 0.6005 - accuracy: 0.6685 - val_loss: 0.6326 - val_accuracy: 0.6493
#
# Epoch 00035: val_loss did not improve from 0.62058
# Epoch 36/300
# 45/45 - 0s - loss: 0.5954 - accuracy: 0.6777 - val_loss: 0.6356 - val_accuracy: 0.6444
#
# Epoch 00036: val_loss did not improve from 0.62058
# Epoch 37/300
# 45/45 - 0s - loss: 0.5914 - accuracy: 0.6822 - val_loss: 0.6230 - val_accuracy: 0.6590
#
# Epoch 00037: val_loss did not improve from 0.62058
# Epoch 38/300
# 45/45 - 0s - loss: 0.5899 - accuracy: 0.6834 - val_loss: 0.6170 - val_accuracy: 0.6602
#
# Epoch 00038: val_loss improved from 0.62058 to 0.61696, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 39/300
# 45/45 - 0s - loss: 0.5881 - accuracy: 0.6882 - val_loss: 0.6204 - val_accuracy: 0.6655
#
# Epoch 00039: val_loss did not improve from 0.61696
# Epoch 40/300
# 45/45 - 0s - loss: 0.5875 - accuracy: 0.6912 - val_loss: 0.6163 - val_accuracy: 0.6703
#
# Epoch 00040: val_loss improved from 0.61696 to 0.61633, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 41/300
# 45/45 - 0s - loss: 0.5887 - accuracy: 0.6882 - val_loss: 0.6245 - val_accuracy: 0.6497
#
# Epoch 00041: val_loss did not improve from 0.61633
# Epoch 42/300
# 45/45 - 0s - loss: 0.5828 - accuracy: 0.6938 - val_loss: 0.6178 - val_accuracy: 0.6598
#
# Epoch 00042: val_loss did not improve from 0.61633
# Epoch 43/300
# 45/45 - 0s - loss: 0.5789 - accuracy: 0.6920 - val_loss: 0.6090 - val_accuracy: 0.6703
#
# Epoch 00043: val_loss improved from 0.61633 to 0.60902, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 44/300
# 45/45 - 0s - loss: 0.5808 - accuracy: 0.6917 - val_loss: 0.6220 - val_accuracy: 0.6513
#
# Epoch 00044: val_loss did not improve from 0.60902
# Epoch 45/300
# 45/45 - 0s - loss: 0.5801 - accuracy: 0.6954 - val_loss: 0.6154 - val_accuracy: 0.6638
#
# Epoch 00045: val_loss did not improve from 0.60902
# Epoch 46/300
# 45/45 - 0s - loss: 0.5719 - accuracy: 0.6998 - val_loss: 0.6146 - val_accuracy: 0.6687
#
# Epoch 00046: val_loss did not improve from 0.60902
# Epoch 47/300
# 45/45 - 0s - loss: 0.5708 - accuracy: 0.6999 - val_loss: 0.6144 - val_accuracy: 0.6642
#
# Epoch 00047: val_loss did not improve from 0.60902
# Epoch 48/300
# 45/45 - 0s - loss: 0.5720 - accuracy: 0.7025 - val_loss: 0.6124 - val_accuracy: 0.6667
#
# Epoch 00048: val_loss did not improve from 0.60902
# Epoch 49/300
# 45/45 - 0s - loss: 0.5689 - accuracy: 0.7007 - val_loss: 0.6061 - val_accuracy: 0.6808
#
# Epoch 00049: val_loss improved from 0.60902 to 0.60607, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 50/300
# 45/45 - 0s - loss: 0.5753 - accuracy: 0.6970 - val_loss: 0.6137 - val_accuracy: 0.6659
#
# Epoch 00050: val_loss did not improve from 0.60607
# Epoch 51/300
# 45/45 - 0s - loss: 0.5711 - accuracy: 0.7001 - val_loss: 0.6206 - val_accuracy: 0.6586
#
# Epoch 00051: val_loss did not improve from 0.60607
# Epoch 52/300
# 45/45 - 0s - loss: 0.5627 - accuracy: 0.7031 - val_loss: 0.6094 - val_accuracy: 0.6687
#
# Epoch 00052: val_loss did not improve from 0.60607
# Epoch 53/300
# 45/45 - 0s - loss: 0.5622 - accuracy: 0.7119 - val_loss: 0.6055 - val_accuracy: 0.6764
#
# Epoch 00053: val_loss improved from 0.60607 to 0.60547, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 54/300
# 45/45 - 0s - loss: 0.5632 - accuracy: 0.7056 - val_loss: 0.6079 - val_accuracy: 0.6679
#
# Epoch 00054: val_loss did not improve from 0.60547
# Epoch 55/300
# 45/45 - 0s - loss: 0.5643 - accuracy: 0.7069 - val_loss: 0.6090 - val_accuracy: 0.6748
#
# Epoch 00055: val_loss did not improve from 0.60547
# Epoch 56/300
# 45/45 - 0s - loss: 0.5625 - accuracy: 0.7057 - val_loss: 0.6081 - val_accuracy: 0.6699
#
# Epoch 00056: val_loss did not improve from 0.60547
# Epoch 57/300
# 45/45 - 0s - loss: 0.5543 - accuracy: 0.7125 - val_loss: 0.6144 - val_accuracy: 0.6642
#
# Epoch 00057: val_loss did not improve from 0.60547
# Epoch 58/300
# 45/45 - 0s - loss: 0.5581 - accuracy: 0.7110 - val_loss: 0.6098 - val_accuracy: 0.6671
#
# Epoch 00058: val_loss did not improve from 0.60547
# Epoch 59/300
# 45/45 - 0s - loss: 0.5579 - accuracy: 0.7121 - val_loss: 0.6067 - val_accuracy: 0.6804
#
# Epoch 00059: val_loss did not improve from 0.60547
# Epoch 60/300
# 45/45 - 0s - loss: 0.5540 - accuracy: 0.7180 - val_loss: 0.6098 - val_accuracy: 0.6671
#
# Epoch 00060: val_loss did not improve from 0.60547
# Epoch 61/300
# 45/45 - 0s - loss: 0.5561 - accuracy: 0.7134 - val_loss: 0.6050 - val_accuracy: 0.6735
#
# Epoch 00061: val_loss improved from 0.60547 to 0.60503, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 62/300
# 45/45 - 0s - loss: 0.5538 - accuracy: 0.7200 - val_loss: 0.6081 - val_accuracy: 0.6723
#
# Epoch 00062: val_loss did not improve from 0.60503
# Epoch 63/300
# 45/45 - 0s - loss: 0.5535 - accuracy: 0.7138 - val_loss: 0.6083 - val_accuracy: 0.6731
#
# Epoch 00063: val_loss did not improve from 0.60503
# Epoch 64/300
# 45/45 - 0s - loss: 0.5432 - accuracy: 0.7252 - val_loss: 0.6059 - val_accuracy: 0.6739
#
# Epoch 00064: val_loss did not improve from 0.60503
# Epoch 65/300
# 45/45 - 0s - loss: 0.5507 - accuracy: 0.7171 - val_loss: 0.6178 - val_accuracy: 0.6586
#
# Epoch 00065: val_loss did not improve from 0.60503
# Epoch 66/300
# 45/45 - 0s - loss: 0.5427 - accuracy: 0.7264 - val_loss: 0.6052 - val_accuracy: 0.6812
#
# Epoch 00066: val_loss did not improve from 0.60503
# Epoch 67/300
# 45/45 - 0s - loss: 0.5349 - accuracy: 0.7326 - val_loss: 0.6088 - val_accuracy: 0.6646
#
# Epoch 00067: val_loss did not improve from 0.60503
# Epoch 68/300
# 45/45 - 0s - loss: 0.5407 - accuracy: 0.7273 - val_loss: 0.6100 - val_accuracy: 0.6691
#
# Epoch 00068: val_loss did not improve from 0.60503
# Epoch 69/300
# 45/45 - 0s - loss: 0.5377 - accuracy: 0.7318 - val_loss: 0.6073 - val_accuracy: 0.6646
#
# Epoch 00069: val_loss did not improve from 0.60503
# Epoch 70/300
# 45/45 - 0s - loss: 0.5350 - accuracy: 0.7278 - val_loss: 0.6124 - val_accuracy: 0.6594
#
# Epoch 00070: val_loss did not improve from 0.60503
# Epoch 71/300
# 45/45 - 0s - loss: 0.5314 - accuracy: 0.7324 - val_loss: 0.6004 - val_accuracy: 0.6861
#
# Epoch 00071: val_loss improved from 0.60503 to 0.60038, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 72/300
# 45/45 - 0s - loss: 0.5379 - accuracy: 0.7255 - val_loss: 0.6141 - val_accuracy: 0.6545
#
# Epoch 00072: val_loss did not improve from 0.60038
# Epoch 73/300
# 45/45 - 0s - loss: 0.5363 - accuracy: 0.7255 - val_loss: 0.6075 - val_accuracy: 0.6707
#
# Epoch 00073: val_loss did not improve from 0.60038
# Epoch 74/300
# 45/45 - 0s - loss: 0.5277 - accuracy: 0.7356 - val_loss: 0.6209 - val_accuracy: 0.6489
#
# Epoch 00074: val_loss did not improve from 0.60038
# Epoch 75/300
# 45/45 - 0s - loss: 0.5268 - accuracy: 0.7339 - val_loss: 0.6165 - val_accuracy: 0.6529
#
# Epoch 00075: val_loss did not improve from 0.60038
# Epoch 76/300
# 45/45 - 0s - loss: 0.5258 - accuracy: 0.7380 - val_loss: 0.6034 - val_accuracy: 0.6808
#
# Epoch 00076: val_loss did not improve from 0.60038
# Epoch 77/300
# 45/45 - 0s - loss: 0.5273 - accuracy: 0.7329 - val_loss: 0.6137 - val_accuracy: 0.6545
# Epoch 00077: val_loss did not improve from 0.60038
# Epoch 78/300
# 45/45 - 0s - loss: 0.5242 - accuracy: 0.7395 - val_loss: 0.6027 - val_accuracy: 0.6784
#
# Epoch 00078: val_loss did not improve from 0.60038
# Epoch 79/300
# 45/45 - 0s - loss: 0.5199 - accuracy: 0.7422 - val_loss: 0.6076 - val_accuracy: 0.6703
#
# Epoch 00079: val_loss did not improve from 0.60038
# Epoch 80/300
# 45/45 - 0s - loss: 0.5183 - accuracy: 0.7408 - val_loss: 0.6019 - val_accuracy: 0.6784
#
# Epoch 00080: val_loss did not improve from 0.60038
# Epoch 81/300
# 45/45 - 0s - loss: 0.5187 - accuracy: 0.7401 - val_loss: 0.6067 - val_accuracy: 0.6719
#
# Epoch 00081: val_loss did not improve from 0.60038
# Epoch 82/300
# 45/45 - 0s - loss: 0.5131 - accuracy: 0.7460 - val_loss: 0.6046 - val_accuracy: 0.6760
#
# Epoch 00082: val_loss did not improve from 0.60038
# Epoch 83/300
# 45/45 - 0s - loss: 0.5183 - accuracy: 0.7403 - val_loss: 0.6077 - val_accuracy: 0.6675
#
# Epoch 00083: val_loss did not improve from 0.60038
# Epoch 84/300
# 45/45 - 0s - loss: 0.5136 - accuracy: 0.7455 - val_loss: 0.6013 - val_accuracy: 0.6727
#
# Epoch 00084: val_loss did not improve from 0.60038
# Epoch 85/300
# 45/45 - 0s - loss: 0.5164 - accuracy: 0.7377 - val_loss: 0.5981 - val_accuracy: 0.6776
#
# Epoch 00085: val_loss improved from 0.60038 to 0.59814, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 86/300
# 45/45 - 0s - loss: 0.5146 - accuracy: 0.7445 - val_loss: 0.6031 - val_accuracy: 0.6723
#
# Epoch 00086: val_loss did not improve from 0.59814
# Epoch 87/300
# 45/45 - 0s - loss: 0.5079 - accuracy: 0.7514 - val_loss: 0.6027 - val_accuracy: 0.6752
#
# Epoch 00087: val_loss did not improve from 0.59814
# Epoch 88/300
# 45/45 - 0s - loss: 0.5016 - accuracy: 0.7505 - val_loss: 0.6023 - val_accuracy: 0.6772
#
# Epoch 00088: val_loss did not improve from 0.59814
# Epoch 89/300
# 45/45 - 0s - loss: 0.5087 - accuracy: 0.7431 - val_loss: 0.6038 - val_accuracy: 0.6735
#
# Epoch 00089: val_loss did not improve from 0.59814
# Epoch 90/300
# 45/45 - 0s - loss: 0.5033 - accuracy: 0.7504 - val_loss: 0.6336 - val_accuracy: 0.6509
#
# Epoch 00090: val_loss did not improve from 0.59814
# Epoch 91/300
# 45/45 - 0s - loss: 0.5064 - accuracy: 0.7526 - val_loss: 0.6053 - val_accuracy: 0.6659
#
# Epoch 00091: val_loss did not improve from 0.59814
# Epoch 92/300
# 45/45 - 0s - loss: 0.5009 - accuracy: 0.7548 - val_loss: 0.6041 - val_accuracy: 0.6772
#
# Epoch 00092: val_loss did not improve from 0.59814
# Epoch 93/300
# 45/45 - 0s - loss: 0.5039 - accuracy: 0.7496 - val_loss: 0.5993 - val_accuracy: 0.6780
#
# Epoch 00093: val_loss did not improve from 0.59814
# Epoch 94/300
# 45/45 - 0s - loss: 0.5033 - accuracy: 0.7472 - val_loss: 0.6123 - val_accuracy: 0.6557
#
# Epoch 00094: val_loss did not improve from 0.59814
# Epoch 95/300
# 45/45 - 0s - loss: 0.4963 - accuracy: 0.7548 - val_loss: 0.6076 - val_accuracy: 0.6727
#
# Epoch 00095: val_loss did not improve from 0.59814
# Epoch 96/300
# 45/45 - 0s - loss: 0.5010 - accuracy: 0.7524 - val_loss: 0.6001 - val_accuracy: 0.6735
#
# Epoch 00096: val_loss did not improve from 0.59814
# Epoch 97/300
# 45/45 - 0s - loss: 0.4949 - accuracy: 0.7605 - val_loss: 0.6020 - val_accuracy: 0.6711
#
# Epoch 00097: val_loss did not improve from 0.59814
# Epoch 98/300
# 45/45 - 0s - loss: 0.4935 - accuracy: 0.7596 - val_loss: 0.6104 - val_accuracy: 0.6630
#
# Epoch 00098: val_loss did not improve from 0.59814
# Epoch 99/300
# 45/45 - 0s - loss: 0.4923 - accuracy: 0.7621 - val_loss: 0.6010 - val_accuracy: 0.6800
#
# Epoch 00099: val_loss did not improve from 0.59814
# Epoch 100/300
# 45/45 - 0s - loss: 0.4984 - accuracy: 0.7577 - val_loss: 0.6030 - val_accuracy: 0.6748
#
# Epoch 00100: val_loss did not improve from 0.59814
# Epoch 101/300
# 45/45 - 0s - loss: 0.4886 - accuracy: 0.7608 - val_loss: 0.6116 - val_accuracy: 0.6650
#
# Epoch 00101: val_loss did not improve from 0.59814
# Epoch 102/300
# 45/45 - 0s - loss: 0.4912 - accuracy: 0.7625 - val_loss: 0.6177 - val_accuracy: 0.6598
#
# Epoch 00102: val_loss did not improve from 0.59814
# Epoch 103/300
# 45/45 - 0s - loss: 0.4925 - accuracy: 0.7626 - val_loss: 0.6122 - val_accuracy: 0.6675
#
# Epoch 00103: val_loss did not improve from 0.59814
# Epoch 104/300
# 45/45 - 0s - loss: 0.4861 - accuracy: 0.7637 - val_loss: 0.6073 - val_accuracy: 0.6723
#
# Epoch 00104: val_loss did not improve from 0.59814
# Epoch 105/300
# 45/45 - 0s - loss: 0.4844 - accuracy: 0.7636 - val_loss: 0.6124 - val_accuracy: 0.6622
#
# Epoch 00105: val_loss did not improve from 0.59814
# Epoch 106/300
# 45/45 - 0s - loss: 0.4926 - accuracy: 0.7603 - val_loss: 0.6046 - val_accuracy: 0.6727
#
# Epoch 00106: val_loss did not improve from 0.59814
# Epoch 107/300
# 45/45 - 0s - loss: 0.4906 - accuracy: 0.7621 - val_loss: 0.6042 - val_accuracy: 0.6707
#
# Epoch 00107: val_loss did not improve from 0.59814
# Epoch 108/300
# 45/45 - 0s - loss: 0.4812 - accuracy: 0.7674 - val_loss: 0.6313 - val_accuracy: 0.6485
#
# Epoch 00108: val_loss did not improve from 0.59814
# Epoch 109/300
# 45/45 - 0s - loss: 0.4785 - accuracy: 0.7664 - val_loss: 0.6058 - val_accuracy: 0.6731
#
# Epoch 00109: val_loss did not improve from 0.59814
# Epoch 110/300
# 45/45 - 0s - loss: 0.4855 - accuracy: 0.7671 - val_loss: 0.6019 - val_accuracy: 0.6715
#
# Epoch 00110: val_loss did not improve from 0.59814
# Epoch 111/300
# 45/45 - 0s - loss: 0.4773 - accuracy: 0.7719 - val_loss: 0.6126 - val_accuracy: 0.6598
#
# Epoch 00111: val_loss did not improve from 0.59814
# Epoch 112/300
# 45/45 - 0s - loss: 0.4759 - accuracy: 0.7698 - val_loss: 0.6126 - val_accuracy: 0.6549
#
# Epoch 00112: val_loss did not improve from 0.59814
# Epoch 113/300
# 45/45 - 0s - loss: 0.4816 - accuracy: 0.7642 - val_loss: 0.6078 - val_accuracy: 0.6634
#
# Epoch 00113: val_loss did not improve from 0.59814
# Epoch 114/300
# 45/45 - 0s - loss: 0.4810 - accuracy: 0.7603 - val_loss: 0.6005 - val_accuracy: 0.6780
#
# Epoch 00114: val_loss did not improve from 0.59814
# Epoch 115/300
# 45/45 - 0s - loss: 0.4779 - accuracy: 0.7675 - val_loss: 0.6000 - val_accuracy: 0.6792
#
# Epoch 00115: val_loss did not improve from 0.59814
# Epoch 116/300
# 45/45 - 0s - loss: 0.4736 - accuracy: 0.7762 - val_loss: 0.6030 - val_accuracy: 0.6711
#
# Epoch 00116: val_loss did not improve from 0.59814
# Epoch 117/300
# 45/45 - 0s - loss: 0.4757 - accuracy: 0.7706 - val_loss: 0.6015 - val_accuracy: 0.6756
#
# Epoch 00117: val_loss did not improve from 0.59814
# Epoch 118/300
# 45/45 - 0s - loss: 0.4695 - accuracy: 0.7770 - val_loss: 0.6048 - val_accuracy: 0.6744
#
# Epoch 00118: val_loss did not improve from 0.59814
# Epoch 119/300
# 45/45 - 0s - loss: 0.4644 - accuracy: 0.7807 - val_loss: 0.6170 - val_accuracy: 0.6574
#
# Epoch 00119: val_loss did not improve from 0.59814
# Epoch 120/300
# 45/45 - 0s - loss: 0.4627 - accuracy: 0.7806 - val_loss: 0.6069 - val_accuracy: 0.6679
#
# Epoch 00120: val_loss did not improve from 0.59814
# Epoch 121/300
# 45/45 - 0s - loss: 0.4648 - accuracy: 0.7775 - val_loss: 0.6087 - val_accuracy: 0.6683
#
# Epoch 00121: val_loss did not improve from 0.59814
# Epoch 122/300
# 45/45 - 0s - loss: 0.4715 - accuracy: 0.7716 - val_loss: 0.6060 - val_accuracy: 0.6723
#
# Epoch 00122: val_loss did not improve from 0.59814
# Epoch 123/300
# 45/45 - 0s - loss: 0.4687 - accuracy: 0.7736 - val_loss: 0.6119 - val_accuracy: 0.6731
#
# Epoch 00123: val_loss did not improve from 0.59814
# Epoch 124/300
# 45/45 - 0s - loss: 0.4662 - accuracy: 0.7766 - val_loss: 0.6061 - val_accuracy: 0.6780
#
# Epoch 00124: val_loss did not improve from 0.59814
# Epoch 125/300
# 45/45 - 0s - loss: 0.4702 - accuracy: 0.7743 - val_loss: 0.6018 - val_accuracy: 0.6667
#
# Epoch 00125: val_loss did not improve from 0.59814
# Epoch 126/300
# 45/45 - 0s - loss: 0.4680 - accuracy: 0.7739 - val_loss: 0.6048 - val_accuracy: 0.6642
#
# Epoch 00126: val_loss did not improve from 0.59814
# Epoch 127/300
# 45/45 - 0s - loss: 0.4632 - accuracy: 0.7769 - val_loss: 0.6052 - val_accuracy: 0.6731
#
# Epoch 00127: val_loss did not improve from 0.59814
# Epoch 128/300
# 45/45 - 0s - loss: 0.4663 - accuracy: 0.7807 - val_loss: 0.6087 - val_accuracy: 0.6606
#
# Epoch 00128: val_loss did not improve from 0.59814
# Epoch 129/300
# 45/45 - 0s - loss: 0.4642 - accuracy: 0.7759 - val_loss: 0.6077 - val_accuracy: 0.6663
#
# Epoch 00129: val_loss did not improve from 0.59814
# Epoch 130/300
# 45/45 - 0s - loss: 0.4517 - accuracy: 0.7875 - val_loss: 0.6105 - val_accuracy: 0.6602
# Epoch 00130: val_loss did not improve from 0.59814
# Epoch 131/300
# 45/45 - 0s - loss: 0.4547 - accuracy: 0.7791 - val_loss: 0.6057 - val_accuracy: 0.6638
#
# Epoch 00131: val_loss did not improve from 0.59814
# Epoch 132/300
# 45/45 - 0s - loss: 0.4583 - accuracy: 0.7832 - val_loss: 0.6032 - val_accuracy: 0.6792
#
# Epoch 00132: val_loss did not improve from 0.59814
# Epoch 133/300
# 45/45 - 0s - loss: 0.4522 - accuracy: 0.7832 - val_loss: 0.6193 - val_accuracy: 0.6590
#
# Epoch 00133: val_loss did not improve from 0.59814
# Epoch 134/300
# 45/45 - 0s - loss: 0.4566 - accuracy: 0.7847 - val_loss: 0.5989 - val_accuracy: 0.6727
#
# Epoch 00134: val_loss did not improve from 0.59814
# Epoch 135/300
# 45/45 - 0s - loss: 0.4569 - accuracy: 0.7793 - val_loss: 0.6119 - val_accuracy: 0.6610
#
# Epoch 00135: val_loss did not improve from 0.59814
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6119 - accuracy: 0.6610
# Independent test: [0.6119263172149658, 0.6610032320022583]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.6521035598705501,
#  'SP': 0.6699029126213593,
#  'ACC': 0.6610032362459547,
#  'MCC': 0.32205749317098337,
#  'Recall': 0.6521035598705501,
#  'Precision': 0.6639209225700164,
#  'F1-score': 0.6579591836734694,
#  'Cutoff': 0.5}

# %%
fpr, tpr, thresholds = roc_curve(y_true, pred)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, lw=1, alpha=0.7, label='ROC (AUC = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Random', alpha=.8)
plt.xlim([0, 1.0])
plt.ylim([0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('CNN_OH_val.png')
plt.show()
