# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\5k\Ubi_5k')
    epoch = 300
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\NEDD')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 45/45 - 5s - loss: 0.6973 - accuracy: 0.5090 - val_loss: 0.6924 - val_accuracy: 0.5109
#
# Epoch 00001: val_loss improved from inf to 0.69239, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 2/300
# 45/45 - 0s - loss: 0.6886 - accuracy: 0.5330 - val_loss: 0.6952 - val_accuracy: 0.5142
#
# Epoch 00002: val_loss did not improve from 0.69239
# Epoch 3/300
# 45/45 - 0s - loss: 0.6813 - accuracy: 0.5563 - val_loss: 0.6851 - val_accuracy: 0.5360
#
# Epoch 00003: val_loss improved from 0.69239 to 0.68511, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 4/300
# 45/45 - 0s - loss: 0.6767 - accuracy: 0.5697 - val_loss: 0.6860 - val_accuracy: 0.5453
#
# Epoch 00004: val_loss did not improve from 0.68511
# Epoch 5/300
# 45/45 - 0s - loss: 0.6754 - accuracy: 0.5683 - val_loss: 0.6924 - val_accuracy: 0.5279
#
# Epoch 00005: val_loss did not improve from 0.68511
# Epoch 6/300
# 45/45 - 0s - loss: 0.6725 - accuracy: 0.5723 - val_loss: 0.6830 - val_accuracy: 0.5518
#
# Epoch 00006: val_loss improved from 0.68511 to 0.68302, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 7/300
# 45/45 - 0s - loss: 0.6705 - accuracy: 0.5801 - val_loss: 0.6831 - val_accuracy: 0.5368
#
# Epoch 00007: val_loss did not improve from 0.68302
# Epoch 8/300
# 45/45 - 0s - loss: 0.6697 - accuracy: 0.5820 - val_loss: 0.6945 - val_accuracy: 0.5316
#
# Epoch 00008: val_loss did not improve from 0.68302
# Epoch 9/300
# 45/45 - 0s - loss: 0.6666 - accuracy: 0.5907 - val_loss: 0.6731 - val_accuracy: 0.5603
#
# Epoch 00009: val_loss improved from 0.68302 to 0.67313, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 10/300
# 45/45 - 0s - loss: 0.6608 - accuracy: 0.6030 - val_loss: 0.6723 - val_accuracy: 0.5886
#
# Epoch 00010: val_loss improved from 0.67313 to 0.67225, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 11/300
# 45/45 - 0s - loss: 0.6547 - accuracy: 0.6104 - val_loss: 0.6676 - val_accuracy: 0.5947
#
# Epoch 00011: val_loss improved from 0.67225 to 0.66756, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 12/300
# 45/45 - 0s - loss: 0.6473 - accuracy: 0.6204 - val_loss: 0.6632 - val_accuracy: 0.5975
#
# Epoch 00012: val_loss improved from 0.66756 to 0.66325, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 13/300
# 45/45 - 0s - loss: 0.6444 - accuracy: 0.6282 - val_loss: 0.6610 - val_accuracy: 0.6230
#
# Epoch 00013: val_loss improved from 0.66325 to 0.66104, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 14/300
# 45/45 - 0s - loss: 0.6432 - accuracy: 0.6273 - val_loss: 0.6545 - val_accuracy: 0.6048
#
# Epoch 00014: val_loss improved from 0.66104 to 0.65450, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 15/300
# 45/45 - 0s - loss: 0.6398 - accuracy: 0.6347 - val_loss: 0.6558 - val_accuracy: 0.6056
#
# Epoch 00015: val_loss did not improve from 0.65450
# Epoch 16/300
# 45/45 - 0s - loss: 0.6370 - accuracy: 0.6356 - val_loss: 0.6543 - val_accuracy: 0.6258
#
# Epoch 00016: val_loss improved from 0.65450 to 0.65433, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 17/300
# 45/45 - 0s - loss: 0.6298 - accuracy: 0.6438 - val_loss: 0.6631 - val_accuracy: 0.5862
#
# Epoch 00017: val_loss did not improve from 0.65433
# Epoch 18/300
# 45/45 - 0s - loss: 0.6306 - accuracy: 0.6415 - val_loss: 0.6484 - val_accuracy: 0.6137
#
# Epoch 00018: val_loss improved from 0.65433 to 0.64844, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 19/300
# 45/45 - 0s - loss: 0.6289 - accuracy: 0.6458 - val_loss: 0.6619 - val_accuracy: 0.6044
#
# Epoch 00019: val_loss did not improve from 0.64844
# Epoch 20/300
# 45/45 - 0s - loss: 0.6261 - accuracy: 0.6442 - val_loss: 0.6503 - val_accuracy: 0.6416
#
# Epoch 00020: val_loss did not improve from 0.64844
# Epoch 21/300
# 45/45 - 0s - loss: 0.6248 - accuracy: 0.6480 - val_loss: 0.6412 - val_accuracy: 0.6533
#
# Epoch 00021: val_loss improved from 0.64844 to 0.64117, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 22/300
# 45/45 - 0s - loss: 0.6207 - accuracy: 0.6547 - val_loss: 0.6486 - val_accuracy: 0.6472
#
# Epoch 00022: val_loss did not improve from 0.64117
# Epoch 23/300
# 45/45 - 0s - loss: 0.6189 - accuracy: 0.6509 - val_loss: 0.6517 - val_accuracy: 0.6452
#
# Epoch 00023: val_loss did not improve from 0.64117
# Epoch 24/300
# 45/45 - 0s - loss: 0.6142 - accuracy: 0.6595 - val_loss: 0.6545 - val_accuracy: 0.6375
#
# Epoch 00024: val_loss did not improve from 0.64117
# Epoch 25/300
# 45/45 - 0s - loss: 0.6164 - accuracy: 0.6598 - val_loss: 0.6515 - val_accuracy: 0.6359
#
# Epoch 00025: val_loss did not improve from 0.64117
# Epoch 26/300
# 45/45 - 0s - loss: 0.6134 - accuracy: 0.6619 - val_loss: 0.6387 - val_accuracy: 0.6468
#
# Epoch 00026: val_loss improved from 0.64117 to 0.63865, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 27/300
# 45/45 - 0s - loss: 0.6120 - accuracy: 0.6660 - val_loss: 0.6457 - val_accuracy: 0.6246
#
# Epoch 00027: val_loss did not improve from 0.63865
# Epoch 28/300
# 45/45 - 0s - loss: 0.6057 - accuracy: 0.6696 - val_loss: 0.6304 - val_accuracy: 0.6501
#
# Epoch 00028: val_loss improved from 0.63865 to 0.63035, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 29/300
# 45/45 - 0s - loss: 0.6046 - accuracy: 0.6687 - val_loss: 0.6362 - val_accuracy: 0.6602
#
# Epoch 00029: val_loss did not improve from 0.63035
# Epoch 30/300
# 45/45 - 0s - loss: 0.6021 - accuracy: 0.6686 - val_loss: 0.6598 - val_accuracy: 0.6290
#
# Epoch 00030: val_loss did not improve from 0.63035
# Epoch 31/300
# 45/45 - 0s - loss: 0.5990 - accuracy: 0.6792 - val_loss: 0.6330 - val_accuracy: 0.6574
# Epoch 00031: val_loss did not improve from 0.63035
# Epoch 32/300
# 45/45 - 0s - loss: 0.6005 - accuracy: 0.6721 - val_loss: 0.6312 - val_accuracy: 0.6590
#
# Epoch 00032: val_loss did not improve from 0.63035
# Epoch 33/300
# 45/45 - 0s - loss: 0.5959 - accuracy: 0.6771 - val_loss: 0.6399 - val_accuracy: 0.6557
#
# Epoch 00033: val_loss did not improve from 0.63035
# Epoch 34/300
# 45/45 - 0s - loss: 0.5981 - accuracy: 0.6770 - val_loss: 0.6310 - val_accuracy: 0.6351
#
# Epoch 00034: val_loss did not improve from 0.63035
# Epoch 35/300
# 45/45 - 0s - loss: 0.5940 - accuracy: 0.6809 - val_loss: 0.6348 - val_accuracy: 0.6557
#
# Epoch 00035: val_loss did not improve from 0.63035
# Epoch 36/300
# 45/45 - 0s - loss: 0.5896 - accuracy: 0.6833 - val_loss: 0.6287 - val_accuracy: 0.6711
#
# Epoch 00036: val_loss improved from 0.63035 to 0.62869, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 37/300
# 45/45 - 0s - loss: 0.5884 - accuracy: 0.6873 - val_loss: 0.6264 - val_accuracy: 0.6659
#
# Epoch 00037: val_loss improved from 0.62869 to 0.62641, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 38/300
# 45/45 - 0s - loss: 0.5902 - accuracy: 0.6832 - val_loss: 0.6306 - val_accuracy: 0.6428
#
# Epoch 00038: val_loss did not improve from 0.62641
# Epoch 39/300
# 45/45 - 0s - loss: 0.5861 - accuracy: 0.6827 - val_loss: 0.6218 - val_accuracy: 0.6727
#
# Epoch 00039: val_loss improved from 0.62641 to 0.62180, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 40/300
# 45/45 - 0s - loss: 0.5836 - accuracy: 0.6895 - val_loss: 0.6279 - val_accuracy: 0.6731
#
# Epoch 00040: val_loss did not improve from 0.62180
# Epoch 41/300
# 45/45 - 0s - loss: 0.5841 - accuracy: 0.6917 - val_loss: 0.6327 - val_accuracy: 0.6622
#
# Epoch 00041: val_loss did not improve from 0.62180
# Epoch 42/300
# 45/45 - 0s - loss: 0.5804 - accuracy: 0.6940 - val_loss: 0.6327 - val_accuracy: 0.6566
#
# Epoch 00042: val_loss did not improve from 0.62180
# Epoch 43/300
# 45/45 - 0s - loss: 0.5823 - accuracy: 0.6913 - val_loss: 0.6306 - val_accuracy: 0.6598
#
# Epoch 00043: val_loss did not improve from 0.62180
# Epoch 44/300
# 45/45 - 0s - loss: 0.5747 - accuracy: 0.6961 - val_loss: 0.6258 - val_accuracy: 0.6598
#
# Epoch 00044: val_loss did not improve from 0.62180
# Epoch 45/300
# 45/45 - 0s - loss: 0.5761 - accuracy: 0.6978 - val_loss: 0.6408 - val_accuracy: 0.6424
#
# Epoch 00045: val_loss did not improve from 0.62180
# Epoch 46/300
# 45/45 - 0s - loss: 0.5749 - accuracy: 0.6971 - val_loss: 0.6298 - val_accuracy: 0.6460
#
# Epoch 00046: val_loss did not improve from 0.62180
# Epoch 47/300
# 45/45 - 0s - loss: 0.5704 - accuracy: 0.7012 - val_loss: 0.6544 - val_accuracy: 0.6311
#
# Epoch 00047: val_loss did not improve from 0.62180
# Epoch 48/300
# 45/45 - 0s - loss: 0.5706 - accuracy: 0.7027 - val_loss: 0.6146 - val_accuracy: 0.6744
#
# Epoch 00048: val_loss improved from 0.62180 to 0.61457, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 49/300
# 45/45 - 0s - loss: 0.5679 - accuracy: 0.7029 - val_loss: 0.6246 - val_accuracy: 0.6671
#
# Epoch 00049: val_loss did not improve from 0.61457
# Epoch 50/300
# 45/45 - 0s - loss: 0.5690 - accuracy: 0.7053 - val_loss: 0.6159 - val_accuracy: 0.6711
#
# Epoch 00050: val_loss did not improve from 0.61457
# Epoch 51/300
# 45/45 - 0s - loss: 0.5681 - accuracy: 0.7057 - val_loss: 0.6107 - val_accuracy: 0.6760
#
# Epoch 00051: val_loss improved from 0.61457 to 0.61074, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 52/300
# 45/45 - 0s - loss: 0.5618 - accuracy: 0.7085 - val_loss: 0.6140 - val_accuracy: 0.6816
#
# Epoch 00052: val_loss did not improve from 0.61074
# Epoch 53/300
# 45/45 - 0s - loss: 0.5631 - accuracy: 0.7097 - val_loss: 0.6242 - val_accuracy: 0.6626
#
# Epoch 00053: val_loss did not improve from 0.61074
# Epoch 54/300
# 45/45 - 0s - loss: 0.5595 - accuracy: 0.7110 - val_loss: 0.6286 - val_accuracy: 0.6622
#
# Epoch 00054: val_loss did not improve from 0.61074
# Epoch 55/300
# 45/45 - 0s - loss: 0.5592 - accuracy: 0.7097 - val_loss: 0.6186 - val_accuracy: 0.6719
#
# Epoch 00055: val_loss did not improve from 0.61074
# Epoch 56/300
# 45/45 - 0s - loss: 0.5568 - accuracy: 0.7157 - val_loss: 0.6569 - val_accuracy: 0.6375
#
# Epoch 00056: val_loss did not improve from 0.61074
# Epoch 57/300
# 45/45 - 0s - loss: 0.5545 - accuracy: 0.7105 - val_loss: 0.6270 - val_accuracy: 0.6574
#
# Epoch 00057: val_loss did not improve from 0.61074
# Epoch 58/300
# 45/45 - 0s - loss: 0.5498 - accuracy: 0.7196 - val_loss: 0.6467 - val_accuracy: 0.6444
#
# Epoch 00058: val_loss did not improve from 0.61074
# Epoch 59/300
# 45/45 - 0s - loss: 0.5550 - accuracy: 0.7158 - val_loss: 0.6272 - val_accuracy: 0.6695
#
# Epoch 00059: val_loss did not improve from 0.61074
# Epoch 60/300
# 45/45 - 0s - loss: 0.5486 - accuracy: 0.7164 - val_loss: 0.6286 - val_accuracy: 0.6626
#
# Epoch 00060: val_loss did not improve from 0.61074
# Epoch 61/300
# 45/45 - 0s - loss: 0.5483 - accuracy: 0.7173 - val_loss: 0.6133 - val_accuracy: 0.6727
#
# Epoch 00061: val_loss did not improve from 0.61074
# Epoch 62/300
# 45/45 - 0s - loss: 0.5444 - accuracy: 0.7181 - val_loss: 0.6294 - val_accuracy: 0.6719
#
# Epoch 00062: val_loss did not improve from 0.61074
# Epoch 63/300
# 45/45 - 0s - loss: 0.5429 - accuracy: 0.7224 - val_loss: 0.6210 - val_accuracy: 0.6630
#
# Epoch 00063: val_loss did not improve from 0.61074
# Epoch 64/300
# 45/45 - 0s - loss: 0.5477 - accuracy: 0.7191 - val_loss: 0.6146 - val_accuracy: 0.6622
#
# Epoch 00064: val_loss did not improve from 0.61074
# Epoch 65/300
# 45/45 - 0s - loss: 0.5448 - accuracy: 0.7207 - val_loss: 0.6221 - val_accuracy: 0.6667
#
# Epoch 00065: val_loss did not improve from 0.61074
# Epoch 66/300
# 45/45 - 0s - loss: 0.5397 - accuracy: 0.7251 - val_loss: 0.6199 - val_accuracy: 0.6659
#
# Epoch 00066: val_loss did not improve from 0.61074
# Epoch 67/300
# 45/45 - 0s - loss: 0.5361 - accuracy: 0.7289 - val_loss: 0.6296 - val_accuracy: 0.6533
#
# Epoch 00067: val_loss did not improve from 0.61074
# Epoch 68/300
# 45/45 - 0s - loss: 0.5385 - accuracy: 0.7254 - val_loss: 0.6147 - val_accuracy: 0.6756
#
# Epoch 00068: val_loss did not improve from 0.61074
# Epoch 69/300
# 45/45 - 0s - loss: 0.5349 - accuracy: 0.7285 - val_loss: 0.6243 - val_accuracy: 0.6675
#
# Epoch 00069: val_loss did not improve from 0.61074
# Epoch 70/300
# 45/45 - 0s - loss: 0.5306 - accuracy: 0.7326 - val_loss: 0.6274 - val_accuracy: 0.6642
#
# Epoch 00070: val_loss did not improve from 0.61074
# Epoch 71/300
# 45/45 - 0s - loss: 0.5319 - accuracy: 0.7284 - val_loss: 0.6241 - val_accuracy: 0.6671
#
# Epoch 00071: val_loss did not improve from 0.61074
# Epoch 72/300
# 45/45 - 0s - loss: 0.5337 - accuracy: 0.7299 - val_loss: 0.6244 - val_accuracy: 0.6667
#
# Epoch 00072: val_loss did not improve from 0.61074
# Epoch 73/300
# 45/45 - 0s - loss: 0.5314 - accuracy: 0.7302 - val_loss: 0.6446 - val_accuracy: 0.6529
#
# Epoch 00073: val_loss did not improve from 0.61074
# Epoch 74/300
# 45/45 - 0s - loss: 0.5340 - accuracy: 0.7296 - val_loss: 0.6292 - val_accuracy: 0.6594
#
# Epoch 00074: val_loss did not improve from 0.61074
# Epoch 75/300
# 45/45 - 0s - loss: 0.5263 - accuracy: 0.7351 - val_loss: 0.6319 - val_accuracy: 0.6570
#
# Epoch 00075: val_loss did not improve from 0.61074
# Epoch 76/300
# 45/45 - 0s - loss: 0.5191 - accuracy: 0.7412 - val_loss: 0.6251 - val_accuracy: 0.6630
#
# Epoch 00076: val_loss did not improve from 0.61074
# Epoch 77/300
# 45/45 - 0s - loss: 0.5237 - accuracy: 0.7378 - val_loss: 0.6169 - val_accuracy: 0.6679
#
# Epoch 00077: val_loss did not improve from 0.61074
# Epoch 78/300
# 45/45 - 0s - loss: 0.5207 - accuracy: 0.7358 - val_loss: 0.6365 - val_accuracy: 0.6578
#
# Epoch 00078: val_loss did not improve from 0.61074
# Epoch 79/300
# 45/45 - 0s - loss: 0.5151 - accuracy: 0.7441 - val_loss: 0.6138 - val_accuracy: 0.6731
#
# Epoch 00079: val_loss did not improve from 0.61074
# Epoch 80/300
# 45/45 - 0s - loss: 0.5157 - accuracy: 0.7365 - val_loss: 0.6127 - val_accuracy: 0.6715
#
# Epoch 00080: val_loss did not improve from 0.61074
# Epoch 81/300
# 45/45 - 0s - loss: 0.5214 - accuracy: 0.7365 - val_loss: 0.6100 - val_accuracy: 0.6727
#
# Epoch 00081: val_loss improved from 0.61074 to 0.61000, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 82/300
# 45/45 - 0s - loss: 0.5162 - accuracy: 0.7417 - val_loss: 0.6084 - val_accuracy: 0.6744
#
# Epoch 00082: val_loss improved from 0.61000 to 0.60839, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 83/300
# 45/45 - 0s - loss: 0.5170 - accuracy: 0.7443 - val_loss: 0.6204 - val_accuracy: 0.6630
#
# Epoch 00083: val_loss did not improve from 0.60839
# Epoch 84/300
# 45/45 - 0s - loss: 0.5094 - accuracy: 0.7459 - val_loss: 0.6168 - val_accuracy: 0.6626
#
# Epoch 00084: val_loss did not improve from 0.60839
# Epoch 85/300
# 45/45 - 0s - loss: 0.5098 - accuracy: 0.7478 - val_loss: 0.6190 - val_accuracy: 0.6642
#
# Epoch 00085: val_loss did not improve from 0.60839
# Epoch 86/300
# 45/45 - 0s - loss: 0.5117 - accuracy: 0.7436 - val_loss: 0.6171 - val_accuracy: 0.6699
#
# Epoch 00086: val_loss did not improve from 0.60839
# Epoch 87/300
# 45/45 - 0s - loss: 0.5091 - accuracy: 0.7453 - val_loss: 0.6185 - val_accuracy: 0.6703
#
# Epoch 00087: val_loss did not improve from 0.60839
# Epoch 88/300
# 45/45 - 0s - loss: 0.5135 - accuracy: 0.7434 - val_loss: 0.6094 - val_accuracy: 0.6707
#
# Epoch 00088: val_loss did not improve from 0.60839
# Epoch 89/300
# 45/45 - 0s - loss: 0.5067 - accuracy: 0.7481 - val_loss: 0.6103 - val_accuracy: 0.6687
#
# Epoch 00089: val_loss did not improve from 0.60839
# Epoch 90/300
# 45/45 - 0s - loss: 0.5038 - accuracy: 0.7477 - val_loss: 0.6089 - val_accuracy: 0.6735
#
# Epoch 00090: val_loss did not improve from 0.60839
# Epoch 91/300
# 45/45 - 0s - loss: 0.4984 - accuracy: 0.7591 - val_loss: 0.6189 - val_accuracy: 0.6626
#
# Epoch 00091: val_loss did not improve from 0.60839
# Epoch 92/300
# 45/45 - 0s - loss: 0.4937 - accuracy: 0.7619 - val_loss: 0.6183 - val_accuracy: 0.6723
#
# Epoch 00092: val_loss did not improve from 0.60839
# Epoch 93/300
# 45/45 - 0s - loss: 0.4976 - accuracy: 0.7582 - val_loss: 0.6206 - val_accuracy: 0.6711
#
# Epoch 00093: val_loss did not improve from 0.60839
# Epoch 94/300
# 45/45 - 0s - loss: 0.4996 - accuracy: 0.7551 - val_loss: 0.6120 - val_accuracy: 0.6796
#
# Epoch 00094: val_loss did not improve from 0.60839
# Epoch 95/300
# 45/45 - 0s - loss: 0.4961 - accuracy: 0.7548 - val_loss: 0.6284 - val_accuracy: 0.6610
#
# Epoch 00095: val_loss did not improve from 0.60839
# Epoch 96/300
# 45/45 - 0s - loss: 0.4962 - accuracy: 0.7532 - val_loss: 0.6171 - val_accuracy: 0.6739
#
# Epoch 00096: val_loss did not improve from 0.60839
# Epoch 97/300
# 45/45 - 0s - loss: 0.4939 - accuracy: 0.7587 - val_loss: 0.6249 - val_accuracy: 0.6618
#
# Epoch 00097: val_loss did not improve from 0.60839
# Epoch 98/300
# 45/45 - 0s - loss: 0.4942 - accuracy: 0.7560 - val_loss: 0.6234 - val_accuracy: 0.6622
#
# Epoch 00098: val_loss did not improve from 0.60839
# Epoch 99/300
# 45/45 - 0s - loss: 0.4900 - accuracy: 0.7569 - val_loss: 0.6080 - val_accuracy: 0.6715
#
# Epoch 00099: val_loss improved from 0.60839 to 0.60801, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.h5
# Epoch 100/300
# 45/45 - 0s - loss: 0.4946 - accuracy: 0.7548 - val_loss: 0.6704 - val_accuracy: 0.6347
#
# Epoch 00100: val_loss did not improve from 0.60801
# Epoch 101/300
# 45/45 - 0s - loss: 0.4886 - accuracy: 0.7604 - val_loss: 0.6328 - val_accuracy: 0.6561
#
# Epoch 00101: val_loss did not improve from 0.60801
# Epoch 102/300
# 45/45 - 0s - loss: 0.4863 - accuracy: 0.7648 - val_loss: 0.6157 - val_accuracy: 0.6780
#
# Epoch 00102: val_loss did not improve from 0.60801
# Epoch 103/300
# 45/45 - 0s - loss: 0.4882 - accuracy: 0.7577 - val_loss: 0.6115 - val_accuracy: 0.6731
#
# Epoch 00103: val_loss did not improve from 0.60801
# Epoch 104/300
# 45/45 - 0s - loss: 0.4846 - accuracy: 0.7635 - val_loss: 0.6151 - val_accuracy: 0.6788
#
# Epoch 00104: val_loss did not improve from 0.60801
# Epoch 105/300
# 45/45 - 0s - loss: 0.4856 - accuracy: 0.7626 - val_loss: 0.6256 - val_accuracy: 0.6707
#
# Epoch 00105: val_loss did not improve from 0.60801
# Epoch 106/300
# 45/45 - 0s - loss: 0.4820 - accuracy: 0.7654 - val_loss: 0.6307 - val_accuracy: 0.6655
#
# Epoch 00106: val_loss did not improve from 0.60801
# Epoch 107/300
# 45/45 - 0s - loss: 0.4772 - accuracy: 0.7704 - val_loss: 0.6183 - val_accuracy: 0.6735
#
# Epoch 00107: val_loss did not improve from 0.60801
# Epoch 108/300
# 45/45 - 0s - loss: 0.4781 - accuracy: 0.7676 - val_loss: 0.6196 - val_accuracy: 0.6719
#
# Epoch 00108: val_loss did not improve from 0.60801
# Epoch 109/300
# 45/45 - 0s - loss: 0.4839 - accuracy: 0.7657 - val_loss: 0.6137 - val_accuracy: 0.6683
#
# Epoch 00109: val_loss did not improve from 0.60801
# Epoch 110/300
# 45/45 - 0s - loss: 0.4752 - accuracy: 0.7710 - val_loss: 0.6575 - val_accuracy: 0.6468
#
# Epoch 00110: val_loss did not improve from 0.60801
# Epoch 111/300
# 45/45 - 0s - loss: 0.4822 - accuracy: 0.7629 - val_loss: 0.6109 - val_accuracy: 0.6800
#
# Epoch 00111: val_loss did not improve from 0.60801
# Epoch 112/300
# 45/45 - 0s - loss: 0.4728 - accuracy: 0.7719 - val_loss: 0.6244 - val_accuracy: 0.6618
#
# Epoch 00112: val_loss did not improve from 0.60801
# Epoch 113/300
# 45/45 - 0s - loss: 0.4816 - accuracy: 0.7630 - val_loss: 0.6125 - val_accuracy: 0.6727
#
# Epoch 00113: val_loss did not improve from 0.60801
# Epoch 114/300
# 45/45 - 0s - loss: 0.4695 - accuracy: 0.7703 - val_loss: 0.6348 - val_accuracy: 0.6646
#
# Epoch 00114: val_loss did not improve from 0.60801
# Epoch 115/300
# 45/45 - 0s - loss: 0.4701 - accuracy: 0.7734 - val_loss: 0.6144 - val_accuracy: 0.6638
#
# Epoch 00115: val_loss did not improve from 0.60801
# Epoch 116/300
# 45/45 - 0s - loss: 0.4744 - accuracy: 0.7691 - val_loss: 0.6165 - val_accuracy: 0.6707
#
# Epoch 00116: val_loss did not improve from 0.60801
# Epoch 117/300
# 45/45 - 0s - loss: 0.4725 - accuracy: 0.7711 - val_loss: 0.6148 - val_accuracy: 0.6727
#
# Epoch 00117: val_loss did not improve from 0.60801
# Epoch 118/300
# 45/45 - 0s - loss: 0.4689 - accuracy: 0.7728 - val_loss: 0.6271 - val_accuracy: 0.6594
#
# Epoch 00118: val_loss did not improve from 0.60801
# Epoch 119/300
# 45/45 - 0s - loss: 0.4655 - accuracy: 0.7760 - val_loss: 0.6253 - val_accuracy: 0.6650
#
# Epoch 00119: val_loss did not improve from 0.60801
# Epoch 120/300
# 45/45 - 0s - loss: 0.4659 - accuracy: 0.7749 - val_loss: 0.6278 - val_accuracy: 0.6517
#
# Epoch 00120: val_loss did not improve from 0.60801
# Epoch 121/300
# 45/45 - 0s - loss: 0.4629 - accuracy: 0.7783 - val_loss: 0.6091 - val_accuracy: 0.6833
#
# Epoch 00121: val_loss did not improve from 0.60801
# Epoch 122/300
# 45/45 - 0s - loss: 0.4603 - accuracy: 0.7828 - val_loss: 0.6277 - val_accuracy: 0.6695
#
# Epoch 00122: val_loss did not improve from 0.60801
# Epoch 123/300
# 45/45 - 0s - loss: 0.4631 - accuracy: 0.7756 - val_loss: 0.6132 - val_accuracy: 0.6824
#
# Epoch 00123: val_loss did not improve from 0.60801
# Epoch 124/300
# 45/45 - 0s - loss: 0.4608 - accuracy: 0.7849 - val_loss: 0.6141 - val_accuracy: 0.6776
#
# Epoch 00124: val_loss did not improve from 0.60801
# Epoch 125/300
# 45/45 - 0s - loss: 0.4660 - accuracy: 0.7771 - val_loss: 0.6123 - val_accuracy: 0.6695
#
# Epoch 00125: val_loss did not improve from 0.60801
# Epoch 126/300
# 45/45 - 0s - loss: 0.4628 - accuracy: 0.7764 - val_loss: 0.6127 - val_accuracy: 0.6768
#
# Epoch 00126: val_loss did not improve from 0.60801
# Epoch 127/300
# 45/45 - 0s - loss: 0.4568 - accuracy: 0.7840 - val_loss: 0.6217 - val_accuracy: 0.6626
#
# Epoch 00127: val_loss did not improve from 0.60801
# Epoch 128/300
# 45/45 - 0s - loss: 0.4551 - accuracy: 0.7800 - val_loss: 0.6184 - val_accuracy: 0.6679
#
# Epoch 00128: val_loss did not improve from 0.60801
# Epoch 129/300
# 45/45 - 0s - loss: 0.4580 - accuracy: 0.7796 - val_loss: 0.6499 - val_accuracy: 0.6545
#
# Epoch 00129: val_loss did not improve from 0.60801
# Epoch 130/300
# 45/45 - 0s - loss: 0.4543 - accuracy: 0.7852 - val_loss: 0.6285 - val_accuracy: 0.6606
#
# Epoch 00130: val_loss did not improve from 0.60801
# Epoch 131/300
# 45/45 - 0s - loss: 0.4537 - accuracy: 0.7819 - val_loss: 0.6106 - val_accuracy: 0.6808
#
# Epoch 00131: val_loss did not improve from 0.60801
# Epoch 132/300
# 45/45 - 0s - loss: 0.4563 - accuracy: 0.7769 - val_loss: 0.6141 - val_accuracy: 0.6715
#
# Epoch 00132: val_loss did not improve from 0.60801
# Epoch 133/300
# 45/45 - 0s - loss: 0.4531 - accuracy: 0.7840 - val_loss: 0.6240 - val_accuracy: 0.6711
#
# Epoch 00133: val_loss did not improve from 0.60801
# Epoch 134/300
# 45/45 - 0s - loss: 0.4530 - accuracy: 0.7807 - val_loss: 0.6558 - val_accuracy: 0.6460
# Epoch 00134: val_loss did not improve from 0.60801
# Epoch 135/300
# 45/45 - 0s - loss: 0.4480 - accuracy: 0.7909 - val_loss: 0.6245 - val_accuracy: 0.6655
#
# Epoch 00135: val_loss did not improve from 0.60801
# Epoch 136/300
# 45/45 - 0s - loss: 0.4534 - accuracy: 0.7845 - val_loss: 0.6131 - val_accuracy: 0.6614
#
# Epoch 00136: val_loss did not improve from 0.60801
# Epoch 137/300
# 45/45 - 0s - loss: 0.4493 - accuracy: 0.7884 - val_loss: 0.6195 - val_accuracy: 0.6739
#
# Epoch 00137: val_loss did not improve from 0.60801
# Epoch 138/300
# 45/45 - 0s - loss: 0.4504 - accuracy: 0.7857 - val_loss: 0.6547 - val_accuracy: 0.6472
#
# Epoch 00138: val_loss did not improve from 0.60801
# Epoch 139/300
# 45/45 - 0s - loss: 0.4487 - accuracy: 0.7857 - val_loss: 0.6286 - val_accuracy: 0.6646
#
# Epoch 00139: val_loss did not improve from 0.60801
# Epoch 140/300
# 45/45 - 0s - loss: 0.4507 - accuracy: 0.7834 - val_loss: 0.6252 - val_accuracy: 0.6594
#
# Epoch 00140: val_loss did not improve from 0.60801
# Epoch 141/300
# 45/45 - 0s - loss: 0.4528 - accuracy: 0.7819 - val_loss: 0.6289 - val_accuracy: 0.6630
#
# Epoch 00141: val_loss did not improve from 0.60801
# Epoch 142/300
# 45/45 - 0s - loss: 0.4456 - accuracy: 0.7913 - val_loss: 0.6333 - val_accuracy: 0.6501
#
# Epoch 00142: val_loss did not improve from 0.60801
# Epoch 143/300
# 45/45 - 0s - loss: 0.4478 - accuracy: 0.7936 - val_loss: 0.6505 - val_accuracy: 0.6505
#
# Epoch 00143: val_loss did not improve from 0.60801
# Epoch 144/300
# 45/45 - 0s - loss: 0.4424 - accuracy: 0.7906 - val_loss: 0.6247 - val_accuracy: 0.6618
#
# Epoch 00144: val_loss did not improve from 0.60801
# Epoch 145/300
# 45/45 - 0s - loss: 0.4318 - accuracy: 0.7985 - val_loss: 0.6242 - val_accuracy: 0.6622
#
# Epoch 00145: val_loss did not improve from 0.60801
# Epoch 146/300
# 45/45 - 0s - loss: 0.4488 - accuracy: 0.7875 - val_loss: 0.6176 - val_accuracy: 0.6695
#
# Epoch 00146: val_loss did not improve from 0.60801
# Epoch 147/300
# 45/45 - 0s - loss: 0.4351 - accuracy: 0.7937 - val_loss: 0.6455 - val_accuracy: 0.6566
#
# Epoch 00147: val_loss did not improve from 0.60801
# Epoch 148/300
# 45/45 - 0s - loss: 0.4404 - accuracy: 0.7956 - val_loss: 0.6492 - val_accuracy: 0.6444
#
# Epoch 00148: val_loss did not improve from 0.60801
# Epoch 149/300
# 45/45 - 0s - loss: 0.4474 - accuracy: 0.7867 - val_loss: 0.6218 - val_accuracy: 0.6703
#
# Epoch 00149: val_loss did not improve from 0.60801
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6218 - accuracy: 0.6703
# Independent test: [0.6218143105506897, 0.670307457447052]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Ubi_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.7993527508090615,
#  'SP': 0.5412621359223301,
#  'ACC': 0.6703074433656958,
#  'MCC': 0.35255934554202945,
#  'Recall': 0.7993527508090615,
#  'Precision': 0.6353697749196141,
#  'F1-score': 0.7079899677534933,
#  'Cutoff': 0.5}
