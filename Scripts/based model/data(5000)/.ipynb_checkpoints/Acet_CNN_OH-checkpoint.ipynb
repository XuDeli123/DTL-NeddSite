# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\5k\Acet_5k')
    epoch = 150
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Paper\data\based_model_data\原数据\训练集\K_NEDD\41window')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 183/183 - 7s - loss: 0.6935 - accuracy: 0.5057 - val_loss: 0.6926 - val_accuracy: 0.5007
#
# Epoch 00001: val_loss improved from inf to 0.69262, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 2/150
# 183/183 - 2s - loss: 0.6901 - accuracy: 0.5315 - val_loss: 0.6900 - val_accuracy: 0.5416
#
# Epoch 00002: val_loss improved from 0.69262 to 0.69000, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 3/150
# 183/183 - 2s - loss: 0.6871 - accuracy: 0.5453 - val_loss: 0.6883 - val_accuracy: 0.5466
#
# Epoch 00003: val_loss improved from 0.69000 to 0.68831, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 4/150
# 183/183 - 2s - loss: 0.6853 - accuracy: 0.5509 - val_loss: 0.6872 - val_accuracy: 0.5486
#
# Epoch 00004: val_loss improved from 0.68831 to 0.68718, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 5/150
# 183/183 - 2s - loss: 0.6835 - accuracy: 0.5600 - val_loss: 0.6874 - val_accuracy: 0.5447
#
# Epoch 00005: val_loss did not improve from 0.68718
# Epoch 6/150
# 183/183 - 2s - loss: 0.6828 - accuracy: 0.5593 - val_loss: 0.6867 - val_accuracy: 0.5478
#
# Epoch 00006: val_loss improved from 0.68718 to 0.68671, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 7/150
# 183/183 - 2s - loss: 0.6826 - accuracy: 0.5596 - val_loss: 0.6868 - val_accuracy: 0.5478
#
# Epoch 00007: val_loss did not improve from 0.68671
# Epoch 8/150
# 183/183 - 2s - loss: 0.6812 - accuracy: 0.5644 - val_loss: 0.6872 - val_accuracy: 0.5449
#
# Epoch 00008: val_loss did not improve from 0.68671
# Epoch 9/150
# 183/183 - 2s - loss: 0.6800 - accuracy: 0.5670 - val_loss: 0.6853 - val_accuracy: 0.5541
#
# Epoch 00009: val_loss improved from 0.68671 to 0.68533, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 10/150
# 183/183 - 2s - loss: 0.6791 - accuracy: 0.5689 - val_loss: 0.6839 - val_accuracy: 0.5595
#
# Epoch 00010: val_loss improved from 0.68533 to 0.68392, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 11/150
# 183/183 - 2s - loss: 0.6763 - accuracy: 0.5762 - val_loss: 0.6841 - val_accuracy: 0.5547
#
# Epoch 00011: val_loss did not improve from 0.68392
# Epoch 12/150
# 183/183 - 2s - loss: 0.6744 - accuracy: 0.5772 - val_loss: 0.6798 - val_accuracy: 0.5720
#
# Epoch 00012: val_loss improved from 0.68392 to 0.67985, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 13/150
# 183/183 - 2s - loss: 0.6692 - accuracy: 0.5904 - val_loss: 0.6754 - val_accuracy: 0.5886
#
# Epoch 00013: val_loss improved from 0.67985 to 0.67536, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 14/150
# 183/183 - 2s - loss: 0.6645 - accuracy: 0.5967 - val_loss: 0.6726 - val_accuracy: 0.5903
#
# Epoch 00014: val_loss improved from 0.67536 to 0.67261, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 15/150
# 183/183 - 2s - loss: 0.6621 - accuracy: 0.5979 - val_loss: 0.6698 - val_accuracy: 0.5928
#
# Epoch 00015: val_loss improved from 0.67261 to 0.66980, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 16/150
# 183/183 - 2s - loss: 0.6572 - accuracy: 0.6065 - val_loss: 0.6654 - val_accuracy: 0.6068
#
# Epoch 00016: val_loss improved from 0.66980 to 0.66538, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 17/150
# 183/183 - 2s - loss: 0.6520 - accuracy: 0.6129 - val_loss: 0.6618 - val_accuracy: 0.6084
#
# Epoch 00017: val_loss improved from 0.66538 to 0.66178, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 18/150
# 183/183 - 2s - loss: 0.6476 - accuracy: 0.6200 - val_loss: 0.6617 - val_accuracy: 0.6060
#
# Epoch 00018: val_loss improved from 0.66178 to 0.66168, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 19/150
# 183/183 - 2s - loss: 0.6437 - accuracy: 0.6268 - val_loss: 0.6563 - val_accuracy: 0.6169
#
# Epoch 00019: val_loss improved from 0.66168 to 0.65635, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 20/150
# 183/183 - 2s - loss: 0.6421 - accuracy: 0.6261 - val_loss: 0.6541 - val_accuracy: 0.6211
#
# Epoch 00020: val_loss improved from 0.65635 to 0.65410, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 21/150
# 183/183 - 2s - loss: 0.6377 - accuracy: 0.6339 - val_loss: 0.6544 - val_accuracy: 0.6188
#
# Epoch 00021: val_loss did not improve from 0.65410
# Epoch 22/150
# 183/183 - 2s - loss: 0.6341 - accuracy: 0.6368 - val_loss: 0.6508 - val_accuracy: 0.6230
#
# Epoch 00022: val_loss improved from 0.65410 to 0.65081, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 23/150
# 183/183 - 2s - loss: 0.6335 - accuracy: 0.6406 - val_loss: 0.6507 - val_accuracy: 0.6221
#
# Epoch 00023: val_loss improved from 0.65081 to 0.65072, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 24/150
# 183/183 - 2s - loss: 0.6320 - accuracy: 0.6407 - val_loss: 0.6500 - val_accuracy: 0.6223
#
# Epoch 00024: val_loss improved from 0.65072 to 0.65004, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 25/150
# 183/183 - 2s - loss: 0.6296 - accuracy: 0.6443 - val_loss: 0.6491 - val_accuracy: 0.6233
#
# Epoch 00025: val_loss improved from 0.65004 to 0.64910, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 26/150
# 183/183 - 2s - loss: 0.6297 - accuracy: 0.6451 - val_loss: 0.6471 - val_accuracy: 0.6265
#
# Epoch 00026: val_loss improved from 0.64910 to 0.64714, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 27/150
# 183/183 - 2s - loss: 0.6268 - accuracy: 0.6472 - val_loss: 0.6461 - val_accuracy: 0.6281
# Epoch 00027: val_loss improved from 0.64714 to 0.64612, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 28/150
# 183/183 - 2s - loss: 0.6257 - accuracy: 0.6482 - val_loss: 0.6454 - val_accuracy: 0.6290
#
# Epoch 00028: val_loss improved from 0.64612 to 0.64539, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 29/150
# 183/183 - 2s - loss: 0.6232 - accuracy: 0.6529 - val_loss: 0.6467 - val_accuracy: 0.6271
#
# Epoch 00029: val_loss did not improve from 0.64539
# Epoch 30/150
# 183/183 - 2s - loss: 0.6232 - accuracy: 0.6544 - val_loss: 0.6446 - val_accuracy: 0.6279
#
# Epoch 00030: val_loss improved from 0.64539 to 0.64465, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 31/150
# 183/183 - 2s - loss: 0.6218 - accuracy: 0.6550 - val_loss: 0.6442 - val_accuracy: 0.6278
#
# Epoch 00031: val_loss improved from 0.64465 to 0.64423, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 32/150
# 183/183 - 2s - loss: 0.6202 - accuracy: 0.6566 - val_loss: 0.6429 - val_accuracy: 0.6282
#
# Epoch 00032: val_loss improved from 0.64423 to 0.64292, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 33/150
# 183/183 - 2s - loss: 0.6169 - accuracy: 0.6594 - val_loss: 0.6437 - val_accuracy: 0.6269
#
# Epoch 00033: val_loss did not improve from 0.64292
# Epoch 34/150
# 183/183 - 2s - loss: 0.6162 - accuracy: 0.6611 - val_loss: 0.6422 - val_accuracy: 0.6300
#
# Epoch 00034: val_loss improved from 0.64292 to 0.64219, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 35/150
# 183/183 - 2s - loss: 0.6158 - accuracy: 0.6586 - val_loss: 0.6428 - val_accuracy: 0.6272
#
# Epoch 00035: val_loss did not improve from 0.64219
# Epoch 36/150
# 183/183 - 2s - loss: 0.6147 - accuracy: 0.6629 - val_loss: 0.6412 - val_accuracy: 0.6308
#
# Epoch 00036: val_loss improved from 0.64219 to 0.64122, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 37/150
# 183/183 - 2s - loss: 0.6158 - accuracy: 0.6598 - val_loss: 0.6415 - val_accuracy: 0.6315
#
# Epoch 00037: val_loss did not improve from 0.64122
# Epoch 38/150
# 183/183 - 2s - loss: 0.6126 - accuracy: 0.6624 - val_loss: 0.6414 - val_accuracy: 0.6289
#
# Epoch 00038: val_loss did not improve from 0.64122
# Epoch 39/150
# 183/183 - 2s - loss: 0.6121 - accuracy: 0.6641 - val_loss: 0.6404 - val_accuracy: 0.6320
#
# Epoch 00039: val_loss improved from 0.64122 to 0.64038, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 40/150
# 183/183 - 2s - loss: 0.6109 - accuracy: 0.6657 - val_loss: 0.6397 - val_accuracy: 0.6313
#
# Epoch 00040: val_loss improved from 0.64038 to 0.63967, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 41/150
# 183/183 - 2s - loss: 0.6103 - accuracy: 0.6659 - val_loss: 0.6385 - val_accuracy: 0.6344
#
# Epoch 00041: val_loss improved from 0.63967 to 0.63850, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 42/150
# 183/183 - 2s - loss: 0.6093 - accuracy: 0.6682 - val_loss: 0.6397 - val_accuracy: 0.6310
#
# Epoch 00042: val_loss did not improve from 0.63850
# Epoch 43/150
# 183/183 - 2s - loss: 0.6092 - accuracy: 0.6670 - val_loss: 0.6381 - val_accuracy: 0.6340
#
# Epoch 00043: val_loss improved from 0.63850 to 0.63813, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 44/150
# 183/183 - 2s - loss: 0.6092 - accuracy: 0.6648 - val_loss: 0.6375 - val_accuracy: 0.6364
#
# Epoch 00044: val_loss improved from 0.63813 to 0.63750, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 45/150
# 183/183 - 2s - loss: 0.6066 - accuracy: 0.6711 - val_loss: 0.6384 - val_accuracy: 0.6351
#
# Epoch 00045: val_loss did not improve from 0.63750
# Epoch 46/150
# 183/183 - 2s - loss: 0.6059 - accuracy: 0.6696 - val_loss: 0.6389 - val_accuracy: 0.6335
#
# Epoch 00046: val_loss did not improve from 0.63750
# Epoch 47/150
# 183/183 - 2s - loss: 0.6042 - accuracy: 0.6727 - val_loss: 0.6368 - val_accuracy: 0.6351
#
# Epoch 00047: val_loss improved from 0.63750 to 0.63683, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 48/150
# 183/183 - 2s - loss: 0.6047 - accuracy: 0.6726 - val_loss: 0.6373 - val_accuracy: 0.6345
#
# Epoch 00048: val_loss did not improve from 0.63683
# Epoch 49/150
# 183/183 - 2s - loss: 0.6045 - accuracy: 0.6719 - val_loss: 0.6366 - val_accuracy: 0.6369
#
# Epoch 00049: val_loss improved from 0.63683 to 0.63659, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 50/150
# 183/183 - 2s - loss: 0.6044 - accuracy: 0.6733 - val_loss: 0.6368 - val_accuracy: 0.6348
#
# Epoch 00050: val_loss did not improve from 0.63659
# Epoch 51/150
# 183/183 - 2s - loss: 0.6050 - accuracy: 0.6729 - val_loss: 0.6358 - val_accuracy: 0.6374
#
# Epoch 00051: val_loss improved from 0.63659 to 0.63575, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 52/150
# 183/183 - 2s - loss: 0.6038 - accuracy: 0.6729 - val_loss: 0.6351 - val_accuracy: 0.6388
#
# Epoch 00052: val_loss improved from 0.63575 to 0.63507, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 53/150
# 183/183 - 2s - loss: 0.6014 - accuracy: 0.6762 - val_loss: 0.6350 - val_accuracy: 0.6373
#
# Epoch 00053: val_loss improved from 0.63507 to 0.63500, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 54/150
# 183/183 - 2s - loss: 0.6018 - accuracy: 0.6741 - val_loss: 0.6355 - val_accuracy: 0.6366
#
# Epoch 00054: val_loss did not improve from 0.63500
# Epoch 55/150
# 183/183 - 2s - loss: 0.6005 - accuracy: 0.6746 - val_loss: 0.6358 - val_accuracy: 0.6359
#
# Epoch 00055: val_loss did not improve from 0.63500
# Epoch 56/150
# 183/183 - 2s - loss: 0.5997 - accuracy: 0.6773 - val_loss: 0.6389 - val_accuracy: 0.6325
#
# Epoch 00056: val_loss did not improve from 0.63500
# Epoch 57/150
# 183/183 - 2s - loss: 0.6003 - accuracy: 0.6771 - val_loss: 0.6342 - val_accuracy: 0.6394
#
# Epoch 00057: val_loss improved from 0.63500 to 0.63423, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 58/150
# 183/183 - 2s - loss: 0.6005 - accuracy: 0.6769 - val_loss: 0.6348 - val_accuracy: 0.6400
#
# Epoch 00058: val_loss did not improve from 0.63423
# Epoch 59/150
# 183/183 - 2s - loss: 0.5986 - accuracy: 0.6786 - val_loss: 0.6353 - val_accuracy: 0.6377
#
# Epoch 00059: val_loss did not improve from 0.63423
# Epoch 60/150
# 183/183 - 2s - loss: 0.5998 - accuracy: 0.6764 - val_loss: 0.6358 - val_accuracy: 0.6371
#
# Epoch 00060: val_loss did not improve from 0.63423
# Epoch 61/150
# 183/183 - 2s - loss: 0.5984 - accuracy: 0.6763 - val_loss: 0.6335 - val_accuracy: 0.6401
#
# Epoch 00061: val_loss improved from 0.63423 to 0.63348, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 62/150
# 183/183 - 2s - loss: 0.5967 - accuracy: 0.6810 - val_loss: 0.6340 - val_accuracy: 0.6405
#
# Epoch 00062: val_loss did not improve from 0.63348
# Epoch 63/150
# 183/183 - 2s - loss: 0.5961 - accuracy: 0.6816 - val_loss: 0.6331 - val_accuracy: 0.6399
#
# Epoch 00063: val_loss improved from 0.63348 to 0.63312, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 64/150
# 183/183 - 2s - loss: 0.5959 - accuracy: 0.6811 - val_loss: 0.6345 - val_accuracy: 0.6380
#
# Epoch 00064: val_loss did not improve from 0.63312
# Epoch 65/150
# 183/183 - 2s - loss: 0.5958 - accuracy: 0.6820 - val_loss: 0.6347 - val_accuracy: 0.6394
#
# Epoch 00065: val_loss did not improve from 0.63312
# Epoch 66/150
# 183/183 - 2s - loss: 0.5971 - accuracy: 0.6819 - val_loss: 0.6335 - val_accuracy: 0.6404
#
# Epoch 00066: val_loss did not improve from 0.63312
# Epoch 67/150
# 183/183 - 2s - loss: 0.5960 - accuracy: 0.6793 - val_loss: 0.6342 - val_accuracy: 0.6371
#
# Epoch 00067: val_loss did not improve from 0.63312
# Epoch 68/150
# 183/183 - 2s - loss: 0.5928 - accuracy: 0.6829 - val_loss: 0.6356 - val_accuracy: 0.6365
#
# Epoch 00068: val_loss did not improve from 0.63312
# Epoch 69/150
# 183/183 - 2s - loss: 0.5942 - accuracy: 0.6812 - val_loss: 0.6343 - val_accuracy: 0.6391
#
# Epoch 00069: val_loss did not improve from 0.63312
# Epoch 70/150
# 183/183 - 2s - loss: 0.5936 - accuracy: 0.6825 - val_loss: 0.6349 - val_accuracy: 0.6378
#
# Epoch 00070: val_loss did not improve from 0.63312
# Epoch 71/150
# 183/183 - 2s - loss: 0.5933 - accuracy: 0.6846 - val_loss: 0.6327 - val_accuracy: 0.6408
#
# Epoch 00071: val_loss improved from 0.63312 to 0.63271, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 72/150
# 183/183 - 2s - loss: 0.5931 - accuracy: 0.6844 - val_loss: 0.6313 - val_accuracy: 0.6406
#
# Epoch 00072: val_loss improved from 0.63271 to 0.63133, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 73/150
# 183/183 - 2s - loss: 0.5912 - accuracy: 0.6848 - val_loss: 0.6320 - val_accuracy: 0.6419
#
# Epoch 00073: val_loss did not improve from 0.63133
# Epoch 74/150
# 183/183 - 2s - loss: 0.5930 - accuracy: 0.6861 - val_loss: 0.6338 - val_accuracy: 0.6399
#
# Epoch 00074: val_loss did not improve from 0.63133
# Epoch 75/150
# 183/183 - 2s - loss: 0.5925 - accuracy: 0.6843 - val_loss: 0.6327 - val_accuracy: 0.6400
#
# Epoch 00075: val_loss did not improve from 0.63133
# Epoch 76/150
# 183/183 - 2s - loss: 0.5905 - accuracy: 0.6845 - val_loss: 0.6319 - val_accuracy: 0.6419
#
# Epoch 00076: val_loss did not improve from 0.63133
# Epoch 77/150
# 183/183 - 2s - loss: 0.5891 - accuracy: 0.6870 - val_loss: 0.6322 - val_accuracy: 0.6413
#
# Epoch 00077: val_loss did not improve from 0.63133
# Epoch 78/150
# 183/183 - 2s - loss: 0.5913 - accuracy: 0.6838 - val_loss: 0.6323 - val_accuracy: 0.6415
#
# Epoch 00078: val_loss did not improve from 0.63133
# Epoch 79/150
# 183/183 - 2s - loss: 0.5906 - accuracy: 0.6835 - val_loss: 0.6323 - val_accuracy: 0.6420
#
# Epoch 00079: val_loss did not improve from 0.63133
# Epoch 80/150
# 183/183 - 2s - loss: 0.5901 - accuracy: 0.6869 - val_loss: 0.6333 - val_accuracy: 0.6398
#
# Epoch 00080: val_loss did not improve from 0.63133
# Epoch 81/150
# 183/183 - 2s - loss: 0.5911 - accuracy: 0.6864 - val_loss: 0.6310 - val_accuracy: 0.6417
#
# Epoch 00081: val_loss improved from 0.63133 to 0.63099, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 82/150
# 183/183 - 2s - loss: 0.5889 - accuracy: 0.6883 - val_loss: 0.6325 - val_accuracy: 0.6430
#
# Epoch 00082: val_loss did not improve from 0.63099
# Epoch 83/150
# 183/183 - 2s - loss: 0.5889 - accuracy: 0.6888 - val_loss: 0.6311 - val_accuracy: 0.6428
#
# Epoch 00083: val_loss did not improve from 0.63099
# Epoch 84/150
# 183/183 - 2s - loss: 0.5868 - accuracy: 0.6893 - val_loss: 0.6323 - val_accuracy: 0.6407
#
# Epoch 00084: val_loss did not improve from 0.63099
# Epoch 85/150
# 183/183 - 2s - loss: 0.5884 - accuracy: 0.6877 - val_loss: 0.6318 - val_accuracy: 0.6414
#
# Epoch 00085: val_loss did not improve from 0.63099
# Epoch 86/150
# 183/183 - 2s - loss: 0.5856 - accuracy: 0.6907 - val_loss: 0.6315 - val_accuracy: 0.6414
#
# Epoch 00086: val_loss did not improve from 0.63099
# Epoch 87/150
# 183/183 - 2s - loss: 0.5878 - accuracy: 0.6892 - val_loss: 0.6314 - val_accuracy: 0.6410
#
# Epoch 00087: val_loss did not improve from 0.63099
# Epoch 88/150
# 183/183 - 2s - loss: 0.5873 - accuracy: 0.6888 - val_loss: 0.6311 - val_accuracy: 0.6434
#
# Epoch 00088: val_loss did not improve from 0.63099
# Epoch 89/150
# 183/183 - 2s - loss: 0.5886 - accuracy: 0.6874 - val_loss: 0.6305 - val_accuracy: 0.6427
#
# Epoch 00089: val_loss improved from 0.63099 to 0.63054, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 90/150
# 183/183 - 2s - loss: 0.5869 - accuracy: 0.6904 - val_loss: 0.6301 - val_accuracy: 0.6426
#
# Epoch 00090: val_loss improved from 0.63054 to 0.63010, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 91/150
# 183/183 - 2s - loss: 0.5871 - accuracy: 0.6878 - val_loss: 0.6308 - val_accuracy: 0.6427
#
# Epoch 00091: val_loss did not improve from 0.63010
# Epoch 92/150
# 183/183 - 2s - loss: 0.5851 - accuracy: 0.6894 - val_loss: 0.6302 - val_accuracy: 0.6430
#
# Epoch 00092: val_loss did not improve from 0.63010
# Epoch 93/150
# 183/183 - 2s - loss: 0.5863 - accuracy: 0.6904 - val_loss: 0.6294 - val_accuracy: 0.6434
#
# Epoch 00093: val_loss improved from 0.63010 to 0.62940, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 94/150
# 183/183 - 2s - loss: 0.5858 - accuracy: 0.6902 - val_loss: 0.6304 - val_accuracy: 0.6429
#
# Epoch 00094: val_loss did not improve from 0.62940
# Epoch 95/150
# 183/183 - 2s - loss: 0.5841 - accuracy: 0.6921 - val_loss: 0.6305 - val_accuracy: 0.6424
#
# Epoch 00095: val_loss did not improve from 0.62940
# Epoch 96/150
# 183/183 - 2s - loss: 0.5842 - accuracy: 0.6921 - val_loss: 0.6306 - val_accuracy: 0.6401
#
# Epoch 00096: val_loss did not improve from 0.62940
# Epoch 97/150
# 183/183 - 2s - loss: 0.5836 - accuracy: 0.6951 - val_loss: 0.6302 - val_accuracy: 0.6416
#
# Epoch 00097: val_loss did not improve from 0.62940
# Epoch 98/150
# 183/183 - 2s - loss: 0.5833 - accuracy: 0.6913 - val_loss: 0.6289 - val_accuracy: 0.6432
#
# Epoch 00098: val_loss improved from 0.62940 to 0.62889, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 99/150
# 183/183 - 2s - loss: 0.5840 - accuracy: 0.6928 - val_loss: 0.6288 - val_accuracy: 0.6428
#
# Epoch 00099: val_loss improved from 0.62889 to 0.62875, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 100/150
# 183/183 - 2s - loss: 0.5837 - accuracy: 0.6919 - val_loss: 0.6296 - val_accuracy: 0.6436
#
# Epoch 00100: val_loss did not improve from 0.62875
# Epoch 101/150
# 183/183 - 2s - loss: 0.5829 - accuracy: 0.6912 - val_loss: 0.6285 - val_accuracy: 0.6429
#
# Epoch 00101: val_loss improved from 0.62875 to 0.62854, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 102/150
# 183/183 - 2s - loss: 0.5830 - accuracy: 0.6929 - val_loss: 0.6290 - val_accuracy: 0.6437
#
# Epoch 00102: val_loss did not improve from 0.62854
# Epoch 103/150
# 183/183 - 2s - loss: 0.5816 - accuracy: 0.6957 - val_loss: 0.6289 - val_accuracy: 0.6418
#
# Epoch 00103: val_loss did not improve from 0.62854
# Epoch 104/150
# 183/183 - 2s - loss: 0.5802 - accuracy: 0.6956 - val_loss: 0.6309 - val_accuracy: 0.6425
#
# Epoch 00104: val_loss did not improve from 0.62854
# Epoch 105/150
# 183/183 - 2s - loss: 0.5812 - accuracy: 0.6958 - val_loss: 0.6298 - val_accuracy: 0.6419
#
# Epoch 00105: val_loss did not improve from 0.62854
# Epoch 106/150
# 183/183 - 2s - loss: 0.5825 - accuracy: 0.6937 - val_loss: 0.6293 - val_accuracy: 0.6402
#
# Epoch 00106: val_loss did not improve from 0.62854
# Epoch 107/150
# 183/183 - 2s - loss: 0.5809 - accuracy: 0.6938 - val_loss: 0.6289 - val_accuracy: 0.6430
#
# Epoch 00107: val_loss did not improve from 0.62854
# Epoch 108/150
# 183/183 - 2s - loss: 0.5822 - accuracy: 0.6944 - val_loss: 0.6284 - val_accuracy: 0.6435
#
# Epoch 00108: val_loss improved from 0.62854 to 0.62842, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 109/150
# 183/183 - 2s - loss: 0.5813 - accuracy: 0.6938 - val_loss: 0.6289 - val_accuracy: 0.6439
#
# Epoch 00109: val_loss did not improve from 0.62842
# Epoch 110/150
# 183/183 - 2s - loss: 0.5818 - accuracy: 0.6941 - val_loss: 0.6289 - val_accuracy: 0.6397
#
# Epoch 00110: val_loss did not improve from 0.62842
# Epoch 111/150
# 183/183 - 2s - loss: 0.5789 - accuracy: 0.6973 - val_loss: 0.6274 - val_accuracy: 0.6432
#
# Epoch 00111: val_loss improved from 0.62842 to 0.62735, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 112/150
# 183/183 - 2s - loss: 0.5796 - accuracy: 0.6948 - val_loss: 0.6297 - val_accuracy: 0.6415
# Epoch 00112: val_loss did not improve from 0.62735
# Epoch 113/150
# 183/183 - 2s - loss: 0.5793 - accuracy: 0.6935 - val_loss: 0.6280 - val_accuracy: 0.6406
#
# Epoch 00113: val_loss did not improve from 0.62735
# Epoch 114/150
# 183/183 - 2s - loss: 0.5792 - accuracy: 0.6947 - val_loss: 0.6276 - val_accuracy: 0.6467
#
# Epoch 00114: val_loss did not improve from 0.62735
# Epoch 115/150
# 183/183 - 2s - loss: 0.5797 - accuracy: 0.6950 - val_loss: 0.6277 - val_accuracy: 0.6452
#
# Epoch 00115: val_loss did not improve from 0.62735
# Epoch 116/150
# 183/183 - 2s - loss: 0.5796 - accuracy: 0.6946 - val_loss: 0.6271 - val_accuracy: 0.6464
#
# Epoch 00116: val_loss improved from 0.62735 to 0.62707, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 117/150
# 183/183 - 2s - loss: 0.5782 - accuracy: 0.6975 - val_loss: 0.6277 - val_accuracy: 0.6431
#
# Epoch 00117: val_loss did not improve from 0.62707
# Epoch 118/150
# 183/183 - 2s - loss: 0.5768 - accuracy: 0.6961 - val_loss: 0.6271 - val_accuracy: 0.6439
#
# Epoch 00118: val_loss did not improve from 0.62707
# Epoch 119/150
# 183/183 - 2s - loss: 0.5767 - accuracy: 0.6995 - val_loss: 0.6262 - val_accuracy: 0.6457
#
# Epoch 00119: val_loss improved from 0.62707 to 0.62624, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 120/150
# 183/183 - 2s - loss: 0.5763 - accuracy: 0.6972 - val_loss: 0.6283 - val_accuracy: 0.6429
#
# Epoch 00120: val_loss did not improve from 0.62624
# Epoch 121/150
# 183/183 - 2s - loss: 0.5772 - accuracy: 0.6974 - val_loss: 0.6282 - val_accuracy: 0.6439
#
# Epoch 00121: val_loss did not improve from 0.62624
# Epoch 122/150
# 183/183 - 2s - loss: 0.5782 - accuracy: 0.6976 - val_loss: 0.6277 - val_accuracy: 0.6439
#
# Epoch 00122: val_loss did not improve from 0.62624
# Epoch 123/150
# 183/183 - 2s - loss: 0.5768 - accuracy: 0.6963 - val_loss: 0.6287 - val_accuracy: 0.6431
#
# Epoch 00123: val_loss did not improve from 0.62624
# Epoch 124/150
# 183/183 - 2s - loss: 0.5765 - accuracy: 0.6974 - val_loss: 0.6270 - val_accuracy: 0.6477
#
# Epoch 00124: val_loss did not improve from 0.62624
# Epoch 125/150
# 183/183 - 2s - loss: 0.5766 - accuracy: 0.6998 - val_loss: 0.6268 - val_accuracy: 0.6435
#
# Epoch 00125: val_loss did not improve from 0.62624
# Epoch 126/150
# 183/183 - 2s - loss: 0.5763 - accuracy: 0.6982 - val_loss: 0.6270 - val_accuracy: 0.6457
#
# Epoch 00126: val_loss did not improve from 0.62624
# Epoch 127/150
# 183/183 - 2s - loss: 0.5768 - accuracy: 0.6989 - val_loss: 0.6271 - val_accuracy: 0.6430
#
# Epoch 00127: val_loss did not improve from 0.62624
# Epoch 128/150
# 183/183 - 2s - loss: 0.5754 - accuracy: 0.6981 - val_loss: 0.6264 - val_accuracy: 0.6423
#
# Epoch 00128: val_loss did not improve from 0.62624
# Epoch 129/150
# 183/183 - 2s - loss: 0.5754 - accuracy: 0.6991 - val_loss: 0.6264 - val_accuracy: 0.6445
#
# Epoch 00129: val_loss did not improve from 0.62624
# Epoch 130/150
# 183/183 - 2s - loss: 0.5750 - accuracy: 0.6978 - val_loss: 0.6267 - val_accuracy: 0.6424
#
# Epoch 00130: val_loss did not improve from 0.62624
# Epoch 131/150
# 183/183 - 2s - loss: 0.5755 - accuracy: 0.6986 - val_loss: 0.6272 - val_accuracy: 0.6416
#
# Epoch 00131: val_loss did not improve from 0.62624
# Epoch 132/150
# 183/183 - 2s - loss: 0.5758 - accuracy: 0.6980 - val_loss: 0.6276 - val_accuracy: 0.6423
#
# Epoch 00132: val_loss did not improve from 0.62624
# Epoch 133/150
# 183/183 - 2s - loss: 0.5738 - accuracy: 0.7010 - val_loss: 0.6269 - val_accuracy: 0.6457
#
# Epoch 00133: val_loss did not improve from 0.62624
# Epoch 134/150
# 183/183 - 2s - loss: 0.5743 - accuracy: 0.7003 - val_loss: 0.6262 - val_accuracy: 0.6455
#
# Epoch 00134: val_loss improved from 0.62624 to 0.62622, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 135/150
# 183/183 - 2s - loss: 0.5725 - accuracy: 0.7010 - val_loss: 0.6267 - val_accuracy: 0.6438
#
# Epoch 00135: val_loss did not improve from 0.62622
# Epoch 136/150
# 183/183 - 2s - loss: 0.5754 - accuracy: 0.6998 - val_loss: 0.6267 - val_accuracy: 0.6437
#
# Epoch 00136: val_loss did not improve from 0.62622
# Epoch 137/150
# 183/183 - 2s - loss: 0.5739 - accuracy: 0.6998 - val_loss: 0.6254 - val_accuracy: 0.6474
#
# Epoch 00137: val_loss improved from 0.62622 to 0.62538, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 138/150
# 183/183 - 2s - loss: 0.5744 - accuracy: 0.7003 - val_loss: 0.6252 - val_accuracy: 0.6476
#
# Epoch 00138: val_loss improved from 0.62538 to 0.62515, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 139/150
# 183/183 - 2s - loss: 0.5753 - accuracy: 0.6981 - val_loss: 0.6263 - val_accuracy: 0.6430
#
# Epoch 00139: val_loss did not improve from 0.62515
# Epoch 140/150
# 183/183 - 2s - loss: 0.5719 - accuracy: 0.7008 - val_loss: 0.6258 - val_accuracy: 0.6460
#
# Epoch 00140: val_loss did not improve from 0.62515
# Epoch 141/150
# 183/183 - 2s - loss: 0.5720 - accuracy: 0.7014 - val_loss: 0.6259 - val_accuracy: 0.6474
#
# Epoch 00141: val_loss did not improve from 0.62515
# Epoch 142/150
# 183/183 - 2s - loss: 0.5722 - accuracy: 0.7028 - val_loss: 0.6272 - val_accuracy: 0.6444
#
# Epoch 00142: val_loss did not improve from 0.62515
# Epoch 143/150
# 183/183 - 2s - loss: 0.5702 - accuracy: 0.7046 - val_loss: 0.6270 - val_accuracy: 0.6454
#
# Epoch 00143: val_loss did not improve from 0.62515
# Epoch 144/150
# 183/183 - 2s - loss: 0.5726 - accuracy: 0.7019 - val_loss: 0.6259 - val_accuracy: 0.6459
#
# Epoch 00144: val_loss did not improve from 0.62515
# Epoch 145/150
# 183/183 - 2s - loss: 0.5706 - accuracy: 0.7038 - val_loss: 0.6251 - val_accuracy: 0.6472
#
# Epoch 00145: val_loss improved from 0.62515 to 0.62515, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 146/150
# 183/183 - 2s - loss: 0.5704 - accuracy: 0.7027 - val_loss: 0.6254 - val_accuracy: 0.6466
#
# Epoch 00146: val_loss did not improve from 0.62515
# Epoch 147/150
# 183/183 - 2s - loss: 0.5709 - accuracy: 0.7019 - val_loss: 0.6270 - val_accuracy: 0.6444
#
# Epoch 00147: val_loss did not improve from 0.62515
# Epoch 148/150
# 183/183 - 2s - loss: 0.5725 - accuracy: 0.6994 - val_loss: 0.6249 - val_accuracy: 0.6472
#
# Epoch 00148: val_loss improved from 0.62515 to 0.62489, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 149/150
# 183/183 - 2s - loss: 0.5711 - accuracy: 0.7031 - val_loss: 0.6250 - val_accuracy: 0.6477
#
# Epoch 00149: val_loss did not improve from 0.62489
# Epoch 150/150
# 183/183 - 2s - loss: 0.5696 - accuracy: 0.7066 - val_loss: 0.6244 - val_accuracy: 0.6477
#
# Epoch 00150: val_loss improved from 0.62489 to 0.62440, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6244 - accuracy: 0.6477
# Independent test: [0.6243996620178223, 0.6476537585258484]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.7067565707995046,
#  'SP': 0.5885509838998211,
#  'ACC': 0.6476537773496629,
#  'MCC': 0.2973925310411309,
#  'Recall': 0.7067565707995046,
#  'Precision': 0.6320452867339404,
#  'F1-score': 0.6673163126096278,
#  'Cutoff': 0.5}

# %%
fpr, tpr, thresholds = roc_curve(y_true, pred)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, lw=1, alpha=0.7, label='ROC (AUC = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Random', alpha=.8)
plt.xlim([0, 1.0])
plt.ylim([0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('CNN_OH_val.png')
plt.show()
