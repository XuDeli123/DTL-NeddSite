# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    #network.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\based\5k\K_5k')
    epoch = 300
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\based\NEDD')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 45/45 - 5s - loss: 0.7003 - accuracy: 0.5001 - val_loss: 0.6938 - val_accuracy: 0.5000
#
# Epoch 00001: val_loss improved from inf to 0.69383, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 2/300
# 45/45 - 1s - loss: 0.6930 - accuracy: 0.5194 - val_loss: 0.6922 - val_accuracy: 0.5093
#
# Epoch 00002: val_loss improved from 0.69383 to 0.69215, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 3/300
# 45/45 - 0s - loss: 0.6889 - accuracy: 0.5449 - val_loss: 0.6891 - val_accuracy: 0.5227
#
# Epoch 00003: val_loss improved from 0.69215 to 0.68915, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 4/300
# 45/45 - 0s - loss: 0.6857 - accuracy: 0.5488 - val_loss: 0.6867 - val_accuracy: 0.5405
#
# Epoch 00004: val_loss improved from 0.68915 to 0.68674, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 5/300
# 45/45 - 0s - loss: 0.6853 - accuracy: 0.5478 - val_loss: 0.6834 - val_accuracy: 0.5583
#
# Epoch 00005: val_loss improved from 0.68674 to 0.68339, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 6/300
# 45/45 - 0s - loss: 0.6814 - accuracy: 0.5593 - val_loss: 0.6825 - val_accuracy: 0.5611
#
# Epoch 00006: val_loss improved from 0.68339 to 0.68254, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 7/300
# 45/45 - 0s - loss: 0.6797 - accuracy: 0.5612 - val_loss: 0.6791 - val_accuracy: 0.5643
#
# Epoch 00007: val_loss improved from 0.68254 to 0.67914, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 8/300
# 45/45 - 0s - loss: 0.6774 - accuracy: 0.5613 - val_loss: 0.6800 - val_accuracy: 0.5878
#
# Epoch 00008: val_loss did not improve from 0.67914
# Epoch 9/300
# 45/45 - 0s - loss: 0.6756 - accuracy: 0.5711 - val_loss: 0.6752 - val_accuracy: 0.5692
#
# Epoch 00009: val_loss improved from 0.67914 to 0.67523, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 10/300
# 45/45 - 0s - loss: 0.6707 - accuracy: 0.5810 - val_loss: 0.6785 - val_accuracy: 0.5631
#
# Epoch 00010: val_loss did not improve from 0.67523
# Epoch 11/300
# 45/45 - 0s - loss: 0.6687 - accuracy: 0.5755 - val_loss: 0.6694 - val_accuracy: 0.5926
#
# Epoch 00011: val_loss improved from 0.67523 to 0.66938, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 12/300
# 45/45 - 0s - loss: 0.6681 - accuracy: 0.5875 - val_loss: 0.6705 - val_accuracy: 0.5765
#
# Epoch 00012: val_loss did not improve from 0.66938
# Epoch 13/300
# 45/45 - 0s - loss: 0.6627 - accuracy: 0.5957 - val_loss: 0.6620 - val_accuracy: 0.5939
#
# Epoch 00013: val_loss improved from 0.66938 to 0.66199, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 14/300
# 45/45 - 0s - loss: 0.6580 - accuracy: 0.6043 - val_loss: 0.6626 - val_accuracy: 0.5736
#
# Epoch 00014: val_loss did not improve from 0.66199
# Epoch 15/300
# 45/45 - 0s - loss: 0.6586 - accuracy: 0.6050 - val_loss: 0.6523 - val_accuracy: 0.6323
#
# Epoch 00015: val_loss improved from 0.66199 to 0.65234, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 16/300
# 45/45 - 0s - loss: 0.6540 - accuracy: 0.6108 - val_loss: 0.6538 - val_accuracy: 0.6319
#
# Epoch 00016: val_loss did not improve from 0.65234
# Epoch 17/300
# 45/45 - 0s - loss: 0.6528 - accuracy: 0.6099 - val_loss: 0.6544 - val_accuracy: 0.6193
#
# Epoch 00017: val_loss did not improve from 0.65234
# Epoch 18/300
# 45/45 - 0s - loss: 0.6502 - accuracy: 0.6147 - val_loss: 0.6502 - val_accuracy: 0.5979
#
# Epoch 00018: val_loss improved from 0.65234 to 0.65020, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 19/300
# 45/45 - 0s - loss: 0.6481 - accuracy: 0.6210 - val_loss: 0.6464 - val_accuracy: 0.6481
#
# Epoch 00019: val_loss improved from 0.65020 to 0.64645, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 20/300
# 45/45 - 0s - loss: 0.6466 - accuracy: 0.6212 - val_loss: 0.6415 - val_accuracy: 0.6408
#
# Epoch 00020: val_loss improved from 0.64645 to 0.64147, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 21/300
# 45/45 - 0s - loss: 0.6436 - accuracy: 0.6236 - val_loss: 0.6460 - val_accuracy: 0.6610
#
# Epoch 00021: val_loss did not improve from 0.64147
# Epoch 22/300
# 45/45 - 0s - loss: 0.6402 - accuracy: 0.6287 - val_loss: 0.6472 - val_accuracy: 0.6363
#
# Epoch 00022: val_loss did not improve from 0.64147
# Epoch 23/300
# 45/45 - 0s - loss: 0.6407 - accuracy: 0.6240 - val_loss: 0.6426 - val_accuracy: 0.6371
#
# Epoch 00023: val_loss did not improve from 0.64147
# Epoch 24/300
# 45/45 - 0s - loss: 0.6393 - accuracy: 0.6311 - val_loss: 0.6530 - val_accuracy: 0.6294
#
# Epoch 00024: val_loss did not improve from 0.64147
# Epoch 25/300
# 45/45 - 0s - loss: 0.6366 - accuracy: 0.6382 - val_loss: 0.6773 - val_accuracy: 0.5845
#
# Epoch 00025: val_loss did not improve from 0.64147
# Epoch 26/300
# 45/45 - 0s - loss: 0.6361 - accuracy: 0.6321 - val_loss: 0.6337 - val_accuracy: 0.6582
#
# Epoch 00026: val_loss improved from 0.64147 to 0.63370, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 27/300
# 45/45 - 0s - loss: 0.6311 - accuracy: 0.6353 - val_loss: 0.6438 - val_accuracy: 0.6379
#
# Epoch 00027: val_loss did not improve from 0.63370
# Epoch 28/300
# 45/45 - 0s - loss: 0.6313 - accuracy: 0.6370 - val_loss: 0.6305 - val_accuracy: 0.6646
#
# Epoch 00028: val_loss improved from 0.63370 to 0.63048, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 29/300
# 45/45 - 0s - loss: 0.6304 - accuracy: 0.6417 - val_loss: 0.6339 - val_accuracy: 0.6590
#
# Epoch 00029: val_loss did not improve from 0.63048
# Epoch 30/300
# 45/45 - 0s - loss: 0.6270 - accuracy: 0.6415 - val_loss: 0.6281 - val_accuracy: 0.6650
#
# Epoch 00030: val_loss improved from 0.63048 to 0.62809, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 31/300
# 45/45 - 0s - loss: 0.6252 - accuracy: 0.6457 - val_loss: 0.6337 - val_accuracy: 0.6529
#
# Epoch 00031: val_loss did not improve from 0.62809
# Epoch 32/300
# 45/45 - 0s - loss: 0.6238 - accuracy: 0.6449 - val_loss: 0.6325 - val_accuracy: 0.6472
#
# Epoch 00032: val_loss did not improve from 0.62809
# Epoch 33/300
# 45/45 - 0s - loss: 0.6258 - accuracy: 0.6461 - val_loss: 0.6339 - val_accuracy: 0.6642
#
# Epoch 00033: val_loss did not improve from 0.62809
# Epoch 34/300
# 45/45 - 0s - loss: 0.6237 - accuracy: 0.6469 - val_loss: 0.6282 - val_accuracy: 0.6663
#
# Epoch 00034: val_loss did not improve from 0.62809
# Epoch 35/300
# 45/45 - 0s - loss: 0.6186 - accuracy: 0.6563 - val_loss: 0.6409 - val_accuracy: 0.6408
#
# Epoch 00035: val_loss did not improve from 0.62809
# Epoch 36/300
# 45/45 - 0s - loss: 0.6182 - accuracy: 0.6565 - val_loss: 0.6251 - val_accuracy: 0.6695
#
# Epoch 00036: val_loss improved from 0.62809 to 0.62515, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 37/300
# 45/45 - 0s - loss: 0.6146 - accuracy: 0.6593 - val_loss: 0.6319 - val_accuracy: 0.6602
#
# Epoch 00037: val_loss did not improve from 0.62515
# Epoch 38/300
# 45/45 - 0s - loss: 0.6132 - accuracy: 0.6593 - val_loss: 0.6199 - val_accuracy: 0.6739
#
# Epoch 00038: val_loss improved from 0.62515 to 0.61989, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 39/300
# 45/45 - 0s - loss: 0.6101 - accuracy: 0.6632 - val_loss: 0.6195 - val_accuracy: 0.6776
#
# Epoch 00039: val_loss improved from 0.61989 to 0.61950, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 40/300
# 45/45 - 0s - loss: 0.6124 - accuracy: 0.6577 - val_loss: 0.6266 - val_accuracy: 0.6703
#
# Epoch 00040: val_loss did not improve from 0.61950
# Epoch 41/300
# 45/45 - 0s - loss: 0.6066 - accuracy: 0.6636 - val_loss: 0.6409 - val_accuracy: 0.6404
#
# Epoch 00041: val_loss did not improve from 0.61950
# Epoch 42/300
# 45/45 - 0s - loss: 0.6056 - accuracy: 0.6620 - val_loss: 0.6561 - val_accuracy: 0.6084
#
# Epoch 00042: val_loss did not improve from 0.61950
# Epoch 43/300
# 45/45 - 0s - loss: 0.6104 - accuracy: 0.6620 - val_loss: 0.6286 - val_accuracy: 0.6598
#
# Epoch 00043: val_loss did not improve from 0.61950
# Epoch 44/300
# 45/45 - 0s - loss: 0.6054 - accuracy: 0.6650 - val_loss: 0.6189 - val_accuracy: 0.6857
#
# Epoch 00044: val_loss improved from 0.61950 to 0.61885, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 45/300
# 45/45 - 0s - loss: 0.6049 - accuracy: 0.6665 - val_loss: 0.6185 - val_accuracy: 0.6824
#
# Epoch 00045: val_loss improved from 0.61885 to 0.61851, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 46/300
# 45/45 - 0s - loss: 0.5976 - accuracy: 0.6745 - val_loss: 0.6223 - val_accuracy: 0.6715
#
# Epoch 00046: val_loss did not improve from 0.61851
# Epoch 47/300
# 45/45 - 0s - loss: 0.5940 - accuracy: 0.6746 - val_loss: 0.6223 - val_accuracy: 0.6642
#
# Epoch 00047: val_loss did not improve from 0.61851
# Epoch 48/300
# 45/45 - 0s - loss: 0.5964 - accuracy: 0.6733 - val_loss: 0.6281 - val_accuracy: 0.6610
#
# Epoch 00048: val_loss did not improve from 0.61851
# Epoch 49/300
# 45/45 - 0s - loss: 0.5922 - accuracy: 0.6786 - val_loss: 0.6169 - val_accuracy: 0.6792
#
# Epoch 00049: val_loss improved from 0.61851 to 0.61689, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 50/300
# 45/45 - 0s - loss: 0.5928 - accuracy: 0.6787 - val_loss: 0.6334 - val_accuracy: 0.6452
#
# Epoch 00050: val_loss did not improve from 0.61689
# Epoch 51/300
# 45/45 - 0s - loss: 0.5898 - accuracy: 0.6794 - val_loss: 0.6201 - val_accuracy: 0.6752
#
# Epoch 00051: val_loss did not improve from 0.61689
# Epoch 52/300
# 45/45 - 0s - loss: 0.5920 - accuracy: 0.6815 - val_loss: 0.6262 - val_accuracy: 0.6497
#
# Epoch 00052: val_loss did not improve from 0.61689
# Epoch 53/300
# 45/45 - 0s - loss: 0.5866 - accuracy: 0.6882 - val_loss: 0.6127 - val_accuracy: 0.6752
#
# Epoch 00053: val_loss improved from 0.61689 to 0.61272, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 54/300
# 45/45 - 0s - loss: 0.5883 - accuracy: 0.6847 - val_loss: 0.6147 - val_accuracy: 0.6804
#
# Epoch 00054: val_loss did not improve from 0.61272
# Epoch 55/300
# 45/45 - 0s - loss: 0.5857 - accuracy: 0.6853 - val_loss: 0.6092 - val_accuracy: 0.6881
#
# Epoch 00055: val_loss improved from 0.61272 to 0.60917, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 56/300
# 45/45 - 0s - loss: 0.5841 - accuracy: 0.6861 - val_loss: 0.6095 - val_accuracy: 0.6723
#
# Epoch 00056: val_loss did not improve from 0.60917
# Epoch 57/300
# 45/45 - 0s - loss: 0.5825 - accuracy: 0.6873 - val_loss: 0.6136 - val_accuracy: 0.6841
#
# Epoch 00057: val_loss did not improve from 0.60917
# Epoch 58/300
# 45/45 - 0s - loss: 0.5809 - accuracy: 0.6887 - val_loss: 0.6237 - val_accuracy: 0.6561
#
# Epoch 00058: val_loss did not improve from 0.60917
# Epoch 59/300
# 45/45 - 0s - loss: 0.5778 - accuracy: 0.6959 - val_loss: 0.6161 - val_accuracy: 0.6650
#
# Epoch 00059: val_loss did not improve from 0.60917
# Epoch 60/300
# 45/45 - 0s - loss: 0.5764 - accuracy: 0.7008 - val_loss: 0.6106 - val_accuracy: 0.6808
#
# Epoch 00060: val_loss did not improve from 0.60917
# Epoch 61/300
# 45/45 - 0s - loss: 0.5721 - accuracy: 0.6964 - val_loss: 0.6065 - val_accuracy: 0.6808
#
# Epoch 00061: val_loss improved from 0.60917 to 0.60653, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 62/300
# 45/45 - 0s - loss: 0.5690 - accuracy: 0.7025 - val_loss: 0.6144 - val_accuracy: 0.6808
#
# Epoch 00062: val_loss did not improve from 0.60653
# Epoch 63/300
# 45/45 - 0s - loss: 0.5774 - accuracy: 0.6935 - val_loss: 0.6101 - val_accuracy: 0.6853
#
# Epoch 00063: val_loss did not improve from 0.60653
# Epoch 64/300
# 45/45 - 0s - loss: 0.5731 - accuracy: 0.6988 - val_loss: 0.6204 - val_accuracy: 0.6727
#
# Epoch 00064: val_loss did not improve from 0.60653
# Epoch 65/300
# 45/45 - 0s - loss: 0.5709 - accuracy: 0.6998 - val_loss: 0.6196 - val_accuracy: 0.6679
#
# Epoch 00065: val_loss did not improve from 0.60653
# Epoch 66/300
# 45/45 - 0s - loss: 0.5671 - accuracy: 0.6992 - val_loss: 0.6127 - val_accuracy: 0.6529
#
# Epoch 00066: val_loss did not improve from 0.60653
# Epoch 67/300
# 45/45 - 0s - loss: 0.5673 - accuracy: 0.7029 - val_loss: 0.6079 - val_accuracy: 0.6691
#
# Epoch 00067: val_loss did not improve from 0.60653
# Epoch 68/300
# 45/45 - 0s - loss: 0.5572 - accuracy: 0.7125 - val_loss: 0.6085 - val_accuracy: 0.6861
#
# Epoch 00068: val_loss did not improve from 0.60653
# Epoch 69/300
# 45/45 - 0s - loss: 0.5619 - accuracy: 0.7046 - val_loss: 0.6064 - val_accuracy: 0.6816
#
# Epoch 00069: val_loss improved from 0.60653 to 0.60639, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 70/300
# 45/45 - 0s - loss: 0.5592 - accuracy: 0.7069 - val_loss: 0.6043 - val_accuracy: 0.6792
#
# Epoch 00070: val_loss improved from 0.60639 to 0.60431, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 71/300
# 45/45 - 0s - loss: 0.5592 - accuracy: 0.7053 - val_loss: 0.6135 - val_accuracy: 0.6727
#
# Epoch 00071: val_loss did not improve from 0.60431
# Epoch 72/300
# 45/45 - 0s - loss: 0.5559 - accuracy: 0.7124 - val_loss: 0.6054 - val_accuracy: 0.6638
#
# Epoch 00072: val_loss did not improve from 0.60431
# Epoch 73/300
# 45/45 - 0s - loss: 0.5531 - accuracy: 0.7115 - val_loss: 0.6038 - val_accuracy: 0.6812
#
# Epoch 00073: val_loss improved from 0.60431 to 0.60384, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 74/300
# 45/45 - 0s - loss: 0.5520 - accuracy: 0.7148 - val_loss: 0.6101 - val_accuracy: 0.6638
#
# Epoch 00074: val_loss did not improve from 0.60384
# Epoch 75/300
# 45/45 - 0s - loss: 0.5560 - accuracy: 0.7114 - val_loss: 0.6198 - val_accuracy: 0.6739
#
# Epoch 00075: val_loss did not improve from 0.60384
# Epoch 76/300
# 45/45 - 0s - loss: 0.5489 - accuracy: 0.7120 - val_loss: 0.6066 - val_accuracy: 0.6828
#
# Epoch 00076: val_loss did not improve from 0.60384
# Epoch 77/300
# 45/45 - 0s - loss: 0.5455 - accuracy: 0.7164 - val_loss: 0.5982 - val_accuracy: 0.6950
#
# Epoch 00077: val_loss improved from 0.60384 to 0.59824, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.h5
# Epoch 78/300
# 45/45 - 0s - loss: 0.5495 - accuracy: 0.7134 - val_loss: 0.6092 - val_accuracy: 0.6833
#
# Epoch 00078: val_loss did not improve from 0.59824
# Epoch 79/300
# 45/45 - 0s - loss: 0.5474 - accuracy: 0.7218 - val_loss: 0.6086 - val_accuracy: 0.6845
#
# Epoch 00079: val_loss did not improve from 0.59824
# Epoch 80/300
# 45/45 - 0s - loss: 0.5454 - accuracy: 0.7188 - val_loss: 0.6140 - val_accuracy: 0.6824
#
# Epoch 00080: val_loss did not improve from 0.59824
# Epoch 81/300
# 45/45 - 0s - loss: 0.5484 - accuracy: 0.7183 - val_loss: 0.6270 - val_accuracy: 0.6622
#
# Epoch 00081: val_loss did not improve from 0.59824
# Epoch 82/300
# 45/45 - 0s - loss: 0.5398 - accuracy: 0.7253 - val_loss: 0.6121 - val_accuracy: 0.6784
#
# Epoch 00082: val_loss did not improve from 0.59824
# Epoch 83/300
# 45/45 - 0s - loss: 0.5446 - accuracy: 0.7210 - val_loss: 0.6098 - val_accuracy: 0.6748
#
# Epoch 00083: val_loss did not improve from 0.59824
# Epoch 84/300
# 45/45 - 0s - loss: 0.5452 - accuracy: 0.7191 - val_loss: 0.6137 - val_accuracy: 0.6780
#
# Epoch 00084: val_loss did not improve from 0.59824
# Epoch 85/300
# 45/45 - 0s - loss: 0.5299 - accuracy: 0.7266 - val_loss: 0.6092 - val_accuracy: 0.6820
#
# Epoch 00085: val_loss did not improve from 0.59824
# Epoch 86/300
# 45/45 - 0s - loss: 0.5330 - accuracy: 0.7270 - val_loss: 0.6064 - val_accuracy: 0.6917
#
# Epoch 00086: val_loss did not improve from 0.59824
# Epoch 87/300
# 45/45 - 0s - loss: 0.5375 - accuracy: 0.7244 - val_loss: 0.6042 - val_accuracy: 0.6837
#
# Epoch 00087: val_loss did not improve from 0.59824
# Epoch 88/300
# 45/45 - 0s - loss: 0.5298 - accuracy: 0.7311 - val_loss: 0.6066 - val_accuracy: 0.6885
#
# Epoch 00088: val_loss did not improve from 0.59824
# Epoch 89/300
# 45/45 - 0s - loss: 0.5352 - accuracy: 0.7238 - val_loss: 0.6012 - val_accuracy: 0.6885
#
# Epoch 00089: val_loss did not improve from 0.59824
# Epoch 90/300
# 45/45 - 0s - loss: 0.5295 - accuracy: 0.7284 - val_loss: 0.6072 - val_accuracy: 0.6606
#
# Epoch 00090: val_loss did not improve from 0.59824
# Epoch 91/300
# 45/45 - 0s - loss: 0.5286 - accuracy: 0.7281 - val_loss: 0.6054 - val_accuracy: 0.6828
#
# Epoch 00091: val_loss did not improve from 0.59824
# Epoch 92/300
# 45/45 - 0s - loss: 0.5251 - accuracy: 0.7341 - val_loss: 0.6081 - val_accuracy: 0.6788
#
# Epoch 00092: val_loss did not improve from 0.59824
# Epoch 93/300
# 45/45 - 0s - loss: 0.5263 - accuracy: 0.7352 - val_loss: 0.6087 - val_accuracy: 0.6719
#
# Epoch 00093: val_loss did not improve from 0.59824
# Epoch 94/300
# 45/45 - 0s - loss: 0.5247 - accuracy: 0.7337 - val_loss: 0.6189 - val_accuracy: 0.6739
#
# Epoch 00094: val_loss did not improve from 0.59824
# Epoch 95/300
# 45/45 - 0s - loss: 0.5192 - accuracy: 0.7392 - val_loss: 0.6130 - val_accuracy: 0.6764
#
# Epoch 00095: val_loss did not improve from 0.59824
# Epoch 96/300
# 45/45 - 0s - loss: 0.5228 - accuracy: 0.7352 - val_loss: 0.6085 - val_accuracy: 0.6582
#
# Epoch 00096: val_loss did not improve from 0.59824
# Epoch 97/300
# 45/45 - 0s - loss: 0.5134 - accuracy: 0.7435 - val_loss: 0.6071 - val_accuracy: 0.6784
#
# Epoch 00097: val_loss did not improve from 0.59824
# Epoch 98/300
# 45/45 - 0s - loss: 0.5150 - accuracy: 0.7416 - val_loss: 0.6055 - val_accuracy: 0.6796
#
# Epoch 00098: val_loss did not improve from 0.59824
# Epoch 99/300
# 45/45 - 0s - loss: 0.5171 - accuracy: 0.7411 - val_loss: 0.6070 - val_accuracy: 0.6837
#
# Epoch 00099: val_loss did not improve from 0.59824
# Epoch 100/300
# 45/45 - 0s - loss: 0.5180 - accuracy: 0.7369 - val_loss: 0.6052 - val_accuracy: 0.6893
#
# Epoch 00100: val_loss did not improve from 0.59824
# Epoch 101/300
# 45/45 - 0s - loss: 0.5151 - accuracy: 0.7438 - val_loss: 0.6061 - val_accuracy: 0.6695
#
# Epoch 00101: val_loss did not improve from 0.59824
# Epoch 102/300
# 45/45 - 0s - loss: 0.5112 - accuracy: 0.7435 - val_loss: 0.6051 - val_accuracy: 0.6739
#
# Epoch 00102: val_loss did not improve from 0.59824
# Epoch 103/300
# 45/45 - 0s - loss: 0.5107 - accuracy: 0.7422 - val_loss: 0.6069 - val_accuracy: 0.6853
#
# Epoch 00103: val_loss did not improve from 0.59824
# Epoch 104/300
# 45/45 - 0s - loss: 0.5055 - accuracy: 0.7463 - val_loss: 0.6061 - val_accuracy: 0.6731
#
# Epoch 00104: val_loss did not improve from 0.59824
# Epoch 105/300
# 45/45 - 0s - loss: 0.5124 - accuracy: 0.7438 - val_loss: 0.6020 - val_accuracy: 0.6849
#
# Epoch 00105: val_loss did not improve from 0.59824
# Epoch 106/300
# 45/45 - 0s - loss: 0.5038 - accuracy: 0.7504 - val_loss: 0.5993 - val_accuracy: 0.6885
#
# Epoch 00106: val_loss did not improve from 0.59824
# Epoch 107/300
# 45/45 - 0s - loss: 0.5104 - accuracy: 0.7467 - val_loss: 0.6039 - val_accuracy: 0.6869
#
# Epoch 00107: val_loss did not improve from 0.59824
# Epoch 108/300
# 45/45 - 0s - loss: 0.5023 - accuracy: 0.7547 - val_loss: 0.6063 - val_accuracy: 0.6764
#
# Epoch 00108: val_loss did not improve from 0.59824
# Epoch 109/300
# 45/45 - 0s - loss: 0.5022 - accuracy: 0.7529 - val_loss: 0.6078 - val_accuracy: 0.6691
#
# Epoch 00109: val_loss did not improve from 0.59824
# Epoch 110/300
# 45/45 - 0s - loss: 0.4996 - accuracy: 0.7523 - val_loss: 0.6017 - val_accuracy: 0.6857
#
# Epoch 00110: val_loss did not improve from 0.59824
# Epoch 111/300
# 45/45 - 0s - loss: 0.5063 - accuracy: 0.7462 - val_loss: 0.6074 - val_accuracy: 0.6841
#
# Epoch 00111: val_loss did not improve from 0.59824
# Epoch 112/300
# 45/45 - 0s - loss: 0.5012 - accuracy: 0.7501 - val_loss: 0.6038 - val_accuracy: 0.6845
#
# Epoch 00112: val_loss did not improve from 0.59824
# Epoch 113/300
# 45/45 - 0s - loss: 0.4962 - accuracy: 0.7583 - val_loss: 0.6125 - val_accuracy: 0.6776
#
# Epoch 00113: val_loss did not improve from 0.59824
# Epoch 114/300
# 45/45 - 0s - loss: 0.4956 - accuracy: 0.7608 - val_loss: 0.6078 - val_accuracy: 0.6744
#
# Epoch 00114: val_loss did not improve from 0.59824
# Epoch 115/300
# 45/45 - 0s - loss: 0.5000 - accuracy: 0.7511 - val_loss: 0.5998 - val_accuracy: 0.6837
#
# Epoch 00115: val_loss did not improve from 0.59824
# Epoch 116/300
# 45/45 - 0s - loss: 0.4962 - accuracy: 0.7563 - val_loss: 0.6045 - val_accuracy: 0.6861
#
# Epoch 00116: val_loss did not improve from 0.59824
# Epoch 117/300
# 45/45 - 0s - loss: 0.4975 - accuracy: 0.7537 - val_loss: 0.6198 - val_accuracy: 0.6723
#
# Epoch 00117: val_loss did not improve from 0.59824
# Epoch 118/300
# 45/45 - 0s - loss: 0.4929 - accuracy: 0.7558 - val_loss: 0.6115 - val_accuracy: 0.6711
#
# Epoch 00118: val_loss did not improve from 0.59824
# Epoch 119/300
# 45/45 - 0s - loss: 0.4983 - accuracy: 0.7534 - val_loss: 0.6108 - val_accuracy: 0.6711
#
# Epoch 00119: val_loss did not improve from 0.59824
# Epoch 120/300
# 45/45 - 0s - loss: 0.4954 - accuracy: 0.7615 - val_loss: 0.6101 - val_accuracy: 0.6772
#
# Epoch 00120: val_loss did not improve from 0.59824
# Epoch 121/300
# 45/45 - 0s - loss: 0.4864 - accuracy: 0.7623 - val_loss: 0.6114 - val_accuracy: 0.6642
#
# Epoch 00121: val_loss did not improve from 0.59824
# Epoch 122/300
# 45/45 - 0s - loss: 0.4919 - accuracy: 0.7566 - val_loss: 0.6082 - val_accuracy: 0.6739
#
# Epoch 00122: val_loss did not improve from 0.59824
# Epoch 123/300
# 45/45 - 0s - loss: 0.4888 - accuracy: 0.7572 - val_loss: 0.6036 - val_accuracy: 0.6752
#
# Epoch 00123: val_loss did not improve from 0.59824
# Epoch 124/300
# 45/45 - 0s - loss: 0.4776 - accuracy: 0.7654 - val_loss: 0.6054 - val_accuracy: 0.6679
#
# Epoch 00124: val_loss did not improve from 0.59824
# Epoch 125/300
# 45/45 - 0s - loss: 0.4860 - accuracy: 0.7645 - val_loss: 0.6075 - val_accuracy: 0.6909
#
# Epoch 00125: val_loss did not improve from 0.59824
# Epoch 126/300
# 45/45 - 0s - loss: 0.4845 - accuracy: 0.7637 - val_loss: 0.6055 - val_accuracy: 0.6691
#
# Epoch 00126: val_loss did not improve from 0.59824
# Epoch 127/300
# 45/45 - 0s - loss: 0.4845 - accuracy: 0.7641 - val_loss: 0.6112 - val_accuracy: 0.6731
#
# Epoch 00127: val_loss did not improve from 0.59824
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6112 - accuracy: 0.6731
# Independent test: [0.6112220287322998, 0.6731391549110413]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\5k\K_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.8058252427184466,
#  'SP': 0.540453074433657,
#  'ACC': 0.6731391585760518,
#  'MCC': 0.35915545775305247,
#  'Recall': 0.8058252427184466,
#  'Precision': 0.6368286445012787,
#  'F1-score': 0.7114285714285714,
#  'Cutoff': 0.5}

# %%
fpr, tpr, thresholds = roc_curve(y_true, pred)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, lw=1, alpha=0.7, label='ROC (AUC = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Random', alpha=.8)
plt.xlim([0, 1.0])
plt.ylim([0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('CNN_OH_val.png')
plt.show()
