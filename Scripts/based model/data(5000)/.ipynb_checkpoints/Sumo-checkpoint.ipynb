# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    #base_learning_rate = 0.0001
    #network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew\data\based\Sumo\处理过程')
    epoch = 300
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Paper\data\based_model_data\原数据\训练集\K_NEDD\41window')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=128)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 41, 128)           2816
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 20, 128)           49280
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 10, 128)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 5, 128)            0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5, 128)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_3 ( (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 89/89 - 1s - loss: 0.6954 - accuracy: 0.5018 - val_loss: 0.6931 - val_accuracy: 0.5034
#
# Epoch 00001: val_loss improved from inf to 0.69313, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.h5
# Epoch 2/300
# 89/89 - 1s - loss: 0.6893 - accuracy: 0.5278 - val_loss: 0.6942 - val_accuracy: 0.5085
#
# Epoch 00002: val_loss did not improve from 0.69313
# Epoch 3/300
# 89/89 - 1s - loss: 0.6861 - accuracy: 0.5404 - val_loss: 0.6975 - val_accuracy: 0.5017
#
# Epoch 00003: val_loss did not improve from 0.69313
# Epoch 4/300
# 89/89 - 1s - loss: 0.6784 - accuracy: 0.5723 - val_loss: 0.6922 - val_accuracy: 0.5161
#
# Epoch 00004: val_loss improved from 0.69313 to 0.69223, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.h5
# Epoch 5/300
# 89/89 - 1s - loss: 0.6733 - accuracy: 0.5831 - val_loss: 0.6970 - val_accuracy: 0.5136
#
# Epoch 00005: val_loss did not improve from 0.69223
# Epoch 6/300
# 89/89 - 1s - loss: 0.6586 - accuracy: 0.5995 - val_loss: 0.6890 - val_accuracy: 0.5402
#
# Epoch 00006: val_loss improved from 0.69223 to 0.68905, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.h5
# Epoch 7/300
# 89/89 - 1s - loss: 0.6508 - accuracy: 0.6136 - val_loss: 0.6914 - val_accuracy: 0.5495
#
# Epoch 00007: val_loss did not improve from 0.68905
# Epoch 8/300
# 89/89 - 1s - loss: 0.6413 - accuracy: 0.6228 - val_loss: 0.7045 - val_accuracy: 0.5233
#
# Epoch 00008: val_loss did not improve from 0.68905
# Epoch 9/300
# 89/89 - 1s - loss: 0.6358 - accuracy: 0.6337 - val_loss: 0.6896 - val_accuracy: 0.5440
#
# Epoch 00009: val_loss did not improve from 0.68905
# Epoch 10/300
# 89/89 - 1s - loss: 0.6263 - accuracy: 0.6388 - val_loss: 0.6831 - val_accuracy: 0.5475
#
# Epoch 00010: val_loss improved from 0.68905 to 0.68308, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.h5
# Epoch 11/300
# 89/89 - 1s - loss: 0.6275 - accuracy: 0.6391 - val_loss: 0.6775 - val_accuracy: 0.5588
#
# Epoch 00011: val_loss improved from 0.68308 to 0.67750, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.h5
# Epoch 12/300
# 89/89 - 1s - loss: 0.6181 - accuracy: 0.6524 - val_loss: 0.6912 - val_accuracy: 0.5489
#
# Epoch 00012: val_loss did not improve from 0.67750
# Epoch 13/300
# 89/89 - 1s - loss: 0.6185 - accuracy: 0.6490 - val_loss: 0.7020 - val_accuracy: 0.5357
#
# Epoch 00013: val_loss did not improve from 0.67750
# Epoch 14/300
# 89/89 - 1s - loss: 0.6132 - accuracy: 0.6585 - val_loss: 0.6748 - val_accuracy: 0.5694
#
# Epoch 00014: val_loss improved from 0.67750 to 0.67484, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.h5
# Epoch 15/300
# 89/89 - 1s - loss: 0.6077 - accuracy: 0.6572 - val_loss: 0.6790 - val_accuracy: 0.5662
#
# Epoch 00015: val_loss did not improve from 0.67484
# Epoch 16/300
# 89/89 - 1s - loss: 0.6044 - accuracy: 0.6666 - val_loss: 0.6738 - val_accuracy: 0.5681
#
# Epoch 00016: val_loss improved from 0.67484 to 0.67377, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.h5
# Epoch 17/300
# 89/89 - 1s - loss: 0.6049 - accuracy: 0.6633 - val_loss: 0.6769 - val_accuracy: 0.5665
#
# Epoch 00017: val_loss did not improve from 0.67377
# Epoch 18/300
# 89/89 - 1s - loss: 0.6002 - accuracy: 0.6661 - val_loss: 0.6765 - val_accuracy: 0.5658
#
# Epoch 00018: val_loss did not improve from 0.67377
# Epoch 19/300
# 89/89 - 1s - loss: 0.5980 - accuracy: 0.6724 - val_loss: 0.6878 - val_accuracy: 0.5564
#
# Epoch 00019: val_loss did not improve from 0.67377
# Epoch 20/300
# 89/89 - 1s - loss: 0.5982 - accuracy: 0.6700 - val_loss: 0.6974 - val_accuracy: 0.5469
#
# Epoch 00020: val_loss did not improve from 0.67377
# Epoch 21/300
# 89/89 - 1s - loss: 0.5907 - accuracy: 0.6842 - val_loss: 0.6778 - val_accuracy: 0.5725
#
# Epoch 00021: val_loss did not improve from 0.67377
# Epoch 22/300
# 89/89 - 1s - loss: 0.5900 - accuracy: 0.6809 - val_loss: 0.6689 - val_accuracy: 0.5844
#
# Epoch 00022: val_loss improved from 0.67377 to 0.66892, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.h5
# Epoch 23/300
# 89/89 - 1s - loss: 0.5919 - accuracy: 0.6762 - val_loss: 0.6756 - val_accuracy: 0.5675
#
# Epoch 00023: val_loss did not improve from 0.66892
# Epoch 24/300
# 89/89 - 1s - loss: 0.5862 - accuracy: 0.6812 - val_loss: 0.6833 - val_accuracy: 0.5571
#
# Epoch 00024: val_loss did not improve from 0.66892
# Epoch 25/300
# 89/89 - 1s - loss: 0.5842 - accuracy: 0.6865 - val_loss: 0.6913 - val_accuracy: 0.5619
#
# Epoch 00025: val_loss did not improve from 0.66892
# Epoch 26/300
# 89/89 - 1s - loss: 0.5841 - accuracy: 0.6812 - val_loss: 0.6795 - val_accuracy: 0.5689
#
# Epoch 00026: val_loss did not improve from 0.66892
# Epoch 27/300
# 89/89 - 1s - loss: 0.5767 - accuracy: 0.6916 - val_loss: 0.6759 - val_accuracy: 0.5794
#
# Epoch 00027: val_loss did not improve from 0.66892
# Epoch 28/300
# 89/89 - 1s - loss: 0.5757 - accuracy: 0.6932 - val_loss: 0.6718 - val_accuracy: 0.5823
#
# Epoch 00028: val_loss did not improve from 0.66892
# Epoch 29/300
# 89/89 - 1s - loss: 0.5720 - accuracy: 0.6960 - val_loss: 0.6737 - val_accuracy: 0.5932
#
# Epoch 00029: val_loss did not improve from 0.66892
# Epoch 30/300
# 89/89 - 1s - loss: 0.5738 - accuracy: 0.6940 - val_loss: 0.6729 - val_accuracy: 0.5844
#
# Epoch 00030: val_loss did not improve from 0.66892
# Epoch 31/300
# 89/89 - 1s - loss: 0.5695 - accuracy: 0.6997 - val_loss: 0.6741 - val_accuracy: 0.5733
#
# Epoch 00031: val_loss did not improve from 0.66892
# Epoch 32/300
# 89/89 - 1s - loss: 0.5698 - accuracy: 0.6982 - val_loss: 0.6708 - val_accuracy: 0.5821
#
# Epoch 00032: val_loss did not improve from 0.66892
# Epoch 33/300
# 89/89 - 1s - loss: 0.5664 - accuracy: 0.7019 - val_loss: 0.6740 - val_accuracy: 0.5778
#
# Epoch 00033: val_loss did not improve from 0.66892
# Epoch 34/300
# 89/89 - 1s - loss: 0.5596 - accuracy: 0.7062 - val_loss: 0.6950 - val_accuracy: 0.5635
#
# Epoch 00034: val_loss did not improve from 0.66892
# Epoch 35/300
# 89/89 - 1s - loss: 0.5648 - accuracy: 0.7036 - val_loss: 0.6748 - val_accuracy: 0.5890
#
# Epoch 00035: val_loss did not improve from 0.66892
# Epoch 36/300
# 89/89 - 1s - loss: 0.5608 - accuracy: 0.7074 - val_loss: 0.6754 - val_accuracy: 0.5826
# Epoch 00036: val_loss did not improve from 0.66892
# Epoch 37/300
# 89/89 - 1s - loss: 0.5554 - accuracy: 0.7083 - val_loss: 0.6811 - val_accuracy: 0.5691
#
# Epoch 00037: val_loss did not improve from 0.66892
# Epoch 38/300
# 89/89 - 1s - loss: 0.5556 - accuracy: 0.7079 - val_loss: 0.6790 - val_accuracy: 0.5725
#
# Epoch 00038: val_loss did not improve from 0.66892
# Epoch 39/300
# 89/89 - 1s - loss: 0.5481 - accuracy: 0.7118 - val_loss: 0.6800 - val_accuracy: 0.5779
#
# Epoch 00039: val_loss did not improve from 0.66892
# Epoch 40/300
# 89/89 - 1s - loss: 0.5521 - accuracy: 0.7133 - val_loss: 0.6897 - val_accuracy: 0.5708
#
# Epoch 00040: val_loss did not improve from 0.66892
# Epoch 41/300
# 89/89 - 1s - loss: 0.5480 - accuracy: 0.7150 - val_loss: 0.6886 - val_accuracy: 0.5677
#
# Epoch 00041: val_loss did not improve from 0.66892
# Epoch 42/300
# 89/89 - 1s - loss: 0.5475 - accuracy: 0.7151 - val_loss: 0.6741 - val_accuracy: 0.5872
#
# Epoch 00042: val_loss did not improve from 0.66892
# Epoch 43/300
# 89/89 - 1s - loss: 0.5386 - accuracy: 0.7277 - val_loss: 0.6820 - val_accuracy: 0.5749
#
# Epoch 00043: val_loss did not improve from 0.66892
# Epoch 44/300
# 89/89 - 1s - loss: 0.5465 - accuracy: 0.7170 - val_loss: 0.6904 - val_accuracy: 0.5742
#
# Epoch 00044: val_loss did not improve from 0.66892
# Epoch 45/300
# 89/89 - 1s - loss: 0.5456 - accuracy: 0.7204 - val_loss: 0.6778 - val_accuracy: 0.5766
#
# Epoch 00045: val_loss did not improve from 0.66892
# Epoch 46/300
# 89/89 - 1s - loss: 0.5306 - accuracy: 0.7342 - val_loss: 0.6834 - val_accuracy: 0.5758
#
# Epoch 00046: val_loss did not improve from 0.66892
# Epoch 47/300
# 89/89 - 1s - loss: 0.5347 - accuracy: 0.7276 - val_loss: 0.6833 - val_accuracy: 0.5743
#
# Epoch 00047: val_loss did not improve from 0.66892
# Epoch 48/300
# 89/89 - 1s - loss: 0.5369 - accuracy: 0.7281 - val_loss: 0.6870 - val_accuracy: 0.5744
#
# Epoch 00048: val_loss did not improve from 0.66892
# Epoch 49/300
# 89/89 - 1s - loss: 0.5267 - accuracy: 0.7298 - val_loss: 0.6882 - val_accuracy: 0.5779
#
# Epoch 00049: val_loss did not improve from 0.66892
# Epoch 50/300
# 89/89 - 1s - loss: 0.5259 - accuracy: 0.7264 - val_loss: 0.6868 - val_accuracy: 0.5736
#
# Epoch 00050: val_loss did not improve from 0.66892
# Epoch 51/300
# 89/89 - 1s - loss: 0.5288 - accuracy: 0.7290 - val_loss: 0.6881 - val_accuracy: 0.5767
#
# Epoch 00051: val_loss did not improve from 0.66892
# Epoch 52/300
# 89/89 - 1s - loss: 0.5237 - accuracy: 0.7318 - val_loss: 0.6728 - val_accuracy: 0.5936
#
# Epoch 00052: val_loss did not improve from 0.66892
# Epoch 53/300
# 89/89 - 1s - loss: 0.5236 - accuracy: 0.7359 - val_loss: 0.6823 - val_accuracy: 0.5812
#
# Epoch 00053: val_loss did not improve from 0.66892
# Epoch 54/300
# 89/89 - 1s - loss: 0.5202 - accuracy: 0.7374 - val_loss: 0.6835 - val_accuracy: 0.5770
#
# Epoch 00054: val_loss did not improve from 0.66892
# Epoch 55/300
# 89/89 - 1s - loss: 0.5181 - accuracy: 0.7393 - val_loss: 0.6821 - val_accuracy: 0.5782
#
# Epoch 00055: val_loss did not improve from 0.66892
# Epoch 56/300
# 89/89 - 1s - loss: 0.5173 - accuracy: 0.7359 - val_loss: 0.6866 - val_accuracy: 0.5775
#
# Epoch 00056: val_loss did not improve from 0.66892
# Epoch 57/300
# 89/89 - 1s - loss: 0.5101 - accuracy: 0.7451 - val_loss: 0.6800 - val_accuracy: 0.5866
#
# Epoch 00057: val_loss did not improve from 0.66892
# Epoch 58/300
# 89/89 - 1s - loss: 0.5117 - accuracy: 0.7450 - val_loss: 0.6864 - val_accuracy: 0.5826
#
# Epoch 00058: val_loss did not improve from 0.66892
# Epoch 59/300
# 89/89 - 1s - loss: 0.5106 - accuracy: 0.7481 - val_loss: 0.6855 - val_accuracy: 0.5785
#
# Epoch 00059: val_loss did not improve from 0.66892
# Epoch 60/300
# 89/89 - 1s - loss: 0.5093 - accuracy: 0.7401 - val_loss: 0.6828 - val_accuracy: 0.5755
#
# Epoch 00060: val_loss did not improve from 0.66892
# Epoch 61/300
# 89/89 - 1s - loss: 0.5028 - accuracy: 0.7491 - val_loss: 0.6849 - val_accuracy: 0.5787
#
# Epoch 00061: val_loss did not improve from 0.66892
# Epoch 62/300
# 89/89 - 1s - loss: 0.5057 - accuracy: 0.7486 - val_loss: 0.6983 - val_accuracy: 0.5672
#
# Epoch 00062: val_loss did not improve from 0.66892
# Epoch 63/300
# 89/89 - 1s - loss: 0.5026 - accuracy: 0.7523 - val_loss: 0.6848 - val_accuracy: 0.5786
#
# Epoch 00063: val_loss did not improve from 0.66892
# Epoch 64/300
# 89/89 - 1s - loss: 0.5047 - accuracy: 0.7427 - val_loss: 0.6911 - val_accuracy: 0.5714
#
# Epoch 00064: val_loss did not improve from 0.66892
# Epoch 65/300
# 89/89 - 1s - loss: 0.4972 - accuracy: 0.7520 - val_loss: 0.6892 - val_accuracy: 0.5798
#
# Epoch 00065: val_loss did not improve from 0.66892
# Epoch 66/300
# 89/89 - 1s - loss: 0.4960 - accuracy: 0.7522 - val_loss: 0.6864 - val_accuracy: 0.5834
#
# Epoch 00066: val_loss did not improve from 0.66892
# Epoch 67/300
# 89/89 - 1s - loss: 0.4918 - accuracy: 0.7543 - val_loss: 0.7016 - val_accuracy: 0.5705
#
# Epoch 00067: val_loss did not improve from 0.66892
# Epoch 68/300
# 89/89 - 1s - loss: 0.4931 - accuracy: 0.7575 - val_loss: 0.6779 - val_accuracy: 0.5839
#
# Epoch 00068: val_loss did not improve from 0.66892
# Epoch 69/300
# 89/89 - 1s - loss: 0.4890 - accuracy: 0.7580 - val_loss: 0.6750 - val_accuracy: 0.5925
#
# Epoch 00069: val_loss did not improve from 0.66892
# Epoch 70/300
# 89/89 - 1s - loss: 0.4913 - accuracy: 0.7598 - val_loss: 0.6901 - val_accuracy: 0.5711
#
# Epoch 00070: val_loss did not improve from 0.66892
# Epoch 71/300
# 89/89 - 1s - loss: 0.4839 - accuracy: 0.7612 - val_loss: 0.6861 - val_accuracy: 0.5831
#
# Epoch 00071: val_loss did not improve from 0.66892
# Epoch 72/300
# 89/89 - 1s - loss: 0.4973 - accuracy: 0.7539 - val_loss: 0.6919 - val_accuracy: 0.5750
#
# Epoch 00072: val_loss did not improve from 0.66892
# 114/114 [==============================] - 0s 3ms/step - loss: 0.6919 - accuracy: 0.5750
# Independent test: [0.6918883919715881, 0.5749965310096741]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Sumo_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.3778725746525389,
#  'SP': 0.7721205449291317,
#  'ACC': 0.5749965597908353,
#  'MCC': 0.16321267706398115,
#  'Recall': 0.3778725746525389,
#  'Precision': 0.6238073602907769,
#  'F1-score': 0.4706487273973777,
#  'Cutoff': 0.5}
