# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\5k\Acet_Ubi\UbidelAcet')
    epoch = 300
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\NEDD')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 45/45 - 5s - loss: 0.6935 - accuracy: 0.5192 - val_loss: 0.6926 - val_accuracy: 0.5239
#
# Epoch 00001: val_loss improved from inf to 0.69258, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 2/300
# 45/45 - 0s - loss: 0.6841 - accuracy: 0.5545 - val_loss: 0.6894 - val_accuracy: 0.5287
#
# Epoch 00002: val_loss improved from 0.69258 to 0.68942, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 3/300
# 45/45 - 0s - loss: 0.6763 - accuracy: 0.5691 - val_loss: 0.6999 - val_accuracy: 0.4891
#
# Epoch 00003: val_loss did not improve from 0.68942
# Epoch 4/300
# 45/45 - 0s - loss: 0.6753 - accuracy: 0.5701 - val_loss: 0.6884 - val_accuracy: 0.5182
#
# Epoch 00004: val_loss improved from 0.68942 to 0.68837, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 5/300
# 45/45 - 0s - loss: 0.6720 - accuracy: 0.5759 - val_loss: 0.6907 - val_accuracy: 0.5405
#
# Epoch 00005: val_loss did not improve from 0.68837
# Epoch 6/300
# 45/45 - 0s - loss: 0.6726 - accuracy: 0.5786 - val_loss: 0.6855 - val_accuracy: 0.5222
#
# Epoch 00006: val_loss improved from 0.68837 to 0.68551, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 7/300
# 45/45 - 0s - loss: 0.6693 - accuracy: 0.5842 - val_loss: 0.6879 - val_accuracy: 0.5121
#
# Epoch 00007: val_loss did not improve from 0.68551
# Epoch 8/300
# 45/45 - 0s - loss: 0.6668 - accuracy: 0.5893 - val_loss: 0.6913 - val_accuracy: 0.5372
#
# Epoch 00008: val_loss did not improve from 0.68551
# Epoch 9/300
# 45/45 - 0s - loss: 0.6658 - accuracy: 0.5938 - val_loss: 0.6865 - val_accuracy: 0.5425
#
# Epoch 00009: val_loss did not improve from 0.68551
# Epoch 10/300
# 45/45 - 0s - loss: 0.6656 - accuracy: 0.5898 - val_loss: 0.6908 - val_accuracy: 0.5465
#
# Epoch 00010: val_loss did not improve from 0.68551
# Epoch 11/300
# 45/45 - 0s - loss: 0.6623 - accuracy: 0.5914 - val_loss: 0.6807 - val_accuracy: 0.5392
#
# Epoch 00011: val_loss improved from 0.68551 to 0.68069, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 12/300
# 45/45 - 0s - loss: 0.6616 - accuracy: 0.5964 - val_loss: 0.6813 - val_accuracy: 0.5376
#
# Epoch 00012: val_loss did not improve from 0.68069
# Epoch 13/300
# 45/45 - 0s - loss: 0.6594 - accuracy: 0.6009 - val_loss: 0.6758 - val_accuracy: 0.5534
#
# Epoch 00013: val_loss improved from 0.68069 to 0.67578, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 14/300
# 45/45 - 0s - loss: 0.6592 - accuracy: 0.5929 - val_loss: 0.6745 - val_accuracy: 0.5546
#
# Epoch 00014: val_loss improved from 0.67578 to 0.67450, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 15/300
# 45/45 - 0s - loss: 0.6558 - accuracy: 0.6050 - val_loss: 0.6906 - val_accuracy: 0.5198
#
# Epoch 00015: val_loss did not improve from 0.67450
# Epoch 16/300
# 45/45 - 0s - loss: 0.6536 - accuracy: 0.6035 - val_loss: 0.6697 - val_accuracy: 0.5720
#
# Epoch 00016: val_loss improved from 0.67450 to 0.66973, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 17/300
# 45/45 - 0s - loss: 0.6495 - accuracy: 0.6165 - val_loss: 0.6696 - val_accuracy: 0.5898
#
# Epoch 00017: val_loss improved from 0.66973 to 0.66963, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 18/300
# 45/45 - 0s - loss: 0.6482 - accuracy: 0.6208 - val_loss: 0.6640 - val_accuracy: 0.6015
#
# Epoch 00018: val_loss improved from 0.66963 to 0.66398, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 19/300
# 45/45 - 0s - loss: 0.6449 - accuracy: 0.6230 - val_loss: 0.6637 - val_accuracy: 0.5740
#
# Epoch 00019: val_loss improved from 0.66398 to 0.66370, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 20/300
# 45/45 - 0s - loss: 0.6432 - accuracy: 0.6251 - val_loss: 0.6598 - val_accuracy: 0.5934
#
# Epoch 00020: val_loss improved from 0.66370 to 0.65982, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 21/300
# 45/45 - 0s - loss: 0.6411 - accuracy: 0.6291 - val_loss: 0.6580 - val_accuracy: 0.6193
#
# Epoch 00021: val_loss improved from 0.65982 to 0.65799, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 22/300
# 45/45 - 0s - loss: 0.6362 - accuracy: 0.6317 - val_loss: 0.6542 - val_accuracy: 0.6141
#
# Epoch 00022: val_loss improved from 0.65799 to 0.65423, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 23/300
# 45/45 - 0s - loss: 0.6359 - accuracy: 0.6365 - val_loss: 0.6668 - val_accuracy: 0.5716
#
# Epoch 00023: val_loss did not improve from 0.65423
# Epoch 24/300
# 45/45 - 0s - loss: 0.6339 - accuracy: 0.6336 - val_loss: 0.6664 - val_accuracy: 0.5902
#
# Epoch 00024: val_loss did not improve from 0.65423
# Epoch 25/300
# 45/45 - 0s - loss: 0.6310 - accuracy: 0.6411 - val_loss: 0.6607 - val_accuracy: 0.6145
#
# Epoch 00025: val_loss did not improve from 0.65423
# Epoch 26/300
# 45/45 - 0s - loss: 0.6251 - accuracy: 0.6469 - val_loss: 0.6622 - val_accuracy: 0.6218
#
# Epoch 00026: val_loss did not improve from 0.65423
# Epoch 27/300
# 45/45 - 0s - loss: 0.6306 - accuracy: 0.6409 - val_loss: 0.6545 - val_accuracy: 0.6197
#
# Epoch 00027: val_loss did not improve from 0.65423
# Epoch 28/300
# 45/45 - 0s - loss: 0.6264 - accuracy: 0.6443 - val_loss: 0.6570 - val_accuracy: 0.6060
#
# Epoch 00028: val_loss did not improve from 0.65423
# Epoch 29/300
# 45/45 - 0s - loss: 0.6222 - accuracy: 0.6520 - val_loss: 0.6604 - val_accuracy: 0.6266
#
# Epoch 00029: val_loss did not improve from 0.65423
# Epoch 30/300
# 45/45 - 0s - loss: 0.6215 - accuracy: 0.6569 - val_loss: 0.6598 - val_accuracy: 0.6234
#
# Epoch 00030: val_loss did not improve from 0.65423
# Epoch 31/300
# 45/45 - 0s - loss: 0.6186 - accuracy: 0.6554 - val_loss: 0.6494 - val_accuracy: 0.6258
#
# Epoch 00031: val_loss improved from 0.65423 to 0.64939, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 32/300
# 45/45 - 0s - loss: 0.6191 - accuracy: 0.6539 - val_loss: 0.6625 - val_accuracy: 0.6108
#
# Epoch 00032: val_loss did not improve from 0.64939
# Epoch 33/300
# 45/45 - 0s - loss: 0.6152 - accuracy: 0.6628 - val_loss: 0.6484 - val_accuracy: 0.6068
#
# Epoch 00033: val_loss improved from 0.64939 to 0.64835, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 34/300
# 45/45 - 0s - loss: 0.6125 - accuracy: 0.6598 - val_loss: 0.6429 - val_accuracy: 0.6307
#
# Epoch 00034: val_loss improved from 0.64835 to 0.64290, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 35/300
# 45/45 - 0s - loss: 0.6089 - accuracy: 0.6601 - val_loss: 0.6508 - val_accuracy: 0.6100
#
# Epoch 00035: val_loss did not improve from 0.64290
# Epoch 36/300
# 45/45 - 0s - loss: 0.6105 - accuracy: 0.6643 - val_loss: 0.6572 - val_accuracy: 0.5934
#
# Epoch 00036: val_loss did not improve from 0.64290
# Epoch 37/300
# 45/45 - 0s - loss: 0.6044 - accuracy: 0.6682 - val_loss: 0.6502 - val_accuracy: 0.6367
#
# Epoch 00037: val_loss did not improve from 0.64290
# Epoch 38/300
# 45/45 - 0s - loss: 0.6094 - accuracy: 0.6632 - val_loss: 0.6623 - val_accuracy: 0.5878
#
# Epoch 00038: val_loss did not improve from 0.64290
# Epoch 39/300
# 45/45 - 0s - loss: 0.6052 - accuracy: 0.6658 - val_loss: 0.6513 - val_accuracy: 0.6108
#
# Epoch 00039: val_loss did not improve from 0.64290
# Epoch 40/300
# 45/45 - 0s - loss: 0.5993 - accuracy: 0.6734 - val_loss: 0.6589 - val_accuracy: 0.5975
#
# Epoch 00040: val_loss did not improve from 0.64290
# Epoch 41/300
# 45/45 - 0s - loss: 0.6069 - accuracy: 0.6688 - val_loss: 0.6521 - val_accuracy: 0.6266
#
# Epoch 00041: val_loss did not improve from 0.64290
# Epoch 42/300
# 45/45 - 0s - loss: 0.6008 - accuracy: 0.6687 - val_loss: 0.6472 - val_accuracy: 0.6206
#
# Epoch 00042: val_loss did not improve from 0.64290
# Epoch 43/300
# 45/45 - 0s - loss: 0.5975 - accuracy: 0.6734 - val_loss: 0.6518 - val_accuracy: 0.6044
#
# Epoch 00043: val_loss did not improve from 0.64290
# Epoch 44/300
# 45/45 - 0s - loss: 0.5961 - accuracy: 0.6748 - val_loss: 0.6514 - val_accuracy: 0.6371
#
# Epoch 00044: val_loss did not improve from 0.64290
# Epoch 45/300
# 45/45 - 0s - loss: 0.5972 - accuracy: 0.6766 - val_loss: 0.6596 - val_accuracy: 0.6137
#
# Epoch 00045: val_loss did not improve from 0.64290
# Epoch 46/300
# 45/45 - 0s - loss: 0.5932 - accuracy: 0.6816 - val_loss: 0.6438 - val_accuracy: 0.6404
#
# Epoch 00046: val_loss did not improve from 0.64290
# Epoch 47/300
# 45/45 - 0s - loss: 0.5884 - accuracy: 0.6821 - val_loss: 0.6820 - val_accuracy: 0.5550
#
# Epoch 00047: val_loss did not improve from 0.64290
# Epoch 48/300
# 45/45 - 0s - loss: 0.5915 - accuracy: 0.6808 - val_loss: 0.6488 - val_accuracy: 0.6129
#
# Epoch 00048: val_loss did not improve from 0.64290
# Epoch 49/300
# 45/45 - 0s - loss: 0.5904 - accuracy: 0.6873 - val_loss: 0.6502 - val_accuracy: 0.6137
#
# Epoch 00049: val_loss did not improve from 0.64290
# Epoch 50/300
# 45/45 - 0s - loss: 0.5895 - accuracy: 0.6816 - val_loss: 0.6525 - val_accuracy: 0.6056
#
# Epoch 00050: val_loss did not improve from 0.64290
# Epoch 51/300
# 45/45 - 0s - loss: 0.5814 - accuracy: 0.6908 - val_loss: 0.6577 - val_accuracy: 0.5939
#
# Epoch 00051: val_loss did not improve from 0.64290
# Epoch 52/300
# 45/45 - 0s - loss: 0.5836 - accuracy: 0.6903 - val_loss: 0.6494 - val_accuracy: 0.6238
#
# Epoch 00052: val_loss did not improve from 0.64290
# Epoch 53/300
# 45/45 - 0s - loss: 0.5787 - accuracy: 0.6907 - val_loss: 0.6451 - val_accuracy: 0.6173
#
# Epoch 00053: val_loss did not improve from 0.64290
# Epoch 54/300
# 45/45 - 0s - loss: 0.5808 - accuracy: 0.6933 - val_loss: 0.6445 - val_accuracy: 0.6157
#
# Epoch 00054: val_loss did not improve from 0.64290
# Epoch 55/300
# 45/45 - 0s - loss: 0.5752 - accuracy: 0.6957 - val_loss: 0.6464 - val_accuracy: 0.6112
#
# Epoch 00055: val_loss did not improve from 0.64290
# Epoch 56/300
# 45/45 - 0s - loss: 0.5723 - accuracy: 0.7016 - val_loss: 0.6555 - val_accuracy: 0.6052
#
# Epoch 00056: val_loss did not improve from 0.64290
# Epoch 57/300
# 45/45 - 0s - loss: 0.5758 - accuracy: 0.6902 - val_loss: 0.6326 - val_accuracy: 0.6424
#
# Epoch 00057: val_loss improved from 0.64290 to 0.63260, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 58/300
# 45/45 - 0s - loss: 0.5737 - accuracy: 0.6955 - val_loss: 0.6594 - val_accuracy: 0.5918
#
# Epoch 00058: val_loss did not improve from 0.63260
# Epoch 59/300
# 45/45 - 0s - loss: 0.5696 - accuracy: 0.7061 - val_loss: 0.6396 - val_accuracy: 0.6238
#
# Epoch 00059: val_loss did not improve from 0.63260
# Epoch 60/300
# 45/45 - 0s - loss: 0.5672 - accuracy: 0.7021 - val_loss: 0.6402 - val_accuracy: 0.6375
#
# Epoch 00060: val_loss did not improve from 0.63260
# Epoch 61/300
# 45/45 - 0s - loss: 0.5698 - accuracy: 0.6991 - val_loss: 0.6517 - val_accuracy: 0.6064
#
# Epoch 00061: val_loss did not improve from 0.63260
# Epoch 62/300
# 45/45 - 0s - loss: 0.5668 - accuracy: 0.6999 - val_loss: 0.6632 - val_accuracy: 0.5854
#
# Epoch 00062: val_loss did not improve from 0.63260
# Epoch 63/300
# 45/45 - 0s - loss: 0.5689 - accuracy: 0.7042 - val_loss: 0.6384 - val_accuracy: 0.6258
#
# Epoch 00063: val_loss did not improve from 0.63260
# Epoch 64/300
# 45/45 - 0s - loss: 0.5582 - accuracy: 0.7122 - val_loss: 0.6284 - val_accuracy: 0.6404
#
# Epoch 00064: val_loss improved from 0.63260 to 0.62838, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 65/300
# 45/45 - 0s - loss: 0.5589 - accuracy: 0.7090 - val_loss: 0.6347 - val_accuracy: 0.6282
#
# Epoch 00065: val_loss did not improve from 0.62838
# Epoch 66/300
# 45/45 - 0s - loss: 0.5553 - accuracy: 0.7091 - val_loss: 0.6881 - val_accuracy: 0.5805
#
# Epoch 00066: val_loss did not improve from 0.62838
# Epoch 67/300
# 45/45 - 0s - loss: 0.5527 - accuracy: 0.7148 - val_loss: 0.6440 - val_accuracy: 0.6311
#
# Epoch 00067: val_loss did not improve from 0.62838
# Epoch 68/300
# 45/45 - 0s - loss: 0.5547 - accuracy: 0.7101 - val_loss: 0.6404 - val_accuracy: 0.6210
#
# Epoch 00068: val_loss did not improve from 0.62838
# Epoch 69/300
# 45/45 - 0s - loss: 0.5538 - accuracy: 0.7136 - val_loss: 0.6293 - val_accuracy: 0.6363
#
# Epoch 00069: val_loss did not improve from 0.62838
# Epoch 70/300
# 45/45 - 0s - loss: 0.5512 - accuracy: 0.7133 - val_loss: 0.6342 - val_accuracy: 0.6404
#
# Epoch 00070: val_loss did not improve from 0.62838
# Epoch 71/300
# 45/45 - 0s - loss: 0.5531 - accuracy: 0.7171 - val_loss: 0.6461 - val_accuracy: 0.6137
#
# Epoch 00071: val_loss did not improve from 0.62838
# Epoch 72/300
# 45/45 - 0s - loss: 0.5484 - accuracy: 0.7148 - val_loss: 0.6413 - val_accuracy: 0.6133
#
# Epoch 00072: val_loss did not improve from 0.62838
# Epoch 73/300
# 45/45 - 0s - loss: 0.5474 - accuracy: 0.7262 - val_loss: 0.6451 - val_accuracy: 0.6125
#
# Epoch 00073: val_loss did not improve from 0.62838
# Epoch 74/300
# 45/45 - 0s - loss: 0.5492 - accuracy: 0.7141 - val_loss: 0.6420 - val_accuracy: 0.6149
#
# Epoch 00074: val_loss did not improve from 0.62838
# Epoch 75/300
# 45/45 - 0s - loss: 0.5476 - accuracy: 0.7171 - val_loss: 0.6438 - val_accuracy: 0.6108
#
# Epoch 00075: val_loss did not improve from 0.62838
# Epoch 76/300
# 45/45 - 0s - loss: 0.5400 - accuracy: 0.7265 - val_loss: 0.6426 - val_accuracy: 0.6262
#
# Epoch 00076: val_loss did not improve from 0.62838
# Epoch 77/300
# 45/45 - 0s - loss: 0.5453 - accuracy: 0.7218 - val_loss: 0.6343 - val_accuracy: 0.6375
#
# Epoch 00077: val_loss did not improve from 0.62838
# Epoch 78/300
# 45/45 - 0s - loss: 0.5386 - accuracy: 0.7214 - val_loss: 0.6378 - val_accuracy: 0.6311
#
# Epoch 00078: val_loss did not improve from 0.62838
# Epoch 79/300
# 45/45 - 0s - loss: 0.5339 - accuracy: 0.7298 - val_loss: 0.6323 - val_accuracy: 0.6379
#
# Epoch 00079: val_loss did not improve from 0.62838
# Epoch 80/300
# 45/45 - 0s - loss: 0.5426 - accuracy: 0.7216 - val_loss: 0.6496 - val_accuracy: 0.6112
#
# Epoch 00080: val_loss did not improve from 0.62838
# Epoch 81/300
# 45/45 - 0s - loss: 0.5302 - accuracy: 0.7320 - val_loss: 0.6475 - val_accuracy: 0.6096
#
# Epoch 00081: val_loss did not improve from 0.62838
# Epoch 82/300
# 45/45 - 0s - loss: 0.5348 - accuracy: 0.7254 - val_loss: 0.6286 - val_accuracy: 0.6448
#
# Epoch 00082: val_loss did not improve from 0.62838
# Epoch 83/300
# 45/45 - 0s - loss: 0.5353 - accuracy: 0.7316 - val_loss: 0.6259 - val_accuracy: 0.6416
#
# Epoch 00083: val_loss improved from 0.62838 to 0.62589, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.h5
# Epoch 84/300
# 45/45 - 0s - loss: 0.5281 - accuracy: 0.7334 - val_loss: 0.6668 - val_accuracy: 0.5922
#
# Epoch 00084: val_loss did not improve from 0.62589
# Epoch 85/300
# 45/45 - 0s - loss: 0.5302 - accuracy: 0.7306 - val_loss: 0.6631 - val_accuracy: 0.5979
#
# Epoch 00085: val_loss did not improve from 0.62589
# Epoch 86/300
# 45/45 - 0s - loss: 0.5242 - accuracy: 0.7312 - val_loss: 0.6457 - val_accuracy: 0.6104
#
# Epoch 00086: val_loss did not improve from 0.62589
# Epoch 87/300
# 45/45 - 0s - loss: 0.5310 - accuracy: 0.7300 - val_loss: 0.6472 - val_accuracy: 0.6080
#
# Epoch 00087: val_loss did not improve from 0.62589
# Epoch 88/300
# 45/45 - 0s - loss: 0.5278 - accuracy: 0.7326 - val_loss: 0.6509 - val_accuracy: 0.6044
#
# Epoch 00088: val_loss did not improve from 0.62589
# Epoch 89/300
# 45/45 - 0s - loss: 0.5285 - accuracy: 0.7296 - val_loss: 0.6341 - val_accuracy: 0.6404
#
# Epoch 00089: val_loss did not improve from 0.62589
# Epoch 90/300
# 45/45 - 0s - loss: 0.5190 - accuracy: 0.7420 - val_loss: 0.6550 - val_accuracy: 0.6032
#
# Epoch 00090: val_loss did not improve from 0.62589
# Epoch 91/300
# 45/45 - 0s - loss: 0.5194 - accuracy: 0.7413 - val_loss: 0.6395 - val_accuracy: 0.6250
#
# Epoch 00091: val_loss did not improve from 0.62589
# Epoch 92/300
# 45/45 - 0s - loss: 0.5185 - accuracy: 0.7410 - val_loss: 0.6383 - val_accuracy: 0.6290
#
# Epoch 00092: val_loss did not improve from 0.62589
# Epoch 93/300
# 45/45 - 0s - loss: 0.5167 - accuracy: 0.7392 - val_loss: 0.6567 - val_accuracy: 0.6007
#
# Epoch 00093: val_loss did not improve from 0.62589
# Epoch 94/300
# 45/45 - 0s - loss: 0.5144 - accuracy: 0.7448 - val_loss: 0.6393 - val_accuracy: 0.6286
#
# Epoch 00094: val_loss did not improve from 0.62589
# Epoch 95/300
# 45/45 - 0s - loss: 0.5075 - accuracy: 0.7464 - val_loss: 0.6320 - val_accuracy: 0.6339
#
# Epoch 00095: val_loss did not improve from 0.62589
# Epoch 96/300
# 45/45 - 0s - loss: 0.5105 - accuracy: 0.7457 - val_loss: 0.6261 - val_accuracy: 0.6456
#
# Epoch 00096: val_loss did not improve from 0.62589
# Epoch 97/300
# 45/45 - 0s - loss: 0.5088 - accuracy: 0.7508 - val_loss: 0.6432 - val_accuracy: 0.6193
#
# Epoch 00097: val_loss did not improve from 0.62589
# Epoch 98/300
# 45/45 - 0s - loss: 0.5105 - accuracy: 0.7430 - val_loss: 0.6502 - val_accuracy: 0.6088
#
# Epoch 00098: val_loss did not improve from 0.62589
# Epoch 99/300
# 45/45 - 0s - loss: 0.5134 - accuracy: 0.7434 - val_loss: 0.6295 - val_accuracy: 0.6359
#
# Epoch 00099: val_loss did not improve from 0.62589
# Epoch 100/300
# 45/45 - 0s - loss: 0.5047 - accuracy: 0.7521 - val_loss: 0.6420 - val_accuracy: 0.6129
#
# Epoch 00100: val_loss did not improve from 0.62589
# Epoch 101/300
# 45/45 - 0s - loss: 0.4966 - accuracy: 0.7526 - val_loss: 0.6407 - val_accuracy: 0.6274
#
# Epoch 00101: val_loss did not improve from 0.62589
# Epoch 102/300
# 45/45 - 0s - loss: 0.5038 - accuracy: 0.7561 - val_loss: 0.6327 - val_accuracy: 0.6343
#
# Epoch 00102: val_loss did not improve from 0.62589
# Epoch 103/300
# 45/45 - 0s - loss: 0.5008 - accuracy: 0.7492 - val_loss: 0.6487 - val_accuracy: 0.6129
#
# Epoch 00103: val_loss did not improve from 0.62589
# Epoch 104/300
# 45/45 - 0s - loss: 0.5034 - accuracy: 0.7521 - val_loss: 0.6531 - val_accuracy: 0.6173
#
# Epoch 00104: val_loss did not improve from 0.62589
# Epoch 105/300
# 45/45 - 0s - loss: 0.4991 - accuracy: 0.7548 - val_loss: 0.6337 - val_accuracy: 0.6258
#
# Epoch 00105: val_loss did not improve from 0.62589
# Epoch 106/300
# 45/45 - 0s - loss: 0.4958 - accuracy: 0.7570 - val_loss: 0.6399 - val_accuracy: 0.6214
#
# Epoch 00106: val_loss did not improve from 0.62589
# Epoch 107/300
# 45/45 - 0s - loss: 0.4937 - accuracy: 0.7558 - val_loss: 0.6489 - val_accuracy: 0.6307
#
# Epoch 00107: val_loss did not improve from 0.62589
# Epoch 108/300
# 45/45 - 0s - loss: 0.4983 - accuracy: 0.7573 - val_loss: 0.6377 - val_accuracy: 0.6250
#
# Epoch 00108: val_loss did not improve from 0.62589
# Epoch 109/300
# 45/45 - 0s - loss: 0.4960 - accuracy: 0.7584 - val_loss: 0.6392 - val_accuracy: 0.6315
#
# Epoch 00109: val_loss did not improve from 0.62589
# Epoch 110/300
# 45/45 - 0s - loss: 0.4882 - accuracy: 0.7587 - val_loss: 0.6465 - val_accuracy: 0.6153
#
# Epoch 00110: val_loss did not improve from 0.62589
# Epoch 111/300
# 45/45 - 0s - loss: 0.4863 - accuracy: 0.7646 - val_loss: 0.6440 - val_accuracy: 0.6197
#
# Epoch 00111: val_loss did not improve from 0.62589
# Epoch 112/300
# 45/45 - 0s - loss: 0.4911 - accuracy: 0.7592 - val_loss: 0.6489 - val_accuracy: 0.6181
#
# Epoch 00112: val_loss did not improve from 0.62589
# Epoch 113/300
# 45/45 - 0s - loss: 0.4838 - accuracy: 0.7641 - val_loss: 0.6301 - val_accuracy: 0.6412
#
# Epoch 00113: val_loss did not improve from 0.62589
# Epoch 114/300
# 45/45 - 0s - loss: 0.4860 - accuracy: 0.7600 - val_loss: 0.6600 - val_accuracy: 0.6076
#
# Epoch 00114: val_loss did not improve from 0.62589
# Epoch 115/300
# 45/45 - 0s - loss: 0.4812 - accuracy: 0.7660 - val_loss: 0.6524 - val_accuracy: 0.6161
#
# Epoch 00115: val_loss did not improve from 0.62589
# Epoch 116/300
# 45/45 - 0s - loss: 0.4854 - accuracy: 0.7595 - val_loss: 0.6691 - val_accuracy: 0.5939
#
# Epoch 00116: val_loss did not improve from 0.62589
# Epoch 117/300
# 45/45 - 0s - loss: 0.4780 - accuracy: 0.7681 - val_loss: 0.6670 - val_accuracy: 0.5983
#
# Epoch 00117: val_loss did not improve from 0.62589
# Epoch 118/300
# 45/45 - 0s - loss: 0.4868 - accuracy: 0.7605 - val_loss: 0.6552 - val_accuracy: 0.6052
#
# Epoch 00118: val_loss did not improve from 0.62589
# Epoch 119/300
# 45/45 - 0s - loss: 0.4757 - accuracy: 0.7715 - val_loss: 0.6390 - val_accuracy: 0.6258
#
# Epoch 00119: val_loss did not improve from 0.62589
# Epoch 120/300
# 45/45 - 0s - loss: 0.4816 - accuracy: 0.7634 - val_loss: 0.6535 - val_accuracy: 0.6048
#
# Epoch 00120: val_loss did not improve from 0.62589
# Epoch 121/300
# 45/45 - 0s - loss: 0.4752 - accuracy: 0.7699 - val_loss: 0.6567 - val_accuracy: 0.6161
#
# Epoch 00121: val_loss did not improve from 0.62589
# Epoch 122/300
# 45/45 - 0s - loss: 0.4786 - accuracy: 0.7681 - val_loss: 0.6452 - val_accuracy: 0.6294
#
# Epoch 00122: val_loss did not improve from 0.62589
# Epoch 123/300
# 45/45 - 0s - loss: 0.4764 - accuracy: 0.7689 - val_loss: 0.6373 - val_accuracy: 0.6311
#
# Epoch 00123: val_loss did not improve from 0.62589
# Epoch 124/300
# 45/45 - 0s - loss: 0.4743 - accuracy: 0.7661 - val_loss: 0.6404 - val_accuracy: 0.6262
#
# Epoch 00124: val_loss did not improve from 0.62589
# Epoch 125/300
# 45/45 - 0s - loss: 0.4780 - accuracy: 0.7657 - val_loss: 0.6502 - val_accuracy: 0.6193
#
# Epoch 00125: val_loss did not improve from 0.62589
# Epoch 126/300
# 45/45 - 0s - loss: 0.4731 - accuracy: 0.7705 - val_loss: 0.6460 - val_accuracy: 0.6274
#
# Epoch 00126: val_loss did not improve from 0.62589
# Epoch 127/300
# 45/45 - 0s - loss: 0.4724 - accuracy: 0.7706 - val_loss: 0.6741 - val_accuracy: 0.5979
#
# Epoch 00127: val_loss did not improve from 0.62589
# Epoch 128/300
# 45/45 - 0s - loss: 0.4695 - accuracy: 0.7733 - val_loss: 0.6583 - val_accuracy: 0.6068
#
# Epoch 00128: val_loss did not improve from 0.62589
# Epoch 129/300
# 45/45 - 0s - loss: 0.4786 - accuracy: 0.7700 - val_loss: 0.6477 - val_accuracy: 0.6201
#
# Epoch 00129: val_loss did not improve from 0.62589
# Epoch 130/300
# 45/45 - 0s - loss: 0.4671 - accuracy: 0.7708 - val_loss: 0.6529 - val_accuracy: 0.6096
#
# Epoch 00130: val_loss did not improve from 0.62589
# Epoch 131/300
# 45/45 - 0s - loss: 0.4733 - accuracy: 0.7708 - val_loss: 0.6456 - val_accuracy: 0.6181
#
# Epoch 00131: val_loss did not improve from 0.62589
# Epoch 132/300
# 45/45 - 0s - loss: 0.4732 - accuracy: 0.7675 - val_loss: 0.6363 - val_accuracy: 0.6258
#
# Epoch 00132: val_loss did not improve from 0.62589
# Epoch 133/300
# 45/45 - 0s - loss: 0.4686 - accuracy: 0.7729 - val_loss: 0.6466 - val_accuracy: 0.6226
#
# Epoch 00133: val_loss did not improve from 0.62589
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6466 - accuracy: 0.6226
# Independent test: [0.6465590596199036, 0.6225728392601013]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\UbidelAcet_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.5501618122977346,
#  'SP': 0.6949838187702265,
#  'ACC': 0.6225728155339806,
#  'MCC': 0.24775755978729957,
#  'Recall': 0.5501618122977346,
#  'Precision': 0.6433301797540208,
#  'F1-score': 0.5931094635848234,
#  'Cutoff': 0.5}
