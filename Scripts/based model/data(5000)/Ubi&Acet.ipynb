# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\client\session.py:1761: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\5k\Acet_Ubi\Acet&Ubi')
    epoch = 300
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\NEDD')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_15 (Conv1D)           (None, 41, 128)           2816
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_15 (MaxPooling (None, 20, 128)           0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 20, 128)           49280
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_16 (MaxPooling (None, 10, 128)           0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 5, 128)            0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 5, 128)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_5 ( (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 45/45 - 1s - loss: 0.6954 - accuracy: 0.5033 - val_loss: 0.6971 - val_accuracy: 0.5008
#
# Epoch 00001: val_loss improved from inf to 0.69715, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 2/300
# 45/45 - 0s - loss: 0.6875 - accuracy: 0.5378 - val_loss: 0.6874 - val_accuracy: 0.5376
#
# Epoch 00002: val_loss improved from 0.69715 to 0.68741, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 3/300
# 45/45 - 0s - loss: 0.6777 - accuracy: 0.5626 - val_loss: 0.6860 - val_accuracy: 0.5449
#
# Epoch 00003: val_loss improved from 0.68741 to 0.68601, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 4/300
# 45/45 - 0s - loss: 0.6725 - accuracy: 0.5760 - val_loss: 0.7075 - val_accuracy: 0.5113
#
# Epoch 00004: val_loss did not improve from 0.68601
# Epoch 5/300
# 45/45 - 0s - loss: 0.6679 - accuracy: 0.5794 - val_loss: 0.6809 - val_accuracy: 0.5530
#
# Epoch 00005: val_loss improved from 0.68601 to 0.68093, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 6/300
# 45/45 - 0s - loss: 0.6582 - accuracy: 0.5931 - val_loss: 0.6945 - val_accuracy: 0.5534
#
# Epoch 00006: val_loss did not improve from 0.68093
# Epoch 7/300
# 45/45 - 0s - loss: 0.6541 - accuracy: 0.6035 - val_loss: 0.6673 - val_accuracy: 0.5704
#
# Epoch 00007: val_loss improved from 0.68093 to 0.66732, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 8/300
# 45/45 - 0s - loss: 0.6441 - accuracy: 0.6203 - val_loss: 0.6693 - val_accuracy: 0.5752
#
# Epoch 00008: val_loss did not improve from 0.66732
# Epoch 9/300
# 45/45 - 0s - loss: 0.6371 - accuracy: 0.6230 - val_loss: 0.6620 - val_accuracy: 0.5667
#
# Epoch 00009: val_loss improved from 0.66732 to 0.66199, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 10/300
# 45/45 - 0s - loss: 0.6334 - accuracy: 0.6336 - val_loss: 0.6558 - val_accuracy: 0.5967
#
# Epoch 00010: val_loss improved from 0.66199 to 0.65579, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 11/300
# 45/45 - 0s - loss: 0.6243 - accuracy: 0.6431 - val_loss: 0.6832 - val_accuracy: 0.5829
#
# Epoch 00011: val_loss did not improve from 0.65579
# Epoch 12/300
# 45/45 - 0s - loss: 0.6197 - accuracy: 0.6483 - val_loss: 0.6585 - val_accuracy: 0.5979
#
# Epoch 00012: val_loss did not improve from 0.65579
# Epoch 13/300
# 45/45 - 0s - loss: 0.6118 - accuracy: 0.6569 - val_loss: 0.6546 - val_accuracy: 0.6056
#
# Epoch 00013: val_loss improved from 0.65579 to 0.65458, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 14/300
# 45/45 - 0s - loss: 0.6072 - accuracy: 0.6669 - val_loss: 0.6334 - val_accuracy: 0.6400
#
# Epoch 00014: val_loss improved from 0.65458 to 0.63342, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 15/300
# 45/45 - 0s - loss: 0.6069 - accuracy: 0.6651 - val_loss: 0.6438 - val_accuracy: 0.6052
#
# Epoch 00015: val_loss did not improve from 0.63342
# Epoch 16/300
# 45/45 - 0s - loss: 0.5963 - accuracy: 0.6735 - val_loss: 0.6299 - val_accuracy: 0.6396
#
# Epoch 00016: val_loss improved from 0.63342 to 0.62986, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 17/300
# 45/45 - 0s - loss: 0.5960 - accuracy: 0.6779 - val_loss: 0.6286 - val_accuracy: 0.6404
#
# Epoch 00017: val_loss improved from 0.62986 to 0.62861, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 18/300
# 45/45 - 0s - loss: 0.5930 - accuracy: 0.6739 - val_loss: 0.6248 - val_accuracy: 0.6489
#
# Epoch 00018: val_loss improved from 0.62861 to 0.62484, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 19/300
# 45/45 - 0s - loss: 0.5867 - accuracy: 0.6880 - val_loss: 0.6200 - val_accuracy: 0.6602
#
# Epoch 00019: val_loss improved from 0.62484 to 0.61999, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 20/300
# 45/45 - 0s - loss: 0.5877 - accuracy: 0.6834 - val_loss: 0.6338 - val_accuracy: 0.6464
#
# Epoch 00020: val_loss did not improve from 0.61999
# Epoch 21/300
# 45/45 - 0s - loss: 0.5816 - accuracy: 0.6903 - val_loss: 0.6237 - val_accuracy: 0.6557
#
# Epoch 00021: val_loss did not improve from 0.61999
# Epoch 22/300
# 45/45 - 0s - loss: 0.5802 - accuracy: 0.6887 - val_loss: 0.6382 - val_accuracy: 0.6250
#
# Epoch 00022: val_loss did not improve from 0.61999
# Epoch 23/300
# 45/45 - 0s - loss: 0.5764 - accuracy: 0.6940 - val_loss: 0.6505 - val_accuracy: 0.6428
#
# Epoch 00023: val_loss did not improve from 0.61999
# Epoch 24/300
# 45/45 - 0s - loss: 0.5763 - accuracy: 0.6892 - val_loss: 0.6204 - val_accuracy: 0.6634
#
# Epoch 00024: val_loss did not improve from 0.61999
# Epoch 25/300
# 45/45 - 0s - loss: 0.5714 - accuracy: 0.6984 - val_loss: 0.6519 - val_accuracy: 0.5995
#
# Epoch 00025: val_loss did not improve from 0.61999
# Epoch 26/300
# 45/45 - 0s - loss: 0.5681 - accuracy: 0.6967 - val_loss: 0.6225 - val_accuracy: 0.6501
#
# Epoch 00026: val_loss did not improve from 0.61999
# Epoch 27/300
# 45/45 - 0s - loss: 0.5633 - accuracy: 0.6976 - val_loss: 0.6301 - val_accuracy: 0.6630
#
# Epoch 00027: val_loss did not improve from 0.61999
# Epoch 28/300
# 45/45 - 0s - loss: 0.5596 - accuracy: 0.7047 - val_loss: 0.6270 - val_accuracy: 0.6436
#
# Epoch 00028: val_loss did not improve from 0.61999
# Epoch 29/300
# 45/45 - 0s - loss: 0.5649 - accuracy: 0.6965 - val_loss: 0.6139 - val_accuracy: 0.6715
#
# Epoch 00029: val_loss improved from 0.61999 to 0.61393, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 30/300
# 45/45 - 0s - loss: 0.5573 - accuracy: 0.7086 - val_loss: 0.6246 - val_accuracy: 0.6727
#
# Epoch 00030: val_loss did not improve from 0.61393
# Epoch 31/300
# 45/45 - 0s - loss: 0.5576 - accuracy: 0.7091 - val_loss: 0.6116 - val_accuracy: 0.6748
#
# Epoch 00031: val_loss improved from 0.61393 to 0.61163, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 32/300
# 45/45 - 0s - loss: 0.5563 - accuracy: 0.7144 - val_loss: 0.6160 - val_accuracy: 0.6610
#
# Epoch 00032: val_loss did not improve from 0.61163
# Epoch 33/300
# 45/45 - 0s - loss: 0.5534 - accuracy: 0.7130 - val_loss: 0.6091 - val_accuracy: 0.6739
#
# Epoch 00033: val_loss improved from 0.61163 to 0.60906, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 34/300
# 45/45 - 0s - loss: 0.5501 - accuracy: 0.7146 - val_loss: 0.6092 - val_accuracy: 0.6808
#
# Epoch 00034: val_loss did not improve from 0.60906
# Epoch 35/300
# 45/45 - 0s - loss: 0.5465 - accuracy: 0.7144 - val_loss: 0.6125 - val_accuracy: 0.6804
#
# Epoch 00035: val_loss did not improve from 0.60906
# Epoch 36/300
# 45/45 - 0s - loss: 0.5495 - accuracy: 0.7117 - val_loss: 0.6450 - val_accuracy: 0.6286
#
# Epoch 00036: val_loss did not improve from 0.60906
# Epoch 37/300
# 45/45 - 0s - loss: 0.5455 - accuracy: 0.7198 - val_loss: 0.6107 - val_accuracy: 0.6752
#
# Epoch 00037: val_loss did not improve from 0.60906
# Epoch 38/300
# 45/45 - 0s - loss: 0.5447 - accuracy: 0.7194 - val_loss: 0.6174 - val_accuracy: 0.6675
#
# Epoch 00038: val_loss did not improve from 0.60906
# Epoch 39/300
# 45/45 - 0s - loss: 0.5378 - accuracy: 0.7289 - val_loss: 0.6105 - val_accuracy: 0.6780
#
# Epoch 00039: val_loss did not improve from 0.60906
# Epoch 40/300
# 45/45 - 0s - loss: 0.5411 - accuracy: 0.7213 - val_loss: 0.6070 - val_accuracy: 0.6796
#
# Epoch 00040: val_loss improved from 0.60906 to 0.60702, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 41/300
# 45/45 - 0s - loss: 0.5337 - accuracy: 0.7261 - val_loss: 0.6069 - val_accuracy: 0.6800
#
# Epoch 00041: val_loss improved from 0.60702 to 0.60695, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 42/300
# 45/45 - 0s - loss: 0.5331 - accuracy: 0.7241 - val_loss: 0.6489 - val_accuracy: 0.6634
#
# Epoch 00042: val_loss did not improve from 0.60695
# Epoch 43/300
# 45/45 - 0s - loss: 0.5321 - accuracy: 0.7260 - val_loss: 0.6063 - val_accuracy: 0.6764
#
# Epoch 00043: val_loss improved from 0.60695 to 0.60629, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 44/300
# 45/45 - 0s - loss: 0.5321 - accuracy: 0.7244 - val_loss: 0.6331 - val_accuracy: 0.6634
#
# Epoch 00044: val_loss did not improve from 0.60629
# Epoch 45/300
# 45/45 - 0s - loss: 0.5311 - accuracy: 0.7291 - val_loss: 0.6116 - val_accuracy: 0.6820
#
# Epoch 00045: val_loss did not improve from 0.60629
# Epoch 46/300
# 45/45 - 0s - loss: 0.5248 - accuracy: 0.7348 - val_loss: 0.6030 - val_accuracy: 0.6816
#
# Epoch 00046: val_loss improved from 0.60629 to 0.60299, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 47/300
# 45/45 - 0s - loss: 0.5297 - accuracy: 0.7275 - val_loss: 0.6162 - val_accuracy: 0.6667
#
# Epoch 00047: val_loss did not improve from 0.60299
# Epoch 48/300
# 45/45 - 0s - loss: 0.5251 - accuracy: 0.7309 - val_loss: 0.6177 - val_accuracy: 0.6804
#
# Epoch 00048: val_loss did not improve from 0.60299
# Epoch 49/300
# 45/45 - 0s - loss: 0.5195 - accuracy: 0.7382 - val_loss: 0.6058 - val_accuracy: 0.6671
#
# Epoch 00049: val_loss did not improve from 0.60299
# Epoch 50/300
# 45/45 - 0s - loss: 0.5206 - accuracy: 0.7341 - val_loss: 0.6043 - val_accuracy: 0.6885
#
# Epoch 00050: val_loss did not improve from 0.60299
# Epoch 51/300
# 45/45 - 0s - loss: 0.5223 - accuracy: 0.7350 - val_loss: 0.6171 - val_accuracy: 0.6719
#
# Epoch 00051: val_loss did not improve from 0.60299
# Epoch 52/300
# 45/45 - 0s - loss: 0.5108 - accuracy: 0.7431 - val_loss: 0.6030 - val_accuracy: 0.6792
#
# Epoch 00052: val_loss did not improve from 0.60299
# Epoch 53/300
# 45/45 - 0s - loss: 0.5163 - accuracy: 0.7378 - val_loss: 0.6148 - val_accuracy: 0.6788
#
# Epoch 00053: val_loss did not improve from 0.60299
# Epoch 54/300
# 45/45 - 0s - loss: 0.5101 - accuracy: 0.7415 - val_loss: 0.6131 - val_accuracy: 0.6735
#
# Epoch 00054: val_loss did not improve from 0.60299
# Epoch 55/300
# 45/45 - 0s - loss: 0.5088 - accuracy: 0.7430 - val_loss: 0.6292 - val_accuracy: 0.6561
#
# Epoch 00055: val_loss did not improve from 0.60299
# Epoch 56/300
# 45/45 - 0s - loss: 0.5104 - accuracy: 0.7449 - val_loss: 0.6122 - val_accuracy: 0.6824
#
# Epoch 00056: val_loss did not improve from 0.60299
# Epoch 57/300
# 45/45 - 0s - loss: 0.5055 - accuracy: 0.7489 - val_loss: 0.6031 - val_accuracy: 0.6816
#
# Epoch 00057: val_loss did not improve from 0.60299
# Epoch 58/300
# 45/45 - 0s - loss: 0.5027 - accuracy: 0.7479 - val_loss: 0.6272 - val_accuracy: 0.6764
#
# Epoch 00058: val_loss did not improve from 0.60299
# Epoch 59/300
# 45/45 - 0s - loss: 0.5051 - accuracy: 0.7426 - val_loss: 0.6087 - val_accuracy: 0.6841
#
# Epoch 00059: val_loss did not improve from 0.60299
# Epoch 60/300
# 45/45 - 0s - loss: 0.5022 - accuracy: 0.7463 - val_loss: 0.6222 - val_accuracy: 0.6687
#
# Epoch 00060: val_loss did not improve from 0.60299
# Epoch 61/300
# 45/45 - 0s - loss: 0.5054 - accuracy: 0.7549 - val_loss: 0.6137 - val_accuracy: 0.6699
#
# Epoch 00061: val_loss did not improve from 0.60299
# Epoch 62/300
# 45/45 - 0s - loss: 0.4959 - accuracy: 0.7508 - val_loss: 0.6121 - val_accuracy: 0.6760
#
# Epoch 00062: val_loss did not improve from 0.60299
# Epoch 63/300
# 45/45 - 0s - loss: 0.5021 - accuracy: 0.7494 - val_loss: 0.6049 - val_accuracy: 0.6804
#
# Epoch 00063: val_loss did not improve from 0.60299
# Epoch 64/300
# 45/45 - 0s - loss: 0.4964 - accuracy: 0.7543 - val_loss: 0.6191 - val_accuracy: 0.6784
#
# Epoch 00064: val_loss did not improve from 0.60299
# Epoch 65/300
# 45/45 - 0s - loss: 0.4937 - accuracy: 0.7555 - val_loss: 0.6179 - val_accuracy: 0.6768
#
# Epoch 00065: val_loss did not improve from 0.60299
# Epoch 66/300
# 45/45 - 0s - loss: 0.4982 - accuracy: 0.7493 - val_loss: 0.6067 - val_accuracy: 0.6796
#
# Epoch 00066: val_loss did not improve from 0.60299
# Epoch 67/300
# 45/45 - 0s - loss: 0.4899 - accuracy: 0.7595 - val_loss: 0.6218 - val_accuracy: 0.6752
#
# Epoch 00067: val_loss did not improve from 0.60299
# Epoch 68/300
# 45/45 - 0s - loss: 0.4868 - accuracy: 0.7607 - val_loss: 0.6050 - val_accuracy: 0.6853
#
# Epoch 00068: val_loss did not improve from 0.60299
# Epoch 69/300
# 45/45 - 0s - loss: 0.4857 - accuracy: 0.7561 - val_loss: 0.6219 - val_accuracy: 0.6711
#
# Epoch 00069: val_loss did not improve from 0.60299
# Epoch 70/300
# 45/45 - 0s - loss: 0.4851 - accuracy: 0.7622 - val_loss: 0.6007 - val_accuracy: 0.6861
#
# Epoch 00070: val_loss improved from 0.60299 to 0.60075, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 71/300
# 45/45 - 0s - loss: 0.4810 - accuracy: 0.7637 - val_loss: 0.6125 - val_accuracy: 0.6752
#
# Epoch 00071: val_loss did not improve from 0.60075
# Epoch 72/300
# 45/45 - 0s - loss: 0.4751 - accuracy: 0.7682 - val_loss: 0.6266 - val_accuracy: 0.6626
#
# Epoch 00072: val_loss did not improve from 0.60075
# Epoch 73/300
# 45/45 - 0s - loss: 0.4827 - accuracy: 0.7643 - val_loss: 0.6161 - val_accuracy: 0.6715
#
# Epoch 00073: val_loss did not improve from 0.60075
# Epoch 74/300
# 45/45 - 0s - loss: 0.4819 - accuracy: 0.7621 - val_loss: 0.6245 - val_accuracy: 0.6780
#
# Epoch 00074: val_loss did not improve from 0.60075
# Epoch 75/300
# 45/45 - 0s - loss: 0.4769 - accuracy: 0.7659 - val_loss: 0.6144 - val_accuracy: 0.6744
#
# Epoch 00075: val_loss did not improve from 0.60075
# Epoch 76/300
# 45/45 - 0s - loss: 0.4737 - accuracy: 0.7707 - val_loss: 0.6090 - val_accuracy: 0.6824
#
# Epoch 00076: val_loss did not improve from 0.60075
# Epoch 77/300
# 45/45 - 0s - loss: 0.4793 - accuracy: 0.7662 - val_loss: 0.6147 - val_accuracy: 0.6768
#
# Epoch 00077: val_loss did not improve from 0.60075
# Epoch 78/300
# 45/45 - 0s - loss: 0.4723 - accuracy: 0.7700 - val_loss: 0.6043 - val_accuracy: 0.6833
#
# Epoch 00078: val_loss did not improve from 0.60075
# Epoch 79/300
# 45/45 - 0s - loss: 0.4718 - accuracy: 0.7759 - val_loss: 0.6036 - val_accuracy: 0.6837
# Epoch 00079: val_loss did not improve from 0.60075
# Epoch 80/300
# 45/45 - 0s - loss: 0.4678 - accuracy: 0.7697 - val_loss: 0.6099 - val_accuracy: 0.6873
#
# Epoch 00080: val_loss did not improve from 0.60075
# Epoch 81/300
# 45/45 - 0s - loss: 0.4692 - accuracy: 0.7726 - val_loss: 0.6165 - val_accuracy: 0.6739
#
# Epoch 00081: val_loss did not improve from 0.60075
# Epoch 82/300
# 45/45 - 0s - loss: 0.4671 - accuracy: 0.7766 - val_loss: 0.6128 - val_accuracy: 0.6784
#
# Epoch 00082: val_loss did not improve from 0.60075
# Epoch 83/300
# 45/45 - 0s - loss: 0.4627 - accuracy: 0.7767 - val_loss: 0.6131 - val_accuracy: 0.6760
#
# Epoch 00083: val_loss did not improve from 0.60075
# Epoch 84/300
# 45/45 - 0s - loss: 0.4667 - accuracy: 0.7715 - val_loss: 0.6146 - val_accuracy: 0.6853
#
# Epoch 00084: val_loss did not improve from 0.60075
# Epoch 85/300
# 45/45 - 0s - loss: 0.4606 - accuracy: 0.7760 - val_loss: 0.6415 - val_accuracy: 0.6703
#
# Epoch 00085: val_loss did not improve from 0.60075
# Epoch 86/300
# 45/45 - 0s - loss: 0.4637 - accuracy: 0.7773 - val_loss: 0.6150 - val_accuracy: 0.6715
#
# Epoch 00086: val_loss did not improve from 0.60075
# Epoch 87/300
# 45/45 - 0s - loss: 0.4563 - accuracy: 0.7783 - val_loss: 0.6068 - val_accuracy: 0.6877
#
# Epoch 00087: val_loss did not improve from 0.60075
# Epoch 88/300
# 45/45 - 0s - loss: 0.4596 - accuracy: 0.7781 - val_loss: 0.6071 - val_accuracy: 0.6828
#
# Epoch 00088: val_loss did not improve from 0.60075
# Epoch 89/300
# 45/45 - 0s - loss: 0.4600 - accuracy: 0.7733 - val_loss: 0.6110 - val_accuracy: 0.6828
#
# Epoch 00089: val_loss did not improve from 0.60075
# Epoch 90/300
# 45/45 - 0s - loss: 0.4573 - accuracy: 0.7795 - val_loss: 0.6107 - val_accuracy: 0.6808
#
# Epoch 00090: val_loss did not improve from 0.60075
# Epoch 91/300
# 45/45 - 0s - loss: 0.4568 - accuracy: 0.7830 - val_loss: 0.6013 - val_accuracy: 0.6873
#
# Epoch 00091: val_loss did not improve from 0.60075
# Epoch 92/300
# 45/45 - 0s - loss: 0.4502 - accuracy: 0.7838 - val_loss: 0.6038 - val_accuracy: 0.6853
#
# Epoch 00092: val_loss did not improve from 0.60075
# Epoch 93/300
# 45/45 - 0s - loss: 0.4526 - accuracy: 0.7855 - val_loss: 0.6065 - val_accuracy: 0.6873
#
# Epoch 00093: val_loss did not improve from 0.60075
# Epoch 94/300
# 45/45 - 0s - loss: 0.4494 - accuracy: 0.7849 - val_loss: 0.6114 - val_accuracy: 0.6853
#
# Epoch 00094: val_loss did not improve from 0.60075
# Epoch 95/300
# 45/45 - 0s - loss: 0.4527 - accuracy: 0.7825 - val_loss: 0.6222 - val_accuracy: 0.6772
#
# Epoch 00095: val_loss did not improve from 0.60075
# Epoch 96/300
# 45/45 - 0s - loss: 0.4549 - accuracy: 0.7814 - val_loss: 0.5992 - val_accuracy: 0.6877
#
# Epoch 00096: val_loss improved from 0.60075 to 0.59921, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.h5
# Epoch 97/300
# 45/45 - 0s - loss: 0.4391 - accuracy: 0.7875 - val_loss: 0.6005 - val_accuracy: 0.6881
#
# Epoch 00097: val_loss did not improve from 0.59921
# Epoch 98/300
# 45/45 - 0s - loss: 0.4451 - accuracy: 0.7880 - val_loss: 0.6161 - val_accuracy: 0.6845
#
# Epoch 00098: val_loss did not improve from 0.59921
# Epoch 99/300
# 45/45 - 0s - loss: 0.4418 - accuracy: 0.7897 - val_loss: 0.6080 - val_accuracy: 0.6849
#
# Epoch 00099: val_loss did not improve from 0.59921
# Epoch 100/300
# 45/45 - 0s - loss: 0.4414 - accuracy: 0.7865 - val_loss: 0.6088 - val_accuracy: 0.6756
#
# Epoch 00100: val_loss did not improve from 0.59921
# Epoch 101/300
# 45/45 - 0s - loss: 0.4349 - accuracy: 0.7904 - val_loss: 0.6177 - val_accuracy: 0.6816
#
# Epoch 00101: val_loss did not improve from 0.59921
# Epoch 102/300
# 45/45 - 0s - loss: 0.4392 - accuracy: 0.7913 - val_loss: 0.6203 - val_accuracy: 0.6853
#
# Epoch 00102: val_loss did not improve from 0.59921
# Epoch 103/300
# 45/45 - 0s - loss: 0.4375 - accuracy: 0.7929 - val_loss: 0.6009 - val_accuracy: 0.6861
#
# Epoch 00103: val_loss did not improve from 0.59921
# Epoch 104/300
# 45/45 - 0s - loss: 0.4362 - accuracy: 0.7944 - val_loss: 0.6090 - val_accuracy: 0.6812
#
# Epoch 00104: val_loss did not improve from 0.59921
# Epoch 105/300
# 45/45 - 0s - loss: 0.4361 - accuracy: 0.7919 - val_loss: 0.6009 - val_accuracy: 0.6861
#
# Epoch 00105: val_loss did not improve from 0.59921
# Epoch 106/300
# 45/45 - 0s - loss: 0.4412 - accuracy: 0.7867 - val_loss: 0.6110 - val_accuracy: 0.6744
#
# Epoch 00106: val_loss did not improve from 0.59921
# Epoch 107/300
# 45/45 - 0s - loss: 0.4388 - accuracy: 0.7913 - val_loss: 0.6141 - val_accuracy: 0.6828
#
# Epoch 00107: val_loss did not improve from 0.59921
# Epoch 108/300
# 45/45 - 0s - loss: 0.4382 - accuracy: 0.7945 - val_loss: 0.6222 - val_accuracy: 0.6776
#
# Epoch 00108: val_loss did not improve from 0.59921
# Epoch 109/300
# 45/45 - 0s - loss: 0.4299 - accuracy: 0.7987 - val_loss: 0.6102 - val_accuracy: 0.6760
#
# Epoch 00109: val_loss did not improve from 0.59921
# Epoch 110/300
# 45/45 - 0s - loss: 0.4308 - accuracy: 0.7954 - val_loss: 0.6204 - val_accuracy: 0.6837
#
# Epoch 00110: val_loss did not improve from 0.59921
# Epoch 111/300
# 45/45 - 0s - loss: 0.4401 - accuracy: 0.7946 - val_loss: 0.6228 - val_accuracy: 0.6796
#
# Epoch 00111: val_loss did not improve from 0.59921
# Epoch 112/300
# 45/45 - 0s - loss: 0.4253 - accuracy: 0.8013 - val_loss: 0.6100 - val_accuracy: 0.6841
#
# Epoch 00112: val_loss did not improve from 0.59921
# Epoch 113/300
# 45/45 - 0s - loss: 0.4276 - accuracy: 0.7996 - val_loss: 0.6093 - val_accuracy: 0.6824
#
# Epoch 00113: val_loss did not improve from 0.59921
# Epoch 114/300
# 45/45 - 0s - loss: 0.4320 - accuracy: 0.7932 - val_loss: 0.6200 - val_accuracy: 0.6744
#
# Epoch 00114: val_loss did not improve from 0.59921
# Epoch 115/300
# 45/45 - 0s - loss: 0.4248 - accuracy: 0.8009 - val_loss: 0.6279 - val_accuracy: 0.6772
#
# Epoch 00115: val_loss did not improve from 0.59921
# Epoch 116/300
# 45/45 - 0s - loss: 0.4262 - accuracy: 0.8006 - val_loss: 0.6104 - val_accuracy: 0.6820
#
# Epoch 00116: val_loss did not improve from 0.59921
# Epoch 117/300
# 45/45 - 0s - loss: 0.4222 - accuracy: 0.8018 - val_loss: 0.6174 - val_accuracy: 0.6764
#
# Epoch 00117: val_loss did not improve from 0.59921
# Epoch 118/300
# 45/45 - 0s - loss: 0.4197 - accuracy: 0.8063 - val_loss: 0.6162 - val_accuracy: 0.6772
#
# Epoch 00118: val_loss did not improve from 0.59921
# Epoch 119/300
# 45/45 - 0s - loss: 0.4206 - accuracy: 0.8045 - val_loss: 0.6173 - val_accuracy: 0.6792
#
# Epoch 00119: val_loss did not improve from 0.59921
# Epoch 120/300
# 45/45 - 0s - loss: 0.4204 - accuracy: 0.8001 - val_loss: 0.6074 - val_accuracy: 0.6877
#
# Epoch 00120: val_loss did not improve from 0.59921
# Epoch 121/300
# 45/45 - 0s - loss: 0.4147 - accuracy: 0.8053 - val_loss: 0.6078 - val_accuracy: 0.6938
#
# Epoch 00121: val_loss did not improve from 0.59921
# Epoch 122/300
# 45/45 - 0s - loss: 0.4235 - accuracy: 0.8023 - val_loss: 0.6099 - val_accuracy: 0.6808
#
# Epoch 00122: val_loss did not improve from 0.59921
# Epoch 123/300
# 45/45 - 0s - loss: 0.4185 - accuracy: 0.8032 - val_loss: 0.6115 - val_accuracy: 0.6849
#
# Epoch 00123: val_loss did not improve from 0.59921
# Epoch 124/300
# 45/45 - 0s - loss: 0.4130 - accuracy: 0.8084 - val_loss: 0.6166 - val_accuracy: 0.6853
#
# Epoch 00124: val_loss did not improve from 0.59921
# Epoch 125/300
# 45/45 - 0s - loss: 0.4248 - accuracy: 0.8030 - val_loss: 0.6106 - val_accuracy: 0.6804
#
# Epoch 00125: val_loss did not improve from 0.59921
# Epoch 126/300
# 45/45 - 0s - loss: 0.4199 - accuracy: 0.8018 - val_loss: 0.6154 - val_accuracy: 0.6784
#
# Epoch 00126: val_loss did not improve from 0.59921
# Epoch 127/300
# 45/45 - 0s - loss: 0.4119 - accuracy: 0.8063 - val_loss: 0.6202 - val_accuracy: 0.6861
#
# Epoch 00127: val_loss did not improve from 0.59921
# Epoch 128/300
# 45/45 - 0s - loss: 0.4167 - accuracy: 0.8054 - val_loss: 0.6128 - val_accuracy: 0.6849
#
# Epoch 00128: val_loss did not improve from 0.59921
# Epoch 129/300
# 45/45 - 0s - loss: 0.4129 - accuracy: 0.8027 - val_loss: 0.6035 - val_accuracy: 0.6930
#
# Epoch 00129: val_loss did not improve from 0.59921
# Epoch 130/300
# 45/45 - 0s - loss: 0.4095 - accuracy: 0.8121 - val_loss: 0.6108 - val_accuracy: 0.6772
#
# Epoch 00130: val_loss did not improve from 0.59921
# Epoch 131/300
# 45/45 - 0s - loss: 0.4157 - accuracy: 0.8053 - val_loss: 0.6132 - val_accuracy: 0.6772
#
# Epoch 00131: val_loss did not improve from 0.59921
# Epoch 132/300
# 45/45 - 0s - loss: 0.4012 - accuracy: 0.8106 - val_loss: 0.6268 - val_accuracy: 0.6764
# Epoch 00132: val_loss did not improve from 0.59921
# Epoch 133/300
# 45/45 - 0s - loss: 0.4088 - accuracy: 0.8059 - val_loss: 0.6052 - val_accuracy: 0.6893
#
# Epoch 00133: val_loss did not improve from 0.59921
# Epoch 134/300
# 45/45 - 0s - loss: 0.4077 - accuracy: 0.8072 - val_loss: 0.6159 - val_accuracy: 0.6772
#
# Epoch 00134: val_loss did not improve from 0.59921
# Epoch 135/300
# 45/45 - 0s - loss: 0.4074 - accuracy: 0.8115 - val_loss: 0.6413 - val_accuracy: 0.6699
#
# Epoch 00135: val_loss did not improve from 0.59921
# Epoch 136/300
# 45/45 - 0s - loss: 0.4010 - accuracy: 0.8101 - val_loss: 0.6075 - val_accuracy: 0.6905
#
# Epoch 00136: val_loss did not improve from 0.59921
# Epoch 137/300
# 45/45 - 0s - loss: 0.4044 - accuracy: 0.8123 - val_loss: 0.6048 - val_accuracy: 0.6897
#
# Epoch 00137: val_loss did not improve from 0.59921
# Epoch 138/300
# 45/45 - 0s - loss: 0.4095 - accuracy: 0.8037 - val_loss: 0.6230 - val_accuracy: 0.6748
#
# Epoch 00138: val_loss did not improve from 0.59921
# Epoch 139/300
# 45/45 - 0s - loss: 0.4033 - accuracy: 0.8103 - val_loss: 0.6086 - val_accuracy: 0.6909
#
# Epoch 00139: val_loss did not improve from 0.59921
# Epoch 140/300
# 45/45 - 0s - loss: 0.4097 - accuracy: 0.8093 - val_loss: 0.6160 - val_accuracy: 0.6873
#
# Epoch 00140: val_loss did not improve from 0.59921
# Epoch 141/300
# 45/45 - 0s - loss: 0.4005 - accuracy: 0.8133 - val_loss: 0.6063 - val_accuracy: 0.6837
#
# Epoch 00141: val_loss did not improve from 0.59921
# Epoch 142/300
# 45/45 - 0s - loss: 0.3992 - accuracy: 0.8172 - val_loss: 0.6207 - val_accuracy: 0.6824
#
# Epoch 00142: val_loss did not improve from 0.59921
# Epoch 143/300
# 45/45 - 0s - loss: 0.4022 - accuracy: 0.8104 - val_loss: 0.6115 - val_accuracy: 0.6780
#
# Epoch 00143: val_loss did not improve from 0.59921
# Epoch 144/300
# 45/45 - 0s - loss: 0.3970 - accuracy: 0.8176 - val_loss: 0.6172 - val_accuracy: 0.6824
#
# Epoch 00144: val_loss did not improve from 0.59921
# Epoch 145/300
# 45/45 - 0s - loss: 0.4054 - accuracy: 0.8143 - val_loss: 0.6078 - val_accuracy: 0.6816
#
# Epoch 00145: val_loss did not improve from 0.59921
# Epoch 146/300
# 45/45 - 0s - loss: 0.4027 - accuracy: 0.8137 - val_loss: 0.6072 - val_accuracy: 0.6837
#
# Epoch 00146: val_loss did not improve from 0.59921
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6072 - accuracy: 0.6837
# Independent test: [0.6072324514389038, 0.6836569309234619]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\Acet&&Ubi_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.7694174757281553,
#  'SP': 0.5978964401294499,
#  'ACC': 0.6836569579288025,
#  'MCC': 0.37283922246460477,
#  'Recall': 0.7694174757281553,
#  'Precision': 0.6567679558011049,
#  'F1-score': 0.7086438152011922,
#  'Cutoff': 0.5}
