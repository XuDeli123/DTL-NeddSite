# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\5k\Acet_Ubi\AcetdelUbi')
    epoch = 300
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\data\based\NEDD')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 45/45 - 5s - loss: 0.7026 - accuracy: 0.5090 - val_loss: 0.6923 - val_accuracy: 0.5036
#
# Epoch 00001: val_loss improved from inf to 0.69233, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 2/300
# 45/45 - 0s - loss: 0.6926 - accuracy: 0.5239 - val_loss: 0.6921 - val_accuracy: 0.5028
#
# Epoch 00002: val_loss improved from 0.69233 to 0.69208, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 3/300
# 45/45 - 0s - loss: 0.6892 - accuracy: 0.5397 - val_loss: 0.6898 - val_accuracy: 0.5328
#
# Epoch 00003: val_loss improved from 0.69208 to 0.68975, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 4/300
# 45/45 - 0s - loss: 0.6870 - accuracy: 0.5453 - val_loss: 0.6877 - val_accuracy: 0.5449
#
# Epoch 00004: val_loss improved from 0.68975 to 0.68767, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 5/300
# 45/45 - 0s - loss: 0.6854 - accuracy: 0.5553 - val_loss: 0.6882 - val_accuracy: 0.5473
#
# Epoch 00005: val_loss did not improve from 0.68767
# Epoch 6/300
# 45/45 - 0s - loss: 0.6839 - accuracy: 0.5503 - val_loss: 0.6890 - val_accuracy: 0.5332
#
# Epoch 00006: val_loss did not improve from 0.68767
# Epoch 7/300
# 45/45 - 0s - loss: 0.6818 - accuracy: 0.5590 - val_loss: 0.6833 - val_accuracy: 0.5421
#
# Epoch 00007: val_loss improved from 0.68767 to 0.68331, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 8/300
# 45/45 - 0s - loss: 0.6790 - accuracy: 0.5688 - val_loss: 0.6798 - val_accuracy: 0.5663
#
# Epoch 00008: val_loss improved from 0.68331 to 0.67984, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 9/300
# 45/45 - 0s - loss: 0.6767 - accuracy: 0.5717 - val_loss: 0.6886 - val_accuracy: 0.5413
#
# Epoch 00009: val_loss did not improve from 0.67984
# Epoch 10/300
# 45/45 - 0s - loss: 0.6751 - accuracy: 0.5802 - val_loss: 0.6722 - val_accuracy: 0.6092
#
# Epoch 00010: val_loss improved from 0.67984 to 0.67218, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 11/300
# 45/45 - 0s - loss: 0.6674 - accuracy: 0.5935 - val_loss: 0.6661 - val_accuracy: 0.6169
#
# Epoch 00011: val_loss improved from 0.67218 to 0.66607, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 12/300
# 45/45 - 1s - loss: 0.6649 - accuracy: 0.5941 - val_loss: 0.6603 - val_accuracy: 0.6226
#
# Epoch 00012: val_loss improved from 0.66607 to 0.66026, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 13/300
# 45/45 - 0s - loss: 0.6614 - accuracy: 0.6016 - val_loss: 0.6559 - val_accuracy: 0.6286
#
# Epoch 00013: val_loss improved from 0.66026 to 0.65589, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 14/300
# 45/45 - 0s - loss: 0.6576 - accuracy: 0.6094 - val_loss: 0.6635 - val_accuracy: 0.5850
#
# Epoch 00014: val_loss did not improve from 0.65589
# Epoch 15/300
# 45/45 - 0s - loss: 0.6528 - accuracy: 0.6149 - val_loss: 0.6595 - val_accuracy: 0.6100
#
# Epoch 00015: val_loss did not improve from 0.65589
# Epoch 16/300
# 45/45 - 0s - loss: 0.6485 - accuracy: 0.6139 - val_loss: 0.6599 - val_accuracy: 0.6028
#
# Epoch 00016: val_loss did not improve from 0.65589
# Epoch 17/300
# 45/45 - 0s - loss: 0.6469 - accuracy: 0.6270 - val_loss: 0.6569 - val_accuracy: 0.5971
#
# Epoch 00017: val_loss did not improve from 0.65589
# Epoch 18/300
# 45/45 - 0s - loss: 0.6439 - accuracy: 0.6236 - val_loss: 0.6573 - val_accuracy: 0.6044
#
# Epoch 00018: val_loss did not improve from 0.65589
# Epoch 19/300
# 45/45 - 0s - loss: 0.6421 - accuracy: 0.6289 - val_loss: 0.6515 - val_accuracy: 0.6149
#
# Epoch 00019: val_loss improved from 0.65589 to 0.65147, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 20/300
# 45/45 - 0s - loss: 0.6390 - accuracy: 0.6316 - val_loss: 0.6527 - val_accuracy: 0.6214
#
# Epoch 00020: val_loss did not improve from 0.65147
# Epoch 21/300
# 45/45 - 0s - loss: 0.6388 - accuracy: 0.6369 - val_loss: 0.6499 - val_accuracy: 0.6311
#
# Epoch 00021: val_loss improved from 0.65147 to 0.64994, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 22/300
# 45/45 - 0s - loss: 0.6305 - accuracy: 0.6380 - val_loss: 0.6445 - val_accuracy: 0.6250
#
# Epoch 00022: val_loss improved from 0.64994 to 0.64446, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 23/300
# 45/45 - 0s - loss: 0.6333 - accuracy: 0.6390 - val_loss: 0.6468 - val_accuracy: 0.6335
#
# Epoch 00023: val_loss did not improve from 0.64446
# Epoch 24/300
# 45/45 - 0s - loss: 0.6337 - accuracy: 0.6395 - val_loss: 0.6512 - val_accuracy: 0.6153
#
# Epoch 00024: val_loss did not improve from 0.64446
# Epoch 25/300
# 45/45 - 0s - loss: 0.6314 - accuracy: 0.6406 - val_loss: 0.6520 - val_accuracy: 0.6165
#
# Epoch 00025: val_loss did not improve from 0.64446
# Epoch 26/300
# 45/45 - 0s - loss: 0.6293 - accuracy: 0.6443 - val_loss: 0.6502 - val_accuracy: 0.6104
#
# Epoch 00026: val_loss did not improve from 0.64446
# Epoch 27/300
# 45/45 - 0s - loss: 0.6239 - accuracy: 0.6495 - val_loss: 0.6521 - val_accuracy: 0.6157
#
# Epoch 00027: val_loss did not improve from 0.64446
# Epoch 28/300
# 45/45 - 0s - loss: 0.6210 - accuracy: 0.6546 - val_loss: 0.6483 - val_accuracy: 0.6121
#
# Epoch 00028: val_loss did not improve from 0.64446
# Epoch 29/300
# 45/45 - 0s - loss: 0.6200 - accuracy: 0.6518 - val_loss: 0.6413 - val_accuracy: 0.6189
#
# Epoch 00029: val_loss improved from 0.64446 to 0.64128, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 30/300
# 45/45 - 0s - loss: 0.6229 - accuracy: 0.6466 - val_loss: 0.6441 - val_accuracy: 0.6165
#
# Epoch 00030: val_loss did not improve from 0.64128
# Epoch 31/300
# 45/45 - 0s - loss: 0.6189 - accuracy: 0.6528 - val_loss: 0.6462 - val_accuracy: 0.6145
#
# Epoch 00031: val_loss did not improve from 0.64128
# Epoch 32/300
# 45/45 - 0s - loss: 0.6138 - accuracy: 0.6604 - val_loss: 0.6460 - val_accuracy: 0.6161
#
# Epoch 00032: val_loss did not improve from 0.64128
# Epoch 33/300
# 45/45 - 0s - loss: 0.6182 - accuracy: 0.6524 - val_loss: 0.6462 - val_accuracy: 0.6185
#
# Epoch 00033: val_loss did not improve from 0.64128
# Epoch 34/300
# 45/45 - 0s - loss: 0.6140 - accuracy: 0.6602 - val_loss: 0.6440 - val_accuracy: 0.6189
#
# Epoch 00034: val_loss did not improve from 0.64128
# Epoch 35/300
# 45/45 - 0s - loss: 0.6120 - accuracy: 0.6614 - val_loss: 0.6397 - val_accuracy: 0.6246
#
# Epoch 00035: val_loss improved from 0.64128 to 0.63974, saving model to D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.h5
# Epoch 36/300
# 45/45 - 0s - loss: 0.6109 - accuracy: 0.6603 - val_loss: 0.6511 - val_accuracy: 0.6088
#
# Epoch 00036: val_loss did not improve from 0.63974
# Epoch 37/300
# 45/45 - 0s - loss: 0.6043 - accuracy: 0.6692 - val_loss: 0.6417 - val_accuracy: 0.6242
#
# Epoch 00037: val_loss did not improve from 0.63974
# Epoch 38/300
# 45/45 - 0s - loss: 0.6021 - accuracy: 0.6670 - val_loss: 0.6546 - val_accuracy: 0.5975
#
# Epoch 00038: val_loss did not improve from 0.63974
# Epoch 39/300
# 45/45 - 0s - loss: 0.6046 - accuracy: 0.6661 - val_loss: 0.6447 - val_accuracy: 0.6193
#
# Epoch 00039: val_loss did not improve from 0.63974
# Epoch 40/300
# 45/45 - 0s - loss: 0.6078 - accuracy: 0.6672 - val_loss: 0.6483 - val_accuracy: 0.6076
#
# Epoch 00040: val_loss did not improve from 0.63974
# Epoch 41/300
# 45/45 - 0s - loss: 0.5983 - accuracy: 0.6702 - val_loss: 0.6441 - val_accuracy: 0.6177
#
# Epoch 00041: val_loss did not improve from 0.63974
# Epoch 42/300
# 45/45 - 0s - loss: 0.5999 - accuracy: 0.6723 - val_loss: 0.6515 - val_accuracy: 0.6080
#
# Epoch 00042: val_loss did not improve from 0.63974
# Epoch 43/300
# 45/45 - 0s - loss: 0.5964 - accuracy: 0.6753 - val_loss: 0.6726 - val_accuracy: 0.5825
#
# Epoch 00043: val_loss did not improve from 0.63974
# Epoch 44/300
# 45/45 - 0s - loss: 0.5971 - accuracy: 0.6754 - val_loss: 0.6590 - val_accuracy: 0.5983
#
# Epoch 00044: val_loss did not improve from 0.63974
# Epoch 45/300
# 45/45 - 0s - loss: 0.5982 - accuracy: 0.6725 - val_loss: 0.6603 - val_accuracy: 0.5975
#
# Epoch 00045: val_loss did not improve from 0.63974
# Epoch 46/300
# 45/45 - 0s - loss: 0.5965 - accuracy: 0.6735 - val_loss: 0.6490 - val_accuracy: 0.6052
#
# Epoch 00046: val_loss did not improve from 0.63974
# Epoch 47/300
# 45/45 - 0s - loss: 0.5917 - accuracy: 0.6807 - val_loss: 0.6522 - val_accuracy: 0.6064
#
# Epoch 00047: val_loss did not improve from 0.63974
# Epoch 48/300
# 45/45 - 0s - loss: 0.5911 - accuracy: 0.6784 - val_loss: 0.6539 - val_accuracy: 0.6064
#
# Epoch 00048: val_loss did not improve from 0.63974
# Epoch 49/300
# 45/45 - 0s - loss: 0.5901 - accuracy: 0.6901 - val_loss: 0.6458 - val_accuracy: 0.6262
#
# Epoch 00049: val_loss did not improve from 0.63974
# Epoch 50/300
# 45/45 - 0s - loss: 0.5800 - accuracy: 0.6895 - val_loss: 0.6523 - val_accuracy: 0.6036
#
# Epoch 00050: val_loss did not improve from 0.63974
# Epoch 51/300
# 45/45 - 0s - loss: 0.5823 - accuracy: 0.6926 - val_loss: 0.6459 - val_accuracy: 0.6133
#
# Epoch 00051: val_loss did not improve from 0.63974
# Epoch 52/300
# 45/45 - 0s - loss: 0.5857 - accuracy: 0.6941 - val_loss: 0.6597 - val_accuracy: 0.5930
#
# Epoch 00052: val_loss did not improve from 0.63974
# Epoch 53/300
# 45/45 - 0s - loss: 0.5829 - accuracy: 0.6858 - val_loss: 0.6438 - val_accuracy: 0.6153
#
# Epoch 00053: val_loss did not improve from 0.63974
# Epoch 54/300
# 45/45 - 0s - loss: 0.5744 - accuracy: 0.6953 - val_loss: 0.6540 - val_accuracy: 0.6048
#
# Epoch 00054: val_loss did not improve from 0.63974
# Epoch 55/300
# 45/45 - 0s - loss: 0.5737 - accuracy: 0.6931 - val_loss: 0.6531 - val_accuracy: 0.5991
#
# Epoch 00055: val_loss did not improve from 0.63974
# Epoch 56/300
# 45/45 - 0s - loss: 0.5802 - accuracy: 0.6908 - val_loss: 0.6483 - val_accuracy: 0.6141
#
# Epoch 00056: val_loss did not improve from 0.63974
# Epoch 57/300
# 45/45 - 0s - loss: 0.5807 - accuracy: 0.6881 - val_loss: 0.6472 - val_accuracy: 0.6173
#
# Epoch 00057: val_loss did not improve from 0.63974
# Epoch 58/300
# 45/45 - 0s - loss: 0.5747 - accuracy: 0.6934 - val_loss: 0.6507 - val_accuracy: 0.6141
#
# Epoch 00058: val_loss did not improve from 0.63974
# Epoch 59/300
# 45/45 - 0s - loss: 0.5698 - accuracy: 0.6988 - val_loss: 0.6538 - val_accuracy: 0.6060
#
# Epoch 00059: val_loss did not improve from 0.63974
# Epoch 60/300
# 45/45 - 0s - loss: 0.5691 - accuracy: 0.7015 - val_loss: 0.6541 - val_accuracy: 0.6076
#
# Epoch 00060: val_loss did not improve from 0.63974
# Epoch 61/300
# 45/45 - 0s - loss: 0.5679 - accuracy: 0.7033 - val_loss: 0.6497 - val_accuracy: 0.6121
#
# Epoch 00061: val_loss did not improve from 0.63974
# Epoch 62/300
# 45/45 - 0s - loss: 0.5630 - accuracy: 0.6997 - val_loss: 0.6458 - val_accuracy: 0.6169
#
# Epoch 00062: val_loss did not improve from 0.63974
# Epoch 63/300
# 45/45 - 0s - loss: 0.5663 - accuracy: 0.7040 - val_loss: 0.6411 - val_accuracy: 0.6206
#
# Epoch 00063: val_loss did not improve from 0.63974
# Epoch 64/300
# 45/45 - 0s - loss: 0.5623 - accuracy: 0.7047 - val_loss: 0.6471 - val_accuracy: 0.6201
#
# Epoch 00064: val_loss did not improve from 0.63974
# Epoch 65/300
# 45/45 - 0s - loss: 0.5589 - accuracy: 0.7091 - val_loss: 0.6519 - val_accuracy: 0.6080
#
# Epoch 00065: val_loss did not improve from 0.63974
# Epoch 66/300
# 45/45 - 0s - loss: 0.5632 - accuracy: 0.7038 - val_loss: 0.6456 - val_accuracy: 0.6193
#
# Epoch 00066: val_loss did not improve from 0.63974
# Epoch 67/300
# 45/45 - 0s - loss: 0.5580 - accuracy: 0.7067 - val_loss: 0.6536 - val_accuracy: 0.6076
#
# Epoch 00067: val_loss did not improve from 0.63974
# Epoch 68/300
# 45/45 - 0s - loss: 0.5543 - accuracy: 0.7125 - val_loss: 0.6479 - val_accuracy: 0.6153
#
# Epoch 00068: val_loss did not improve from 0.63974
# Epoch 69/300
# 45/45 - 0s - loss: 0.5488 - accuracy: 0.7172 - val_loss: 0.6553 - val_accuracy: 0.6080
#
# Epoch 00069: val_loss did not improve from 0.63974
# Epoch 70/300
# 45/45 - 0s - loss: 0.5575 - accuracy: 0.7091 - val_loss: 0.6522 - val_accuracy: 0.6088
#
# Epoch 00070: val_loss did not improve from 0.63974
# Epoch 71/300
# 45/45 - 0s - loss: 0.5546 - accuracy: 0.7129 - val_loss: 0.6520 - val_accuracy: 0.6056
#
# Epoch 00071: val_loss did not improve from 0.63974
# Epoch 72/300
# 45/45 - 0s - loss: 0.5457 - accuracy: 0.7148 - val_loss: 0.6579 - val_accuracy: 0.6028
#
# Epoch 00072: val_loss did not improve from 0.63974
# Epoch 73/300
# 45/45 - 0s - loss: 0.5489 - accuracy: 0.7201 - val_loss: 0.6474 - val_accuracy: 0.6173
#
# Epoch 00073: val_loss did not improve from 0.63974
# Epoch 74/300
# 45/45 - 0s - loss: 0.5453 - accuracy: 0.7208 - val_loss: 0.6520 - val_accuracy: 0.6157
#
# Epoch 00074: val_loss did not improve from 0.63974
# Epoch 75/300
# 45/45 - 0s - loss: 0.5490 - accuracy: 0.7122 - val_loss: 0.6498 - val_accuracy: 0.6141
#
# Epoch 00075: val_loss did not improve from 0.63974
# Epoch 76/300
# 45/45 - 0s - loss: 0.5453 - accuracy: 0.7177 - val_loss: 0.6580 - val_accuracy: 0.6019
#
# Epoch 00076: val_loss did not improve from 0.63974
# Epoch 77/300
# 45/45 - 0s - loss: 0.5437 - accuracy: 0.7219 - val_loss: 0.6471 - val_accuracy: 0.6226
#
# Epoch 00077: val_loss did not improve from 0.63974
# Epoch 78/300
# 45/45 - 0s - loss: 0.5374 - accuracy: 0.7278 - val_loss: 0.6574 - val_accuracy: 0.6023
#
# Epoch 00078: val_loss did not improve from 0.63974
# Epoch 79/300
# 45/45 - 0s - loss: 0.5382 - accuracy: 0.7239 - val_loss: 0.6484 - val_accuracy: 0.6234
#
# Epoch 00079: val_loss did not improve from 0.63974
# Epoch 80/300
# 45/45 - 0s - loss: 0.5400 - accuracy: 0.7260 - val_loss: 0.6552 - val_accuracy: 0.6145
#
# Epoch 00080: val_loss did not improve from 0.63974
# Epoch 81/300
# 45/45 - 0s - loss: 0.5314 - accuracy: 0.7308 - val_loss: 0.6504 - val_accuracy: 0.6197
#
# Epoch 00081: val_loss did not improve from 0.63974
# Epoch 82/300
# 45/45 - 0s - loss: 0.5334 - accuracy: 0.7325 - val_loss: 0.6596 - val_accuracy: 0.6125
#
# Epoch 00082: val_loss did not improve from 0.63974
# Epoch 83/300
# 45/45 - 0s - loss: 0.5352 - accuracy: 0.7267 - val_loss: 0.6639 - val_accuracy: 0.5979
#
# Epoch 00083: val_loss did not improve from 0.63974
# Epoch 84/300
# 45/45 - 0s - loss: 0.5319 - accuracy: 0.7321 - val_loss: 0.6511 - val_accuracy: 0.6161
# Epoch 00084: val_loss did not improve from 0.63974
# Epoch 85/300
# 45/45 - 0s - loss: 0.5320 - accuracy: 0.7233 - val_loss: 0.6515 - val_accuracy: 0.6137
#
# Epoch 00085: val_loss did not improve from 0.63974
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6515 - accuracy: 0.6137
# Independent test: [0.6514788866043091, 0.6136731505393982]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew_datachange\model\based_model\5k\AcetdelUbi_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.7305825242718447,
#  'SP': 0.4967637540453074,
#  'ACC': 0.613673139158576,
#  'MCC': 0.23382794267842702,
#  'Recall': 0.7305825242718447,
#  'Precision': 0.5921311475409836,
#  'F1-score': 0.6541108294096342,
#  'Cutoff': 0.5}
