# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\client\session.py:1761: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.0001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\based\K去除NEDD')
    epoch = 150
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\based\K去除NEDD')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 41, 128)           2816
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 554/554 - 7s - loss: 0.6926 - accuracy: 0.5121 - val_loss: 0.6904 - val_accuracy: 0.5325
#
# Epoch 00001: val_loss improved from inf to 0.69037, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 2/150
# 554/554 - 6s - loss: 0.6884 - accuracy: 0.5386 - val_loss: 0.6862 - val_accuracy: 0.5556
#
# Epoch 00002: val_loss improved from 0.69037 to 0.68623, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 3/150
# 554/554 - 6s - loss: 0.6858 - accuracy: 0.5469 - val_loss: 0.6848 - val_accuracy: 0.5523
#
# Epoch 00003: val_loss improved from 0.68623 to 0.68483, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 4/150
# 554/554 - 6s - loss: 0.6835 - accuracy: 0.5536 - val_loss: 0.6829 - val_accuracy: 0.5692
#
# Epoch 00004: val_loss improved from 0.68483 to 0.68287, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 5/150
# 554/554 - 6s - loss: 0.6806 - accuracy: 0.5610 - val_loss: 0.6801 - val_accuracy: 0.5847
#
# Epoch 00005: val_loss improved from 0.68287 to 0.68007, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 6/150
# 554/554 - 6s - loss: 0.6751 - accuracy: 0.5734 - val_loss: 0.6725 - val_accuracy: 0.5927
#
# Epoch 00006: val_loss improved from 0.68007 to 0.67250, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 7/150
# 554/554 - 6s - loss: 0.6682 - accuracy: 0.5874 - val_loss: 0.6646 - val_accuracy: 0.6094
#
# Epoch 00007: val_loss improved from 0.67250 to 0.66463, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 8/150
# 554/554 - 6s - loss: 0.6619 - accuracy: 0.5984 - val_loss: 0.6573 - val_accuracy: 0.6219
#
# Epoch 00008: val_loss improved from 0.66463 to 0.65734, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 9/150
# 554/554 - 6s - loss: 0.6567 - accuracy: 0.6062 - val_loss: 0.6522 - val_accuracy: 0.6300
#
# Epoch 00009: val_loss improved from 0.65734 to 0.65222, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 10/150
# 554/554 - 6s - loss: 0.6522 - accuracy: 0.6134 - val_loss: 0.6506 - val_accuracy: 0.6321
#
# Epoch 00010: val_loss improved from 0.65222 to 0.65064, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 11/150
# 554/554 - 6s - loss: 0.6492 - accuracy: 0.6182 - val_loss: 0.6488 - val_accuracy: 0.6272
#
# Epoch 00011: val_loss improved from 0.65064 to 0.64879, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 12/150
# 554/554 - 6s - loss: 0.6462 - accuracy: 0.6206 - val_loss: 0.6483 - val_accuracy: 0.6349
#
# Epoch 00012: val_loss improved from 0.64879 to 0.64834, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 13/150
# 554/554 - 6s - loss: 0.6439 - accuracy: 0.6243 - val_loss: 0.6438 - val_accuracy: 0.6383
#
# Epoch 00013: val_loss improved from 0.64834 to 0.64378, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 14/150
# 554/554 - 6s - loss: 0.6429 - accuracy: 0.6253 - val_loss: 0.6422 - val_accuracy: 0.6347
#
# Epoch 00014: val_loss improved from 0.64378 to 0.64218, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 15/150
# 554/554 - 6s - loss: 0.6409 - accuracy: 0.6298 - val_loss: 0.6393 - val_accuracy: 0.6392
#
# Epoch 00015: val_loss improved from 0.64218 to 0.63935, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 16/150
# 554/554 - 6s - loss: 0.6387 - accuracy: 0.6318 - val_loss: 0.6409 - val_accuracy: 0.6393
#
# Epoch 00016: val_loss did not improve from 0.63935
# Epoch 17/150
# 554/554 - 6s - loss: 0.6378 - accuracy: 0.6333 - val_loss: 0.6410 - val_accuracy: 0.6391
#
# Epoch 00017: val_loss did not improve from 0.63935
# Epoch 18/150
# 554/554 - 6s - loss: 0.6367 - accuracy: 0.6345 - val_loss: 0.6391 - val_accuracy: 0.6427
#
# Epoch 00018: val_loss improved from 0.63935 to 0.63907, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 19/150
# 554/554 - 6s - loss: 0.6351 - accuracy: 0.6382 - val_loss: 0.6389 - val_accuracy: 0.6415
#
# Epoch 00019: val_loss improved from 0.63907 to 0.63891, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 20/150
# 554/554 - 6s - loss: 0.6331 - accuracy: 0.6390 - val_loss: 0.6376 - val_accuracy: 0.6433
#
# Epoch 00020: val_loss improved from 0.63891 to 0.63762, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 21/150
# 554/554 - 6s - loss: 0.6323 - accuracy: 0.6406 - val_loss: 0.6363 - val_accuracy: 0.6471
#
# Epoch 00021: val_loss improved from 0.63762 to 0.63628, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 22/150
# 554/554 - 6s - loss: 0.6316 - accuracy: 0.6410 - val_loss: 0.6353 - val_accuracy: 0.6460
#
# Epoch 00022: val_loss improved from 0.63628 to 0.63533, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 23/150
# 554/554 - 6s - loss: 0.6309 - accuracy: 0.6428 - val_loss: 0.6348 - val_accuracy: 0.6452
#
# Epoch 00023: val_loss improved from 0.63533 to 0.63482, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 24/150
# 554/554 - 6s - loss: 0.6300 - accuracy: 0.6440 - val_loss: 0.6355 - val_accuracy: 0.6480
#
# Epoch 00024: val_loss did not improve from 0.63482
# Epoch 25/150
# 554/554 - 6s - loss: 0.6289 - accuracy: 0.6448 - val_loss: 0.6331 - val_accuracy: 0.6505
#
# Epoch 00025: val_loss improved from 0.63482 to 0.63310, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 26/150
# 554/554 - 6s - loss: 0.6277 - accuracy: 0.6459 - val_loss: 0.6320 - val_accuracy: 0.6492
#
# Epoch 00026: val_loss improved from 0.63310 to 0.63197, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 27/150
# 554/554 - 6s - loss: 0.6273 - accuracy: 0.6475 - val_loss: 0.6298 - val_accuracy: 0.6496
#
# Epoch 00027: val_loss improved from 0.63197 to 0.62981, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 28/150
# 554/554 - 6s - loss: 0.6257 - accuracy: 0.6469 - val_loss: 0.6298 - val_accuracy: 0.6534
#
# Epoch 00028: val_loss did not improve from 0.62981
# Epoch 29/150
# 554/554 - 6s - loss: 0.6256 - accuracy: 0.6487 - val_loss: 0.6308 - val_accuracy: 0.6503
#
# Epoch 00029: val_loss did not improve from 0.62981
# Epoch 30/150
# 554/554 - 6s - loss: 0.6246 - accuracy: 0.6501 - val_loss: 0.6279 - val_accuracy: 0.6520
#
# Epoch 00030: val_loss improved from 0.62981 to 0.62788, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 31/150
# 554/554 - 6s - loss: 0.6244 - accuracy: 0.6494 - val_loss: 0.6312 - val_accuracy: 0.6551
#
# Epoch 00031: val_loss did not improve from 0.62788
# Epoch 32/150
# 554/554 - 6s - loss: 0.6241 - accuracy: 0.6508 - val_loss: 0.6290 - val_accuracy: 0.6544
#
# Epoch 00032: val_loss did not improve from 0.62788
# Epoch 33/150
# 554/554 - 6s - loss: 0.6237 - accuracy: 0.6503 - val_loss: 0.6297 - val_accuracy: 0.6540
#
# Epoch 00033: val_loss did not improve from 0.62788
# Epoch 34/150
# 554/554 - 6s - loss: 0.6224 - accuracy: 0.6523 - val_loss: 0.6287 - val_accuracy: 0.6537
#
# Epoch 00034: val_loss did not improve from 0.62788
# Epoch 35/150
# 554/554 - 6s - loss: 0.6217 - accuracy: 0.6529 - val_loss: 0.6277 - val_accuracy: 0.6576
#
# Epoch 00035: val_loss improved from 0.62788 to 0.62769, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 36/150
# 554/554 - 6s - loss: 0.6224 - accuracy: 0.6521 - val_loss: 0.6285 - val_accuracy: 0.6575
#
# Epoch 00036: val_loss did not improve from 0.62769
# Epoch 37/150
# 554/554 - 6s - loss: 0.6212 - accuracy: 0.6534 - val_loss: 0.6280 - val_accuracy: 0.6574
#
# Epoch 00037: val_loss did not improve from 0.62769
# Epoch 38/150
# 554/554 - 6s - loss: 0.6209 - accuracy: 0.6547 - val_loss: 0.6270 - val_accuracy: 0.6562
#
# Epoch 00038: val_loss improved from 0.62769 to 0.62698, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 39/150
# 554/554 - 6s - loss: 0.6191 - accuracy: 0.6578 - val_loss: 0.6274 - val_accuracy: 0.6585
#
# Epoch 00039: val_loss did not improve from 0.62698
# Epoch 40/150
# 554/554 - 6s - loss: 0.6190 - accuracy: 0.6565 - val_loss: 0.6239 - val_accuracy: 0.6590
#
# Epoch 00040: val_loss improved from 0.62698 to 0.62391, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 41/150
# 554/554 - 6s - loss: 0.6196 - accuracy: 0.6559 - val_loss: 0.6267 - val_accuracy: 0.6578
#
# Epoch 00041: val_loss did not improve from 0.62391
# Epoch 42/150
# 554/554 - 6s - loss: 0.6189 - accuracy: 0.6562 - val_loss: 0.6245 - val_accuracy: 0.6591
#
# Epoch 00042: val_loss did not improve from 0.62391
# Epoch 43/150
# 554/554 - 6s - loss: 0.6187 - accuracy: 0.6565 - val_loss: 0.6227 - val_accuracy: 0.6601
#
# Epoch 00043: val_loss improved from 0.62391 to 0.62274, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 44/150
# 554/554 - 6s - loss: 0.6182 - accuracy: 0.6569 - val_loss: 0.6244 - val_accuracy: 0.6593
#
# Epoch 00044: val_loss did not improve from 0.62274
# Epoch 45/150
# 554/554 - 6s - loss: 0.6175 - accuracy: 0.6581 - val_loss: 0.6227 - val_accuracy: 0.6599
#
# Epoch 00045: val_loss improved from 0.62274 to 0.62268, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 46/150
# 554/554 - 6s - loss: 0.6170 - accuracy: 0.6578 - val_loss: 0.6236 - val_accuracy: 0.6592
#
# Epoch 00046: val_loss did not improve from 0.62268
# Epoch 47/150
# 554/554 - 6s - loss: 0.6174 - accuracy: 0.6575 - val_loss: 0.6227 - val_accuracy: 0.6609
#
# Epoch 00047: val_loss did not improve from 0.62268
# Epoch 48/150
# 554/554 - 6s - loss: 0.6173 - accuracy: 0.6570 - val_loss: 0.6256 - val_accuracy: 0.6602
#
# Epoch 00048: val_loss did not improve from 0.62268
# Epoch 49/150
# 554/554 - 6s - loss: 0.6168 - accuracy: 0.6567 - val_loss: 0.6231 - val_accuracy: 0.6607
#
# Epoch 00049: val_loss did not improve from 0.62268
# Epoch 50/150
# 554/554 - 6s - loss: 0.6161 - accuracy: 0.6604 - val_loss: 0.6221 - val_accuracy: 0.6618
#
# Epoch 00050: val_loss improved from 0.62268 to 0.62214, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 51/150
# 554/554 - 6s - loss: 0.6159 - accuracy: 0.6601 - val_loss: 0.6212 - val_accuracy: 0.6623
#
# Epoch 00051: val_loss improved from 0.62214 to 0.62117, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 52/150
# 554/554 - 6s - loss: 0.6148 - accuracy: 0.6604 - val_loss: 0.6216 - val_accuracy: 0.6609
#
# Epoch 00052: val_loss did not improve from 0.62117
# Epoch 53/150
# 554/554 - 6s - loss: 0.6151 - accuracy: 0.6610 - val_loss: 0.6230 - val_accuracy: 0.6606
#
# Epoch 00053: val_loss did not improve from 0.62117
# Epoch 54/150
# 554/554 - 6s - loss: 0.6150 - accuracy: 0.6595 - val_loss: 0.6232 - val_accuracy: 0.6611
#
# Epoch 00054: val_loss did not improve from 0.62117
# Epoch 55/150
# 554/554 - 6s - loss: 0.6148 - accuracy: 0.6604 - val_loss: 0.6189 - val_accuracy: 0.6621
#
# Epoch 00055: val_loss improved from 0.62117 to 0.61886, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 56/150
# 554/554 - 6s - loss: 0.6150 - accuracy: 0.6605 - val_loss: 0.6211 - val_accuracy: 0.6615
#
# Epoch 00056: val_loss did not improve from 0.61886
# Epoch 57/150
# 554/554 - 6s - loss: 0.6140 - accuracy: 0.6610 - val_loss: 0.6202 - val_accuracy: 0.6616
#
# Epoch 00057: val_loss did not improve from 0.61886
# Epoch 58/150
# 554/554 - 6s - loss: 0.6138 - accuracy: 0.6619 - val_loss: 0.6206 - val_accuracy: 0.6642
#
# Epoch 00058: val_loss did not improve from 0.61886
# Epoch 59/150
# 554/554 - 6s - loss: 0.6141 - accuracy: 0.6602 - val_loss: 0.6204 - val_accuracy: 0.6640
#
# Epoch 00059: val_loss did not improve from 0.61886
# Epoch 60/150
# 554/554 - 6s - loss: 0.6130 - accuracy: 0.6627 - val_loss: 0.6196 - val_accuracy: 0.6616
#
# Epoch 00060: val_loss did not improve from 0.61886
# Epoch 61/150
# 554/554 - 6s - loss: 0.6125 - accuracy: 0.6622 - val_loss: 0.6197 - val_accuracy: 0.6630
#
# Epoch 00061: val_loss did not improve from 0.61886
# Epoch 62/150
# 554/554 - 6s - loss: 0.6126 - accuracy: 0.6617 - val_loss: 0.6187 - val_accuracy: 0.6623
#
# Epoch 00062: val_loss improved from 0.61886 to 0.61871, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 63/150
# 554/554 - 6s - loss: 0.6121 - accuracy: 0.6633 - val_loss: 0.6208 - val_accuracy: 0.6614
#
# Epoch 00063: val_loss did not improve from 0.61871
# Epoch 64/150
# 554/554 - 6s - loss: 0.6130 - accuracy: 0.6623 - val_loss: 0.6184 - val_accuracy: 0.6637
#
# Epoch 00064: val_loss improved from 0.61871 to 0.61844, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 65/150
# 554/554 - 6s - loss: 0.6127 - accuracy: 0.6625 - val_loss: 0.6181 - val_accuracy: 0.6622
#
# Epoch 00065: val_loss improved from 0.61844 to 0.61812, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 66/150
# 554/554 - 6s - loss: 0.6123 - accuracy: 0.6629 - val_loss: 0.6204 - val_accuracy: 0.6619
# Epoch 00066: val_loss did not improve from 0.61812
# Epoch 67/150
# 554/554 - 6s - loss: 0.6119 - accuracy: 0.6643 - val_loss: 0.6189 - val_accuracy: 0.6626
#
# Epoch 00067: val_loss did not improve from 0.61812
# Epoch 68/150
# 554/554 - 6s - loss: 0.6113 - accuracy: 0.6637 - val_loss: 0.6183 - val_accuracy: 0.6645
#
# Epoch 00068: val_loss did not improve from 0.61812
# Epoch 69/150
# 554/554 - 6s - loss: 0.6116 - accuracy: 0.6648 - val_loss: 0.6157 - val_accuracy: 0.6649
#
# Epoch 00069: val_loss improved from 0.61812 to 0.61572, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 70/150
# 554/554 - 6s - loss: 0.6110 - accuracy: 0.6642 - val_loss: 0.6185 - val_accuracy: 0.6616
#
# Epoch 00070: val_loss did not improve from 0.61572
# Epoch 71/150
# 554/554 - 6s - loss: 0.6108 - accuracy: 0.6654 - val_loss: 0.6178 - val_accuracy: 0.6642
#
# Epoch 00071: val_loss did not improve from 0.61572
# Epoch 72/150
# 554/554 - 6s - loss: 0.6106 - accuracy: 0.6646 - val_loss: 0.6181 - val_accuracy: 0.6638
#
# Epoch 00072: val_loss did not improve from 0.61572
# Epoch 73/150
# 554/554 - 6s - loss: 0.6107 - accuracy: 0.6646 - val_loss: 0.6183 - val_accuracy: 0.6628
#
# Epoch 00073: val_loss did not improve from 0.61572
# Epoch 74/150
# 554/554 - 6s - loss: 0.6105 - accuracy: 0.6654 - val_loss: 0.6179 - val_accuracy: 0.6641
#
# Epoch 00074: val_loss did not improve from 0.61572
# Epoch 75/150
# 554/554 - 6s - loss: 0.6103 - accuracy: 0.6652 - val_loss: 0.6186 - val_accuracy: 0.6644
#
# Epoch 00075: val_loss did not improve from 0.61572
# Epoch 76/150
# 554/554 - 6s - loss: 0.6099 - accuracy: 0.6653 - val_loss: 0.6170 - val_accuracy: 0.6635
#
# Epoch 00076: val_loss did not improve from 0.61572
# Epoch 77/150
# 554/554 - 6s - loss: 0.6112 - accuracy: 0.6642 - val_loss: 0.6182 - val_accuracy: 0.6636
#
# Epoch 00077: val_loss did not improve from 0.61572
# Epoch 78/150
# 554/554 - 6s - loss: 0.6098 - accuracy: 0.6655 - val_loss: 0.6172 - val_accuracy: 0.6624
#
# Epoch 00078: val_loss did not improve from 0.61572
# Epoch 79/150
# 554/554 - 6s - loss: 0.6096 - accuracy: 0.6660 - val_loss: 0.6187 - val_accuracy: 0.6633
#
# Epoch 00079: val_loss did not improve from 0.61572
# Epoch 80/150
# 554/554 - 6s - loss: 0.6092 - accuracy: 0.6652 - val_loss: 0.6173 - val_accuracy: 0.6637
#
# Epoch 00080: val_loss did not improve from 0.61572
# Epoch 81/150
# 554/554 - 6s - loss: 0.6096 - accuracy: 0.6664 - val_loss: 0.6159 - val_accuracy: 0.6652
#
# Epoch 00081: val_loss did not improve from 0.61572
# Epoch 82/150
# 554/554 - 6s - loss: 0.6090 - accuracy: 0.6652 - val_loss: 0.6164 - val_accuracy: 0.6649
#
# Epoch 00082: val_loss did not improve from 0.61572
# Epoch 83/150
# 554/554 - 6s - loss: 0.6090 - accuracy: 0.6656 - val_loss: 0.6178 - val_accuracy: 0.6647
#
# Epoch 00083: val_loss did not improve from 0.61572
# Epoch 84/150
# 554/554 - 6s - loss: 0.6084 - accuracy: 0.6672 - val_loss: 0.6155 - val_accuracy: 0.6651
#
# Epoch 00084: val_loss improved from 0.61572 to 0.61550, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 85/150
# 554/554 - 6s - loss: 0.6093 - accuracy: 0.6655 - val_loss: 0.6158 - val_accuracy: 0.6660
#
# Epoch 00085: val_loss did not improve from 0.61550
# Epoch 86/150
# 554/554 - 6s - loss: 0.6087 - accuracy: 0.6664 - val_loss: 0.6154 - val_accuracy: 0.6635
#
# Epoch 00086: val_loss improved from 0.61550 to 0.61543, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 87/150
# 554/554 - 6s - loss: 0.6076 - accuracy: 0.6667 - val_loss: 0.6148 - val_accuracy: 0.6659
#
# Epoch 00087: val_loss improved from 0.61543 to 0.61476, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 88/150
# 554/554 - 6s - loss: 0.6079 - accuracy: 0.6667 - val_loss: 0.6158 - val_accuracy: 0.6657
#
# Epoch 00088: val_loss did not improve from 0.61476
# Epoch 89/150
# 554/554 - 6s - loss: 0.6071 - accuracy: 0.6683 - val_loss: 0.6157 - val_accuracy: 0.6661
#
# Epoch 00089: val_loss did not improve from 0.61476
# Epoch 90/150
# 554/554 - 6s - loss: 0.6074 - accuracy: 0.6674 - val_loss: 0.6158 - val_accuracy: 0.6659
#
# Epoch 00090: val_loss did not improve from 0.61476
# Epoch 91/150
# 554/554 - 6s - loss: 0.6073 - accuracy: 0.6675 - val_loss: 0.6164 - val_accuracy: 0.6669
#
# Epoch 00091: val_loss did not improve from 0.61476
# Epoch 92/150
# 554/554 - 6s - loss: 0.6087 - accuracy: 0.6660 - val_loss: 0.6151 - val_accuracy: 0.6671
#
# Epoch 00092: val_loss did not improve from 0.61476
# Epoch 93/150
# 554/554 - 6s - loss: 0.6077 - accuracy: 0.6660 - val_loss: 0.6153 - val_accuracy: 0.6656
#
# Epoch 00093: val_loss did not improve from 0.61476
# Epoch 94/150
# 554/554 - 6s - loss: 0.6065 - accuracy: 0.6685 - val_loss: 0.6165 - val_accuracy: 0.6663
#
# Epoch 00094: val_loss did not improve from 0.61476
# Epoch 95/150
# 554/554 - 6s - loss: 0.6064 - accuracy: 0.6687 - val_loss: 0.6154 - val_accuracy: 0.6681
#
# Epoch 00095: val_loss did not improve from 0.61476
# Epoch 96/150
# 554/554 - 6s - loss: 0.6061 - accuracy: 0.6693 - val_loss: 0.6174 - val_accuracy: 0.6668
#
# Epoch 00096: val_loss did not improve from 0.61476
# Epoch 97/150
# 554/554 - 6s - loss: 0.6068 - accuracy: 0.6683 - val_loss: 0.6160 - val_accuracy: 0.6669
#
# Epoch 00097: val_loss did not improve from 0.61476
# Epoch 98/150
# 554/554 - 6s - loss: 0.6067 - accuracy: 0.6685 - val_loss: 0.6150 - val_accuracy: 0.6682
#
# Epoch 00098: val_loss did not improve from 0.61476
# Epoch 99/150
# 554/554 - 6s - loss: 0.6062 - accuracy: 0.6683 - val_loss: 0.6136 - val_accuracy: 0.6641
#
# Epoch 00099: val_loss improved from 0.61476 to 0.61363, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 100/150
# 554/554 - 6s - loss: 0.6062 - accuracy: 0.6696 - val_loss: 0.6151 - val_accuracy: 0.6661
#
# Epoch 00100: val_loss did not improve from 0.61363
# Epoch 101/150
# 554/554 - 6s - loss: 0.6059 - accuracy: 0.6687 - val_loss: 0.6162 - val_accuracy: 0.6682
#
# Epoch 00101: val_loss did not improve from 0.61363
# Epoch 102/150
# 554/554 - 6s - loss: 0.6057 - accuracy: 0.6689 - val_loss: 0.6154 - val_accuracy: 0.6682
#
# Epoch 00102: val_loss did not improve from 0.61363
# Epoch 103/150
# 554/554 - 6s - loss: 0.6048 - accuracy: 0.6708 - val_loss: 0.6154 - val_accuracy: 0.6667
#
# Epoch 00103: val_loss did not improve from 0.61363
# Epoch 104/150
# 554/554 - 6s - loss: 0.6050 - accuracy: 0.6699 - val_loss: 0.6141 - val_accuracy: 0.6661
#
# Epoch 00104: val_loss did not improve from 0.61363
# Epoch 105/150
# 554/554 - 6s - loss: 0.6056 - accuracy: 0.6699 - val_loss: 0.6148 - val_accuracy: 0.6654
#
# Epoch 00105: val_loss did not improve from 0.61363
# Epoch 106/150
# 554/554 - 6s - loss: 0.6052 - accuracy: 0.6704 - val_loss: 0.6157 - val_accuracy: 0.6671
#
# Epoch 00106: val_loss did not improve from 0.61363
# Epoch 107/150
# 554/554 - 6s - loss: 0.6047 - accuracy: 0.6701 - val_loss: 0.6139 - val_accuracy: 0.6680
#
# Epoch 00107: val_loss did not improve from 0.61363
# Epoch 108/150
# 554/554 - 6s - loss: 0.6052 - accuracy: 0.6692 - val_loss: 0.6131 - val_accuracy: 0.6676
#
# Epoch 00108: val_loss improved from 0.61363 to 0.61312, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 109/150
# 554/554 - 6s - loss: 0.6050 - accuracy: 0.6705 - val_loss: 0.6131 - val_accuracy: 0.6665
#
# Epoch 00109: val_loss improved from 0.61312 to 0.61309, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 110/150
# 554/554 - 6s - loss: 0.6051 - accuracy: 0.6697 - val_loss: 0.6128 - val_accuracy: 0.6661
#
# Epoch 00110: val_loss improved from 0.61309 to 0.61276, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 111/150
# 554/554 - 6s - loss: 0.6049 - accuracy: 0.6690 - val_loss: 0.6139 - val_accuracy: 0.6676
#
# Epoch 00111: val_loss did not improve from 0.61276
# Epoch 112/150
# 554/554 - 6s - loss: 0.6040 - accuracy: 0.6711 - val_loss: 0.6165 - val_accuracy: 0.6681
#
# Epoch 00112: val_loss did not improve from 0.61276
# Epoch 113/150
# 554/554 - 6s - loss: 0.6044 - accuracy: 0.6702 - val_loss: 0.6136 - val_accuracy: 0.6678
# Epoch 00113: val_loss did not improve from 0.61276
# Epoch 114/150
# 554/554 - 6s - loss: 0.6034 - accuracy: 0.6714 - val_loss: 0.6142 - val_accuracy: 0.6684
#
# Epoch 00114: val_loss did not improve from 0.61276
# Epoch 115/150
# 554/554 - 6s - loss: 0.6042 - accuracy: 0.6695 - val_loss: 0.6135 - val_accuracy: 0.6674
#
# Epoch 00115: val_loss did not improve from 0.61276
# Epoch 116/150
# 554/554 - 6s - loss: 0.6027 - accuracy: 0.6727 - val_loss: 0.6145 - val_accuracy: 0.6664
#
# Epoch 00116: val_loss did not improve from 0.61276
# Epoch 117/150
# 554/554 - 6s - loss: 0.6039 - accuracy: 0.6722 - val_loss: 0.6152 - val_accuracy: 0.6676
#
# Epoch 00117: val_loss did not improve from 0.61276
# Epoch 118/150
# 554/554 - 6s - loss: 0.6036 - accuracy: 0.6699 - val_loss: 0.6135 - val_accuracy: 0.6676
#
# Epoch 00118: val_loss did not improve from 0.61276
# Epoch 119/150
# 554/554 - 6s - loss: 0.6031 - accuracy: 0.6720 - val_loss: 0.6129 - val_accuracy: 0.6659
#
# Epoch 00119: val_loss did not improve from 0.61276
# Epoch 120/150
# 554/554 - 6s - loss: 0.6031 - accuracy: 0.6726 - val_loss: 0.6137 - val_accuracy: 0.6663
#
# Epoch 00120: val_loss did not improve from 0.61276
# Epoch 121/150
# 554/554 - 6s - loss: 0.6028 - accuracy: 0.6720 - val_loss: 0.6136 - val_accuracy: 0.6658
#
# Epoch 00121: val_loss did not improve from 0.61276
# Epoch 122/150
# 554/554 - 6s - loss: 0.6039 - accuracy: 0.6727 - val_loss: 0.6127 - val_accuracy: 0.6649
#
# Epoch 00122: val_loss improved from 0.61276 to 0.61271, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 123/150
# 554/554 - 6s - loss: 0.6020 - accuracy: 0.6734 - val_loss: 0.6131 - val_accuracy: 0.6682
#
# Epoch 00123: val_loss did not improve from 0.61271
# Epoch 124/150
# 554/554 - 6s - loss: 0.6019 - accuracy: 0.6743 - val_loss: 0.6134 - val_accuracy: 0.6642
#
# Epoch 00124: val_loss did not improve from 0.61271
# Epoch 125/150
# 554/554 - 6s - loss: 0.6031 - accuracy: 0.6713 - val_loss: 0.6154 - val_accuracy: 0.6652
#
# Epoch 00125: val_loss did not improve from 0.61271
# Epoch 126/150
# 554/554 - 6s - loss: 0.6024 - accuracy: 0.6730 - val_loss: 0.6147 - val_accuracy: 0.6683
#
# Epoch 00126: val_loss did not improve from 0.61271
# Epoch 127/150
# 554/554 - 6s - loss: 0.6015 - accuracy: 0.6739 - val_loss: 0.6132 - val_accuracy: 0.6669
#
# Epoch 00127: val_loss did not improve from 0.61271
# Epoch 128/150
# 554/554 - 6s - loss: 0.6026 - accuracy: 0.6724 - val_loss: 0.6132 - val_accuracy: 0.6697
#
# Epoch 00128: val_loss did not improve from 0.61271
# Epoch 129/150
# 554/554 - 6s - loss: 0.6023 - accuracy: 0.6728 - val_loss: 0.6132 - val_accuracy: 0.6702
#
# Epoch 00129: val_loss did not improve from 0.61271
# Epoch 130/150
# 554/554 - 6s - loss: 0.6019 - accuracy: 0.6725 - val_loss: 0.6116 - val_accuracy: 0.6673
#
# Epoch 00130: val_loss improved from 0.61271 to 0.61162, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 131/150
# 554/554 - 6s - loss: 0.6008 - accuracy: 0.6725 - val_loss: 0.6129 - val_accuracy: 0.6670
#
# Epoch 00131: val_loss did not improve from 0.61162
# Epoch 132/150
# 554/554 - 6s - loss: 0.6023 - accuracy: 0.6729 - val_loss: 0.6130 - val_accuracy: 0.6651
#
# Epoch 00132: val_loss did not improve from 0.61162
# Epoch 133/150
# 554/554 - 6s - loss: 0.6012 - accuracy: 0.6736 - val_loss: 0.6123 - val_accuracy: 0.6661
#
# Epoch 00133: val_loss did not improve from 0.61162
# Epoch 134/150
# 554/554 - 6s - loss: 0.6018 - accuracy: 0.6730 - val_loss: 0.6132 - val_accuracy: 0.6676
#
# Epoch 00134: val_loss did not improve from 0.61162
# Epoch 135/150
# 554/554 - 6s - loss: 0.6008 - accuracy: 0.6739 - val_loss: 0.6119 - val_accuracy: 0.6679
#
# Epoch 00135: val_loss did not improve from 0.61162
# Epoch 136/150
# 554/554 - 6s - loss: 0.6010 - accuracy: 0.6742 - val_loss: 0.6125 - val_accuracy: 0.6669
#
# Epoch 00136: val_loss did not improve from 0.61162
# Epoch 137/150
# 554/554 - 6s - loss: 0.6012 - accuracy: 0.6730 - val_loss: 0.6117 - val_accuracy: 0.6683
#
# Epoch 00137: val_loss did not improve from 0.61162
# Epoch 138/150
# 554/554 - 6s - loss: 0.6015 - accuracy: 0.6731 - val_loss: 0.6116 - val_accuracy: 0.6673
#
# Epoch 00138: val_loss improved from 0.61162 to 0.61161, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 139/150
# 554/554 - 6s - loss: 0.6014 - accuracy: 0.6732 - val_loss: 0.6117 - val_accuracy: 0.6694
#
# Epoch 00139: val_loss did not improve from 0.61161
# Epoch 140/150
# 554/554 - 6s - loss: 0.6010 - accuracy: 0.6751 - val_loss: 0.6127 - val_accuracy: 0.6685
#
# Epoch 00140: val_loss did not improve from 0.61161
# Epoch 141/150
# 554/554 - 6s - loss: 0.6002 - accuracy: 0.6748 - val_loss: 0.6129 - val_accuracy: 0.6659
#
# Epoch 00141: val_loss did not improve from 0.61161
# Epoch 142/150
# 554/554 - 6s - loss: 0.6005 - accuracy: 0.6755 - val_loss: 0.6119 - val_accuracy: 0.6666
#
# Epoch 00142: val_loss did not improve from 0.61161
# Epoch 143/150
# 554/554 - 6s - loss: 0.6010 - accuracy: 0.6733 - val_loss: 0.6140 - val_accuracy: 0.6669
#
# Epoch 00143: val_loss did not improve from 0.61161
# Epoch 144/150
# 554/554 - 6s - loss: 0.6007 - accuracy: 0.6736 - val_loss: 0.6134 - val_accuracy: 0.6680
#
# Epoch 00144: val_loss did not improve from 0.61161
# Epoch 145/150
# 554/554 - 6s - loss: 0.5999 - accuracy: 0.6742 - val_loss: 0.6124 - val_accuracy: 0.6695
#
# Epoch 00145: val_loss did not improve from 0.61161
# Epoch 146/150
# 554/554 - 6s - loss: 0.6008 - accuracy: 0.6736 - val_loss: 0.6134 - val_accuracy: 0.6681
#
# Epoch 00146: val_loss did not improve from 0.61161
# Epoch 147/150
# 554/554 - 6s - loss: 0.6001 - accuracy: 0.6745 - val_loss: 0.6115 - val_accuracy: 0.6671
#
# Epoch 00147: val_loss improved from 0.61161 to 0.61152, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.h5
# Epoch 148/150
# 554/554 - 6s - loss: 0.6007 - accuracy: 0.6746 - val_loss: 0.6149 - val_accuracy: 0.6702
#
# Epoch 00148: val_loss did not improve from 0.61152
# Epoch 149/150
# 554/554 - 6s - loss: 0.6006 - accuracy: 0.6739 - val_loss: 0.6120 - val_accuracy: 0.6683
#
# Epoch 00149: val_loss did not improve from 0.61152
# Epoch 150/150
# 554/554 - 6s - loss: 0.6006 - accuracy: 0.6741 - val_loss: 0.6140 - val_accuracy: 0.6669
#
# Epoch 00150: val_loss did not improve from 0.61152
# 56/56 [==============================] - 0s 4ms/step - loss: 0.6140 - accuracy: 0.6669
# Independent test: [0.6140289902687073, 0.6669253706932068]

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric
# Out:
# {'SN': 0.6931000423310286,
#  'SP': 0.6407506702412868,
#  'ACC': 0.6669253562861578,
#  'MCC': 0.334309106665413,
#  'Recall': 0.6931000423310286,
#  'Precision': 0.6586216143738267,
#  'F1-score': 0.6754211069095909,
#  'Cutoff': 0.5}

# %%
fpr, tpr, thresholds = roc_curve(y_true, pred)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, lw=1, alpha=0.7, label='ROC (AUC = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Random', alpha=.8)
plt.xlim([0, 1.0])
plt.ylim([0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('CNN_OH_val.png')
plt.show()
