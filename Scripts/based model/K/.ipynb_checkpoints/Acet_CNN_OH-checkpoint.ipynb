# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.0001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def save_predict_result(data, output):
    with open(output, 'w') as f:
        f.write('# result for true and predict \n')
        for i in data:
            f.write('%d\t%.8f\n' % (i[0], float(i[1])))
    return None

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
def evaluate(X, y, indep=None, batch_size=256, epochs=150):
    classes = sorted(list(set(y)))

    X_train, y_train = X, y
    X_test, y_test = indep[0], indep[1]

    X_train = one_hot(X_train)
    X_test = one_hot(X_test)

    X_train_t = X_train
    X_test_t = X_test
    X_train_t.shape = (X_train_t.shape[0], X_train_t.shape[2], X_train_t.shape[3])
    X_test_t.shape = (X_test_t.shape[0], X_test_t.shape[2], X_test_t.shape[3]) #删除无效维度
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((X_train_t, y_train))
    train_db = train_db.shuffle(len(X)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    test_db = tf.data.Dataset.from_tensor_slices((X_test_t, y_test))
    test_db = test_db.map(preprocess).batch(batch_size)

    network = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath=r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5', monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=test_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)

    print("Independent test:", network.evaluate(test_db))
    tmp_result = np.zeros((len(y_test), len(classes)))
    tmp_result[:, 0], tmp_result[:, 1] = y_test, network.predict(X_test_t, batch_size=batch_size)[:, 0]
    return tmp_result, history, y_test

# %%
def main():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew\data\based\Acet\处理过程')
    epoch = 150
    X, y = One_hot_raw('train.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Paper\data\based_model_data\原数据\训练集\K_NEDD\41window')
    indep = One_hot_raw('test.txt')
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH')
    ind_res, history, y_test = evaluate(X, y, indep=indep, epochs=epoch, batch_size=256)
    save_predict_result(ind_res, r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.txt')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('new-data-cnn.png')
    
if __name__ == '__main__':
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 183/183 - 7s - loss: 0.6928 - accuracy: 0.5161 - val_loss: 0.6923 - val_accuracy: 0.5146
#
# Epoch 00001: val_loss improved from inf to 0.69227, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 2/150
# 183/183 - 2s - loss: 0.6889 - accuracy: 0.5356 - val_loss: 0.6902 - val_accuracy: 0.5304
#
# Epoch 00002: val_loss improved from 0.69227 to 0.69018, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 3/150
# 183/183 - 2s - loss: 0.6859 - accuracy: 0.5487 - val_loss: 0.6891 - val_accuracy: 0.5374
#
# Epoch 00003: val_loss improved from 0.69018 to 0.68912, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 4/150
# 183/183 - 2s - loss: 0.6843 - accuracy: 0.5536 - val_loss: 0.6885 - val_accuracy: 0.5418
#
# Epoch 00004: val_loss improved from 0.68912 to 0.68855, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 5/150
# 183/183 - 2s - loss: 0.6831 - accuracy: 0.5582 - val_loss: 0.6871 - val_accuracy: 0.5456
#
# Epoch 00005: val_loss improved from 0.68855 to 0.68707, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 6/150
# 183/183 - 2s - loss: 0.6823 - accuracy: 0.5583 - val_loss: 0.6868 - val_accuracy: 0.5491
#
# Epoch 00006: val_loss improved from 0.68707 to 0.68680, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 7/150
# 183/183 - 2s - loss: 0.6802 - accuracy: 0.5644 - val_loss: 0.6855 - val_accuracy: 0.5512
#
# Epoch 00007: val_loss improved from 0.68680 to 0.68548, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 8/150
# 183/183 - 2s - loss: 0.6793 - accuracy: 0.5681 - val_loss: 0.6845 - val_accuracy: 0.5591
#
# Epoch 00008: val_loss improved from 0.68548 to 0.68449, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 9/150
# 183/183 - 2s - loss: 0.6773 - accuracy: 0.5720 - val_loss: 0.6822 - val_accuracy: 0.5660
#
# Epoch 00009: val_loss improved from 0.68449 to 0.68222, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 10/150
# 183/183 - 2s - loss: 0.6731 - accuracy: 0.5793 - val_loss: 0.6789 - val_accuracy: 0.5783
#
# Epoch 00010: val_loss improved from 0.68222 to 0.67888, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 11/150
# 183/183 - 2s - loss: 0.6691 - accuracy: 0.5906 - val_loss: 0.6745 - val_accuracy: 0.5866
#
# Epoch 00011: val_loss improved from 0.67888 to 0.67446, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 12/150
# 183/183 - 2s - loss: 0.6636 - accuracy: 0.5990 - val_loss: 0.6695 - val_accuracy: 0.5987
#
# Epoch 00012: val_loss improved from 0.67446 to 0.66953, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 13/150
# 183/183 - 2s - loss: 0.6575 - accuracy: 0.6071 - val_loss: 0.6651 - val_accuracy: 0.6075
#
# Epoch 00013: val_loss improved from 0.66953 to 0.66505, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 14/150
# 183/183 - 2s - loss: 0.6514 - accuracy: 0.6173 - val_loss: 0.6622 - val_accuracy: 0.6100
#
# Epoch 00014: val_loss improved from 0.66505 to 0.66218, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 15/150
# 183/183 - 2s - loss: 0.6470 - accuracy: 0.6187 - val_loss: 0.6582 - val_accuracy: 0.6169
#
# Epoch 00015: val_loss improved from 0.66218 to 0.65823, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 16/150
# 183/183 - 2s - loss: 0.6444 - accuracy: 0.6262 - val_loss: 0.6581 - val_accuracy: 0.6107
#
# Epoch 00016: val_loss improved from 0.65823 to 0.65807, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 17/150
# 183/183 - 2s - loss: 0.6431 - accuracy: 0.6272 - val_loss: 0.6563 - val_accuracy: 0.6166
#
# Epoch 00017: val_loss improved from 0.65807 to 0.65634, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 18/150
# 183/183 - 2s - loss: 0.6375 - accuracy: 0.6313 - val_loss: 0.6520 - val_accuracy: 0.6229
#
# Epoch 00018: val_loss improved from 0.65634 to 0.65198, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 19/150
# 183/183 - 2s - loss: 0.6371 - accuracy: 0.6340 - val_loss: 0.6505 - val_accuracy: 0.6249
#
# Epoch 00019: val_loss improved from 0.65198 to 0.65049, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 20/150
# 183/183 - 2s - loss: 0.6354 - accuracy: 0.6368 - val_loss: 0.6504 - val_accuracy: 0.6248
#
# Epoch 00020: val_loss improved from 0.65049 to 0.65036, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 21/150
# 183/183 - 2s - loss: 0.6313 - accuracy: 0.6409 - val_loss: 0.6509 - val_accuracy: 0.6158
#
# Epoch 00021: val_loss did not improve from 0.65036
# Epoch 22/150
# 183/183 - 2s - loss: 0.6308 - accuracy: 0.6412 - val_loss: 0.6481 - val_accuracy: 0.6260
#
# Epoch 00022: val_loss improved from 0.65036 to 0.64805, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 23/150
# 183/183 - 2s - loss: 0.6270 - accuracy: 0.6471 - val_loss: 0.6474 - val_accuracy: 0.6243
#
# Epoch 00023: val_loss improved from 0.64805 to 0.64744, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 24/150
# 183/183 - 2s - loss: 0.6261 - accuracy: 0.6463 - val_loss: 0.6453 - val_accuracy: 0.6308
#
# Epoch 00024: val_loss improved from 0.64744 to 0.64527, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 25/150
# 183/183 - 2s - loss: 0.6260 - accuracy: 0.6457 - val_loss: 0.6471 - val_accuracy: 0.6242
#
# Epoch 00025: val_loss did not improve from 0.64527
# Epoch 26/150
# 183/183 - 2s - loss: 0.6234 - accuracy: 0.6512 - val_loss: 0.6436 - val_accuracy: 0.6282
#
# Epoch 00026: val_loss improved from 0.64527 to 0.64363, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 27/150
# 183/183 - 2s - loss: 0.6218 - accuracy: 0.6528 - val_loss: 0.6438 - val_accuracy: 0.6294
#
# Epoch 00027: val_loss did not improve from 0.64363
# Epoch 28/150
# 183/183 - 2s - loss: 0.6203 - accuracy: 0.6529 - val_loss: 0.6446 - val_accuracy: 0.6261
#
# Epoch 00028: val_loss did not improve from 0.64363
# Epoch 29/150
# 183/183 - 2s - loss: 0.6194 - accuracy: 0.6565 - val_loss: 0.6428 - val_accuracy: 0.6298
#
# Epoch 00029: val_loss improved from 0.64363 to 0.64282, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 30/150
# 183/183 - 2s - loss: 0.6190 - accuracy: 0.6578 - val_loss: 0.6425 - val_accuracy: 0.6277
#
# Epoch 00030: val_loss improved from 0.64282 to 0.64247, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 31/150
# 183/183 - 2s - loss: 0.6164 - accuracy: 0.6608 - val_loss: 0.6419 - val_accuracy: 0.6280
#
# Epoch 00031: val_loss improved from 0.64247 to 0.64186, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 32/150
# 183/183 - 2s - loss: 0.6164 - accuracy: 0.6580 - val_loss: 0.6418 - val_accuracy: 0.6277
#
# Epoch 00032: val_loss improved from 0.64186 to 0.64176, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 33/150
# 183/183 - 2s - loss: 0.6136 - accuracy: 0.6626 - val_loss: 0.6414 - val_accuracy: 0.6298
#
# Epoch 00033: val_loss improved from 0.64176 to 0.64140, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 34/150
# 183/183 - 2s - loss: 0.6147 - accuracy: 0.6618 - val_loss: 0.6409 - val_accuracy: 0.6322
#
# Epoch 00034: val_loss improved from 0.64140 to 0.64094, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 35/150
# 183/183 - 2s - loss: 0.6122 - accuracy: 0.6633 - val_loss: 0.6408 - val_accuracy: 0.6270
#
# Epoch 00035: val_loss improved from 0.64094 to 0.64076, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 36/150
# 183/183 - 2s - loss: 0.6114 - accuracy: 0.6634 - val_loss: 0.6414 - val_accuracy: 0.6287
#
# Epoch 00036: val_loss did not improve from 0.64076
# Epoch 37/150
# 183/183 - 2s - loss: 0.6110 - accuracy: 0.6635 - val_loss: 0.6414 - val_accuracy: 0.6264
#
# Epoch 00037: val_loss did not improve from 0.64076
# Epoch 38/150
# 183/183 - 2s - loss: 0.6091 - accuracy: 0.6677 - val_loss: 0.6395 - val_accuracy: 0.6287
#
# Epoch 00038: val_loss improved from 0.64076 to 0.63950, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 39/150
# 183/183 - 2s - loss: 0.6092 - accuracy: 0.6660 - val_loss: 0.6428 - val_accuracy: 0.6263
#
# Epoch 00039: val_loss did not improve from 0.63950
# Epoch 40/150
# 183/183 - 2s - loss: 0.6085 - accuracy: 0.6681 - val_loss: 0.6388 - val_accuracy: 0.6301
#
# Epoch 00040: val_loss improved from 0.63950 to 0.63876, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 41/150
# 183/183 - 2s - loss: 0.6079 - accuracy: 0.6687 - val_loss: 0.6385 - val_accuracy: 0.6309
#
# Epoch 00041: val_loss improved from 0.63876 to 0.63853, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 42/150
# 183/183 - 2s - loss: 0.6083 - accuracy: 0.6667 - val_loss: 0.6383 - val_accuracy: 0.6313
#
# Epoch 00042: val_loss improved from 0.63853 to 0.63833, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 43/150
# 183/183 - 2s - loss: 0.6074 - accuracy: 0.6695 - val_loss: 0.6394 - val_accuracy: 0.6300
#
# Epoch 00043: val_loss did not improve from 0.63833
# Epoch 44/150
# 183/183 - 2s - loss: 0.6054 - accuracy: 0.6718 - val_loss: 0.6372 - val_accuracy: 0.6305
#
# Epoch 00044: val_loss improved from 0.63833 to 0.63720, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 45/150
# 183/183 - 2s - loss: 0.6048 - accuracy: 0.6714 - val_loss: 0.6362 - val_accuracy: 0.6346
#
# Epoch 00045: val_loss improved from 0.63720 to 0.63623, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 46/150
# 183/183 - 2s - loss: 0.6043 - accuracy: 0.6709 - val_loss: 0.6367 - val_accuracy: 0.6319
#
# Epoch 00046: val_loss did not improve from 0.63623
# Epoch 47/150
# 183/183 - 2s - loss: 0.6024 - accuracy: 0.6735 - val_loss: 0.6389 - val_accuracy: 0.6335
#
# Epoch 00047: val_loss did not improve from 0.63623
# Epoch 48/150
# 183/183 - 2s - loss: 0.6021 - accuracy: 0.6739 - val_loss: 0.6372 - val_accuracy: 0.6329
#
# Epoch 00048: val_loss did not improve from 0.63623
# Epoch 49/150
# 183/183 - 2s - loss: 0.6026 - accuracy: 0.6750 - val_loss: 0.6376 - val_accuracy: 0.6324
#
# Epoch 00049: val_loss did not improve from 0.63623
# Epoch 50/150
# 183/183 - 2s - loss: 0.6026 - accuracy: 0.6729 - val_loss: 0.6354 - val_accuracy: 0.6360
#
# Epoch 00050: val_loss improved from 0.63623 to 0.63544, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 51/150
# 183/183 - 2s - loss: 0.5989 - accuracy: 0.6778 - val_loss: 0.6368 - val_accuracy: 0.6324
#
# Epoch 00051: val_loss did not improve from 0.63544
# Epoch 52/150
# 183/183 - 2s - loss: 0.5971 - accuracy: 0.6788 - val_loss: 0.6357 - val_accuracy: 0.6326
#
# Epoch 00052: val_loss did not improve from 0.63544
# Epoch 53/150
# 183/183 - 2s - loss: 0.6010 - accuracy: 0.6738 - val_loss: 0.6351 - val_accuracy: 0.6355
#
# Epoch 00053: val_loss improved from 0.63544 to 0.63514, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 54/150
# 183/183 - 2s - loss: 0.6000 - accuracy: 0.6749 - val_loss: 0.6345 - val_accuracy: 0.6344
#
# Epoch 00054: val_loss improved from 0.63514 to 0.63450, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 55/150
# 183/183 - 2s - loss: 0.5998 - accuracy: 0.6786 - val_loss: 0.6345 - val_accuracy: 0.6354
#
# Epoch 00055: val_loss improved from 0.63450 to 0.63449, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 56/150
# 183/183 - 2s - loss: 0.5993 - accuracy: 0.6774 - val_loss: 0.6351 - val_accuracy: 0.6340
#
# Epoch 00056: val_loss did not improve from 0.63449
# Epoch 57/150
# 183/183 - 2s - loss: 0.5995 - accuracy: 0.6766 - val_loss: 0.6344 - val_accuracy: 0.6342
#
# Epoch 00057: val_loss improved from 0.63449 to 0.63440, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 58/150
# 183/183 - 2s - loss: 0.5978 - accuracy: 0.6785 - val_loss: 0.6342 - val_accuracy: 0.6362
#
# Epoch 00058: val_loss improved from 0.63440 to 0.63425, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 59/150
# 183/183 - 2s - loss: 0.5967 - accuracy: 0.6816 - val_loss: 0.6344 - val_accuracy: 0.6367
#
# Epoch 00059: val_loss did not improve from 0.63425
# Epoch 60/150
# 183/183 - 2s - loss: 0.5967 - accuracy: 0.6797 - val_loss: 0.6336 - val_accuracy: 0.6377
#
# Epoch 00060: val_loss improved from 0.63425 to 0.63363, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 61/150
# 183/183 - 2s - loss: 0.5945 - accuracy: 0.6809 - val_loss: 0.6328 - val_accuracy: 0.6380
#
# Epoch 00061: val_loss improved from 0.63363 to 0.63282, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 62/150
# 183/183 - 2s - loss: 0.5961 - accuracy: 0.6786 - val_loss: 0.6327 - val_accuracy: 0.6384
#
# Epoch 00062: val_loss improved from 0.63282 to 0.63274, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5
# Epoch 63/150
# 183/183 - 2s - loss: 0.5951 - accuracy: 0.6821 - val_loss: 0.6344 - val_accuracy: 0.6377
# Epoch 00063: val_loss did not improve from 0.63274
# Epoch 64/150
# 183/183 - 2s - loss: 0.5935 - accuracy: 0.6821 - val_loss: 0.6330 - val_accuracy: 0.6393
#
# Epoch 00064: val_loss did not improve from 0.63274
# Epoch 65/150
# 183/183 - 2s - loss: 0.5939 - accuracy: 0.6798 - val_loss: 0.6335 - val_accuracy: 0.6390
#
# Epoch 00065: val_loss did not improve from 0.63274
# Epoch 66/150
# 183/183 - 2s - loss: 0.5938 - accuracy: 0.6825 - val_loss: 0.6344 - val_accuracy: 0.6371
#
# Epoch 00066: val_loss did not improve from 0.63274
# Epoch 67/150
# 183/183 - 2s - loss: 0.5933 - accuracy: 0.6842 - val_loss: 0.6323 - val_accuracy: 0.6402
#
# Epoch 00067: val_loss improved from 0.63274 to 0.63227, saving model to D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.h5

# %%
f = open(r'D:\PycharmProjects\pythonProject\Papernew\model\based_model\原数据\Acet_CNN_OH\dataoh.txt')
y_true = []
pred = []
for line in f:
    if line.startswith('#'):
        pass
    else:
        name = line.replace('\n','').split('	')
        y_true.append(int(name[0]))
        pred.append(float(name[1]))
f.close()

# %%
# 性能评估
def calculate_metrics(labels, scores, cutoff=0.5, po_label=1):
    my_metrics = {
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }

    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:
            if scores[i] >= cutoff:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if scores[i] < cutoff:
                tn = tn + 1
            else:
                fp = fp + 1

    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if (
                                                                                                                     tp + fp) * (
                                                                                                                     tp + fn) * (
                                                                                                                     tn + fp) * (
                                                                                                                     tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'
    my_metrics['Recall'] = my_metrics['SN']
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
metric = calculate_metrics(y_true, pred)
metric

# %%
fpr, tpr, thresholds = roc_curve(y_true, pred)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, lw=1, alpha=0.7, label='ROC (AUC = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Random', alpha=.8)
plt.xlim([0, 1.0])
plt.ylim([0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('CNN_OH_val.png')
plt.show()
