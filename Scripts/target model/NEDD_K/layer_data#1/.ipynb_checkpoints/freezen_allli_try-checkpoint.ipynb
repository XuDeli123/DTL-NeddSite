# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from sklearn.model_selection import KFold,StratifiedKFold

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def build_network():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH')
    cnn = load_model('dataoh.h5')
    cnn.trainable = True #固定所有预训练模型层的参数
    base_model = Model(inputs=cnn.layers[0].input,outputs=cnn.layers[11].output)
    base_model.summary()
    base_model.trainable = True
    for layer in base_model.layers[:11]:
        layer.trainable = False
    #Dense = tf.keras.layers.Dense(64,activation=tf.nn.relu)
    #global_average_layer = tf.keras.layers.GlobalAveragePooling1D()
    prediction_layer = tf.keras.layers.Dense(1,activation=tf.nn.sigmoid)
    model1 = tf.keras.Sequential([
        base_model,
        #layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        #layers.Dropout(0.5),
        #Dense,
        #layers.Dropout(0.5),
        #global_average_layer,
        prediction_layer
    ])
    base_learning_rate = 0.01
    model1.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #model1.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    model1.summary()
    return model1

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
batch_size=256

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\NEDD\迁移数据\训练集')
epochs = 300
x_train,y_train = One_hot_raw('train.txt')#十折交叉验证10
x_test,y_test = One_hot_raw('test.txt')#独立测试1

# %%
classes = sorted(list(set(y_train)))
x_train = one_hot(x_train)
x_test = one_hot(x_test)
x_train.shape = (x_train.shape[0],x_train.shape[2],x_train.shape[3])
x_test.shape = (x_test.shape[0],x_test.shape[2],x_test.shape[3])

# %%
# 构建独立测试集对象，预处理，批量化
test_db = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_db = test_db.map(preprocess).batch(batch_size)

# %%
prediction_result_cv = []
prediction_result_ind = []

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try')

# %%
out = os.getcwd() + '\\'

# %%
from sklearn.model_selection import KFold,StratifiedKFold
kf = StratifiedKFold(n_splits=10,shuffle=True)
for n_fold,(tr_idx,val_idx)in enumerate(kf.split(x_train,y_train)):
    tr_x,tr_y,val_x,val_y = x_train[tr_idx],y_train[tr_idx],x_train[val_idx],y_train[val_idx]
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((tr_x, tr_y))
    train_db = train_db.shuffle(len(tr_x)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    valid_db = tf.data.Dataset.from_tensor_slices((val_x, val_y))
    valid_db = valid_db.map(preprocess).batch(batch_size)
    #if not os.path.exists('%s_%d.h5' % (out, n_fold)):
    model1 = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath='%s_%d.h5' % (out, n_fold), monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = model1.fit(train_db, epochs=epochs, validation_data=valid_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)
    #network.load_weights('%s_%d.h5' % (out, n_fold))
    #history = network.fit(train_db, epochs=50, validation_data=valid_db, verbose=2)
    scores1 = model1.predict(val_x, batch_size=batch_size)[:, 0]
    score_val = pd.DataFrame(scores1)
    y_val = pd.DataFrame(val_y)
    datav=pd.concat([score_val,y_val],axis=1)
    print(n_fold + 1) 
    n_fold_str = str(n_fold + 1)
    pathv ='val_out'+ n_fold_str
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\result\val\\'+pathv+'.csv',encoding='utf-8')
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\result\valtxt\\'+pathv+'.txt',sep='\t',index=False,encoding='utf-8')
    scores2 = model1.predict(x_test, batch_size=batch_size)[:, 0]
    score_indep = pd.DataFrame(scores2)
    test_y = pd.DataFrame(y_test)
    datai = pd.concat([score_indep,test_y],axis=1)
    pathi ='indep_out'+ n_fold_str
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\result\indep\\'+pathi+'.csv',encoding='utf-8')
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\result\indeptxt\\'+pathi+'.txt',sep='\t',index=False,encoding='utf-8')
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1)                 208001
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 208,003
# Trainable params: 67
# Non-trainable params: 207,936
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 4s - loss: 0.7436 - accuracy: 0.4533 - val_loss: 0.7163 - val_accuracy: 0.4756
#
# Epoch 00001: val_loss improved from inf to 0.71632, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.7129 - accuracy: 0.3584 - val_loss: 0.7043 - val_accuracy: 0.4622
#
# Epoch 00002: val_loss improved from 0.71632 to 0.70428, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 3/300
# 8/8 - 0s - loss: 0.7016 - accuracy: 0.3890 - val_loss: 0.6949 - val_accuracy: 0.4667
#
# Epoch 00003: val_loss improved from 0.70428 to 0.69491, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 4/300
# 8/8 - 0s - loss: 0.6898 - accuracy: 0.4829 - val_loss: 0.6863 - val_accuracy: 0.4978
#
# Epoch 00004: val_loss improved from 0.69491 to 0.68630, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 5/300
# 8/8 - 0s - loss: 0.6781 - accuracy: 0.5922 - val_loss: 0.6777 - val_accuracy: 0.6044
#
# Epoch 00005: val_loss improved from 0.68630 to 0.67770, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 6/300
# 8/8 - 0s - loss: 0.6637 - accuracy: 0.6317 - val_loss: 0.6684 - val_accuracy: 0.6711
#
# Epoch 00006: val_loss improved from 0.67770 to 0.66841, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 7/300
# 8/8 - 0s - loss: 0.6507 - accuracy: 0.6826 - val_loss: 0.6594 - val_accuracy: 0.7200
#
# Epoch 00007: val_loss improved from 0.66841 to 0.65944, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 8/300
# 8/8 - 0s - loss: 0.6414 - accuracy: 0.6965 - val_loss: 0.6513 - val_accuracy: 0.7244
#
# Epoch 00008: val_loss improved from 0.65944 to 0.65128, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 9/300
# 8/8 - 0s - loss: 0.6343 - accuracy: 0.6950 - val_loss: 0.6442 - val_accuracy: 0.7067
#
# Epoch 00009: val_loss improved from 0.65128 to 0.64417, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 10/300
# 8/8 - 0s - loss: 0.6249 - accuracy: 0.7108 - val_loss: 0.6366 - val_accuracy: 0.7156
#
# Epoch 00010: val_loss improved from 0.64417 to 0.63658, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 11/300
# 8/8 - 0s - loss: 0.6184 - accuracy: 0.7088 - val_loss: 0.6311 - val_accuracy: 0.7067
#
# Epoch 00011: val_loss improved from 0.63658 to 0.63105, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 12/300
# 8/8 - 0s - loss: 0.6107 - accuracy: 0.7069 - val_loss: 0.6244 - val_accuracy: 0.6978
#
# Epoch 00012: val_loss improved from 0.63105 to 0.62442, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 13/300
# 8/8 - 0s - loss: 0.6085 - accuracy: 0.7064 - val_loss: 0.6196 - val_accuracy: 0.7111
#
# Epoch 00013: val_loss improved from 0.62442 to 0.61956, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 14/300
# 8/8 - 0s - loss: 0.6111 - accuracy: 0.6797 - val_loss: 0.6182 - val_accuracy: 0.7067
#
# Epoch 00014: val_loss improved from 0.61956 to 0.61824, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 15/300
# 8/8 - 0s - loss: 0.5993 - accuracy: 0.7024 - val_loss: 0.6119 - val_accuracy: 0.7200
#
# Epoch 00015: val_loss improved from 0.61824 to 0.61186, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 16/300
# 8/8 - 0s - loss: 0.6004 - accuracy: 0.7054 - val_loss: 0.6076 - val_accuracy: 0.7156
#
# Epoch 00016: val_loss improved from 0.61186 to 0.60755, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 17/300
# 8/8 - 0s - loss: 0.5941 - accuracy: 0.7064 - val_loss: 0.6063 - val_accuracy: 0.7111
#
# Epoch 00017: val_loss improved from 0.60755 to 0.60635, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 18/300
# 8/8 - 0s - loss: 0.5964 - accuracy: 0.7004 - val_loss: 0.6022 - val_accuracy: 0.7111
#
# Epoch 00018: val_loss improved from 0.60635 to 0.60217, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 19/300
# 8/8 - 0s - loss: 0.5871 - accuracy: 0.7163 - val_loss: 0.5997 - val_accuracy: 0.7111
#
# Epoch 00019: val_loss improved from 0.60217 to 0.59966, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 20/300
# 8/8 - 0s - loss: 0.5906 - accuracy: 0.7044 - val_loss: 0.5974 - val_accuracy: 0.7111
#
# Epoch 00020: val_loss improved from 0.59966 to 0.59738, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 21/300
# 8/8 - 0s - loss: 0.5936 - accuracy: 0.7000 - val_loss: 0.5968 - val_accuracy: 0.7111
#
# Epoch 00021: val_loss improved from 0.59738 to 0.59682, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 22/300
# 8/8 - 0s - loss: 0.5831 - accuracy: 0.7088 - val_loss: 0.5930 - val_accuracy: 0.7022
#
# Epoch 00022: val_loss improved from 0.59682 to 0.59299, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 23/300
# 8/8 - 0s - loss: 0.5829 - accuracy: 0.7103 - val_loss: 0.5912 - val_accuracy: 0.7022
#
# Epoch 00023: val_loss improved from 0.59299 to 0.59124, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 24/300
# 8/8 - 0s - loss: 0.5809 - accuracy: 0.7103 - val_loss: 0.5901 - val_accuracy: 0.7022
#
# Epoch 00024: val_loss improved from 0.59124 to 0.59014, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 25/300
# 8/8 - 0s - loss: 0.5845 - accuracy: 0.7049 - val_loss: 0.5889 - val_accuracy: 0.7022
#
# Epoch 00025: val_loss improved from 0.59014 to 0.58894, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 26/300
# 8/8 - 0s - loss: 0.5867 - accuracy: 0.7034 - val_loss: 0.5893 - val_accuracy: 0.7067
#
# Epoch 00026: val_loss did not improve from 0.58894
# Epoch 27/300
# 8/8 - 0s - loss: 0.5795 - accuracy: 0.7088 - val_loss: 0.5901 - val_accuracy: 0.7111
#
# Epoch 00027: val_loss did not improve from 0.58894
# Epoch 28/300
# 8/8 - 0s - loss: 0.5875 - accuracy: 0.6975 - val_loss: 0.5921 - val_accuracy: 0.7200
#
# Epoch 00028: val_loss did not improve from 0.58894
# Epoch 29/300
# 8/8 - 0s - loss: 0.5748 - accuracy: 0.7173 - val_loss: 0.5870 - val_accuracy: 0.7067
#
# Epoch 00029: val_loss improved from 0.58894 to 0.58702, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 30/300
# 8/8 - 0s - loss: 0.5758 - accuracy: 0.7123 - val_loss: 0.5880 - val_accuracy: 0.7156
#
# Epoch 00030: val_loss did not improve from 0.58702
# Epoch 31/300
# 8/8 - 0s - loss: 0.5832 - accuracy: 0.6965 - val_loss: 0.5882 - val_accuracy: 0.7156
#
# Epoch 00031: val_loss did not improve from 0.58702
# Epoch 32/300
# 8/8 - 0s - loss: 0.5776 - accuracy: 0.7088 - val_loss: 0.5876 - val_accuracy: 0.7200
#
# Epoch 00032: val_loss did not improve from 0.58702
# Epoch 33/300
# 8/8 - 0s - loss: 0.5714 - accuracy: 0.7227 - val_loss: 0.5872 - val_accuracy: 0.7200
#
# Epoch 00033: val_loss did not improve from 0.58702
# Epoch 34/300
# 8/8 - 0s - loss: 0.5752 - accuracy: 0.7123 - val_loss: 0.5854 - val_accuracy: 0.7111
#
# Epoch 00034: val_loss improved from 0.58702 to 0.58537, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 35/300
# 8/8 - 0s - loss: 0.5755 - accuracy: 0.7024 - val_loss: 0.5853 - val_accuracy: 0.7111
#
# Epoch 00035: val_loss improved from 0.58537 to 0.58530, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 36/300
# 8/8 - 0s - loss: 0.5825 - accuracy: 0.7009 - val_loss: 0.5845 - val_accuracy: 0.7111
#
# Epoch 00036: val_loss improved from 0.58530 to 0.58448, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 37/300
# 8/8 - 0s - loss: 0.5713 - accuracy: 0.7168 - val_loss: 0.5847 - val_accuracy: 0.7111
#
# Epoch 00037: val_loss did not improve from 0.58448
# Epoch 38/300
# 8/8 - 0s - loss: 0.5834 - accuracy: 0.6975 - val_loss: 0.5860 - val_accuracy: 0.7156
#
# Epoch 00038: val_loss did not improve from 0.58448
# Epoch 39/300
# 8/8 - 0s - loss: 0.5751 - accuracy: 0.7084 - val_loss: 0.5864 - val_accuracy: 0.7200
#
# Epoch 00039: val_loss did not improve from 0.58448
# Epoch 40/300
# 8/8 - 0s - loss: 0.5722 - accuracy: 0.7049 - val_loss: 0.5842 - val_accuracy: 0.7156
#
# Epoch 00040: val_loss improved from 0.58448 to 0.58421, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 41/300
# 8/8 - 0s - loss: 0.5765 - accuracy: 0.7069 - val_loss: 0.5852 - val_accuracy: 0.7156
#
# Epoch 00041: val_loss did not improve from 0.58421
# Epoch 42/300
# 8/8 - 0s - loss: 0.5805 - accuracy: 0.7009 - val_loss: 0.5868 - val_accuracy: 0.7200
#
# Epoch 00042: val_loss did not improve from 0.58421
# Epoch 43/300
# 8/8 - 0s - loss: 0.5681 - accuracy: 0.7217 - val_loss: 0.5900 - val_accuracy: 0.7200
#
# Epoch 00043: val_loss did not improve from 0.58421
# Epoch 44/300
# 8/8 - 0s - loss: 0.5693 - accuracy: 0.7088 - val_loss: 0.5852 - val_accuracy: 0.7156
#
# Epoch 00044: val_loss did not improve from 0.58421
# Epoch 45/300
# 8/8 - 0s - loss: 0.5741 - accuracy: 0.7039 - val_loss: 0.5820 - val_accuracy: 0.7067
#
# Epoch 00045: val_loss improved from 0.58421 to 0.58201, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 46/300
# 8/8 - 0s - loss: 0.5758 - accuracy: 0.7049 - val_loss: 0.5836 - val_accuracy: 0.7111
#
# Epoch 00046: val_loss did not improve from 0.58201
# Epoch 47/300
# 8/8 - 0s - loss: 0.5714 - accuracy: 0.7049 - val_loss: 0.5856 - val_accuracy: 0.7156
#
# Epoch 00047: val_loss did not improve from 0.58201
# Epoch 48/300
# 8/8 - 0s - loss: 0.5679 - accuracy: 0.7093 - val_loss: 0.5841 - val_accuracy: 0.7156
#
# Epoch 00048: val_loss did not improve from 0.58201
# Epoch 49/300
# 8/8 - 0s - loss: 0.5786 - accuracy: 0.7034 - val_loss: 0.5821 - val_accuracy: 0.7067
#
# Epoch 00049: val_loss did not improve from 0.58201
# Epoch 50/300
# 8/8 - 0s - loss: 0.5776 - accuracy: 0.7014 - val_loss: 0.5854 - val_accuracy: 0.7156
#
# Epoch 00050: val_loss did not improve from 0.58201
# Epoch 51/300
# 8/8 - 0s - loss: 0.5730 - accuracy: 0.7024 - val_loss: 0.5858 - val_accuracy: 0.7156
#
# Epoch 00051: val_loss did not improve from 0.58201
# Epoch 52/300
# 8/8 - 0s - loss: 0.5670 - accuracy: 0.7113 - val_loss: 0.5859 - val_accuracy: 0.7200
#
# Epoch 00052: val_loss did not improve from 0.58201
# Epoch 53/300
# 8/8 - 0s - loss: 0.5689 - accuracy: 0.7059 - val_loss: 0.5840 - val_accuracy: 0.7111
#
# Epoch 00053: val_loss did not improve from 0.58201
# Epoch 54/300
# 8/8 - 0s - loss: 0.5798 - accuracy: 0.6960 - val_loss: 0.5905 - val_accuracy: 0.7200
#
# Epoch 00054: val_loss did not improve from 0.58201
# Epoch 55/300
# 8/8 - 0s - loss: 0.5679 - accuracy: 0.7093 - val_loss: 0.5885 - val_accuracy: 0.7156
#
# Epoch 00055: val_loss did not improve from 0.58201
# Epoch 56/300
# 8/8 - 0s - loss: 0.5662 - accuracy: 0.7177 - val_loss: 0.5907 - val_accuracy: 0.7200
#
# Epoch 00056: val_loss did not improve from 0.58201
# Epoch 57/300
# 8/8 - 0s - loss: 0.5716 - accuracy: 0.7123 - val_loss: 0.5869 - val_accuracy: 0.7156
#
# Epoch 00057: val_loss did not improve from 0.58201
# Epoch 58/300
# 8/8 - 0s - loss: 0.5683 - accuracy: 0.7093 - val_loss: 0.5837 - val_accuracy: 0.7111
#
# Epoch 00058: val_loss did not improve from 0.58201
# Epoch 59/300
# 8/8 - 0s - loss: 0.5702 - accuracy: 0.7024 - val_loss: 0.5856 - val_accuracy: 0.7156
#
# Epoch 00059: val_loss did not improve from 0.58201
# Epoch 60/300
# 8/8 - 0s - loss: 0.5674 - accuracy: 0.7103 - val_loss: 0.5885 - val_accuracy: 0.7156
#
# Epoch 00060: val_loss did not improve from 0.58201
# Epoch 61/300
# 8/8 - 0s - loss: 0.5642 - accuracy: 0.7138 - val_loss: 0.5816 - val_accuracy: 0.7022
#
# Epoch 00061: val_loss improved from 0.58201 to 0.58164, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 62/300
# 8/8 - 0s - loss: 0.5737 - accuracy: 0.7054 - val_loss: 0.5830 - val_accuracy: 0.7111
# Epoch 00062: val_loss did not improve from 0.58164
# Epoch 63/300
# 8/8 - 0s - loss: 0.5661 - accuracy: 0.7133 - val_loss: 0.5861 - val_accuracy: 0.7156
#
# Epoch 00063: val_loss did not improve from 0.58164
# Epoch 64/300
# 8/8 - 0s - loss: 0.5694 - accuracy: 0.7088 - val_loss: 0.5896 - val_accuracy: 0.7156
#
# Epoch 00064: val_loss did not improve from 0.58164
# Epoch 65/300
# 8/8 - 0s - loss: 0.5702 - accuracy: 0.7088 - val_loss: 0.5851 - val_accuracy: 0.7156
#
# Epoch 00065: val_loss did not improve from 0.58164
# Epoch 66/300
# 8/8 - 0s - loss: 0.5692 - accuracy: 0.7098 - val_loss: 0.5842 - val_accuracy: 0.7156
#
# Epoch 00066: val_loss did not improve from 0.58164
# Epoch 67/300
# 8/8 - 0s - loss: 0.5636 - accuracy: 0.7113 - val_loss: 0.5843 - val_accuracy: 0.7111
#
# Epoch 00067: val_loss did not improve from 0.58164
# Epoch 68/300
# 8/8 - 0s - loss: 0.5675 - accuracy: 0.7103 - val_loss: 0.5886 - val_accuracy: 0.7156
#
# Epoch 00068: val_loss did not improve from 0.58164
# Epoch 69/300
# 8/8 - 0s - loss: 0.5741 - accuracy: 0.7074 - val_loss: 0.5897 - val_accuracy: 0.7156
#
# Epoch 00069: val_loss did not improve from 0.58164
# Epoch 70/300
# 8/8 - 0s - loss: 0.5707 - accuracy: 0.7014 - val_loss: 0.5838 - val_accuracy: 0.7111
#
# Epoch 00070: val_loss did not improve from 0.58164
# Epoch 71/300
# 8/8 - 0s - loss: 0.5680 - accuracy: 0.7148 - val_loss: 0.5876 - val_accuracy: 0.7156
#
# Epoch 00071: val_loss did not improve from 0.58164
# Epoch 72/300
# 8/8 - 0s - loss: 0.5762 - accuracy: 0.6970 - val_loss: 0.5833 - val_accuracy: 0.7067
#
# Epoch 00072: val_loss did not improve from 0.58164
# Epoch 73/300
# 8/8 - 0s - loss: 0.5726 - accuracy: 0.6995 - val_loss: 0.5847 - val_accuracy: 0.7156
#
# Epoch 00073: val_loss did not improve from 0.58164
# Epoch 74/300
# 8/8 - 0s - loss: 0.5679 - accuracy: 0.7103 - val_loss: 0.5844 - val_accuracy: 0.7067
#
# Epoch 00074: val_loss did not improve from 0.58164
# Epoch 75/300
# 8/8 - 0s - loss: 0.5733 - accuracy: 0.6985 - val_loss: 0.5856 - val_accuracy: 0.7156
#
# Epoch 00075: val_loss did not improve from 0.58164
# Epoch 76/300
# 8/8 - 0s - loss: 0.5710 - accuracy: 0.7019 - val_loss: 0.5881 - val_accuracy: 0.7156
#
# Epoch 00076: val_loss did not improve from 0.58164
# Epoch 77/300
# 8/8 - 0s - loss: 0.5689 - accuracy: 0.7069 - val_loss: 0.5850 - val_accuracy: 0.7067
#
# Epoch 00077: val_loss did not improve from 0.58164
# Epoch 78/300
# 8/8 - 0s - loss: 0.5594 - accuracy: 0.7212 - val_loss: 0.5884 - val_accuracy: 0.7156
#
# Epoch 00078: val_loss did not improve from 0.58164
# Epoch 79/300
# 8/8 - 0s - loss: 0.5641 - accuracy: 0.7123 - val_loss: 0.5851 - val_accuracy: 0.7067
#
# Epoch 00079: val_loss did not improve from 0.58164
# Epoch 80/300
# 8/8 - 0s - loss: 0.5624 - accuracy: 0.7123 - val_loss: 0.5910 - val_accuracy: 0.7111
#
# Epoch 00080: val_loss did not improve from 0.58164
# Epoch 81/300
# 8/8 - 0s - loss: 0.5655 - accuracy: 0.7118 - val_loss: 0.5864 - val_accuracy: 0.7156
#
# Epoch 00081: val_loss did not improve from 0.58164
# Epoch 82/300
# 8/8 - 0s - loss: 0.5673 - accuracy: 0.7079 - val_loss: 0.5878 - val_accuracy: 0.7156
#
# Epoch 00082: val_loss did not improve from 0.58164
# Epoch 83/300
# 8/8 - 0s - loss: 0.5670 - accuracy: 0.7138 - val_loss: 0.5832 - val_accuracy: 0.7067
#
# Epoch 00083: val_loss did not improve from 0.58164
# Epoch 84/300
# 8/8 - 0s - loss: 0.5679 - accuracy: 0.7153 - val_loss: 0.5830 - val_accuracy: 0.7067
#
# Epoch 00084: val_loss did not improve from 0.58164
# Epoch 85/300
# 8/8 - 0s - loss: 0.5631 - accuracy: 0.7113 - val_loss: 0.5835 - val_accuracy: 0.7111
#
# Epoch 00085: val_loss did not improve from 0.58164
# Epoch 86/300
# 8/8 - 0s - loss: 0.5639 - accuracy: 0.7187 - val_loss: 0.5853 - val_accuracy: 0.7111
#
# Epoch 00086: val_loss did not improve from 0.58164
# Epoch 87/300
# 8/8 - 0s - loss: 0.5692 - accuracy: 0.7064 - val_loss: 0.5837 - val_accuracy: 0.7111
#
# Epoch 00087: val_loss did not improve from 0.58164
# Epoch 88/300
# 8/8 - 0s - loss: 0.5760 - accuracy: 0.6955 - val_loss: 0.5817 - val_accuracy: 0.7244
#
# Epoch 00088: val_loss did not improve from 0.58164
# Epoch 89/300
# 8/8 - 0s - loss: 0.5620 - accuracy: 0.7182 - val_loss: 0.5865 - val_accuracy: 0.7156
#
# Epoch 00089: val_loss did not improve from 0.58164
# Epoch 90/300
# 8/8 - 0s - loss: 0.5570 - accuracy: 0.7177 - val_loss: 0.5845 - val_accuracy: 0.7111
#
# Epoch 00090: val_loss did not improve from 0.58164
# Epoch 91/300
# 8/8 - 0s - loss: 0.5603 - accuracy: 0.7123 - val_loss: 0.5829 - val_accuracy: 0.7022
#
# Epoch 00091: val_loss did not improve from 0.58164
# Epoch 92/300
# 8/8 - 0s - loss: 0.5645 - accuracy: 0.7039 - val_loss: 0.5823 - val_accuracy: 0.7067
#
# Epoch 00092: val_loss did not improve from 0.58164
# Epoch 93/300
# 8/8 - 0s - loss: 0.5679 - accuracy: 0.7054 - val_loss: 0.5852 - val_accuracy: 0.7156
#
# Epoch 00093: val_loss did not improve from 0.58164
# Epoch 94/300
# 8/8 - 0s - loss: 0.5681 - accuracy: 0.7069 - val_loss: 0.5883 - val_accuracy: 0.7111
#
# Epoch 00094: val_loss did not improve from 0.58164
# Epoch 95/300
# 8/8 - 0s - loss: 0.5680 - accuracy: 0.7207 - val_loss: 0.5914 - val_accuracy: 0.7111
#
# Epoch 00095: val_loss did not improve from 0.58164
# Epoch 96/300
# 8/8 - 0s - loss: 0.5676 - accuracy: 0.7074 - val_loss: 0.5855 - val_accuracy: 0.7156
#
# Epoch 00096: val_loss did not improve from 0.58164
# Epoch 97/300
# 8/8 - 0s - loss: 0.5676 - accuracy: 0.7024 - val_loss: 0.5871 - val_accuracy: 0.7156
#
# Epoch 00097: val_loss did not improve from 0.58164
# Epoch 98/300
# 8/8 - 0s - loss: 0.5682 - accuracy: 0.7059 - val_loss: 0.5856 - val_accuracy: 0.7111
#
# Epoch 00098: val_loss did not improve from 0.58164
# Epoch 99/300
# 8/8 - 0s - loss: 0.5645 - accuracy: 0.7108 - val_loss: 0.5816 - val_accuracy: 0.7111
#
# Epoch 00099: val_loss improved from 0.58164 to 0.58157, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_0.h5
# Epoch 100/300
# 8/8 - 0s - loss: 0.5570 - accuracy: 0.7227 - val_loss: 0.5888 - val_accuracy: 0.7156
#
# Epoch 00100: val_loss did not improve from 0.58157
# Epoch 101/300
# 8/8 - 0s - loss: 0.5688 - accuracy: 0.7084 - val_loss: 0.5841 - val_accuracy: 0.7067
#
# Epoch 00101: val_loss did not improve from 0.58157
# Epoch 102/300
# 8/8 - 0s - loss: 0.5649 - accuracy: 0.7173 - val_loss: 0.5836 - val_accuracy: 0.7067
#
# Epoch 00102: val_loss did not improve from 0.58157
# Epoch 103/300
# 8/8 - 0s - loss: 0.5641 - accuracy: 0.7158 - val_loss: 0.5820 - val_accuracy: 0.7156
#
# Epoch 00103: val_loss did not improve from 0.58157
# Epoch 104/300
# 8/8 - 0s - loss: 0.5621 - accuracy: 0.7207 - val_loss: 0.5827 - val_accuracy: 0.7022
#
# Epoch 00104: val_loss did not improve from 0.58157
# Epoch 105/300
# 8/8 - 0s - loss: 0.5663 - accuracy: 0.7049 - val_loss: 0.5843 - val_accuracy: 0.7111
#
# Epoch 00105: val_loss did not improve from 0.58157
# Epoch 106/300
# 8/8 - 0s - loss: 0.5683 - accuracy: 0.7064 - val_loss: 0.5908 - val_accuracy: 0.7111
#
# Epoch 00106: val_loss did not improve from 0.58157
# Epoch 107/300
# 8/8 - 0s - loss: 0.5670 - accuracy: 0.7049 - val_loss: 0.5826 - val_accuracy: 0.7111
#
# Epoch 00107: val_loss did not improve from 0.58157
# Epoch 108/300
# 8/8 - 0s - loss: 0.5748 - accuracy: 0.6965 - val_loss: 0.5842 - val_accuracy: 0.7067
#
# Epoch 00108: val_loss did not improve from 0.58157
# Epoch 109/300
# 8/8 - 0s - loss: 0.5686 - accuracy: 0.7103 - val_loss: 0.5848 - val_accuracy: 0.7067
#
# Epoch 00109: val_loss did not improve from 0.58157
# Epoch 110/300
# 8/8 - 0s - loss: 0.5673 - accuracy: 0.7113 - val_loss: 0.5855 - val_accuracy: 0.7111
#
# Epoch 00110: val_loss did not improve from 0.58157
# Epoch 111/300
# 8/8 - 0s - loss: 0.5593 - accuracy: 0.7202 - val_loss: 0.5853 - val_accuracy: 0.7156
#
# Epoch 00111: val_loss did not improve from 0.58157
# Epoch 112/300
# 8/8 - 0s - loss: 0.5665 - accuracy: 0.7088 - val_loss: 0.5836 - val_accuracy: 0.7022
#
# Epoch 00112: val_loss did not improve from 0.58157
# Epoch 113/300
# 8/8 - 0s - loss: 0.5635 - accuracy: 0.7118 - val_loss: 0.5837 - val_accuracy: 0.7067
#
# Epoch 00113: val_loss did not improve from 0.58157
# Epoch 114/300
# 8/8 - 0s - loss: 0.5562 - accuracy: 0.7192 - val_loss: 0.5817 - val_accuracy: 0.7156
#
# Epoch 00114: val_loss did not improve from 0.58157
# Epoch 115/300
# 8/8 - 0s - loss: 0.5633 - accuracy: 0.7133 - val_loss: 0.5857 - val_accuracy: 0.7156
#
# Epoch 00115: val_loss did not improve from 0.58157
# Epoch 116/300
# 8/8 - 0s - loss: 0.5674 - accuracy: 0.7039 - val_loss: 0.5836 - val_accuracy: 0.7067
# Epoch 00116: val_loss did not improve from 0.58157
# Epoch 117/300
# 8/8 - 0s - loss: 0.5587 - accuracy: 0.7054 - val_loss: 0.5819 - val_accuracy: 0.7111
#
# Epoch 00117: val_loss did not improve from 0.58157
# Epoch 118/300
# 8/8 - 0s - loss: 0.5695 - accuracy: 0.7079 - val_loss: 0.5865 - val_accuracy: 0.7156
#
# Epoch 00118: val_loss did not improve from 0.58157
# Epoch 119/300
# 8/8 - 0s - loss: 0.5679 - accuracy: 0.7113 - val_loss: 0.5894 - val_accuracy: 0.7156
#
# Epoch 00119: val_loss did not improve from 0.58157
# Epoch 120/300
# 8/8 - 0s - loss: 0.5696 - accuracy: 0.7133 - val_loss: 0.5865 - val_accuracy: 0.7200
#
# Epoch 00120: val_loss did not improve from 0.58157
# Epoch 121/300
# 8/8 - 0s - loss: 0.5649 - accuracy: 0.7118 - val_loss: 0.5882 - val_accuracy: 0.7200
#
# Epoch 00121: val_loss did not improve from 0.58157
# Epoch 122/300
# 8/8 - 0s - loss: 0.5677 - accuracy: 0.7059 - val_loss: 0.5849 - val_accuracy: 0.7067
#
# Epoch 00122: val_loss did not improve from 0.58157
# Epoch 123/300
# 8/8 - 0s - loss: 0.5663 - accuracy: 0.7074 - val_loss: 0.5914 - val_accuracy: 0.7111
#
# Epoch 00123: val_loss did not improve from 0.58157
# Epoch 124/300
# 8/8 - 0s - loss: 0.5695 - accuracy: 0.7064 - val_loss: 0.5863 - val_accuracy: 0.7156
#
# Epoch 00124: val_loss did not improve from 0.58157
# Epoch 125/300
# 8/8 - 0s - loss: 0.5600 - accuracy: 0.7118 - val_loss: 0.5844 - val_accuracy: 0.7156
#
# Epoch 00125: val_loss did not improve from 0.58157
# Epoch 126/300
# 8/8 - 0s - loss: 0.5679 - accuracy: 0.7074 - val_loss: 0.5863 - val_accuracy: 0.7156
#
# Epoch 00126: val_loss did not improve from 0.58157
# Epoch 127/300
# 8/8 - 0s - loss: 0.5675 - accuracy: 0.7079 - val_loss: 0.5836 - val_accuracy: 0.7111
#
# Epoch 00127: val_loss did not improve from 0.58157
# Epoch 128/300
# 8/8 - 0s - loss: 0.5722 - accuracy: 0.7034 - val_loss: 0.5853 - val_accuracy: 0.7067
#
# Epoch 00128: val_loss did not improve from 0.58157
# Epoch 129/300
# 8/8 - 0s - loss: 0.5658 - accuracy: 0.7079 - val_loss: 0.5893 - val_accuracy: 0.7200
#
# Epoch 00129: val_loss did not improve from 0.58157
# Epoch 130/300
# 8/8 - 0s - loss: 0.5712 - accuracy: 0.7034 - val_loss: 0.5847 - val_accuracy: 0.7111
#
# Epoch 00130: val_loss did not improve from 0.58157
# Epoch 131/300
# 8/8 - 0s - loss: 0.5569 - accuracy: 0.7133 - val_loss: 0.5831 - val_accuracy: 0.7067
#
# Epoch 00131: val_loss did not improve from 0.58157
# Epoch 132/300
# 8/8 - 0s - loss: 0.5653 - accuracy: 0.7000 - val_loss: 0.5866 - val_accuracy: 0.7156
#
# Epoch 00132: val_loss did not improve from 0.58157
# Epoch 133/300
# 8/8 - 0s - loss: 0.5616 - accuracy: 0.7088 - val_loss: 0.5852 - val_accuracy: 0.7111
#
# Epoch 00133: val_loss did not improve from 0.58157
# Epoch 134/300
# 8/8 - 0s - loss: 0.5584 - accuracy: 0.7173 - val_loss: 0.5855 - val_accuracy: 0.7156
#
# Epoch 00134: val_loss did not improve from 0.58157
# Epoch 135/300
# 8/8 - 0s - loss: 0.5694 - accuracy: 0.7054 - val_loss: 0.5849 - val_accuracy: 0.7111
#
# Epoch 00135: val_loss did not improve from 0.58157
# Epoch 136/300
# 8/8 - 0s - loss: 0.5584 - accuracy: 0.7173 - val_loss: 0.5823 - val_accuracy: 0.7111
#
# Epoch 00136: val_loss did not improve from 0.58157
# Epoch 137/300
# 8/8 - 0s - loss: 0.5636 - accuracy: 0.7093 - val_loss: 0.5877 - val_accuracy: 0.7156
#
# Epoch 00137: val_loss did not improve from 0.58157
# Epoch 138/300
# 8/8 - 0s - loss: 0.5626 - accuracy: 0.7153 - val_loss: 0.5858 - val_accuracy: 0.7156
#
# Epoch 00138: val_loss did not improve from 0.58157
# Epoch 139/300
# 8/8 - 0s - loss: 0.5684 - accuracy: 0.7074 - val_loss: 0.5858 - val_accuracy: 0.7156
#
# Epoch 00139: val_loss did not improve from 0.58157
# Epoch 140/300
# 8/8 - 0s - loss: 0.5573 - accuracy: 0.7158 - val_loss: 0.5853 - val_accuracy: 0.7156
#
# Epoch 00140: val_loss did not improve from 0.58157
# Epoch 141/300
# 8/8 - 0s - loss: 0.5649 - accuracy: 0.7123 - val_loss: 0.5824 - val_accuracy: 0.7111
#
# Epoch 00141: val_loss did not improve from 0.58157
# Epoch 142/300
# 8/8 - 0s - loss: 0.5611 - accuracy: 0.7113 - val_loss: 0.5836 - val_accuracy: 0.7067
#
# Epoch 00142: val_loss did not improve from 0.58157
# Epoch 143/300
# 8/8 - 0s - loss: 0.5656 - accuracy: 0.7024 - val_loss: 0.5824 - val_accuracy: 0.7156
#
# Epoch 00143: val_loss did not improve from 0.58157
# Epoch 144/300
# 8/8 - 0s - loss: 0.5664 - accuracy: 0.7123 - val_loss: 0.5823 - val_accuracy: 0.7111
#
# Epoch 00144: val_loss did not improve from 0.58157
# Epoch 145/300
# 8/8 - 0s - loss: 0.5542 - accuracy: 0.7197 - val_loss: 0.5825 - val_accuracy: 0.7111
#
# Epoch 00145: val_loss did not improve from 0.58157
# Epoch 146/300
# 8/8 - 0s - loss: 0.5620 - accuracy: 0.7138 - val_loss: 0.5853 - val_accuracy: 0.7111
#
# Epoch 00146: val_loss did not improve from 0.58157
# Epoch 147/300
# 8/8 - 0s - loss: 0.5592 - accuracy: 0.7143 - val_loss: 0.5850 - val_accuracy: 0.7111
#
# Epoch 00147: val_loss did not improve from 0.58157
# Epoch 148/300
# 8/8 - 0s - loss: 0.5650 - accuracy: 0.7103 - val_loss: 0.5879 - val_accuracy: 0.7200
#
# Epoch 00148: val_loss did not improve from 0.58157
# Epoch 149/300
# 8/8 - 0s - loss: 0.5617 - accuracy: 0.7133 - val_loss: 0.5831 - val_accuracy: 0.7067
#
# Epoch 00149: val_loss did not improve from 0.58157
# 1
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Functional)         (None, 1)                 208001
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 208,003
# Trainable params: 67
# Non-trainable params: 207,936
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 1s - loss: 0.6668 - accuracy: 0.5724 - val_loss: 0.6648 - val_accuracy: 0.5733
#
# Epoch 00001: val_loss improved from inf to 0.66479, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\_1.h5
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-8535758296c4> in <module>
#      13     best_saving = tf.keras.callbacks.ModelCheckpoint(filepath='%s_%d.h5' % (out, n_fold), monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
#      14     early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
# ---> 15     history = model1.fit(train_db, epochs=epochs, validation_data=valid_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)
#      16     #network.load_weights('%s_%d.h5' % (out, n_fold))
#      17     #history = network.fit(train_db, epochs=50, validation_data=valid_db, verbose=2)
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1143           epoch_logs.update(val_logs)
#    1144
# -> 1145         callbacks.on_epoch_end(epoch, epoch_logs)
#    1146         training_logs = epoch_logs
#    1147         if self.stop_training:
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     426     for callback in self.callbacks:
#     427       if getattr(callback, '_supports_tf_logs', False):
# --> 428         callback.on_epoch_end(epoch, logs)
#     429       else:
#     430         if numpy_logs is None:  # Only convert once.
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#    1342     # pylint: disable=protected-access
#    1343     if self.save_freq == 'epoch':
# -> 1344       self._save_model(epoch=epoch, logs=logs)
#    1345
#    1346   def _should_save_on_batch(self, batch):
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1416                         'directory: {}'.format(filepath))
#    1417         # Re-throw the error for any other causes.
# -> 1418         raise e
#    1419
#    1420   def _get_file_path(self, epoch, logs):
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1394                     filepath, overwrite=True, options=self._options)
#    1395               else:
# -> 1396                 self.model.save(filepath, overwrite=True, options=self._options)
#    1397             else:
#    1398               if self.verbose > 0:
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\keras\engine\training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    1999     """
#    2000     # pylint: enable=line-too-long
# -> 2001     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    2002                     signatures, options, save_traces)
#    2003
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\keras\saving\save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     151           'to the Tensorflow SavedModel format (by setting save_format="tf") '
#     152           'or using `save_weights`.')
# --> 153     hdf5_format.save_model_to_hdf5(
#     154         model, filepath, overwrite, include_optimizer)
#     155   else:
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     129     if (include_optimizer and model.optimizer and
#     130         not isinstance(model.optimizer, optimizer_v1.TFOptimizer)):
# --> 131       save_optimizer_weights_to_hdf5_group(f, model.optimizer)
#     132
#     133     f.flush()
#
# D:\Anoconda3\envs\tf\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py in save_optimizer_weights_to_hdf5_group(hdf5_group, optimizer)
#     593     weight_values = K.batch_get_value(symbolic_weights)
#     594     for name, val in zip(weight_names, weight_values):
# --> 595       param_dset = weights_group.create_dataset(
#     596           name, val.shape, dtype=val.dtype)
#     597       if not val.shape:
#
# D:\Anoconda3\envs\tf\lib\site-packages\h5py\_hl\group.py in create_dataset(self, name, shape, dtype, data, **kwds)
#     137             dset = dataset.Dataset(dsid)
#     138             if name is not None:
# --> 139                 self[name] = dset
#     140             return dset
#     141
#
# D:\Anoconda3\envs\tf\lib\site-packages\h5py\_hl\group.py in __setitem__(self, name, obj)
#     371
#     372             if isinstance(obj, HLObject):
# --> 373                 h5o.link(obj.id, self.id, name, lcpl=lcpl, lapl=self._lapl)
#     374
#     375             elif isinstance(obj, SoftLink):
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5o.pyx in h5py.h5o.link()
#
# OSError: Unable to create link (name already exists)

# %%
#遍历表格求初始里程
#交叉验证
import os
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try')
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\result\val'
filenames=os.listdir(path)#得到字符串列表
scores_val=[]
lables_val=[]
fpr_list_val = []
tpr_list_val = []
roc_auc_list_val=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_val=data.iloc[:,1]
        scores_val.append(score_val)
        lable_val = data.iloc[:,2]
        lables_val.append(lable_val)
        fpr_val,tpr_val,thresholds_val= roc_curve(lables_val[i],scores_val[i])   #y_true,y_score
        fpr_list_val.append(fpr_val)
        tpr_list_val.append(tpr_val)
        roc_auc_val = auc(fpr_val,tpr_val)
        roc_auc_list_val.append(roc_auc_val)
        i+=1

# %%
roc_auc_list_val
# Out:
# [0.7698324905183312,
#  0.7941645408163265,
#  0.8030973451327433,
#  0.8353350189633375,
#  0.7803413400758533,
#  0.8065739570164349,
#  0.7586125158027814,
#  0.8319374209860936,
#  0.7478666245259166,
#  0.8089923469387754]

# %%
i=1
tprs_val = []
mean_fpr_val = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Validation ROC')
for fpr_val,tpr_val,roc_auc_val in zip(fpr_list_val,tpr_list_val,roc_auc_list_val):
    tprs_val.append(np.interp(mean_fpr_val, fpr_val, tpr_val))
    tprs_val[-1][0] = 0.0
    plt.plot(fpr_val, tpr_val, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_val)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_val.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_val = np.mean(tprs_val, axis=0)
mean_tpr_val[-1] = 1.0
mean_auc_val = auc(mean_fpr_val, mean_tpr_val)
std_auc_val = np.std(roc_auc_list_val)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_val, std_auc_val),lw=2, alpha=.8)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_val),lw=2, alpha=.8)
std_tpr_val = np.std(tprs_val, axis=0)
tprs_upper_val = np.minimum(mean_tpr_val + std_tpr_val, 1)
tprs_lower_val = np.maximum(mean_tpr_val - std_tpr_val, 0)
plt.fill_between(mean_fpr_val, tprs_lower_val, tprs_upper_val, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Cross-Validation ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_val_mean.png')
plt.show()

# %%
def calculate_metrics_val(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_val = []
for score_val,lable_val in zip(scores_val,lables_val):
    val_my_calculate_metrics = calculate_metrics_val(lable_val,score_val)
    my_calculate_metrics_list_val.append(val_my_calculate_metrics)

# %%
my_calculate_metrics_list_val
# Out:
# [{'SN': 0.8584070796460177,
#   'SP': 0.5892857142857143,
#   'ACC': 0.7244444444444444,
#   'MCC': 0.46510755299545414,
#   'Recall': 0.8584070796460177,
#   'Precision': 0.6783216783216783,
#   'F1-score': 0.7578125,
#   'Cutoff': 0.5},
#  {'SN': 0.8214285714285714,
#   'SP': 0.5625,
#   'ACC': 0.6919642857142857,
#   'MCC': 0.39748418438347904,
#   'Recall': 0.8214285714285714,
#   'Precision': 0.6524822695035462,
#   'F1-score': 0.7272727272727273,
#   'Cutoff': 0.5},
#  {'SN': 0.7433628318584071,
#   'SP': 0.7142857142857143,
#   'ACC': 0.7288888888888889,
#   'MCC': 0.4578656641508689,
#   'Recall': 0.7433628318584071,
#   'Precision': 0.7241379310344828,
#   'F1-score': 0.7336244541484717,
#   'Cutoff': 0.5},
#  {'SN': 0.8584070796460177,
#   'SP': 0.6160714285714286,
#   'ACC': 0.7377777777777778,
#   'MCC': 0.4893181194313631,
#   'Recall': 0.8584070796460177,
#   'Precision': 0.6928571428571428,
#   'F1-score': 0.766798418972332,
#   'Cutoff': 0.5},
#  {'SN': 0.7610619469026548,
#   'SP': 0.6517857142857143,
#   'ACC': 0.7066666666666667,
#   'MCC': 0.41541584271274284,
#   'Recall': 0.7610619469026548,
#   'Precision': 0.688,
#   'F1-score': 0.7226890756302521,
#   'Cutoff': 0.5},
#  {'SN': 0.8303571428571429,
#   'SP': 0.6017699115044248,
#   'ACC': 0.7155555555555555,
#   'MCC': 0.4436704669950916,
#   'Recall': 0.8303571428571429,
#   'Precision': 0.6739130434782609,
#   'F1-score': 0.744,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6283185840707964,
#   'ACC': 0.6888888888888889,
#   'MCC': 0.3810684897571042,
#   'Recall': 0.75,
#   'Precision': 0.6666666666666666,
#   'F1-score': 0.7058823529411765,
#   'Cutoff': 0.5},
#  {'SN': 0.8214285714285714,
#   'SP': 0.7345132743362832,
#   'ACC': 0.7777777777777778,
#   'MCC': 0.557929172518477,
#   'Recall': 0.8214285714285714,
#   'Precision': 0.7540983606557377,
#   'F1-score': 0.7863247863247863,
#   'Cutoff': 0.5},
#  {'SN': 0.7678571428571429,
#   'SP': 0.6283185840707964,
#   'ACC': 0.6977777777777778,
#   'MCC': 0.3999864179814647,
#   'Recall': 0.7678571428571429,
#   'Precision': 0.671875,
#   'F1-score': 0.7166666666666667,
#   'Cutoff': 0.5},
#  {'SN': 0.8035714285714286,
#   'SP': 0.6964285714285714,
#   'ACC': 0.75,
#   'MCC': 0.5028948456749697,
#   'Recall': 0.8035714285714286,
#   'Precision': 0.7258064516129032,
#   'F1-score': 0.7627118644067796,
#   'Cutoff': 0.5}]

# %%
performance_val=pd.DataFrame(my_calculate_metrics_list_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.858407  0.589286  0.724444  0.465108  0.858407   0.678322  0.757812
# 1  0.821429  0.562500  0.691964  0.397484  0.821429   0.652482  0.727273
# 2  0.743363  0.714286  0.728889  0.457866  0.743363   0.724138  0.733624
# 3  0.858407  0.616071  0.737778  0.489318  0.858407   0.692857  0.766798
# 4  0.761062  0.651786  0.706667  0.415416  0.761062   0.688000  0.722689
# 5  0.830357  0.601770  0.715556  0.443670  0.830357   0.673913  0.744000
# 6  0.750000  0.628319  0.688889  0.381068  0.750000   0.666667  0.705882
# 7  0.821429  0.734513  0.777778  0.557929  0.821429   0.754098  0.786325
# 8  0.767857  0.628319  0.697778  0.399986  0.767857   0.671875  0.716667
# 9  0.803571  0.696429  0.750000  0.502895  0.803571   0.725806  0.762712
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_val = performance_val.std(axis = 0,ddof=1)
mean_val = performance_val.mean(axis = 0)
data_mean_val = pd.DataFrame(mean_val)
data_mean_val = data_mean_val.T
data_std_val = pd.DataFrame(std_val)
data_std_val = data_std_val.T
performance_val = performance_val.append(data_mean_val)
performance_val = performance_val.append(data_std_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.858407  0.589286  0.724444  0.465108  0.858407   0.678322  0.757812
# 1  0.821429  0.562500  0.691964  0.397484  0.821429   0.652482  0.727273
# 2  0.743363  0.714286  0.728889  0.457866  0.743363   0.724138  0.733624
# 3  0.858407  0.616071  0.737778  0.489318  0.858407   0.692857  0.766798
# 4  0.761062  0.651786  0.706667  0.415416  0.761062   0.688000  0.722689
# 5  0.830357  0.601770  0.715556  0.443670  0.830357   0.673913  0.744000
# 6  0.750000  0.628319  0.688889  0.381068  0.750000   0.666667  0.705882
# 7  0.821429  0.734513  0.777778  0.557929  0.821429   0.754098  0.786325
# 8  0.767857  0.628319  0.697778  0.399986  0.767857   0.671875  0.716667
# 9  0.803571  0.696429  0.750000  0.502895  0.803571   0.725806  0.762712
# 0  0.801588  0.642328  0.721974  0.451074  0.801588   0.692816  0.742378
# 0  0.043343  0.056377  0.028007  0.055295  0.043343   0.031911  0.025533
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_val.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\result\CNN_OH_performance_val.csv',encoding='utf-8')

# %% [markdown]
# 独立测试

# %%
#遍历表格求初始里程
#独立测试
import os
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\result\indep'
filenames=os.listdir(path)#得到字符串列表
scores_indep=[]
lables_indep=[]
fpr_list_indep = []
tpr_list_indep = []
roc_auc_list_indep=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_indep=data.iloc[:,1]
        scores_indep.append(score_indep)
        lable_indep = data.iloc[:,2]
        lables_indep.append(lable_indep)
        fpr_indep,tpr_indep,thresholds_indep= roc_curve(lables_indep[i],scores_indep[i])   #y_true,y_score
        fpr_list_indep.append(fpr_indep)
        tpr_list_indep.append(tpr_indep)
        roc_auc_indep = auc(fpr_indep,tpr_indep)
        roc_auc_list_indep.append(roc_auc_indep)
        i+=1

# %%
roc_auc_list_indep
# Out:
# [0.7779815051020408,
#  0.7793367346938775,
#  0.7822863520408163,
#  0.781329719387755,
#  0.7800542091836735,
#  0.782126913265306,
#  0.782126913265306,
#  0.775031887755102,
#  0.7818877551020408,
#  0.7810905612244898]

# %%
i=1
tprs_indep = []
mean_fpr_indep = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Independent ROC')
for fpr_indep,tpr_indep,roc_auc_indep in zip(fpr_list_indep,tpr_list_indep,roc_auc_list_indep):
    tprs_indep.append(np.interp(mean_fpr_indep, fpr_indep, tpr_indep))
    tprs_indep[-1][0] = 0.0
    plt.plot(fpr_indep, tpr_indep, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_indep)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_indep.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_indep = np.mean(tprs_indep, axis=0)
mean_tpr_indep[-1] = 1.0
mean_auc_indep = auc(mean_fpr_indep, mean_tpr_indep)
std_auc_indep = np.std(roc_auc_list_indep)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_indep, std_auc_indep),lw=2, alpha=.8)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_indep),lw=2, alpha=.8)
std_tpr_indep = np.std(tprs_indep, axis=0)
tprs_upper_indep = np.minimum(mean_tpr_indep + std_tpr_indep, 1)
tprs_lower_indep = np.maximum(mean_tpr_indep - std_tpr_indep, 0)
plt.fill_between(mean_fpr_indep, tprs_lower_indep, tprs_upper_indep, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Independent ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_indep_mean.png')
plt.show()

# %%
def calculate_metrics_indep(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_indep = []
for score_indep,lable_indep in zip(scores_indep,lables_indep):
    indep_my_calculate_metrics = calculate_metrics_indep(lable_indep,score_indep)
    my_calculate_metrics_list_indep.append(indep_my_calculate_metrics)

# %%
my_calculate_metrics_list_indep
# Out:
# [{'SN': 0.7857142857142857,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7232142857142857,
#   'MCC': 0.44995770596336576,
#   'Recall': 0.7857142857142857,
#   'Precision': 0.6984126984126984,
#   'F1-score': 0.7394957983193278,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.6696428571428571,
#   'ACC': 0.7321428571428571,
#   'MCC': 0.4679560142019004,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.7063492063492064,
#   'F1-score': 0.7478991596638656,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.6785714285714286,
#   'ACC': 0.7366071428571429,
#   'MCC': 0.4764345694740244,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.712,
#   'F1-score': 0.7510548523206751,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.6428571428571429,
#   'ACC': 0.71875,
#   'MCC': 0.4426285492822835,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.689922480620155,
#   'F1-score': 0.7385892116182573,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.6785714285714286,
#   'ACC': 0.7366071428571429,
#   'MCC': 0.4764345694740244,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.712,
#   'F1-score': 0.7510548523206751,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7276785714285714,
#   'MCC': 0.4594967547604227,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.7007874015748031,
#   'F1-score': 0.7447698744769874,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.6428571428571429,
#   'ACC': 0.71875,
#   'MCC': 0.4426285492822835,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.689922480620155,
#   'F1-score': 0.7385892116182573,
#   'Cutoff': 0.5},
#  {'SN': 0.7857142857142857,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7232142857142857,
#   'MCC': 0.44995770596336576,
#   'Recall': 0.7857142857142857,
#   'Precision': 0.6984126984126984,
#   'F1-score': 0.7394957983193278,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.6785714285714286,
#   'ACC': 0.7366071428571429,
#   'MCC': 0.4764345694740244,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.712,
#   'F1-score': 0.7510548523206751,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.6696428571428571,
#   'ACC': 0.7321428571428571,
#   'MCC': 0.4679560142019004,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.7063492063492064,
#   'F1-score': 0.7478991596638656,
#   'Cutoff': 0.5}]

# %%
performance_indep=pd.DataFrame(my_calculate_metrics_list_indep)
performance_indep
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.785714  0.660714  0.723214  0.449958  0.785714   0.698413  0.739496
# 1  0.794643  0.669643  0.732143  0.467956  0.794643   0.706349  0.747899
# 2  0.794643  0.678571  0.736607  0.476435  0.794643   0.712000  0.751055
# 3  0.794643  0.642857  0.718750  0.442629  0.794643   0.689922  0.738589
# 4  0.794643  0.678571  0.736607  0.476435  0.794643   0.712000  0.751055
# 5  0.794643  0.660714  0.727679  0.459497  0.794643   0.700787  0.744770
# 6  0.794643  0.642857  0.718750  0.442629  0.794643   0.689922  0.738589
# 7  0.785714  0.660714  0.723214  0.449958  0.785714   0.698413  0.739496
# 8  0.794643  0.678571  0.736607  0.476435  0.794643   0.712000  0.751055
# 9  0.794643  0.669643  0.732143  0.467956  0.794643   0.706349  0.747899
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_indep = performance_indep.std(axis = 0,ddof=1)
mean_indep = performance_indep.mean(axis = 0)
data_mean_indep = pd.DataFrame(mean_indep)
data_mean_indep = data_mean_indep.T
data_std_indep = pd.DataFrame(std_indep)
data_std_indep = data_std_indep.T
performance_indep = performance_indep.append(data_mean_indep)
performance_indep = performance_indep.append(data_std_indep)
performance_indep
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.785714  0.660714  0.723214  0.449958  0.785714   0.698413  0.739496
# 1  0.794643  0.669643  0.732143  0.467956  0.794643   0.706349  0.747899
# 2  0.794643  0.678571  0.736607  0.476435  0.794643   0.712000  0.751055
# 3  0.794643  0.642857  0.718750  0.442629  0.794643   0.689922  0.738589
# 4  0.794643  0.678571  0.736607  0.476435  0.794643   0.712000  0.751055
# 5  0.794643  0.660714  0.727679  0.459497  0.794643   0.700787  0.744770
# 6  0.794643  0.642857  0.718750  0.442629  0.794643   0.689922  0.738589
# 7  0.785714  0.660714  0.723214  0.449958  0.785714   0.698413  0.739496
# 8  0.794643  0.678571  0.736607  0.476435  0.794643   0.712000  0.751055
# 9  0.794643  0.669643  0.732143  0.467956  0.794643   0.706349  0.747899
# 0  0.792857  0.664286  0.728571  0.460989  0.792857   0.702616  0.744990
# 0  0.003765  0.013442  0.007229  0.013875  0.003765   0.008518  0.005474
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_indep.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\freeze_allli_try\result\CNN_OH_performance_indep.csv',encoding='utf-8')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
