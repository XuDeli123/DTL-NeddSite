# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from sklearn.model_selection import KFold,StratifiedKFold

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def build_network():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH70877')
    cnn = load_model('dataoh.h5')
    cnn.trainable = True #固定所有预训练模型层的参数
    base_model = Model(inputs=cnn.layers[0].input,outputs=cnn.layers[11].output)
    base_model.summary()
    base_model.trainable = True
    for layer in base_model.layers:
        layer.trainable = False
    #Dense = tf.keras.layers.Dense(64,activation=tf.nn.relu)
    #global_average_layer = tf.keras.layers.GlobalAveragePooling1D()
    #prediction_layer = tf.keras.layers.Dense(1,activation=tf.nn.sigmoid)
    model1 = tf.keras.Sequential([
        base_model,
        #layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        #layers.Dropout(0.5),
        #Dense,
        #layers.Dropout(0.5),
        #global_average_layer,
        #prediction_layer
    ])
    base_learning_rate = 0.01
    model1.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #model1.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    model1.summary()
    return model1

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
batch_size=256

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\NEDD\迁移数据\训练集')
epochs = 300
x_train,y_train = One_hot_raw('train.txt')#十折交叉验证10
x_test,y_test = One_hot_raw('test.txt')#独立测试1

# %%
classes = sorted(list(set(y_train)))
x_train = one_hot(x_train)
x_test = one_hot(x_test)
x_train.shape = (x_train.shape[0],x_train.shape[2],x_train.shape[3])
x_test.shape = (x_test.shape[0],x_test.shape[2],x_test.shape[3])

# %%
# 构建独立测试集对象，预处理，批量化
test_db = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_db = test_db.map(preprocess).batch(batch_size)

# %%
prediction_result_cv = []
prediction_result_ind = []

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try')

# %%
out = os.getcwd() + '\\'

# %%
from sklearn.model_selection import KFold,StratifiedKFold
kf = StratifiedKFold(n_splits=10,shuffle=True)
for n_fold,(tr_idx,val_idx)in enumerate(kf.split(x_train,y_train)):
    tr_x,tr_y,val_x,val_y = x_train[tr_idx],y_train[tr_idx],x_train[val_idx],y_train[val_idx]
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((tr_x, tr_y))
    train_db = train_db.shuffle(len(tr_x)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    valid_db = tf.data.Dataset.from_tensor_slices((val_x, val_y))
    valid_db = valid_db.map(preprocess).batch(batch_size)
    #if not os.path.exists('%s_%d.h5' % (out, n_fold)):
    model1 = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath='%s_%d.h5' % (out, n_fold), monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = model1.fit(train_db, epochs=epochs, validation_data=valid_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)
    #network.load_weights('%s_%d.h5' % (out, n_fold))
    #history = network.fit(train_db, epochs=50, validation_data=valid_db, verbose=2)
    scores1 = model1.predict(val_x, batch_size=batch_size)[:, 0]
    score_val = pd.DataFrame(scores1)
    y_val = pd.DataFrame(val_y)
    datav=pd.concat([score_val,y_val],axis=1)
    print(n_fold + 1) 
    n_fold_str = str(n_fold + 1)
    pathv ='val_out'+ n_fold_str
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\result\val\\'+pathv+'.csv',encoding='utf-8')
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\result\valtxt\\'+pathv+'.txt',sep='\t',index=False,encoding='utf-8')
    scores2 = model1.predict(x_test, batch_size=batch_size)[:, 0]
    score_indep = pd.DataFrame(scores2)
    test_y = pd.DataFrame(y_test)
    datai = pd.concat([score_indep,test_y],axis=1)
    pathi ='indep_out'+ n_fold_str
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\result\indep\\'+pathi+'.csv',encoding='utf-8')
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\result\indeptxt\\'+pathi+'.txt',sep='\t',index=False,encoding='utf-8')
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3_input (InputLayer)  [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 41, 128)           2816
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 5s - loss: 0.5821 - accuracy: 0.6965 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00001: val_loss improved from inf to 0.58115, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\_0.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.5893 - accuracy: 0.6896 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00002: val_loss did not improve from 0.58115
# Epoch 3/300
# 8/8 - 0s - loss: 0.5806 - accuracy: 0.6925 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00003: val_loss did not improve from 0.58115
# Epoch 4/300
# 8/8 - 0s - loss: 0.5718 - accuracy: 0.7054 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00004: val_loss did not improve from 0.58115
# Epoch 5/300
# 8/8 - 0s - loss: 0.5722 - accuracy: 0.7079 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00005: val_loss did not improve from 0.58115
# Epoch 6/300
# 8/8 - 0s - loss: 0.5787 - accuracy: 0.7064 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00006: val_loss did not improve from 0.58115
# Epoch 7/300
# 8/8 - 0s - loss: 0.5796 - accuracy: 0.7000 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00007: val_loss did not improve from 0.58115
# Epoch 8/300
# 8/8 - 0s - loss: 0.5799 - accuracy: 0.7029 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00008: val_loss did not improve from 0.58115
# Epoch 9/300
# 8/8 - 0s - loss: 0.5835 - accuracy: 0.6886 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00009: val_loss did not improve from 0.58115
# Epoch 10/300
# 8/8 - 0s - loss: 0.5791 - accuracy: 0.7009 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00010: val_loss did not improve from 0.58115
# Epoch 11/300
# 8/8 - 0s - loss: 0.5817 - accuracy: 0.6960 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00011: val_loss did not improve from 0.58115
# Epoch 12/300
# 8/8 - 0s - loss: 0.5795 - accuracy: 0.6985 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00012: val_loss did not improve from 0.58115
# Epoch 13/300
# 8/8 - 0s - loss: 0.5794 - accuracy: 0.7029 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00013: val_loss did not improve from 0.58115
# Epoch 14/300
# 8/8 - 0s - loss: 0.5812 - accuracy: 0.6950 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00014: val_loss did not improve from 0.58115
# Epoch 15/300
# 8/8 - 0s - loss: 0.5767 - accuracy: 0.6945 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00015: val_loss did not improve from 0.58115
# Epoch 16/300
# 8/8 - 0s - loss: 0.5746 - accuracy: 0.7009 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00016: val_loss did not improve from 0.58115
# Epoch 17/300
# 8/8 - 0s - loss: 0.5815 - accuracy: 0.6955 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00017: val_loss did not improve from 0.58115
# Epoch 18/300
# 8/8 - 0s - loss: 0.5815 - accuracy: 0.6950 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00018: val_loss did not improve from 0.58115
# Epoch 19/300
# 8/8 - 0s - loss: 0.5798 - accuracy: 0.6995 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00019: val_loss did not improve from 0.58115
# Epoch 20/300
# 8/8 - 0s - loss: 0.5825 - accuracy: 0.6960 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00020: val_loss did not improve from 0.58115
# Epoch 21/300
# 8/8 - 0s - loss: 0.5808 - accuracy: 0.7014 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00021: val_loss did not improve from 0.58115
# Epoch 22/300
# 8/8 - 0s - loss: 0.5790 - accuracy: 0.6930 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00022: val_loss did not improve from 0.58115
# Epoch 23/300
# 8/8 - 0s - loss: 0.5783 - accuracy: 0.7014 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00023: val_loss did not improve from 0.58115
# Epoch 24/300
# 8/8 - 0s - loss: 0.5815 - accuracy: 0.7054 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00024: val_loss did not improve from 0.58115
# Epoch 25/300
# 8/8 - 0s - loss: 0.5771 - accuracy: 0.6965 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00025: val_loss did not improve from 0.58115
# Epoch 26/300
# 8/8 - 0s - loss: 0.5803 - accuracy: 0.6920 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00026: val_loss did not improve from 0.58115
# Epoch 27/300
# 8/8 - 0s - loss: 0.5814 - accuracy: 0.6960 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00027: val_loss did not improve from 0.58115
# Epoch 28/300
# 8/8 - 0s - loss: 0.5805 - accuracy: 0.6980 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00028: val_loss did not improve from 0.58115
# Epoch 29/300
# 8/8 - 0s - loss: 0.5745 - accuracy: 0.7113 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00029: val_loss did not improve from 0.58115
# Epoch 30/300
# 8/8 - 0s - loss: 0.5762 - accuracy: 0.6985 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00030: val_loss did not improve from 0.58115
# Epoch 31/300
# 8/8 - 0s - loss: 0.5810 - accuracy: 0.7069 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00031: val_loss did not improve from 0.58115
# Epoch 32/300
# 8/8 - 0s - loss: 0.5829 - accuracy: 0.7004 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00032: val_loss did not improve from 0.58115
# Epoch 33/300
# 8/8 - 0s - loss: 0.5823 - accuracy: 0.6985 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00033: val_loss did not improve from 0.58115
# Epoch 34/300
# 8/8 - 0s - loss: 0.5776 - accuracy: 0.6990 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00034: val_loss did not improve from 0.58115
# Epoch 35/300
# 8/8 - 0s - loss: 0.5816 - accuracy: 0.7059 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00035: val_loss did not improve from 0.58115
# Epoch 36/300
# 8/8 - 0s - loss: 0.5807 - accuracy: 0.6960 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00036: val_loss did not improve from 0.58115
# Epoch 37/300
# 8/8 - 0s - loss: 0.5723 - accuracy: 0.7009 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00037: val_loss did not improve from 0.58115
# Epoch 38/300
# 8/8 - 0s - loss: 0.5748 - accuracy: 0.7004 - val_loss: 0.5811 - val_accuracy: 0.6844
# Epoch 00038: val_loss did not improve from 0.58115
# Epoch 39/300
# 8/8 - 0s - loss: 0.5799 - accuracy: 0.7024 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00039: val_loss did not improve from 0.58115
# Epoch 40/300
# 8/8 - 0s - loss: 0.5749 - accuracy: 0.7034 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00040: val_loss did not improve from 0.58115
# Epoch 41/300
# 8/8 - 0s - loss: 0.5802 - accuracy: 0.7148 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00041: val_loss did not improve from 0.58115
# Epoch 42/300
# 8/8 - 0s - loss: 0.5848 - accuracy: 0.6901 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00042: val_loss did not improve from 0.58115
# Epoch 43/300
# 8/8 - 0s - loss: 0.5781 - accuracy: 0.7000 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00043: val_loss did not improve from 0.58115
# Epoch 44/300
# 8/8 - 0s - loss: 0.5806 - accuracy: 0.6960 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00044: val_loss did not improve from 0.58115
# Epoch 45/300
# 8/8 - 0s - loss: 0.5787 - accuracy: 0.7054 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00045: val_loss did not improve from 0.58115
# Epoch 46/300
# 8/8 - 0s - loss: 0.5683 - accuracy: 0.7059 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00046: val_loss did not improve from 0.58115
# Epoch 47/300
# 8/8 - 0s - loss: 0.5827 - accuracy: 0.6925 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00047: val_loss did not improve from 0.58115
# Epoch 48/300
# 8/8 - 0s - loss: 0.5782 - accuracy: 0.6945 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00048: val_loss did not improve from 0.58115
# Epoch 49/300
# 8/8 - 0s - loss: 0.5812 - accuracy: 0.7014 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00049: val_loss did not improve from 0.58115
# Epoch 50/300
# 8/8 - 0s - loss: 0.5765 - accuracy: 0.6831 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00050: val_loss did not improve from 0.58115
# Epoch 51/300
# 8/8 - 0s - loss: 0.5764 - accuracy: 0.7054 - val_loss: 0.5811 - val_accuracy: 0.6844
#
# Epoch 00051: val_loss did not improve from 0.58115
# 1
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3_input (InputLayer)  [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 41, 128)           2816
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 0s - loss: 0.5843 - accuracy: 0.6930 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00001: val_loss improved from inf to 0.59547, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\_1.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.5730 - accuracy: 0.7034 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00002: val_loss did not improve from 0.59547
# Epoch 3/300
# 8/8 - 0s - loss: 0.5775 - accuracy: 0.6896 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00003: val_loss did not improve from 0.59547
# Epoch 4/300
# 8/8 - 0s - loss: 0.5754 - accuracy: 0.6960 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00004: val_loss did not improve from 0.59547
# Epoch 5/300
# 8/8 - 0s - loss: 0.5804 - accuracy: 0.6906 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00005: val_loss did not improve from 0.59547
# Epoch 6/300
# 8/8 - 0s - loss: 0.5806 - accuracy: 0.6980 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00006: val_loss did not improve from 0.59547
# Epoch 7/300
# 8/8 - 0s - loss: 0.5794 - accuracy: 0.6802 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00007: val_loss did not improve from 0.59547
# Epoch 8/300
# 8/8 - 0s - loss: 0.5809 - accuracy: 0.7029 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00008: val_loss did not improve from 0.59547
# Epoch 9/300
# 8/8 - 0s - loss: 0.5865 - accuracy: 0.6881 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00009: val_loss did not improve from 0.59547
# Epoch 10/300
# 8/8 - 0s - loss: 0.5827 - accuracy: 0.6906 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00010: val_loss did not improve from 0.59547
# Epoch 11/300
# 8/8 - 0s - loss: 0.5767 - accuracy: 0.7009 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00011: val_loss did not improve from 0.59547
# Epoch 12/300
# 8/8 - 0s - loss: 0.5721 - accuracy: 0.6940 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00012: val_loss did not improve from 0.59547
# Epoch 13/300
# 8/8 - 0s - loss: 0.5746 - accuracy: 0.7088 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00013: val_loss did not improve from 0.59547
# Epoch 14/300
# 8/8 - 0s - loss: 0.5823 - accuracy: 0.7009 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00014: val_loss did not improve from 0.59547
# Epoch 15/300
# 8/8 - 0s - loss: 0.5732 - accuracy: 0.7108 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00015: val_loss did not improve from 0.59547
# Epoch 16/300
# 8/8 - 0s - loss: 0.5802 - accuracy: 0.6975 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00016: val_loss did not improve from 0.59547
# Epoch 17/300
# 8/8 - 0s - loss: 0.5817 - accuracy: 0.6990 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00017: val_loss did not improve from 0.59547
# Epoch 18/300
# 8/8 - 0s - loss: 0.5779 - accuracy: 0.6925 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00018: val_loss did not improve from 0.59547
# Epoch 19/300
# 8/8 - 0s - loss: 0.5855 - accuracy: 0.6950 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00019: val_loss did not improve from 0.59547
# Epoch 20/300
# 8/8 - 0s - loss: 0.5845 - accuracy: 0.7014 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00020: val_loss did not improve from 0.59547
# Epoch 21/300
# 8/8 - 0s - loss: 0.5811 - accuracy: 0.7044 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00021: val_loss did not improve from 0.59547
# Epoch 22/300
# 8/8 - 0s - loss: 0.5841 - accuracy: 0.7019 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00022: val_loss did not improve from 0.59547
# Epoch 23/300
# 8/8 - 0s - loss: 0.5818 - accuracy: 0.6871 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00023: val_loss did not improve from 0.59547
# Epoch 24/300
# 8/8 - 0s - loss: 0.5740 - accuracy: 0.6965 - val_loss: 0.5955 - val_accuracy: 0.7200
# Epoch 00024: val_loss did not improve from 0.59547
# Epoch 25/300
# 8/8 - 0s - loss: 0.5753 - accuracy: 0.6995 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00025: val_loss did not improve from 0.59547
# Epoch 26/300
# 8/8 - 0s - loss: 0.5690 - accuracy: 0.7064 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00026: val_loss did not improve from 0.59547
# Epoch 27/300
# 8/8 - 0s - loss: 0.5792 - accuracy: 0.6950 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00027: val_loss did not improve from 0.59547
# Epoch 28/300
# 8/8 - 0s - loss: 0.5845 - accuracy: 0.6980 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00028: val_loss did not improve from 0.59547
# Epoch 29/300
# 8/8 - 0s - loss: 0.5795 - accuracy: 0.6970 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00029: val_loss did not improve from 0.59547
# Epoch 30/300
# 8/8 - 0s - loss: 0.5830 - accuracy: 0.6945 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00030: val_loss did not improve from 0.59547
# Epoch 31/300
# 8/8 - 0s - loss: 0.5724 - accuracy: 0.6950 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00031: val_loss did not improve from 0.59547
# Epoch 32/300
# 8/8 - 0s - loss: 0.5783 - accuracy: 0.7074 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00032: val_loss did not improve from 0.59547
# Epoch 33/300
# 8/8 - 0s - loss: 0.5789 - accuracy: 0.6925 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00033: val_loss did not improve from 0.59547
# Epoch 34/300
# 8/8 - 0s - loss: 0.5806 - accuracy: 0.6945 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00034: val_loss did not improve from 0.59547
# Epoch 35/300
# 8/8 - 0s - loss: 0.5797 - accuracy: 0.7004 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00035: val_loss did not improve from 0.59547
# Epoch 36/300
# 8/8 - 0s - loss: 0.5756 - accuracy: 0.7014 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00036: val_loss did not improve from 0.59547
# Epoch 37/300
# 8/8 - 0s - loss: 0.5785 - accuracy: 0.7000 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00037: val_loss did not improve from 0.59547
# Epoch 38/300
# 8/8 - 0s - loss: 0.5782 - accuracy: 0.6945 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00038: val_loss did not improve from 0.59547
# Epoch 39/300
# 8/8 - 0s - loss: 0.5689 - accuracy: 0.7088 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00039: val_loss did not improve from 0.59547
# Epoch 40/300
# 8/8 - 0s - loss: 0.5784 - accuracy: 0.7118 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00040: val_loss did not improve from 0.59547
# Epoch 41/300
# 8/8 - 0s - loss: 0.5716 - accuracy: 0.7088 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00041: val_loss did not improve from 0.59547
# Epoch 42/300
# 8/8 - 0s - loss: 0.5829 - accuracy: 0.7000 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00042: val_loss did not improve from 0.59547
# Epoch 43/300
# 8/8 - 0s - loss: 0.5754 - accuracy: 0.7054 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00043: val_loss did not improve from 0.59547
# Epoch 44/300
# 8/8 - 0s - loss: 0.5746 - accuracy: 0.7108 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00044: val_loss did not improve from 0.59547
# Epoch 45/300
# 8/8 - 0s - loss: 0.5792 - accuracy: 0.6955 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00045: val_loss did not improve from 0.59547
# Epoch 46/300
# 8/8 - 0s - loss: 0.5779 - accuracy: 0.7004 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00046: val_loss did not improve from 0.59547
# Epoch 47/300
# 8/8 - 0s - loss: 0.5788 - accuracy: 0.6990 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00047: val_loss did not improve from 0.59547
# Epoch 48/300
# 8/8 - 0s - loss: 0.5809 - accuracy: 0.6945 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00048: val_loss did not improve from 0.59547
# Epoch 49/300
# 8/8 - 0s - loss: 0.5808 - accuracy: 0.6995 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00049: val_loss did not improve from 0.59547
# Epoch 50/300
# 8/8 - 0s - loss: 0.5822 - accuracy: 0.6891 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00050: val_loss did not improve from 0.59547
# Epoch 51/300
# 8/8 - 0s - loss: 0.5742 - accuracy: 0.7029 - val_loss: 0.5955 - val_accuracy: 0.7200
#
# Epoch 00051: val_loss did not improve from 0.59547
# 2
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3_input (InputLayer)  [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 41, 128)           2816
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_2 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 1s - loss: 0.5786 - accuracy: 0.7024 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00001: val_loss improved from inf to 0.59166, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\_2.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.5688 - accuracy: 0.7049 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00002: val_loss did not improve from 0.59166
# Epoch 3/300
# 8/8 - 0s - loss: 0.5791 - accuracy: 0.6975 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00003: val_loss did not improve from 0.59166
# Epoch 4/300
# 8/8 - 0s - loss: 0.5792 - accuracy: 0.6980 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00004: val_loss did not improve from 0.59166
# Epoch 5/300
# 8/8 - 0s - loss: 0.5731 - accuracy: 0.6965 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00005: val_loss did not improve from 0.59166
# Epoch 6/300
# 8/8 - 0s - loss: 0.5804 - accuracy: 0.7009 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00006: val_loss did not improve from 0.59166
# Epoch 7/300
# 8/8 - 0s - loss: 0.5835 - accuracy: 0.6920 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00007: val_loss did not improve from 0.59166
# Epoch 8/300
# 8/8 - 0s - loss: 0.5840 - accuracy: 0.6975 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00008: val_loss did not improve from 0.59166
# Epoch 9/300
# 8/8 - 0s - loss: 0.5806 - accuracy: 0.6886 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00009: val_loss did not improve from 0.59166
# Epoch 10/300
# 8/8 - 0s - loss: 0.5725 - accuracy: 0.6945 - val_loss: 0.5917 - val_accuracy: 0.7156
# Epoch 00010: val_loss did not improve from 0.59166
# Epoch 11/300
# 8/8 - 0s - loss: 0.5719 - accuracy: 0.7084 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00011: val_loss did not improve from 0.59166
# Epoch 12/300
# 8/8 - 0s - loss: 0.5724 - accuracy: 0.7093 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00012: val_loss did not improve from 0.59166
# Epoch 13/300
# 8/8 - 0s - loss: 0.5778 - accuracy: 0.6970 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00013: val_loss did not improve from 0.59166
# Epoch 14/300
# 8/8 - 0s - loss: 0.5741 - accuracy: 0.7029 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00014: val_loss did not improve from 0.59166
# Epoch 15/300
# 8/8 - 0s - loss: 0.5748 - accuracy: 0.7029 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00015: val_loss did not improve from 0.59166
# Epoch 16/300
# 8/8 - 0s - loss: 0.5801 - accuracy: 0.6970 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00016: val_loss did not improve from 0.59166
# Epoch 17/300
# 8/8 - 0s - loss: 0.5754 - accuracy: 0.6930 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00017: val_loss did not improve from 0.59166
# Epoch 18/300
# 8/8 - 0s - loss: 0.5749 - accuracy: 0.7019 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00018: val_loss did not improve from 0.59166
# Epoch 19/300
# 8/8 - 0s - loss: 0.5797 - accuracy: 0.6985 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00019: val_loss did not improve from 0.59166
# Epoch 20/300
# 8/8 - 0s - loss: 0.5868 - accuracy: 0.6965 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00020: val_loss did not improve from 0.59166
# Epoch 21/300
# 8/8 - 0s - loss: 0.5809 - accuracy: 0.7049 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00021: val_loss did not improve from 0.59166
# Epoch 22/300
# 8/8 - 0s - loss: 0.5824 - accuracy: 0.6945 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00022: val_loss did not improve from 0.59166
# Epoch 23/300
# 8/8 - 0s - loss: 0.5771 - accuracy: 0.7019 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00023: val_loss did not improve from 0.59166
# Epoch 24/300
# 8/8 - 0s - loss: 0.5752 - accuracy: 0.7069 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00024: val_loss did not improve from 0.59166
# Epoch 25/300
# 8/8 - 0s - loss: 0.5809 - accuracy: 0.7009 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00025: val_loss did not improve from 0.59166
# Epoch 26/300
# 8/8 - 0s - loss: 0.5797 - accuracy: 0.7009 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00026: val_loss did not improve from 0.59166
# Epoch 27/300
# 8/8 - 0s - loss: 0.5737 - accuracy: 0.7133 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00027: val_loss did not improve from 0.59166
# Epoch 28/300
# 8/8 - 0s - loss: 0.5770 - accuracy: 0.7044 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00028: val_loss did not improve from 0.59166
# Epoch 29/300
# 8/8 - 0s - loss: 0.5764 - accuracy: 0.7000 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00029: val_loss did not improve from 0.59166
# Epoch 30/300
# 8/8 - 0s - loss: 0.5746 - accuracy: 0.7084 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00030: val_loss did not improve from 0.59166
# Epoch 31/300
# 8/8 - 0s - loss: 0.5783 - accuracy: 0.6990 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00031: val_loss did not improve from 0.59166
# Epoch 32/300
# 8/8 - 0s - loss: 0.5742 - accuracy: 0.6990 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00032: val_loss did not improve from 0.59166
# Epoch 33/300
# 8/8 - 0s - loss: 0.5740 - accuracy: 0.7103 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00033: val_loss did not improve from 0.59166
# Epoch 34/300
# 8/8 - 0s - loss: 0.5811 - accuracy: 0.6901 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00034: val_loss did not improve from 0.59166
# Epoch 35/300
# 8/8 - 0s - loss: 0.5767 - accuracy: 0.7039 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00035: val_loss did not improve from 0.59166
# Epoch 36/300
# 8/8 - 0s - loss: 0.5811 - accuracy: 0.6960 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00036: val_loss did not improve from 0.59166
# Epoch 37/300
# 8/8 - 0s - loss: 0.5803 - accuracy: 0.6985 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00037: val_loss did not improve from 0.59166
# Epoch 38/300
# 8/8 - 0s - loss: 0.5731 - accuracy: 0.7009 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00038: val_loss did not improve from 0.59166
# Epoch 39/300
# 8/8 - 0s - loss: 0.5694 - accuracy: 0.7113 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00039: val_loss did not improve from 0.59166
# Epoch 40/300
# 8/8 - 0s - loss: 0.5826 - accuracy: 0.6930 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00040: val_loss did not improve from 0.59166
# Epoch 41/300
# 8/8 - 0s - loss: 0.5795 - accuracy: 0.6950 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00041: val_loss did not improve from 0.59166
# Epoch 42/300
# 8/8 - 0s - loss: 0.5813 - accuracy: 0.6955 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00042: val_loss did not improve from 0.59166
# Epoch 43/300
# 8/8 - 0s - loss: 0.5745 - accuracy: 0.7000 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00043: val_loss did not improve from 0.59166
# Epoch 44/300
# 8/8 - 0s - loss: 0.5771 - accuracy: 0.7024 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00044: val_loss did not improve from 0.59166
# Epoch 45/300
# 8/8 - 0s - loss: 0.5798 - accuracy: 0.6911 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00045: val_loss did not improve from 0.59166
# Epoch 46/300
# 8/8 - 0s - loss: 0.5865 - accuracy: 0.6935 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00046: val_loss did not improve from 0.59166
# Epoch 47/300
# 8/8 - 0s - loss: 0.5833 - accuracy: 0.6960 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00047: val_loss did not improve from 0.59166
# Epoch 48/300
# 8/8 - 0s - loss: 0.5759 - accuracy: 0.7088 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00048: val_loss did not improve from 0.59166
# Epoch 49/300
# 8/8 - 0s - loss: 0.5716 - accuracy: 0.6980 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00049: val_loss did not improve from 0.59166
# Epoch 50/300
# 8/8 - 0s - loss: 0.5746 - accuracy: 0.6970 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00050: val_loss did not improve from 0.59166
# Epoch 51/300
# 8/8 - 0s - loss: 0.5884 - accuracy: 0.6896 - val_loss: 0.5917 - val_accuracy: 0.7156
#
# Epoch 00051: val_loss did not improve from 0.59166
# 3
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3_input (InputLayer)  [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 41, 128)           2816
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_3 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 1s - loss: 0.5797 - accuracy: 0.7049 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00001: val_loss improved from inf to 0.60313, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\_3.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.5758 - accuracy: 0.6896 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00002: val_loss did not improve from 0.60313
# Epoch 3/300
# 8/8 - 0s - loss: 0.5724 - accuracy: 0.7009 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00003: val_loss did not improve from 0.60313
# Epoch 4/300
# 8/8 - 0s - loss: 0.5868 - accuracy: 0.6915 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00004: val_loss did not improve from 0.60313
# Epoch 5/300
# 8/8 - 0s - loss: 0.5797 - accuracy: 0.7123 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00005: val_loss did not improve from 0.60313
# Epoch 6/300
# 8/8 - 0s - loss: 0.5800 - accuracy: 0.6920 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00006: val_loss did not improve from 0.60313
# Epoch 7/300
# 8/8 - 0s - loss: 0.5763 - accuracy: 0.7019 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00007: val_loss did not improve from 0.60313
# Epoch 8/300
# 8/8 - 0s - loss: 0.5750 - accuracy: 0.6985 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00008: val_loss did not improve from 0.60313
# Epoch 9/300
# 8/8 - 0s - loss: 0.5736 - accuracy: 0.6990 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00009: val_loss did not improve from 0.60313
# Epoch 10/300
# 8/8 - 0s - loss: 0.5825 - accuracy: 0.6891 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00010: val_loss did not improve from 0.60313
# Epoch 11/300
# 8/8 - 0s - loss: 0.5745 - accuracy: 0.7004 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00011: val_loss did not improve from 0.60313
# Epoch 12/300
# 8/8 - 0s - loss: 0.5804 - accuracy: 0.6980 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00012: val_loss did not improve from 0.60313
# Epoch 13/300
# 8/8 - 0s - loss: 0.5779 - accuracy: 0.7103 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00013: val_loss did not improve from 0.60313
# Epoch 14/300
# 8/8 - 0s - loss: 0.5846 - accuracy: 0.6920 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00014: val_loss did not improve from 0.60313
# Epoch 15/300
# 8/8 - 0s - loss: 0.5767 - accuracy: 0.7000 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00015: val_loss did not improve from 0.60313
# Epoch 16/300
# 8/8 - 0s - loss: 0.5718 - accuracy: 0.6980 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00016: val_loss did not improve from 0.60313
# Epoch 17/300
# 8/8 - 0s - loss: 0.5783 - accuracy: 0.7103 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00017: val_loss did not improve from 0.60313
# Epoch 18/300
# 8/8 - 0s - loss: 0.5816 - accuracy: 0.6985 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00018: val_loss did not improve from 0.60313
# Epoch 19/300
# 8/8 - 0s - loss: 0.5857 - accuracy: 0.6906 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00019: val_loss did not improve from 0.60313
# Epoch 20/300
# 8/8 - 0s - loss: 0.5702 - accuracy: 0.7064 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00020: val_loss did not improve from 0.60313
# Epoch 21/300
# 8/8 - 0s - loss: 0.5735 - accuracy: 0.7103 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00021: val_loss did not improve from 0.60313
# Epoch 22/300
# 8/8 - 0s - loss: 0.5782 - accuracy: 0.7059 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00022: val_loss did not improve from 0.60313
# Epoch 23/300
# 8/8 - 0s - loss: 0.5858 - accuracy: 0.6920 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00023: val_loss did not improve from 0.60313
# Epoch 24/300
# 8/8 - 0s - loss: 0.5733 - accuracy: 0.7014 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00024: val_loss did not improve from 0.60313
# Epoch 25/300
# 8/8 - 0s - loss: 0.5758 - accuracy: 0.7069 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00025: val_loss did not improve from 0.60313
# Epoch 26/300
# 8/8 - 0s - loss: 0.5759 - accuracy: 0.6915 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00026: val_loss did not improve from 0.60313
# Epoch 27/300
# 8/8 - 0s - loss: 0.5730 - accuracy: 0.7039 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00027: val_loss did not improve from 0.60313
# Epoch 28/300
# 8/8 - 0s - loss: 0.5766 - accuracy: 0.7019 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00028: val_loss did not improve from 0.60313
# Epoch 29/300
# 8/8 - 0s - loss: 0.5793 - accuracy: 0.7009 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00029: val_loss did not improve from 0.60313
# Epoch 30/300
# 8/8 - 0s - loss: 0.5748 - accuracy: 0.6950 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00030: val_loss did not improve from 0.60313
# Epoch 31/300
# 8/8 - 0s - loss: 0.5825 - accuracy: 0.6920 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00031: val_loss did not improve from 0.60313
# Epoch 32/300
# 8/8 - 0s - loss: 0.5711 - accuracy: 0.7084 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00032: val_loss did not improve from 0.60313
# Epoch 33/300
# 8/8 - 0s - loss: 0.5836 - accuracy: 0.6886 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00033: val_loss did not improve from 0.60313
# Epoch 34/300
# 8/8 - 0s - loss: 0.5748 - accuracy: 0.7029 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00034: val_loss did not improve from 0.60313
# Epoch 35/300
# 8/8 - 0s - loss: 0.5831 - accuracy: 0.6911 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00035: val_loss did not improve from 0.60313
# Epoch 36/300
# 8/8 - 0s - loss: 0.5737 - accuracy: 0.7098 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00036: val_loss did not improve from 0.60313
# Epoch 37/300
# 8/8 - 0s - loss: 0.5779 - accuracy: 0.7049 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00037: val_loss did not improve from 0.60313
# Epoch 38/300
# 8/8 - 0s - loss: 0.5785 - accuracy: 0.7000 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00038: val_loss did not improve from 0.60313
# Epoch 39/300
# 8/8 - 0s - loss: 0.5796 - accuracy: 0.6925 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00039: val_loss did not improve from 0.60313
# Epoch 40/300
# 8/8 - 0s - loss: 0.5777 - accuracy: 0.6930 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00040: val_loss did not improve from 0.60313
# Epoch 41/300
# 8/8 - 0s - loss: 0.5739 - accuracy: 0.7069 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00041: val_loss did not improve from 0.60313
# Epoch 42/300
# 8/8 - 0s - loss: 0.5868 - accuracy: 0.6846 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00042: val_loss did not improve from 0.60313
# Epoch 43/300
# 8/8 - 0s - loss: 0.5744 - accuracy: 0.7079 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00043: val_loss did not improve from 0.60313
# Epoch 44/300
# 8/8 - 0s - loss: 0.5785 - accuracy: 0.7044 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00044: val_loss did not improve from 0.60313
# Epoch 45/300
# 8/8 - 0s - loss: 0.5732 - accuracy: 0.6940 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00045: val_loss did not improve from 0.60313
# Epoch 46/300
# 8/8 - 0s - loss: 0.5751 - accuracy: 0.7024 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00046: val_loss did not improve from 0.60313
# Epoch 47/300
# 8/8 - 0s - loss: 0.5775 - accuracy: 0.7034 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00047: val_loss did not improve from 0.60313
# Epoch 48/300
# 8/8 - 0s - loss: 0.5797 - accuracy: 0.7108 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00048: val_loss did not improve from 0.60313
# Epoch 49/300
# 8/8 - 0s - loss: 0.5749 - accuracy: 0.7014 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00049: val_loss did not improve from 0.60313
# Epoch 50/300
# 8/8 - 0s - loss: 0.5822 - accuracy: 0.6970 - val_loss: 0.6031 - val_accuracy: 0.6711
#
# Epoch 00050: val_loss did not improve from 0.60313
# Epoch 51/300
# 8/8 - 0s - loss: 0.5730 - accuracy: 0.7098 - val_loss: 0.6031 - val_accuracy: 0.6711
# Epoch 00051: val_loss did not improve from 0.60313
# 4
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3_input (InputLayer)  [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 41, 128)           2816
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_4 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 1s - loss: 0.5750 - accuracy: 0.7054 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00001: val_loss improved from inf to 0.56729, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\_4.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.5832 - accuracy: 0.6891 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00002: val_loss did not improve from 0.56729
# Epoch 3/300
# 8/8 - 0s - loss: 0.5825 - accuracy: 0.6891 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00003: val_loss did not improve from 0.56729
# Epoch 4/300
# 8/8 - 0s - loss: 0.5849 - accuracy: 0.6960 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00004: val_loss did not improve from 0.56729
# Epoch 5/300
# 8/8 - 0s - loss: 0.5826 - accuracy: 0.6965 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00005: val_loss did not improve from 0.56729
# Epoch 6/300
# 8/8 - 0s - loss: 0.5898 - accuracy: 0.6906 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00006: val_loss did not improve from 0.56729
# Epoch 7/300
# 8/8 - 0s - loss: 0.5784 - accuracy: 0.7034 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00007: val_loss did not improve from 0.56729
# Epoch 8/300
# 8/8 - 0s - loss: 0.5888 - accuracy: 0.6886 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00008: val_loss did not improve from 0.56729
# Epoch 9/300
# 8/8 - 0s - loss: 0.5857 - accuracy: 0.6841 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00009: val_loss did not improve from 0.56729
# Epoch 10/300
# 8/8 - 0s - loss: 0.5793 - accuracy: 0.6950 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00010: val_loss did not improve from 0.56729
# Epoch 11/300
# 8/8 - 0s - loss: 0.5755 - accuracy: 0.6960 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00011: val_loss did not improve from 0.56729
# Epoch 12/300
# 8/8 - 0s - loss: 0.5841 - accuracy: 0.6990 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00012: val_loss did not improve from 0.56729
# Epoch 13/300
# 8/8 - 0s - loss: 0.5809 - accuracy: 0.7009 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00013: val_loss did not improve from 0.56729
# Epoch 14/300
# 8/8 - 0s - loss: 0.5836 - accuracy: 0.6891 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00014: val_loss did not improve from 0.56729
# Epoch 15/300
# 8/8 - 0s - loss: 0.5806 - accuracy: 0.7024 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00015: val_loss did not improve from 0.56729
# Epoch 16/300
# 8/8 - 0s - loss: 0.5765 - accuracy: 0.6906 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00016: val_loss did not improve from 0.56729
# Epoch 17/300
# 8/8 - 0s - loss: 0.5760 - accuracy: 0.6970 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00017: val_loss did not improve from 0.56729
# Epoch 18/300
# 8/8 - 0s - loss: 0.5879 - accuracy: 0.6846 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00018: val_loss did not improve from 0.56729
# Epoch 19/300
# 8/8 - 0s - loss: 0.5909 - accuracy: 0.6935 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00019: val_loss did not improve from 0.56729
# Epoch 20/300
# 8/8 - 0s - loss: 0.5779 - accuracy: 0.6955 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00020: val_loss did not improve from 0.56729
# Epoch 21/300
# 8/8 - 0s - loss: 0.5814 - accuracy: 0.7009 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00021: val_loss did not improve from 0.56729
# Epoch 22/300
# 8/8 - 0s - loss: 0.5841 - accuracy: 0.6985 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00022: val_loss did not improve from 0.56729
# Epoch 23/300
# 8/8 - 0s - loss: 0.5848 - accuracy: 0.6891 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00023: val_loss did not improve from 0.56729
# Epoch 24/300
# 8/8 - 0s - loss: 0.5879 - accuracy: 0.6935 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00024: val_loss did not improve from 0.56729
# Epoch 25/300
# 8/8 - 0s - loss: 0.5852 - accuracy: 0.6836 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00025: val_loss did not improve from 0.56729
# Epoch 26/300
# 8/8 - 0s - loss: 0.5833 - accuracy: 0.6915 - val_loss: 0.5673 - val_accuracy: 0.7467
#
# Epoch 00026: val_loss did not improve from 0.56729
# Epoch 27/300
# ...
#
# Epoch 00024: val_loss did not improve from 0.58301
# Epoch 25/300
# 8/8 - 0s - loss: 0.5786 - accuracy: 0.6917 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00025: val_loss did not improve from 0.58301
# Epoch 26/300
# 8/8 - 0s - loss: 0.5823 - accuracy: 0.6907 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00026: val_loss did not improve from 0.58301
# Epoch 27/300
# 8/8 - 0s - loss: 0.5837 - accuracy: 0.6907 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00027: val_loss did not improve from 0.58301
# Epoch 28/300
# 8/8 - 0s - loss: 0.5878 - accuracy: 0.6759 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00028: val_loss did not improve from 0.58301
# Epoch 29/300
# 8/8 - 0s - loss: 0.5805 - accuracy: 0.6971 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00029: val_loss did not improve from 0.58301
# Epoch 30/300
# 8/8 - 0s - loss: 0.5806 - accuracy: 0.6971 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00030: val_loss did not improve from 0.58301
# Epoch 31/300
# 8/8 - 0s - loss: 0.5765 - accuracy: 0.6957 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00031: val_loss did not improve from 0.58301
# Epoch 32/300
# 8/8 - 0s - loss: 0.5799 - accuracy: 0.7011 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00032: val_loss did not improve from 0.58301
# Epoch 33/300
# 8/8 - 0s - loss: 0.5791 - accuracy: 0.6996 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00033: val_loss did not improve from 0.58301
# Epoch 34/300
# 8/8 - 0s - loss: 0.5760 - accuracy: 0.7011 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00034: val_loss did not improve from 0.58301
# Epoch 35/300
# 8/8 - 0s - loss: 0.5746 - accuracy: 0.7055 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00035: val_loss did not improve from 0.58301
# Epoch 36/300
# 8/8 - 0s - loss: 0.5767 - accuracy: 0.6912 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00036: val_loss did not improve from 0.58301
# Epoch 37/300
# 8/8 - 0s - loss: 0.5786 - accuracy: 0.6927 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00037: val_loss did not improve from 0.58301
# Epoch 38/300
# 8/8 - 0s - loss: 0.5841 - accuracy: 0.6902 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00038: val_loss did not improve from 0.58301
# Epoch 39/300
# 8/8 - 0s - loss: 0.5859 - accuracy: 0.6902 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00039: val_loss did not improve from 0.58301
# Epoch 40/300
# 8/8 - 0s - loss: 0.5884 - accuracy: 0.6892 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00040: val_loss did not improve from 0.58301
# Epoch 41/300
# 8/8 - 0s - loss: 0.5782 - accuracy: 0.6976 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00041: val_loss did not improve from 0.58301
# Epoch 42/300
# 8/8 - 0s - loss: 0.5823 - accuracy: 0.6902 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00042: val_loss did not improve from 0.58301
# Epoch 43/300
# 8/8 - 0s - loss: 0.5737 - accuracy: 0.6942 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00043: val_loss did not improve from 0.58301
# Epoch 44/300
# 8/8 - 0s - loss: 0.5781 - accuracy: 0.7026 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00044: val_loss did not improve from 0.58301
# Epoch 45/300
# 8/8 - 0s - loss: 0.5803 - accuracy: 0.6976 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00045: val_loss did not improve from 0.58301
# Epoch 46/300
# 8/8 - 0s - loss: 0.5828 - accuracy: 0.6942 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00046: val_loss did not improve from 0.58301
# Epoch 47/300
# 8/8 - 0s - loss: 0.5788 - accuracy: 0.6986 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00047: val_loss did not improve from 0.58301
# Epoch 48/300
# 8/8 - 0s - loss: 0.5802 - accuracy: 0.6942 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00048: val_loss did not improve from 0.58301
# Epoch 49/300
# 8/8 - 0s - loss: 0.5765 - accuracy: 0.6996 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00049: val_loss did not improve from 0.58301
# Epoch 50/300
# 8/8 - 0s - loss: 0.5905 - accuracy: 0.6882 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00050: val_loss did not improve from 0.58301
# Epoch 51/300
# 8/8 - 0s - loss: 0.5801 - accuracy: 0.6957 - val_loss: 0.5830 - val_accuracy: 0.7232
#
# Epoch 00051: val_loss did not improve from 0.58301
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000230E7489C10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 9
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3_input (InputLayer)  [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 41, 128)           2816
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_9 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 1s - loss: 0.5774 - accuracy: 0.6996 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00001: val_loss improved from inf to 0.57149, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\_9.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.5892 - accuracy: 0.6873 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00002: val_loss did not improve from 0.57149
# Epoch 3/300
# 8/8 - 0s - loss: 0.5729 - accuracy: 0.6991 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00003: val_loss did not improve from 0.57149
# Epoch 4/300
# 8/8 - 0s - loss: 0.5890 - accuracy: 0.6922 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00004: val_loss did not improve from 0.57149
# Epoch 5/300
# 8/8 - 0s - loss: 0.5844 - accuracy: 0.6932 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00005: val_loss did not improve from 0.57149
# Epoch 6/300
# 8/8 - 0s - loss: 0.5807 - accuracy: 0.7045 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00006: val_loss did not improve from 0.57149
# Epoch 7/300
# 8/8 - 0s - loss: 0.5873 - accuracy: 0.6976 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00007: val_loss did not improve from 0.57149
# Epoch 8/300
# 8/8 - 0s - loss: 0.5801 - accuracy: 0.6897 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00008: val_loss did not improve from 0.57149
# Epoch 9/300
# 8/8 - 0s - loss: 0.5754 - accuracy: 0.7050 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00009: val_loss did not improve from 0.57149
# Epoch 10/300
# 8/8 - 0s - loss: 0.5858 - accuracy: 0.6937 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00010: val_loss did not improve from 0.57149
# Epoch 11/300
# 8/8 - 0s - loss: 0.5728 - accuracy: 0.6986 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00011: val_loss did not improve from 0.57149
# Epoch 12/300
# 8/8 - 0s - loss: 0.5797 - accuracy: 0.7031 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00012: val_loss did not improve from 0.57149
# Epoch 13/300
# 8/8 - 0s - loss: 0.5727 - accuracy: 0.6966 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00013: val_loss did not improve from 0.57149
# Epoch 14/300
# 8/8 - 0s - loss: 0.5840 - accuracy: 0.6947 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00014: val_loss did not improve from 0.57149
# Epoch 15/300
# 8/8 - 0s - loss: 0.5828 - accuracy: 0.6937 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00015: val_loss did not improve from 0.57149
# Epoch 16/300
# 8/8 - 0s - loss: 0.5793 - accuracy: 0.6981 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00016: val_loss did not improve from 0.57149
# Epoch 17/300
# 8/8 - 0s - loss: 0.5855 - accuracy: 0.6952 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00017: val_loss did not improve from 0.57149
# Epoch 18/300
# 8/8 - 0s - loss: 0.5797 - accuracy: 0.6961 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00018: val_loss did not improve from 0.57149
# Epoch 19/300
# 8/8 - 0s - loss: 0.5840 - accuracy: 0.6877 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00019: val_loss did not improve from 0.57149
# Epoch 20/300
# 8/8 - 0s - loss: 0.5822 - accuracy: 0.6966 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00020: val_loss did not improve from 0.57149
# Epoch 21/300
# 8/8 - 0s - loss: 0.5767 - accuracy: 0.7006 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00021: val_loss did not improve from 0.57149
# Epoch 22/300
# 8/8 - 0s - loss: 0.5807 - accuracy: 0.6937 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00022: val_loss did not improve from 0.57149
# Epoch 23/300
# 8/8 - 0s - loss: 0.5776 - accuracy: 0.6986 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00023: val_loss did not improve from 0.57149
# Epoch 24/300
# 8/8 - 0s - loss: 0.5858 - accuracy: 0.6818 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00024: val_loss did not improve from 0.57149
# Epoch 25/300
# 8/8 - 0s - loss: 0.5812 - accuracy: 0.6892 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00025: val_loss did not improve from 0.57149
# Epoch 26/300
# 8/8 - 0s - loss: 0.5788 - accuracy: 0.6952 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00026: val_loss did not improve from 0.57149
# Epoch 27/300
# 8/8 - 0s - loss: 0.5716 - accuracy: 0.7026 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00027: val_loss did not improve from 0.57149
# Epoch 28/300
# 8/8 - 0s - loss: 0.5923 - accuracy: 0.6917 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00028: val_loss did not improve from 0.57149
# Epoch 29/300
# 8/8 - 0s - loss: 0.5816 - accuracy: 0.6942 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00029: val_loss did not improve from 0.57149
# Epoch 30/300
# 8/8 - 0s - loss: 0.5784 - accuracy: 0.7021 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00030: val_loss did not improve from 0.57149
# Epoch 31/300
# 8/8 - 0s - loss: 0.5783 - accuracy: 0.6986 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00031: val_loss did not improve from 0.57149
# Epoch 32/300
# 8/8 - 0s - loss: 0.5792 - accuracy: 0.6966 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00032: val_loss did not improve from 0.57149
# Epoch 33/300
# 8/8 - 0s - loss: 0.5793 - accuracy: 0.7001 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00033: val_loss did not improve from 0.57149
# Epoch 34/300
# 8/8 - 0s - loss: 0.5756 - accuracy: 0.7001 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00034: val_loss did not improve from 0.57149
# Epoch 35/300
# 8/8 - 0s - loss: 0.5818 - accuracy: 0.7016 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00035: val_loss did not improve from 0.57149
# Epoch 36/300
# 8/8 - 0s - loss: 0.5787 - accuracy: 0.7011 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00036: val_loss did not improve from 0.57149
# Epoch 37/300
# 8/8 - 0s - loss: 0.5855 - accuracy: 0.6996 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00037: val_loss did not improve from 0.57149
# Epoch 38/300
# 8/8 - 0s - loss: 0.5794 - accuracy: 0.6902 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00038: val_loss did not improve from 0.57149
# Epoch 39/300
# 8/8 - 0s - loss: 0.5875 - accuracy: 0.6897 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00039: val_loss did not improve from 0.57149
# Epoch 40/300
# 8/8 - 0s - loss: 0.5774 - accuracy: 0.6961 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00040: val_loss did not improve from 0.57149
# Epoch 41/300
# 8/8 - 0s - loss: 0.5820 - accuracy: 0.6952 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00041: val_loss did not improve from 0.57149
# Epoch 42/300
# 8/8 - 0s - loss: 0.5831 - accuracy: 0.6947 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00042: val_loss did not improve from 0.57149
# Epoch 43/300
# 8/8 - 0s - loss: 0.5805 - accuracy: 0.6971 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00043: val_loss did not improve from 0.57149
# Epoch 44/300
# 8/8 - 0s - loss: 0.5805 - accuracy: 0.6882 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00044: val_loss did not improve from 0.57149
# Epoch 45/300
# 8/8 - 0s - loss: 0.5795 - accuracy: 0.6942 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00045: val_loss did not improve from 0.57149
# Epoch 46/300
# 8/8 - 0s - loss: 0.5705 - accuracy: 0.7016 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00046: val_loss did not improve from 0.57149
# Epoch 47/300
# 8/8 - 0s - loss: 0.5803 - accuracy: 0.6922 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00047: val_loss did not improve from 0.57149
# Epoch 48/300
# 8/8 - 0s - loss: 0.5769 - accuracy: 0.6986 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00048: val_loss did not improve from 0.57149
# Epoch 49/300
# 8/8 - 0s - loss: 0.5829 - accuracy: 0.6813 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00049: val_loss did not improve from 0.57149
# Epoch 50/300
# 8/8 - 0s - loss: 0.5829 - accuracy: 0.6937 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00050: val_loss did not improve from 0.57149
# Epoch 51/300
# 8/8 - 0s - loss: 0.5795 - accuracy: 0.6932 - val_loss: 0.5715 - val_accuracy: 0.7143
#
# Epoch 00051: val_loss did not improve from 0.57149
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000230E5CF59D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10

# %%
#遍历表格求初始里程
#交叉验证
import os
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try')
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\result\val'
filenames=os.listdir(path)#得到字符串列表
scores_val=[]
lables_val=[]
fpr_list_val = []
tpr_list_val = []
roc_auc_list_val=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_val=data.iloc[:,1]
        scores_val.append(score_val)
        lable_val = data.iloc[:,2]
        lables_val.append(lable_val)
        fpr_val,tpr_val,thresholds_val= roc_curve(lables_val[i],scores_val[i])   #y_true,y_score
        fpr_list_val.append(fpr_val)
        tpr_list_val.append(tpr_val)
        roc_auc_val = auc(fpr_val,tpr_val)
        roc_auc_list_val.append(roc_auc_val)
        i+=1

# %%
roc_auc_list_val
# Out:
# [0.7859513274336284,
#  0.7991071428571428,
#  0.7553729456384325,
#  0.7707806573957017,
#  0.7434418457648545,
#  0.8059418457648546,
#  0.8012010113780026,
#  0.8072850821744627,
#  0.749486409608091,
#  0.778938137755102]

# %%
i=1
tprs_val = []
mean_fpr_val = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Validation ROC')
for fpr_val,tpr_val,roc_auc_val in zip(fpr_list_val,tpr_list_val,roc_auc_list_val):
    tprs_val.append(np.interp(mean_fpr_val, fpr_val, tpr_val))
    tprs_val[-1][0] = 0.0
    plt.plot(fpr_val, tpr_val, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_val)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_val.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_val = np.mean(tprs_val, axis=0)
mean_tpr_val[-1] = 1.0
mean_auc_val = auc(mean_fpr_val, mean_tpr_val)
std_auc_val = np.std(roc_auc_list_val)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_val, std_auc_val),lw=2, alpha=.8)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_val),lw=2, alpha=.8)
std_tpr_val = np.std(tprs_val, axis=0)
tprs_upper_val = np.minimum(mean_tpr_val + std_tpr_val, 1)
tprs_lower_val = np.maximum(mean_tpr_val - std_tpr_val, 0)
plt.fill_between(mean_fpr_val, tprs_lower_val, tprs_upper_val, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Cross-Validation ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_val_mean.png')
plt.show()

# %%
def calculate_metrics_val(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_val = []
for score_val,lable_val in zip(scores_val,lables_val):
    val_my_calculate_metrics = calculate_metrics_val(lable_val,score_val)
    my_calculate_metrics_list_val.append(val_my_calculate_metrics)

# %%
my_calculate_metrics_list_val
# Out:
# [{'SN': 0.7964601769911505,
#   'SP': 0.5714285714285714,
#   'ACC': 0.6844444444444444,
#   'MCC': 0.37771616279560183,
#   'Recall': 0.7964601769911505,
#   'Precision': 0.6521739130434783,
#   'F1-score': 0.7171314741035857,
#   'Cutoff': 0.5},
#  {'SN': 0.7410714285714286,
#   'SP': 0.6875,
#   'ACC': 0.7142857142857143,
#   'MCC': 0.4291877335725994,
#   'Recall': 0.7410714285714286,
#   'Precision': 0.7033898305084746,
#   'F1-score': 0.7217391304347827,
#   'Cutoff': 0.5},
#  {'SN': 0.7699115044247787,
#   'SP': 0.6696428571428571,
#   'ACC': 0.72,
#   'MCC': 0.4418646894884593,
#   'Recall': 0.7699115044247787,
#   'Precision': 0.7016129032258065,
#   'F1-score': 0.7341772151898734,
#   'Cutoff': 0.5},
#  {'SN': 0.7433628318584071,
#   'SP': 0.6875,
#   'ACC': 0.7155555555555555,
#   'MCC': 0.4315795434686004,
#   'Recall': 0.7433628318584071,
#   'Precision': 0.7058823529411765,
#   'F1-score': 0.7241379310344828,
#   'Cutoff': 0.5},
#  {'SN': 0.6902654867256637,
#   'SP': 0.6517857142857143,
#   'ACC': 0.6711111111111111,
#   'MCC': 0.342321789773742,
#   'Recall': 0.6902654867256637,
#   'Precision': 0.6666666666666666,
#   'F1-score': 0.6782608695652174,
#   'Cutoff': 0.5},
#  {'SN': 0.8125,
#   'SP': 0.6814159292035398,
#   'ACC': 0.7466666666666667,
#   'MCC': 0.4980653938450099,
#   'Recall': 0.8125,
#   'Precision': 0.7165354330708661,
#   'F1-score': 0.7615062761506276,
#   'Cutoff': 0.5},
#  {'SN': 0.8482142857142857,
#   'SP': 0.7079646017699115,
#   'ACC': 0.7777777777777778,
#   'MCC': 0.5615285991566674,
#   'Recall': 0.8482142857142857,
#   'Precision': 0.7421875,
#   'F1-score': 0.7916666666666666,
#   'Cutoff': 0.5},
#  {'SN': 0.8214285714285714,
#   'SP': 0.6902654867256637,
#   'ACC': 0.7555555555555555,
#   'MCC': 0.5159928796257054,
#   'Recall': 0.8214285714285714,
#   'Precision': 0.7244094488188977,
#   'F1-score': 0.7698744769874477,
#   'Cutoff': 0.5},
#  {'SN': 0.7321428571428571,
#   'SP': 0.6194690265486725,
#   'ACC': 0.6755555555555556,
#   'MCC': 0.3537991387697044,
#   'Recall': 0.7321428571428571,
#   'Precision': 0.656,
#   'F1-score': 0.6919831223628692,
#   'Cutoff': 0.5},
#  {'SN': 0.8125,
#   'SP': 0.6339285714285714,
#   'ACC': 0.7232142857142857,
#   'MCC': 0.4537212554003923,
#   'Recall': 0.8125,
#   'Precision': 0.6893939393939394,
#   'F1-score': 0.7459016393442623,
#   'Cutoff': 0.5}]

# %%
performance_val=pd.DataFrame(my_calculate_metrics_list_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.796460  0.571429  0.684444  0.377716  0.796460   0.652174  0.717131
# 1  0.741071  0.687500  0.714286  0.429188  0.741071   0.703390  0.721739
# 2  0.769912  0.669643  0.720000  0.441865  0.769912   0.701613  0.734177
# 3  0.743363  0.687500  0.715556  0.431580  0.743363   0.705882  0.724138
# 4  0.690265  0.651786  0.671111  0.342322  0.690265   0.666667  0.678261
# 5  0.812500  0.681416  0.746667  0.498065  0.812500   0.716535  0.761506
# 6  0.848214  0.707965  0.777778  0.561529  0.848214   0.742188  0.791667
# 7  0.821429  0.690265  0.755556  0.515993  0.821429   0.724409  0.769874
# 8  0.732143  0.619469  0.675556  0.353799  0.732143   0.656000  0.691983
# 9  0.812500  0.633929  0.723214  0.453721  0.812500   0.689394  0.745902
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_val = performance_val.std(axis = 0,ddof=1)
mean_val = performance_val.mean(axis = 0)
data_mean_val = pd.DataFrame(mean_val)
data_mean_val = data_mean_val.T
data_std_val = pd.DataFrame(std_val)
data_std_val = data_std_val.T
performance_val = performance_val.append(data_mean_val)
performance_val = performance_val.append(data_std_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.796460  0.571429  0.684444  0.377716  0.796460   0.652174  0.717131
# 1  0.741071  0.687500  0.714286  0.429188  0.741071   0.703390  0.721739
# 2  0.769912  0.669643  0.720000  0.441865  0.769912   0.701613  0.734177
# 3  0.743363  0.687500  0.715556  0.431580  0.743363   0.705882  0.724138
# 4  0.690265  0.651786  0.671111  0.342322  0.690265   0.666667  0.678261
# 5  0.812500  0.681416  0.746667  0.498065  0.812500   0.716535  0.761506
# 6  0.848214  0.707965  0.777778  0.561529  0.848214   0.742188  0.791667
# 7  0.821429  0.690265  0.755556  0.515993  0.821429   0.724409  0.769874
# 8  0.732143  0.619469  0.675556  0.353799  0.732143   0.656000  0.691983
# 9  0.812500  0.633929  0.723214  0.453721  0.812500   0.689394  0.745902
# 0  0.776786  0.660090  0.718417  0.440578  0.776786   0.695825  0.733638
# 0  0.049387  0.041520  0.034930  0.070823  0.049387   0.029759  0.034823
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_val.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\result\CNN_OH_performance_val.csv',encoding='utf-8')

# %% [markdown]
# 独立测试

# %%
#遍历表格求初始里程
#独立测试
import os
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\result\indep'
filenames=os.listdir(path)#得到字符串列表
scores_indep=[]
lables_indep=[]
fpr_list_indep = []
tpr_list_indep = []
roc_auc_list_indep=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_indep=data.iloc[:,1]
        scores_indep.append(score_indep)
        lable_indep = data.iloc[:,2]
        lables_indep.append(lable_indep)
        fpr_indep,tpr_indep,thresholds_indep= roc_curve(lables_indep[i],scores_indep[i])   #y_true,y_score
        fpr_list_indep.append(fpr_indep)
        tpr_list_indep.append(tpr_indep)
        roc_auc_indep = auc(fpr_indep,tpr_indep)
        roc_auc_list_indep.append(roc_auc_indep)
        i+=1

# %%
roc_auc_list_indep
# Out:
# [0.7412308673469389,
#  0.7412308673469389,
#  0.7412308673469389,
#  0.7412308673469389,
#  0.7412308673469389,
#  0.7412308673469389,
#  0.7412308673469389,
#  0.7412308673469389,
#  0.7412308673469389,
#  0.7412308673469389]

# %%
i=1
tprs_indep = []
mean_fpr_indep = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Independent ROC')
for fpr_indep,tpr_indep,roc_auc_indep in zip(fpr_list_indep,tpr_list_indep,roc_auc_list_indep):
    tprs_indep.append(np.interp(mean_fpr_indep, fpr_indep, tpr_indep))
    tprs_indep[-1][0] = 0.0
    plt.plot(fpr_indep, tpr_indep, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_indep)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_indep.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_indep = np.mean(tprs_indep, axis=0)
mean_tpr_indep[-1] = 1.0
mean_auc_indep = auc(mean_fpr_indep, mean_tpr_indep)
std_auc_indep = np.std(roc_auc_list_indep)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_indep, std_auc_indep),lw=2, alpha=.8)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_indep),lw=2, alpha=.8)
std_tpr_indep = np.std(tprs_indep, axis=0)
tprs_upper_indep = np.minimum(mean_tpr_indep + std_tpr_indep, 1)
tprs_lower_indep = np.maximum(mean_tpr_indep - std_tpr_indep, 0)
plt.fill_between(mean_fpr_indep, tprs_lower_indep, tprs_upper_indep, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Independent ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_indep_mean.png')
plt.show()

# %%
def calculate_metrics_indep(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_indep = []
for score_indep,lable_indep in zip(scores_indep,lables_indep):
    indep_my_calculate_metrics = calculate_metrics_indep(lable_indep,score_indep)
    my_calculate_metrics_list_indep.append(indep_my_calculate_metrics)

# %%
my_calculate_metrics_list_indep
# Out:
# [{'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.6607142857142857,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.41236123387957546,
#   'Recall': 0.75,
#   'Precision': 0.6885245901639344,
#   'F1-score': 0.717948717948718,
#   'Cutoff': 0.5}]

# %%
performance_indep=pd.DataFrame(my_calculate_metrics_list_indep)
performance_indep
# Out:
#      SN        SP       ACC       MCC  Recall  Precision  F1-score  Cutoff
# 0  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5
# 1  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5
# 2  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5
# 3  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5
# 4  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5
# 5  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5
# 6  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5
# 7  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5
# 8  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5
# 9  0.75  0.660714  0.705357  0.412361    0.75   0.688525  0.717949     0.5

# %%
std_indep = performance_indep.std(axis = 0,ddof=1)
mean_indep = performance_indep.mean(axis = 0)
data_mean_indep = pd.DataFrame(mean_indep)
data_mean_indep = data_mean_indep.T
data_std_indep = pd.DataFrame(std_indep)
data_std_indep = data_std_indep.T
performance_indep = performance_indep.append(data_mean_indep)
performance_indep = performance_indep.append(data_std_indep)
performance_indep
# Out:
#      SN        SP           ACC       MCC  Recall     Precision  F1-score  \
# 0  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 1  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 2  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 3  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 4  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 5  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 6  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 7  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 8  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 9  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 0  0.75  0.660714  7.053571e-01  0.412361    0.75  6.885246e-01  0.717949
# 0  0.00  0.000000  1.170278e-16  0.000000    0.00  1.170278e-16  0.000000
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_indep.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K\try\K除NEDD_freeze_allli_try\result\CNN_OH_performance_indep.csv',encoding='utf-8')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
