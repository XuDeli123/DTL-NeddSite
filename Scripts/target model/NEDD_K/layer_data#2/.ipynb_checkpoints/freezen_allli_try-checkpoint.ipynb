# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from sklearn.model_selection import KFold,StratifiedKFold

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def build_network():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH')
    cnn = load_model('dataoh.h5')
    cnn.trainable = True #固定所有预训练模型层的参数
    base_model = Model(inputs=cnn.layers[0].input,outputs=cnn.layers[11].output)
    base_model.summary()
    base_model.trainable = True
    for layer in base_model.layers:
        layer.trainable = False
    #Dense = tf.keras.layers.Dense(64,activation=tf.nn.relu)
    #global_average_layer = tf.keras.layers.GlobalAveragePooling1D()
    #prediction_layer = tf.keras.layers.Dense(1,activation=tf.nn.sigmoid)
    model1 = tf.keras.Sequential([
        base_model,
        #layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        #layers.Dropout(0.5),
        #Dense,
        #layers.Dropout(0.5),
        #global_average_layer,
        #prediction_layer
    ])
    base_learning_rate = 0.01
    model1.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #model1.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    model1.summary()
    return model1

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
batch_size=256

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\NEDD\不自然数据\1正2345负')
epochs = 300
x_train,y_train = One_hot_raw('train.txt')#十折交叉验证10
x_test,y_test = One_hot_raw('test.txt')#独立测试1

# %%
classes = sorted(list(set(y_train)))
x_train = one_hot(x_train)
x_test = one_hot(x_test)
x_train.shape = (x_train.shape[0],x_train.shape[2],x_train.shape[3])
x_test.shape = (x_test.shape[0],x_test.shape[2],x_test.shape[3])

# %%
# 构建独立测试集对象，预处理，批量化
test_db = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_db = test_db.map(preprocess).batch(batch_size)

# %%
prediction_result_cv = []
prediction_result_ind = []

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try')

# %%
out = os.getcwd() + '\\'

# %%
from sklearn.model_selection import KFold,StratifiedKFold
kf = StratifiedKFold(n_splits=10,shuffle=True)
for n_fold,(tr_idx,val_idx)in enumerate(kf.split(x_train,y_train)):
    tr_x,tr_y,val_x,val_y = x_train[tr_idx],y_train[tr_idx],x_train[val_idx],y_train[val_idx]
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((tr_x, tr_y))
    train_db = train_db.shuffle(len(tr_x)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    valid_db = tf.data.Dataset.from_tensor_slices((val_x, val_y))
    valid_db = valid_db.map(preprocess).batch(batch_size)
    #if not os.path.exists('%s_%d.h5' % (out, n_fold)):
    model1 = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath='%s_%d.h5' % (out, n_fold), monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = model1.fit(train_db, epochs=epochs, validation_data=valid_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)
    #network.load_weights('%s_%d.h5' % (out, n_fold))
    #history = network.fit(train_db, epochs=50, validation_data=valid_db, verbose=2)
    scores1 = model1.predict(val_x, batch_size=batch_size)[:, 0]
    score_val = pd.DataFrame(scores1)
    y_val = pd.DataFrame(val_y)
    datav=pd.concat([score_val,y_val],axis=1)
    print(n_fold + 1) 
    n_fold_str = str(n_fold + 1)
    pathv ='val_out'+ n_fold_str
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\result\val\\'+pathv+'.csv',encoding='utf-8')
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\result\valtxt\\'+pathv+'.txt',sep='\t',index=False,encoding='utf-8')
    scores2 = model1.predict(x_test, batch_size=batch_size)[:, 0]
    score_indep = pd.DataFrame(scores2)
    test_y = pd.DataFrame(y_test)
    datai = pd.concat([score_indep,test_y],axis=1)
    pathi ='indep_out'+ n_fold_str
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\result\indep\\'+pathi+'.csv',encoding='utf-8')
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\result\indeptxt\\'+pathi+'.txt',sep='\t',index=False,encoding='utf-8')
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 5s - loss: 0.7517 - accuracy: 0.5279 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00001: val_loss improved from inf to 0.70210, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\_0.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.7578 - accuracy: 0.5250 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00002: val_loss did not improve from 0.70210
# Epoch 3/300
# 8/8 - 0s - loss: 0.7559 - accuracy: 0.5309 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00003: val_loss did not improve from 0.70210
# Epoch 4/300
# 8/8 - 0s - loss: 0.7499 - accuracy: 0.5358 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00004: val_loss did not improve from 0.70210
# Epoch 5/300
# 8/8 - 0s - loss: 0.7590 - accuracy: 0.5260 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00005: val_loss did not improve from 0.70210
# Epoch 6/300
# 8/8 - 0s - loss: 0.7559 - accuracy: 0.5358 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00006: val_loss did not improve from 0.70210
# Epoch 7/300
# 8/8 - 0s - loss: 0.7582 - accuracy: 0.5334 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00007: val_loss did not improve from 0.70210
# Epoch 8/300
# 8/8 - 0s - loss: 0.7582 - accuracy: 0.5348 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00008: val_loss did not improve from 0.70210
# Epoch 9/300
# 8/8 - 0s - loss: 0.7626 - accuracy: 0.5274 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00009: val_loss did not improve from 0.70210
# Epoch 10/300
# 8/8 - 0s - loss: 0.7610 - accuracy: 0.5274 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00010: val_loss did not improve from 0.70210
# Epoch 11/300
# 8/8 - 0s - loss: 0.7543 - accuracy: 0.5309 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00011: val_loss did not improve from 0.70210
# Epoch 12/300
# 8/8 - 0s - loss: 0.7622 - accuracy: 0.5319 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00012: val_loss did not improve from 0.70210
# Epoch 13/300
# 8/8 - 0s - loss: 0.7620 - accuracy: 0.5279 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00013: val_loss did not improve from 0.70210
# Epoch 14/300
# 8/8 - 0s - loss: 0.7578 - accuracy: 0.5373 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00014: val_loss did not improve from 0.70210
# Epoch 15/300
# 8/8 - 0s - loss: 0.7594 - accuracy: 0.5255 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00015: val_loss did not improve from 0.70210
# Epoch 16/300
# 8/8 - 0s - loss: 0.7580 - accuracy: 0.5240 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00016: val_loss did not improve from 0.70210
# Epoch 17/300
# 8/8 - 0s - loss: 0.7590 - accuracy: 0.5319 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00017: val_loss did not improve from 0.70210
# Epoch 18/300
# 8/8 - 0s - loss: 0.7645 - accuracy: 0.5264 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00018: val_loss did not improve from 0.70210
# Epoch 19/300
# 8/8 - 0s - loss: 0.7521 - accuracy: 0.5339 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00019: val_loss did not improve from 0.70210
# Epoch 20/300
# 8/8 - 0s - loss: 0.7571 - accuracy: 0.5230 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00020: val_loss did not improve from 0.70210
# Epoch 21/300
# 8/8 - 0s - loss: 0.7530 - accuracy: 0.5319 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00021: val_loss did not improve from 0.70210
# Epoch 22/300
# 8/8 - 0s - loss: 0.7558 - accuracy: 0.5195 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00022: val_loss did not improve from 0.70210
# Epoch 23/300
# 8/8 - 0s - loss: 0.7567 - accuracy: 0.5205 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00023: val_loss did not improve from 0.70210
# Epoch 24/300
# 8/8 - 0s - loss: 0.7655 - accuracy: 0.5304 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00024: val_loss did not improve from 0.70210
# Epoch 25/300
# 8/8 - 0s - loss: 0.7556 - accuracy: 0.5319 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00025: val_loss did not improve from 0.70210
# Epoch 26/300
# 8/8 - 0s - loss: 0.7588 - accuracy: 0.5329 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00026: val_loss did not improve from 0.70210
# Epoch 27/300
# 8/8 - 0s - loss: 0.7526 - accuracy: 0.5413 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00027: val_loss did not improve from 0.70210
# Epoch 28/300
# 8/8 - 0s - loss: 0.7626 - accuracy: 0.5363 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00028: val_loss did not improve from 0.70210
# Epoch 29/300
# 8/8 - 0s - loss: 0.7501 - accuracy: 0.5304 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00029: val_loss did not improve from 0.70210
# Epoch 30/300
# 8/8 - 0s - loss: 0.7605 - accuracy: 0.5260 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00030: val_loss did not improve from 0.70210
# Epoch 31/300
# 8/8 - 0s - loss: 0.7587 - accuracy: 0.5324 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00031: val_loss did not improve from 0.70210
# Epoch 32/300
# 8/8 - 0s - loss: 0.7478 - accuracy: 0.5388 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00032: val_loss did not improve from 0.70210
# Epoch 33/300
# 8/8 - 0s - loss: 0.7572 - accuracy: 0.5304 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00033: val_loss did not improve from 0.70210
# Epoch 34/300
# 8/8 - 0s - loss: 0.7639 - accuracy: 0.5230 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00034: val_loss did not improve from 0.70210
# Epoch 35/300
# 8/8 - 0s - loss: 0.7573 - accuracy: 0.5309 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00035: val_loss did not improve from 0.70210
# Epoch 36/300
# 8/8 - 0s - loss: 0.7580 - accuracy: 0.5175 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00036: val_loss did not improve from 0.70210
# Epoch 37/300
# 8/8 - 0s - loss: 0.7530 - accuracy: 0.5388 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00037: val_loss did not improve from 0.70210
# Epoch 38/300
# 8/8 - 0s - loss: 0.7576 - accuracy: 0.5255 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00038: val_loss did not improve from 0.70210
# Epoch 39/300
# 8/8 - 0s - loss: 0.7503 - accuracy: 0.5344 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00039: val_loss did not improve from 0.70210
# Epoch 40/300
# 8/8 - 0s - loss: 0.7618 - accuracy: 0.5146 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00040: val_loss did not improve from 0.70210
# Epoch 41/300
# 8/8 - 0s - loss: 0.7530 - accuracy: 0.5373 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00041: val_loss did not improve from 0.70210
# Epoch 42/300
# 8/8 - 0s - loss: 0.7617 - accuracy: 0.5250 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00042: val_loss did not improve from 0.70210
# Epoch 43/300
# 8/8 - 0s - loss: 0.7596 - accuracy: 0.5353 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00043: val_loss did not improve from 0.70210
# Epoch 44/300
# 8/8 - 0s - loss: 0.7566 - accuracy: 0.5240 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00044: val_loss did not improve from 0.70210
# Epoch 45/300
# 8/8 - 0s - loss: 0.7495 - accuracy: 0.5477 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00045: val_loss did not improve from 0.70210
# Epoch 46/300
# 8/8 - 0s - loss: 0.7555 - accuracy: 0.5235 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00046: val_loss did not improve from 0.70210
# Epoch 47/300
# 8/8 - 0s - loss: 0.7573 - accuracy: 0.5235 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00047: val_loss did not improve from 0.70210
# Epoch 48/300
# 8/8 - 0s - loss: 0.7548 - accuracy: 0.5388 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00048: val_loss did not improve from 0.70210
# Epoch 49/300
# 8/8 - 0s - loss: 0.7587 - accuracy: 0.5240 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00049: val_loss did not improve from 0.70210
# Epoch 50/300
# 8/8 - 0s - loss: 0.7590 - accuracy: 0.5329 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00050: val_loss did not improve from 0.70210
# Epoch 51/300
# 8/8 - 0s - loss: 0.7655 - accuracy: 0.5126 - val_loss: 0.7021 - val_accuracy: 0.5867
#
# Epoch 00051: val_loss did not improve from 0.70210
# 1
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 0s - loss: 0.7495 - accuracy: 0.5393 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00001: val_loss improved from inf to 0.71871, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\_1.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.7536 - accuracy: 0.5353 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00002: val_loss did not improve from 0.71871
# Epoch 3/300
# 8/8 - 0s - loss: 0.7512 - accuracy: 0.5403 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00003: val_loss did not improve from 0.71871
# Epoch 4/300
# 8/8 - 0s - loss: 0.7504 - accuracy: 0.5324 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00004: val_loss did not improve from 0.71871
# Epoch 5/300
# 8/8 - 0s - loss: 0.7445 - accuracy: 0.5378 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00005: val_loss did not improve from 0.71871
# Epoch 6/300
# 8/8 - 0s - loss: 0.7533 - accuracy: 0.5398 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00006: val_loss did not improve from 0.71871
# Epoch 7/300
# 8/8 - 0s - loss: 0.7542 - accuracy: 0.5403 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00007: val_loss did not improve from 0.71871
# Epoch 8/300
# 8/8 - 0s - loss: 0.7521 - accuracy: 0.5294 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00008: val_loss did not improve from 0.71871
# Epoch 9/300
# 8/8 - 0s - loss: 0.7657 - accuracy: 0.5230 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00009: val_loss did not improve from 0.71871
# Epoch 10/300
# 8/8 - 0s - loss: 0.7519 - accuracy: 0.5339 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00010: val_loss did not improve from 0.71871
# Epoch 11/300
# 8/8 - 0s - loss: 0.7504 - accuracy: 0.5329 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00011: val_loss did not improve from 0.71871
# Epoch 12/300
# 8/8 - 0s - loss: 0.7563 - accuracy: 0.5304 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00012: val_loss did not improve from 0.71871
# Epoch 13/300
# 8/8 - 0s - loss: 0.7546 - accuracy: 0.5363 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00013: val_loss did not improve from 0.71871
# Epoch 14/300
# 8/8 - 0s - loss: 0.7645 - accuracy: 0.5284 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00014: val_loss did not improve from 0.71871
# Epoch 15/300
# 8/8 - 0s - loss: 0.7464 - accuracy: 0.5408 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00015: val_loss did not improve from 0.71871
# Epoch 16/300
# 8/8 - 0s - loss: 0.7514 - accuracy: 0.5487 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00016: val_loss did not improve from 0.71871
# Epoch 17/300
# 8/8 - 0s - loss: 0.7532 - accuracy: 0.5418 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00017: val_loss did not improve from 0.71871
# Epoch 18/300
# 8/8 - 0s - loss: 0.7556 - accuracy: 0.5274 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00018: val_loss did not improve from 0.71871
# Epoch 19/300
# 8/8 - 0s - loss: 0.7572 - accuracy: 0.5250 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00019: val_loss did not improve from 0.71871
# Epoch 20/300
# 8/8 - 0s - loss: 0.7533 - accuracy: 0.5329 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00020: val_loss did not improve from 0.71871
# Epoch 21/300
# 8/8 - 0s - loss: 0.7570 - accuracy: 0.5428 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00021: val_loss did not improve from 0.71871
# Epoch 22/300
# 8/8 - 0s - loss: 0.7596 - accuracy: 0.5284 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00022: val_loss did not improve from 0.71871
# Epoch 23/300
# 8/8 - 0s - loss: 0.7635 - accuracy: 0.5220 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00023: val_loss did not improve from 0.71871
# Epoch 24/300
# 8/8 - 0s - loss: 0.7476 - accuracy: 0.5250 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00024: val_loss did not improve from 0.71871
# Epoch 25/300
# 8/8 - 0s - loss: 0.7526 - accuracy: 0.5339 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00025: val_loss did not improve from 0.71871
# Epoch 26/300
# 8/8 - 0s - loss: 0.7497 - accuracy: 0.5329 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00026: val_loss did not improve from 0.71871
# Epoch 27/300
# 8/8 - 0s - loss: 0.7495 - accuracy: 0.5368 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00027: val_loss did not improve from 0.71871
# Epoch 28/300
# 8/8 - 0s - loss: 0.7566 - accuracy: 0.5344 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00028: val_loss did not improve from 0.71871
# Epoch 29/300
# 8/8 - 0s - loss: 0.7539 - accuracy: 0.5348 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00029: val_loss did not improve from 0.71871
# Epoch 30/300
# 8/8 - 0s - loss: 0.7622 - accuracy: 0.5230 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00030: val_loss did not improve from 0.71871
# Epoch 31/300
# 8/8 - 0s - loss: 0.7584 - accuracy: 0.5255 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00031: val_loss did not improve from 0.71871
# Epoch 32/300
# 8/8 - 0s - loss: 0.7541 - accuracy: 0.5398 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00032: val_loss did not improve from 0.71871
# Epoch 33/300
# 8/8 - 0s - loss: 0.7524 - accuracy: 0.5279 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00033: val_loss did not improve from 0.71871
# Epoch 34/300
# 8/8 - 0s - loss: 0.7495 - accuracy: 0.5472 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00034: val_loss did not improve from 0.71871
# Epoch 35/300
# 8/8 - 0s - loss: 0.7447 - accuracy: 0.5408 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00035: val_loss did not improve from 0.71871
# Epoch 36/300
# 8/8 - 0s - loss: 0.7588 - accuracy: 0.5294 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00036: val_loss did not improve from 0.71871
# Epoch 37/300
# 8/8 - 0s - loss: 0.7516 - accuracy: 0.5269 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00037: val_loss did not improve from 0.71871
# Epoch 38/300
# 8/8 - 0s - loss: 0.7524 - accuracy: 0.5447 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00038: val_loss did not improve from 0.71871
# Epoch 39/300
# 8/8 - 0s - loss: 0.7492 - accuracy: 0.5437 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00039: val_loss did not improve from 0.71871
# Epoch 40/300
# 8/8 - 0s - loss: 0.7510 - accuracy: 0.5269 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00040: val_loss did not improve from 0.71871
# Epoch 41/300
# 8/8 - 0s - loss: 0.7526 - accuracy: 0.5304 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00041: val_loss did not improve from 0.71871
# Epoch 42/300
# 8/8 - 0s - loss: 0.7494 - accuracy: 0.5299 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00042: val_loss did not improve from 0.71871
# Epoch 43/300
# 8/8 - 0s - loss: 0.7564 - accuracy: 0.5348 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00043: val_loss did not improve from 0.71871
# Epoch 44/300
# 8/8 - 0s - loss: 0.7582 - accuracy: 0.5348 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00044: val_loss did not improve from 0.71871
# Epoch 45/300
# 8/8 - 0s - loss: 0.7565 - accuracy: 0.5314 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00045: val_loss did not improve from 0.71871
# Epoch 46/300
# 8/8 - 0s - loss: 0.7573 - accuracy: 0.5264 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00046: val_loss did not improve from 0.71871
# Epoch 47/300
# 8/8 - 0s - loss: 0.7542 - accuracy: 0.5314 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00047: val_loss did not improve from 0.71871
# Epoch 48/300
# 8/8 - 0s - loss: 0.7518 - accuracy: 0.5309 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00048: val_loss did not improve from 0.71871
# Epoch 49/300
# 8/8 - 0s - loss: 0.7531 - accuracy: 0.5329 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00049: val_loss did not improve from 0.71871
# Epoch 50/300
# 8/8 - 0s - loss: 0.7595 - accuracy: 0.5195 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00050: val_loss did not improve from 0.71871
# Epoch 51/300
# 8/8 - 0s - loss: 0.7552 - accuracy: 0.5314 - val_loss: 0.7187 - val_accuracy: 0.5467
#
# Epoch 00051: val_loss did not improve from 0.71871
# 2
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_2 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 0s - loss: 0.7599 - accuracy: 0.5264 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00001: val_loss improved from inf to 0.69193, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\_2.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.7583 - accuracy: 0.5314 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00002: val_loss did not improve from 0.69193
# Epoch 3/300
# 8/8 - 0s - loss: 0.7529 - accuracy: 0.5294 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00003: val_loss did not improve from 0.69193
# Epoch 4/300
# 8/8 - 0s - loss: 0.7591 - accuracy: 0.5279 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00004: val_loss did not improve from 0.69193
# Epoch 5/300
# 8/8 - 0s - loss: 0.7580 - accuracy: 0.5319 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00005: val_loss did not improve from 0.69193
# Epoch 6/300
# 8/8 - 0s - loss: 0.7542 - accuracy: 0.5329 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00006: val_loss did not improve from 0.69193
# Epoch 7/300
# 8/8 - 0s - loss: 0.7589 - accuracy: 0.5289 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00007: val_loss did not improve from 0.69193
# Epoch 8/300
# 8/8 - 0s - loss: 0.7546 - accuracy: 0.5284 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00008: val_loss did not improve from 0.69193
# Epoch 9/300
# 8/8 - 0s - loss: 0.7505 - accuracy: 0.5353 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00009: val_loss did not improve from 0.69193
# Epoch 10/300
# 8/8 - 0s - loss: 0.7579 - accuracy: 0.5383 - val_loss: 0.6919 - val_accuracy: 0.5911
# Epoch 00010: val_loss did not improve from 0.69193
# Epoch 11/300
# 8/8 - 0s - loss: 0.7506 - accuracy: 0.5413 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00011: val_loss did not improve from 0.69193
# Epoch 12/300
# 8/8 - 0s - loss: 0.7521 - accuracy: 0.5363 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00012: val_loss did not improve from 0.69193
# Epoch 13/300
# 8/8 - 0s - loss: 0.7643 - accuracy: 0.5319 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00013: val_loss did not improve from 0.69193
# Epoch 14/300
# 8/8 - 0s - loss: 0.7575 - accuracy: 0.5260 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00014: val_loss did not improve from 0.69193
# Epoch 15/300
# 8/8 - 0s - loss: 0.7534 - accuracy: 0.5344 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00015: val_loss did not improve from 0.69193
# Epoch 16/300
# 8/8 - 0s - loss: 0.7576 - accuracy: 0.5284 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00016: val_loss did not improve from 0.69193
# Epoch 17/300
# 8/8 - 0s - loss: 0.7508 - accuracy: 0.5353 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00017: val_loss did not improve from 0.69193
# Epoch 18/300
# 8/8 - 0s - loss: 0.7572 - accuracy: 0.5339 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00018: val_loss did not improve from 0.69193
# Epoch 19/300
# 8/8 - 0s - loss: 0.7665 - accuracy: 0.5269 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00019: val_loss did not improve from 0.69193
# Epoch 20/300
# 8/8 - 0s - loss: 0.7589 - accuracy: 0.5329 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00020: val_loss did not improve from 0.69193
# Epoch 21/300
# 8/8 - 0s - loss: 0.7570 - accuracy: 0.5279 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00021: val_loss did not improve from 0.69193
# Epoch 22/300
# 8/8 - 0s - loss: 0.7624 - accuracy: 0.5388 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00022: val_loss did not improve from 0.69193
# Epoch 23/300
# 8/8 - 0s - loss: 0.7598 - accuracy: 0.5304 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00023: val_loss did not improve from 0.69193
# Epoch 24/300
# 8/8 - 0s - loss: 0.7544 - accuracy: 0.5339 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00024: val_loss did not improve from 0.69193
# Epoch 25/300
# 8/8 - 0s - loss: 0.7533 - accuracy: 0.5447 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00025: val_loss did not improve from 0.69193
# Epoch 26/300
# 8/8 - 0s - loss: 0.7514 - accuracy: 0.5314 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00026: val_loss did not improve from 0.69193
# Epoch 27/300
# 8/8 - 0s - loss: 0.7576 - accuracy: 0.5373 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00027: val_loss did not improve from 0.69193
# Epoch 28/300
# 8/8 - 0s - loss: 0.7596 - accuracy: 0.5398 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00028: val_loss did not improve from 0.69193
# Epoch 29/300
# 8/8 - 0s - loss: 0.7518 - accuracy: 0.5348 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00029: val_loss did not improve from 0.69193
# Epoch 30/300
# 8/8 - 0s - loss: 0.7555 - accuracy: 0.5304 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00030: val_loss did not improve from 0.69193
# Epoch 31/300
# 8/8 - 0s - loss: 0.7618 - accuracy: 0.5166 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00031: val_loss did not improve from 0.69193
# Epoch 32/300
# 8/8 - 0s - loss: 0.7649 - accuracy: 0.5215 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00032: val_loss did not improve from 0.69193
# Epoch 33/300
# 8/8 - 0s - loss: 0.7620 - accuracy: 0.5260 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00033: val_loss did not improve from 0.69193
# Epoch 34/300
# 8/8 - 0s - loss: 0.7584 - accuracy: 0.5319 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00034: val_loss did not improve from 0.69193
# Epoch 35/300
# 8/8 - 0s - loss: 0.7602 - accuracy: 0.5344 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00035: val_loss did not improve from 0.69193
# Epoch 36/300
# 8/8 - 0s - loss: 0.7687 - accuracy: 0.5255 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00036: val_loss did not improve from 0.69193
# Epoch 37/300
# 8/8 - 0s - loss: 0.7535 - accuracy: 0.5442 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00037: val_loss did not improve from 0.69193
# Epoch 38/300
# 8/8 - 0s - loss: 0.7508 - accuracy: 0.5393 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00038: val_loss did not improve from 0.69193
# Epoch 39/300
# 8/8 - 0s - loss: 0.7617 - accuracy: 0.5294 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00039: val_loss did not improve from 0.69193
# Epoch 40/300
# 8/8 - 0s - loss: 0.7442 - accuracy: 0.5507 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00040: val_loss did not improve from 0.69193
# Epoch 41/300
# 8/8 - 0s - loss: 0.7531 - accuracy: 0.5289 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00041: val_loss did not improve from 0.69193
# Epoch 42/300
# 8/8 - 0s - loss: 0.7583 - accuracy: 0.5250 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00042: val_loss did not improve from 0.69193
# Epoch 43/300
# 8/8 - 0s - loss: 0.7711 - accuracy: 0.5230 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00043: val_loss did not improve from 0.69193
# Epoch 44/300
# 8/8 - 0s - loss: 0.7563 - accuracy: 0.5457 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00044: val_loss did not improve from 0.69193
# Epoch 45/300
# 8/8 - 0s - loss: 0.7654 - accuracy: 0.5195 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00045: val_loss did not improve from 0.69193
# Epoch 46/300
# 8/8 - 0s - loss: 0.7472 - accuracy: 0.5344 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00046: val_loss did not improve from 0.69193
# Epoch 47/300
# 8/8 - 0s - loss: 0.7592 - accuracy: 0.5195 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00047: val_loss did not improve from 0.69193
# Epoch 48/300
# 8/8 - 0s - loss: 0.7596 - accuracy: 0.5230 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00048: val_loss did not improve from 0.69193
# Epoch 49/300
# 8/8 - 0s - loss: 0.7605 - accuracy: 0.5344 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00049: val_loss did not improve from 0.69193
# Epoch 50/300
# 8/8 - 0s - loss: 0.7645 - accuracy: 0.5225 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00050: val_loss did not improve from 0.69193
# Epoch 51/300
# 8/8 - 0s - loss: 0.7607 - accuracy: 0.5240 - val_loss: 0.6919 - val_accuracy: 0.5911
#
# Epoch 00051: val_loss did not improve from 0.69193
# 3
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_3 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 0s - loss: 0.7593 - accuracy: 0.5319 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00001: val_loss improved from inf to 0.71969, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\_3.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.7525 - accuracy: 0.5304 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00002: val_loss did not improve from 0.71969
# Epoch 3/300
# 8/8 - 0s - loss: 0.7535 - accuracy: 0.5304 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00003: val_loss did not improve from 0.71969
# Epoch 4/300
# 8/8 - 0s - loss: 0.7675 - accuracy: 0.5175 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00004: val_loss did not improve from 0.71969
# Epoch 5/300
# 8/8 - 0s - loss: 0.7462 - accuracy: 0.5269 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00005: val_loss did not improve from 0.71969
# Epoch 6/300
# 8/8 - 0s - loss: 0.7547 - accuracy: 0.5344 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00006: val_loss did not improve from 0.71969
# Epoch 7/300
# 8/8 - 0s - loss: 0.7570 - accuracy: 0.5269 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00007: val_loss did not improve from 0.71969
# Epoch 8/300
# 8/8 - 0s - loss: 0.7484 - accuracy: 0.5447 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00008: val_loss did not improve from 0.71969
# Epoch 9/300
# 8/8 - 0s - loss: 0.7471 - accuracy: 0.5279 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00009: val_loss did not improve from 0.71969
# Epoch 10/300
# 8/8 - 0s - loss: 0.7554 - accuracy: 0.5250 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00010: val_loss did not improve from 0.71969
# Epoch 11/300
# 8/8 - 0s - loss: 0.7513 - accuracy: 0.5383 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00011: val_loss did not improve from 0.71969
# Epoch 12/300
# 8/8 - 0s - loss: 0.7556 - accuracy: 0.5482 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00012: val_loss did not improve from 0.71969
# Epoch 13/300
# 8/8 - 0s - loss: 0.7534 - accuracy: 0.5299 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00013: val_loss did not improve from 0.71969
# Epoch 14/300
# 8/8 - 0s - loss: 0.7575 - accuracy: 0.5274 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00014: val_loss did not improve from 0.71969
# Epoch 15/300
# 8/8 - 0s - loss: 0.7509 - accuracy: 0.5289 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00015: val_loss did not improve from 0.71969
# Epoch 16/300
# 8/8 - 0s - loss: 0.7494 - accuracy: 0.5319 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00016: val_loss did not improve from 0.71969
# Epoch 17/300
# 8/8 - 0s - loss: 0.7582 - accuracy: 0.5339 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00017: val_loss did not improve from 0.71969
# Epoch 18/300
# 8/8 - 0s - loss: 0.7552 - accuracy: 0.5284 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00018: val_loss did not improve from 0.71969
# Epoch 19/300
# 8/8 - 0s - loss: 0.7581 - accuracy: 0.5205 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00019: val_loss did not improve from 0.71969
# Epoch 20/300
# 8/8 - 0s - loss: 0.7615 - accuracy: 0.5210 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00020: val_loss did not improve from 0.71969
# Epoch 21/300
# 8/8 - 0s - loss: 0.7602 - accuracy: 0.5225 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00021: val_loss did not improve from 0.71969
# Epoch 22/300
# 8/8 - 0s - loss: 0.7546 - accuracy: 0.5383 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00022: val_loss did not improve from 0.71969
# Epoch 23/300
# 8/8 - 0s - loss: 0.7541 - accuracy: 0.5329 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00023: val_loss did not improve from 0.71969
# Epoch 24/300
# 8/8 - 0s - loss: 0.7590 - accuracy: 0.5324 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00024: val_loss did not improve from 0.71969
# Epoch 25/300
# 8/8 - 0s - loss: 0.7531 - accuracy: 0.5126 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00025: val_loss did not improve from 0.71969
# Epoch 26/300
# 8/8 - 0s - loss: 0.7566 - accuracy: 0.5304 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00026: val_loss did not improve from 0.71969
# Epoch 27/300
# 8/8 - 0s - loss: 0.7610 - accuracy: 0.5210 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00027: val_loss did not improve from 0.71969
# Epoch 28/300
# 8/8 - 0s - loss: 0.7557 - accuracy: 0.5388 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00028: val_loss did not improve from 0.71969
# Epoch 29/300
# 8/8 - 0s - loss: 0.7633 - accuracy: 0.5210 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00029: val_loss did not improve from 0.71969
# Epoch 30/300
# 8/8 - 0s - loss: 0.7603 - accuracy: 0.5260 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00030: val_loss did not improve from 0.71969
# Epoch 31/300
# 8/8 - 0s - loss: 0.7536 - accuracy: 0.5368 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00031: val_loss did not improve from 0.71969
# Epoch 32/300
# 8/8 - 0s - loss: 0.7546 - accuracy: 0.5269 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00032: val_loss did not improve from 0.71969
# Epoch 33/300
# 8/8 - 0s - loss: 0.7615 - accuracy: 0.5319 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00033: val_loss did not improve from 0.71969
# Epoch 34/300
# 8/8 - 0s - loss: 0.7543 - accuracy: 0.5378 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00034: val_loss did not improve from 0.71969
# Epoch 35/300
# 8/8 - 0s - loss: 0.7476 - accuracy: 0.5344 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00035: val_loss did not improve from 0.71969
# Epoch 36/300
# 8/8 - 0s - loss: 0.7655 - accuracy: 0.5200 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00036: val_loss did not improve from 0.71969
# Epoch 37/300
# 8/8 - 0s - loss: 0.7557 - accuracy: 0.5344 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00037: val_loss did not improve from 0.71969
# Epoch 38/300
# 8/8 - 0s - loss: 0.7551 - accuracy: 0.5235 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00038: val_loss did not improve from 0.71969
# Epoch 39/300
# 8/8 - 0s - loss: 0.7576 - accuracy: 0.5334 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00039: val_loss did not improve from 0.71969
# Epoch 40/300
# 8/8 - 0s - loss: 0.7576 - accuracy: 0.5156 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00040: val_loss did not improve from 0.71969
# Epoch 41/300
# 8/8 - 0s - loss: 0.7578 - accuracy: 0.5403 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00041: val_loss did not improve from 0.71969
# Epoch 42/300
# 8/8 - 0s - loss: 0.7498 - accuracy: 0.5418 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00042: val_loss did not improve from 0.71969
# Epoch 43/300
# 8/8 - 0s - loss: 0.7571 - accuracy: 0.5339 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00043: val_loss did not improve from 0.71969
# Epoch 44/300
# 8/8 - 0s - loss: 0.7551 - accuracy: 0.5314 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00044: val_loss did not improve from 0.71969
# Epoch 45/300
# 8/8 - 0s - loss: 0.7593 - accuracy: 0.5235 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00045: val_loss did not improve from 0.71969
# Epoch 46/300
# 8/8 - 0s - loss: 0.7477 - accuracy: 0.5413 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00046: val_loss did not improve from 0.71969
# Epoch 47/300
# 8/8 - 0s - loss: 0.7525 - accuracy: 0.5358 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00047: val_loss did not improve from 0.71969
# Epoch 48/300
# 8/8 - 0s - loss: 0.7413 - accuracy: 0.5408 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00048: val_loss did not improve from 0.71969
# Epoch 49/300
# 8/8 - 0s - loss: 0.7566 - accuracy: 0.5269 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00049: val_loss did not improve from 0.71969
# Epoch 50/300
# 8/8 - 0s - loss: 0.7526 - accuracy: 0.5423 - val_loss: 0.7197 - val_accuracy: 0.5200
#
# Epoch 00050: val_loss did not improve from 0.71969
# Epoch 51/300
# 8/8 - 0s - loss: 0.7546 - accuracy: 0.5344 - val_loss: 0.7197 - val_accuracy: 0.5200
# Epoch 00051: val_loss did not improve from 0.71969
# 4
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_4 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 1s - loss: 0.7505 - accuracy: 0.5339 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00001: val_loss improved from inf to 0.74281, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\_4.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.7565 - accuracy: 0.5344 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00002: val_loss did not improve from 0.74281
# Epoch 3/300
# 8/8 - 0s - loss: 0.7539 - accuracy: 0.5348 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00003: val_loss did not improve from 0.74281
# Epoch 4/300
# 8/8 - 0s - loss: 0.7489 - accuracy: 0.5418 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00004: val_loss did not improve from 0.74281
# Epoch 5/300
# 8/8 - 0s - loss: 0.7525 - accuracy: 0.5447 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00005: val_loss did not improve from 0.74281
# Epoch 6/300
# 8/8 - 0s - loss: 0.7432 - accuracy: 0.5428 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00006: val_loss did not improve from 0.74281
# Epoch 7/300
# 8/8 - 0s - loss: 0.7461 - accuracy: 0.5472 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00007: val_loss did not improve from 0.74281
# Epoch 8/300
# 8/8 - 0s - loss: 0.7464 - accuracy: 0.5348 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00008: val_loss did not improve from 0.74281
# Epoch 9/300
# 8/8 - 0s - loss: 0.7489 - accuracy: 0.5339 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00009: val_loss did not improve from 0.74281
# Epoch 10/300
# 8/8 - 0s - loss: 0.7557 - accuracy: 0.5403 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00010: val_loss did not improve from 0.74281
# Epoch 11/300
# 8/8 - 0s - loss: 0.7581 - accuracy: 0.5373 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00011: val_loss did not improve from 0.74281
# Epoch 12/300
# 8/8 - 0s - loss: 0.7564 - accuracy: 0.5398 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00012: val_loss did not improve from 0.74281
# Epoch 13/300
# 8/8 - 0s - loss: 0.7484 - accuracy: 0.5408 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00013: val_loss did not improve from 0.74281
# Epoch 14/300
# 8/8 - 0s - loss: 0.7467 - accuracy: 0.5319 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00014: val_loss did not improve from 0.74281
# Epoch 15/300
# 8/8 - 0s - loss: 0.7539 - accuracy: 0.5388 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00015: val_loss did not improve from 0.74281
# Epoch 16/300
# 8/8 - 0s - loss: 0.7527 - accuracy: 0.5398 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00016: val_loss did not improve from 0.74281
# Epoch 17/300
# 8/8 - 0s - loss: 0.7441 - accuracy: 0.5413 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00017: val_loss did not improve from 0.74281
# Epoch 18/300
# 8/8 - 0s - loss: 0.7447 - accuracy: 0.5457 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00018: val_loss did not improve from 0.74281
# Epoch 19/300
# 8/8 - 0s - loss: 0.7405 - accuracy: 0.5487 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00019: val_loss did not improve from 0.74281
# Epoch 20/300
# 8/8 - 0s - loss: 0.7493 - accuracy: 0.5378 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00020: val_loss did not improve from 0.74281
# Epoch 21/300
# 8/8 - 0s - loss: 0.7473 - accuracy: 0.5368 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00021: val_loss did not improve from 0.74281
# Epoch 22/300
# 8/8 - 0s - loss: 0.7505 - accuracy: 0.5274 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00022: val_loss did not improve from 0.74281
# Epoch 23/300
# 8/8 - 0s - loss: 0.7538 - accuracy: 0.5353 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00023: val_loss did not improve from 0.74281
# Epoch 24/300
# 8/8 - 0s - loss: 0.7524 - accuracy: 0.5329 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00024: val_loss did not improve from 0.74281
# Epoch 25/300
# 8/8 - 0s - loss: 0.7508 - accuracy: 0.5378 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00025: val_loss did not improve from 0.74281
# Epoch 26/300
# 8/8 - 0s - loss: 0.7575 - accuracy: 0.5329 - val_loss: 0.7428 - val_accuracy: 0.4889
#
# Epoch 00026: val_loss did not improve from 0.74281
# Epoch 27/300
# ...
#
# Epoch 00024: val_loss did not improve from 0.70954
# Epoch 25/300
# 8/8 - 0s - loss: 0.7535 - accuracy: 0.5321 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00025: val_loss did not improve from 0.70954
# Epoch 26/300
# 8/8 - 0s - loss: 0.7585 - accuracy: 0.5321 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00026: val_loss did not improve from 0.70954
# Epoch 27/300
# 8/8 - 0s - loss: 0.7565 - accuracy: 0.5222 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00027: val_loss did not improve from 0.70954
# Epoch 28/300
# 8/8 - 0s - loss: 0.7590 - accuracy: 0.5217 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00028: val_loss did not improve from 0.70954
# Epoch 29/300
# 8/8 - 0s - loss: 0.7499 - accuracy: 0.5380 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00029: val_loss did not improve from 0.70954
# Epoch 30/300
# 8/8 - 0s - loss: 0.7561 - accuracy: 0.5208 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00030: val_loss did not improve from 0.70954
# Epoch 31/300
# 8/8 - 0s - loss: 0.7488 - accuracy: 0.5356 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00031: val_loss did not improve from 0.70954
# Epoch 32/300
# 8/8 - 0s - loss: 0.7562 - accuracy: 0.5450 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00032: val_loss did not improve from 0.70954
# Epoch 33/300
# 8/8 - 0s - loss: 0.7553 - accuracy: 0.5277 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00033: val_loss did not improve from 0.70954
# Epoch 34/300
# 8/8 - 0s - loss: 0.7583 - accuracy: 0.5277 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00034: val_loss did not improve from 0.70954
# Epoch 35/300
# 8/8 - 0s - loss: 0.7611 - accuracy: 0.5237 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00035: val_loss did not improve from 0.70954
# Epoch 36/300
# 8/8 - 0s - loss: 0.7517 - accuracy: 0.5183 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00036: val_loss did not improve from 0.70954
# Epoch 37/300
# 8/8 - 0s - loss: 0.7649 - accuracy: 0.5237 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00037: val_loss did not improve from 0.70954
# Epoch 38/300
# 8/8 - 0s - loss: 0.7482 - accuracy: 0.5410 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00038: val_loss did not improve from 0.70954
# Epoch 39/300
# 8/8 - 0s - loss: 0.7607 - accuracy: 0.5306 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00039: val_loss did not improve from 0.70954
# Epoch 40/300
# 8/8 - 0s - loss: 0.7635 - accuracy: 0.5296 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00040: val_loss did not improve from 0.70954
# Epoch 41/300
# 8/8 - 0s - loss: 0.7590 - accuracy: 0.5193 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00041: val_loss did not improve from 0.70954
# Epoch 42/300
# 8/8 - 0s - loss: 0.7578 - accuracy: 0.5252 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00042: val_loss did not improve from 0.70954
# Epoch 43/300
# 8/8 - 0s - loss: 0.7467 - accuracy: 0.5375 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00043: val_loss did not improve from 0.70954
# Epoch 44/300
# 8/8 - 0s - loss: 0.7529 - accuracy: 0.5316 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00044: val_loss did not improve from 0.70954
# Epoch 45/300
# 8/8 - 0s - loss: 0.7562 - accuracy: 0.5311 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00045: val_loss did not improve from 0.70954
# Epoch 46/300
# 8/8 - 0s - loss: 0.7591 - accuracy: 0.5237 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00046: val_loss did not improve from 0.70954
# Epoch 47/300
# 8/8 - 0s - loss: 0.7560 - accuracy: 0.5292 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00047: val_loss did not improve from 0.70954
# Epoch 48/300
# 8/8 - 0s - loss: 0.7517 - accuracy: 0.5257 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00048: val_loss did not improve from 0.70954
# Epoch 49/300
# 8/8 - 0s - loss: 0.7552 - accuracy: 0.5292 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00049: val_loss did not improve from 0.70954
# Epoch 50/300
# 8/8 - 0s - loss: 0.7545 - accuracy: 0.5356 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00050: val_loss did not improve from 0.70954
# Epoch 51/300
# 8/8 - 0s - loss: 0.7633 - accuracy: 0.5277 - val_loss: 0.7095 - val_accuracy: 0.5714
#
# Epoch 00051: val_loss did not improve from 0.70954
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001C92CC93040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 9
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_9 (Functional)         (None, 1)                 208001
# =================================================================
# Total params: 208,001
# Trainable params: 0
# Non-trainable params: 208,001
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 0s - loss: 0.7549 - accuracy: 0.5440 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00001: val_loss improved from inf to 0.72286, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\_9.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.7398 - accuracy: 0.5390 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00002: val_loss did not improve from 0.72286
# Epoch 3/300
# 8/8 - 0s - loss: 0.7538 - accuracy: 0.5346 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00003: val_loss did not improve from 0.72286
# Epoch 4/300
# 8/8 - 0s - loss: 0.7541 - accuracy: 0.5331 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00004: val_loss did not improve from 0.72286
# Epoch 5/300
# 8/8 - 0s - loss: 0.7559 - accuracy: 0.5371 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00005: val_loss did not improve from 0.72286
# Epoch 6/300
# 8/8 - 0s - loss: 0.7483 - accuracy: 0.5435 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00006: val_loss did not improve from 0.72286
# Epoch 7/300
# 8/8 - 0s - loss: 0.7595 - accuracy: 0.5356 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00007: val_loss did not improve from 0.72286
# Epoch 8/300
# 8/8 - 0s - loss: 0.7546 - accuracy: 0.5306 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00008: val_loss did not improve from 0.72286
# Epoch 9/300
# 8/8 - 0s - loss: 0.7494 - accuracy: 0.5415 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00009: val_loss did not improve from 0.72286
# Epoch 10/300
# 8/8 - 0s - loss: 0.7535 - accuracy: 0.5371 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00010: val_loss did not improve from 0.72286
# Epoch 11/300
# 8/8 - 0s - loss: 0.7510 - accuracy: 0.5371 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00011: val_loss did not improve from 0.72286
# Epoch 12/300
# 8/8 - 0s - loss: 0.7466 - accuracy: 0.5479 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00012: val_loss did not improve from 0.72286
# Epoch 13/300
# 8/8 - 0s - loss: 0.7542 - accuracy: 0.5346 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00013: val_loss did not improve from 0.72286
# Epoch 14/300
# 8/8 - 0s - loss: 0.7545 - accuracy: 0.5395 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00014: val_loss did not improve from 0.72286
# Epoch 15/300
# 8/8 - 0s - loss: 0.7529 - accuracy: 0.5346 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00015: val_loss did not improve from 0.72286
# Epoch 16/300
# 8/8 - 0s - loss: 0.7531 - accuracy: 0.5356 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00016: val_loss did not improve from 0.72286
# Epoch 17/300
# 8/8 - 0s - loss: 0.7507 - accuracy: 0.5366 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00017: val_loss did not improve from 0.72286
# Epoch 18/300
# 8/8 - 0s - loss: 0.7493 - accuracy: 0.5331 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00018: val_loss did not improve from 0.72286
# Epoch 19/300
# 8/8 - 0s - loss: 0.7545 - accuracy: 0.5415 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00019: val_loss did not improve from 0.72286
# Epoch 20/300
# 8/8 - 0s - loss: 0.7548 - accuracy: 0.5395 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00020: val_loss did not improve from 0.72286
# Epoch 21/300
# 8/8 - 0s - loss: 0.7574 - accuracy: 0.5296 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00021: val_loss did not improve from 0.72286
# Epoch 22/300
# 8/8 - 0s - loss: 0.7427 - accuracy: 0.5390 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00022: val_loss did not improve from 0.72286
# Epoch 23/300
# 8/8 - 0s - loss: 0.7540 - accuracy: 0.5212 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00023: val_loss did not improve from 0.72286
# Epoch 24/300
# 8/8 - 0s - loss: 0.7568 - accuracy: 0.5267 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00024: val_loss did not improve from 0.72286
# Epoch 25/300
# 8/8 - 0s - loss: 0.7581 - accuracy: 0.5272 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00025: val_loss did not improve from 0.72286
# Epoch 26/300
# 8/8 - 0s - loss: 0.7604 - accuracy: 0.5203 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00026: val_loss did not improve from 0.72286
# Epoch 27/300
# 8/8 - 0s - loss: 0.7541 - accuracy: 0.5395 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00027: val_loss did not improve from 0.72286
# Epoch 28/300
# 8/8 - 0s - loss: 0.7549 - accuracy: 0.5336 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00028: val_loss did not improve from 0.72286
# Epoch 29/300
# 8/8 - 0s - loss: 0.7475 - accuracy: 0.5430 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00029: val_loss did not improve from 0.72286
# Epoch 30/300
# 8/8 - 0s - loss: 0.7530 - accuracy: 0.5301 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00030: val_loss did not improve from 0.72286
# Epoch 31/300
# 8/8 - 0s - loss: 0.7498 - accuracy: 0.5341 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00031: val_loss did not improve from 0.72286
# Epoch 32/300
# 8/8 - 0s - loss: 0.7591 - accuracy: 0.5435 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00032: val_loss did not improve from 0.72286
# Epoch 33/300
# 8/8 - 0s - loss: 0.7471 - accuracy: 0.5282 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00033: val_loss did not improve from 0.72286
# Epoch 34/300
# 8/8 - 0s - loss: 0.7544 - accuracy: 0.5296 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00034: val_loss did not improve from 0.72286
# Epoch 35/300
# 8/8 - 0s - loss: 0.7534 - accuracy: 0.5395 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00035: val_loss did not improve from 0.72286
# Epoch 36/300
# 8/8 - 0s - loss: 0.7559 - accuracy: 0.5257 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00036: val_loss did not improve from 0.72286
# Epoch 37/300
# 8/8 - 0s - loss: 0.7519 - accuracy: 0.5380 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00037: val_loss did not improve from 0.72286
# Epoch 38/300
# 8/8 - 0s - loss: 0.7564 - accuracy: 0.5321 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00038: val_loss did not improve from 0.72286
# Epoch 39/300
# 8/8 - 0s - loss: 0.7565 - accuracy: 0.5277 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00039: val_loss did not improve from 0.72286
# Epoch 40/300
# 8/8 - 0s - loss: 0.7503 - accuracy: 0.5464 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00040: val_loss did not improve from 0.72286
# Epoch 41/300
# 8/8 - 0s - loss: 0.7468 - accuracy: 0.5361 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00041: val_loss did not improve from 0.72286
# Epoch 42/300
# 8/8 - 0s - loss: 0.7500 - accuracy: 0.5287 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00042: val_loss did not improve from 0.72286
# Epoch 43/300
# 8/8 - 0s - loss: 0.7549 - accuracy: 0.5311 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00043: val_loss did not improve from 0.72286
# Epoch 44/300
# 8/8 - 0s - loss: 0.7479 - accuracy: 0.5366 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00044: val_loss did not improve from 0.72286
# Epoch 45/300
# 8/8 - 0s - loss: 0.7521 - accuracy: 0.5361 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00045: val_loss did not improve from 0.72286
# Epoch 46/300
# 8/8 - 0s - loss: 0.7518 - accuracy: 0.5361 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00046: val_loss did not improve from 0.72286
# Epoch 47/300
# 8/8 - 0s - loss: 0.7539 - accuracy: 0.5272 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00047: val_loss did not improve from 0.72286
# Epoch 48/300
# 8/8 - 0s - loss: 0.7538 - accuracy: 0.5326 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00048: val_loss did not improve from 0.72286
# Epoch 49/300
# 8/8 - 0s - loss: 0.7538 - accuracy: 0.5346 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00049: val_loss did not improve from 0.72286
# Epoch 50/300
# 8/8 - 0s - loss: 0.7633 - accuracy: 0.5252 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00050: val_loss did not improve from 0.72286
# Epoch 51/300
# 8/8 - 0s - loss: 0.7461 - accuracy: 0.5316 - val_loss: 0.7229 - val_accuracy: 0.5179
#
# Epoch 00051: val_loss did not improve from 0.72286
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001C91BDA75E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10

# %%
#遍历表格求初始里程
#交叉验证
import os
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try')
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\result\val'
filenames=os.listdir(path)#得到字符串列表
scores_val=[]
lables_val=[]
fpr_list_val = []
tpr_list_val = []
roc_auc_list_val=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_val=data.iloc[:,1]
        scores_val.append(score_val)
        lable_val = data.iloc[:,2]
        lables_val.append(lable_val)
        fpr_val,tpr_val,thresholds_val= roc_curve(lables_val[i],scores_val[i])   #y_true,y_score
        fpr_list_val.append(fpr_val)
        tpr_list_val.append(tpr_val)
        roc_auc_val = auc(fpr_val,tpr_val)
        roc_auc_list_val.append(roc_auc_val)
        i+=1

# %%
roc_auc_list_val
# Out:
# [0.5787768647281922,
#  0.5546077806122449,
#  0.5579962073324906,
#  0.5823324905183312,
#  0.5552307206068268,
#  0.4907553729456384,
#  0.5860461441213655,
#  0.4916245259165613,
#  0.49873577749683945,
#  0.5527742346938775]

# %%
i=1
tprs_val = []
mean_fpr_val = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Validation ROC')
for fpr_val,tpr_val,roc_auc_val in zip(fpr_list_val,tpr_list_val,roc_auc_list_val):
    tprs_val.append(np.interp(mean_fpr_val, fpr_val, tpr_val))
    tprs_val[-1][0] = 0.0
    plt.plot(fpr_val, tpr_val, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_val)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_val.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_val = np.mean(tprs_val, axis=0)
mean_tpr_val[-1] = 1.0
mean_auc_val = auc(mean_fpr_val, mean_tpr_val)
std_auc_val = np.std(roc_auc_list_val)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_val, std_auc_val),lw=2, alpha=.8)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_val),lw=2, alpha=.8)
std_tpr_val = np.std(tprs_val, axis=0)
tprs_upper_val = np.minimum(mean_tpr_val + std_tpr_val, 1)
tprs_lower_val = np.maximum(mean_tpr_val - std_tpr_val, 0)
plt.fill_between(mean_fpr_val, tprs_lower_val, tprs_upper_val, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Cross-Validation ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_val_mean.png')
plt.show()

# %%
def calculate_metrics_val(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_val = []
for score_val,lable_val in zip(scores_val,lables_val):
    val_my_calculate_metrics = calculate_metrics_val(lable_val,score_val)
    my_calculate_metrics_list_val.append(val_my_calculate_metrics)

# %%
my_calculate_metrics_list_val
# Out:
# [{'SN': 0.8495575221238938,
#   'SP': 0.32142857142857145,
#   'ACC': 0.5866666666666667,
#   'MCC': 0.20146836645445604,
#   'Recall': 0.8495575221238938,
#   'Precision': 0.5581395348837209,
#   'F1-score': 0.6736842105263158,
#   'Cutoff': 0.5},
#  {'SN': 0.8125,
#   'SP': 0.22321428571428573,
#   'ACC': 0.5178571428571429,
#   'MCC': 0.04420496737025352,
#   'Recall': 0.8125,
#   'Precision': 0.5112359550561798,
#   'F1-score': 0.6275862068965518,
#   'Cutoff': 0.5},
#  {'SN': 0.8407079646017699,
#   'SP': 0.25,
#   'ACC': 0.5466666666666666,
#   'MCC': 0.11245744795494089,
#   'Recall': 0.8407079646017699,
#   'Precision': 0.5307262569832403,
#   'F1-score': 0.6506849315068494,
#   'Cutoff': 0.5},
#  {'SN': 0.8761061946902655,
#   'SP': 0.30357142857142855,
#   'ACC': 0.5911111111111111,
#   'MCC': 0.21929815374830838,
#   'Recall': 0.8761061946902655,
#   'Precision': 0.559322033898305,
#   'F1-score': 0.6827586206896552,
#   'Cutoff': 0.5},
#  {'SN': 0.8230088495575221,
#   'SP': 0.21428571428571427,
#   'ACC': 0.52,
#   'MCC': 0.0470141014223117,
#   'Recall': 0.8230088495575221,
#   'Precision': 0.5138121546961326,
#   'F1-score': 0.6326530612244898,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.18584070796460178,
#   'ACC': 0.4888888888888889,
#   'MCC': -0.02460271832904871,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.49171270718232046,
#   'F1-score': 0.6075085324232082,
#   'Cutoff': 0.5},
#  {'SN': 0.8125,
#   'SP': 0.2831858407079646,
#   'ACC': 0.5466666666666666,
#   'MCC': 0.11274408122751677,
#   'Recall': 0.8125,
#   'Precision': 0.5290697674418605,
#   'F1-score': 0.6408450704225352,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.22123893805309736,
#   'ACC': 0.48444444444444446,
#   'MCC': -0.03388839435740388,
#   'Recall': 0.75,
#   'Precision': 0.4883720930232558,
#   'F1-score': 0.5915492957746479,
#   'Cutoff': 0.5},
#  {'SN': 0.7678571428571429,
#   'SP': 0.20353982300884957,
#   'ACC': 0.48444444444444446,
#   'MCC': -0.034650217380710134,
#   'Recall': 0.7678571428571429,
#   'Precision': 0.48863636363636365,
#   'F1-score': 0.5972222222222222,
#   'Cutoff': 0.5},
#  {'SN': 0.8660714285714286,
#   'SP': 0.2767857142857143,
#   'ACC': 0.5714285714285714,
#   'MCC': 0.17681986948101408,
#   'Recall': 0.8660714285714286,
#   'Precision': 0.5449438202247191,
#   'F1-score': 0.6689655172413793,
#   'Cutoff': 0.5}]

# %%
performance_val=pd.DataFrame(my_calculate_metrics_list_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.849558  0.321429  0.586667  0.201468  0.849558   0.558140  0.673684
# 1  0.812500  0.223214  0.517857  0.044205  0.812500   0.511236  0.627586
# 2  0.840708  0.250000  0.546667  0.112457  0.840708   0.530726  0.650685
# 3  0.876106  0.303571  0.591111  0.219298  0.876106   0.559322  0.682759
# 4  0.823009  0.214286  0.520000  0.047014  0.823009   0.513812  0.632653
# 5  0.794643  0.185841  0.488889 -0.024603  0.794643   0.491713  0.607509
# 6  0.812500  0.283186  0.546667  0.112744  0.812500   0.529070  0.640845
# 7  0.750000  0.221239  0.484444 -0.033888  0.750000   0.488372  0.591549
# 8  0.767857  0.203540  0.484444 -0.034650  0.767857   0.488636  0.597222
# 9  0.866071  0.276786  0.571429  0.176820  0.866071   0.544944  0.668966
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_val = performance_val.std(axis = 0,ddof=1)
mean_val = performance_val.mean(axis = 0)
data_mean_val = pd.DataFrame(mean_val)
data_mean_val = data_mean_val.T
data_std_val = pd.DataFrame(std_val)
data_std_val = data_std_val.T
performance_val = performance_val.append(data_mean_val)
performance_val = performance_val.append(data_std_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.849558  0.321429  0.586667  0.201468  0.849558   0.558140  0.673684
# 1  0.812500  0.223214  0.517857  0.044205  0.812500   0.511236  0.627586
# 2  0.840708  0.250000  0.546667  0.112457  0.840708   0.530726  0.650685
# 3  0.876106  0.303571  0.591111  0.219298  0.876106   0.559322  0.682759
# 4  0.823009  0.214286  0.520000  0.047014  0.823009   0.513812  0.632653
# 5  0.794643  0.185841  0.488889 -0.024603  0.794643   0.491713  0.607509
# 6  0.812500  0.283186  0.546667  0.112744  0.812500   0.529070  0.640845
# 7  0.750000  0.221239  0.484444 -0.033888  0.750000   0.488372  0.591549
# 8  0.767857  0.203540  0.484444 -0.034650  0.767857   0.488636  0.597222
# 9  0.866071  0.276786  0.571429  0.176820  0.866071   0.544944  0.668966
# 0  0.819295  0.248309  0.533817  0.082087  0.819295   0.521597  0.637346
# 0  0.040759  0.045774  0.041042  0.097206  0.040759   0.027273  0.032124
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_val.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\result\CNN_OH_performance_val.csv',encoding='utf-8')

# %% [markdown]
# 独立测试

# %%
#遍历表格求初始里程
#独立测试
import os
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\result\indep'
filenames=os.listdir(path)#得到字符串列表
scores_indep=[]
lables_indep=[]
fpr_list_indep = []
tpr_list_indep = []
roc_auc_list_indep=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_indep=data.iloc[:,1]
        scores_indep.append(score_indep)
        lable_indep = data.iloc[:,2]
        lables_indep.append(lable_indep)
        fpr_indep,tpr_indep,thresholds_indep= roc_curve(lables_indep[i],scores_indep[i])   #y_true,y_score
        fpr_list_indep.append(fpr_indep)
        tpr_list_indep.append(tpr_indep)
        roc_auc_indep = auc(fpr_indep,tpr_indep)
        roc_auc_list_indep.append(roc_auc_indep)
        i+=1

# %%
roc_auc_list_indep
# Out:
# [0.4709024234693878,
#  0.4709024234693878,
#  0.4709024234693878,
#  0.4709024234693878,
#  0.4709024234693878,
#  0.4709024234693878,
#  0.4709024234693878,
#  0.4709024234693878,
#  0.4709024234693878,
#  0.4709024234693878]

# %%
i=1
tprs_indep = []
mean_fpr_indep = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Independent ROC')
for fpr_indep,tpr_indep,roc_auc_indep in zip(fpr_list_indep,tpr_list_indep,roc_auc_list_indep):
    tprs_indep.append(np.interp(mean_fpr_indep, fpr_indep, tpr_indep))
    tprs_indep[-1][0] = 0.0
    plt.plot(fpr_indep, tpr_indep, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_indep)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_indep.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_indep = np.mean(tprs_indep, axis=0)
mean_tpr_indep[-1] = 1.0
mean_auc_indep = auc(mean_fpr_indep, mean_tpr_indep)
std_auc_indep = np.std(roc_auc_list_indep)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_indep, std_auc_indep),lw=2, alpha=.8)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_indep),lw=2, alpha=.8)
std_tpr_indep = np.std(tprs_indep, axis=0)
tprs_upper_indep = np.minimum(mean_tpr_indep + std_tpr_indep, 1)
tprs_lower_indep = np.maximum(mean_tpr_indep - std_tpr_indep, 0)
plt.fill_between(mean_fpr_indep, tprs_lower_indep, tprs_upper_indep, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Independent ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_indep_mean.png')
plt.show()

# %%
def calculate_metrics_indep(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_indep = []
for score_indep,lable_indep in zip(scores_indep,lables_indep):
    indep_my_calculate_metrics = calculate_metrics_indep(lable_indep,score_indep)
    my_calculate_metrics_list_indep.append(indep_my_calculate_metrics)

# %%
my_calculate_metrics_list_indep
# Out:
# [{'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.26785714285714285,
#   'ACC': 0.53125,
#   'MCC': 0.0735295740273797,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.52046783625731,
#   'F1-score': 0.6289752650176679,
#   'Cutoff': 0.5}]

# %%
performance_indep=pd.DataFrame(my_calculate_metrics_list_indep)
performance_indep
# Out:
#          SN        SP      ACC      MCC    Recall  Precision  F1-score  Cutoff
# 0  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5
# 1  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5
# 2  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5
# 3  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5
# 4  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5
# 5  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5
# 6  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5
# 7  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5
# 8  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5
# 9  0.794643  0.267857  0.53125  0.07353  0.794643   0.520468  0.628975     0.5

# %%
std_indep = performance_indep.std(axis = 0,ddof=1)
mean_indep = performance_indep.mean(axis = 0)
data_mean_indep = pd.DataFrame(mean_indep)
data_mean_indep = data_mean_indep.T
data_std_indep = pd.DataFrame(std_indep)
data_std_indep = data_std_indep.T
performance_indep = performance_indep.append(data_mean_indep)
performance_indep = performance_indep.append(data_std_indep)
performance_indep
# Out:
#              SN        SP      ACC      MCC        Recall     Precision  \
# 0  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 1  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 2  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 3  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 4  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 5  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 6  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 7  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 8  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 9  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 0  7.946429e-01  0.267857  0.53125  0.07353  7.946429e-01  5.204678e-01
# 0  1.170278e-16  0.000000  0.00000  0.00000  1.170278e-16  1.170278e-16
#
#    F1-score  Cutoff
# 0  0.628975     0.5
# 1  0.628975     0.5
# 2  0.628975     0.5
# 3  0.628975     0.5
# 4  0.628975     0.5
# 5  0.628975     0.5
# 6  0.628975     0.5
# 7  0.628975     0.5
# 8  0.628975     0.5
# 9  0.628975     0.5
# 0  0.628975     0.5
# 0  0.000000     0.0

# %%
performance_indep.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\try\freeze_allli_try\result\CNN_OH_performance_indep.csv',encoding='utf-8')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
