# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from sklearn.model_selection import KFold,StratifiedKFold

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def build_network():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH')
    cnn = load_model('dataoh.h5')
    cnn.trainable = True #固定所有预训练模型层的参数
    base_model = Model(inputs=cnn.layers[0].input,outputs=cnn.layers[8].output)
    base_model.summary()
    base_model.trainable = True
    for layer in base_model.layers[:4]:
        layer.trainable = False
    Dense = tf.keras.layers.Dense(64,activation=tf.nn.relu)
    global_average_layer = tf.keras.layers.GlobalAveragePooling1D()
    prediction_layer = tf.keras.layers.Dense(1,activation=tf.nn.sigmoid)
    model1 = tf.keras.Sequential([
        base_model,
        #layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        #layers.Dropout(0.5),
        Dense,
        layers.Dropout(0.5),
        global_average_layer,
        prediction_layer
    ])
    base_learning_rate = 0.001
    model1.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #model1.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    #model1.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),metrics=['accuracy'])
    model1.summary()
    return model1

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
batch_size=256

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\NEDD\不自然数据\1正2345负')
epochs = 300
x_train,y_train = One_hot_raw('train.txt')#十折交叉验证10
x_test,y_test = One_hot_raw('test.txt')#独立测试1

# %%
classes = sorted(list(set(y_train)))
x_train = one_hot(x_train)
x_test = one_hot(x_test)
x_train.shape = (x_train.shape[0],x_train.shape[2],x_train.shape[3])
x_test.shape = (x_test.shape[0],x_test.shape[2],x_test.shape[3])

# %%
# 构建独立测试集对象，预处理，批量化
test_db = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_db = test_db.map(preprocess).batch(batch_size)

# %%
prediction_result_cv = []
prediction_result_ind = []

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1')

# %%
out = os.getcwd() + '\\'

# %%
from sklearn.model_selection import KFold,StratifiedKFold
kf = StratifiedKFold(n_splits=10,shuffle=True)
for n_fold,(tr_idx,val_idx)in enumerate(kf.split(x_train,y_train)):
    tr_x,tr_y,val_x,val_y = x_train[tr_idx],y_train[tr_idx],x_train[val_idx],y_train[val_idx]
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((tr_x, tr_y))
    train_db = train_db.shuffle(len(tr_x)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    valid_db = tf.data.Dataset.from_tensor_slices((val_x, val_y))
    valid_db = valid_db.map(preprocess).batch(batch_size)
    #if not os.path.exists('%s_%d.h5' % (out, n_fold)):
    model1 = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath='%s_%d.h5' % (out, n_fold), monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = model1.fit(train_db, epochs=epochs, validation_data=valid_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)
    #network.load_weights('%s_%d.h5' % (out, n_fold))
    #history = network.fit(train_db, epochs=50, validation_data=valid_db, verbose=2)
    scores1 = model1.predict(val_x, batch_size=batch_size)[:, 0]
    score_val = pd.DataFrame(scores1)
    y_val = pd.DataFrame(val_y)
    datav=pd.concat([score_val,y_val],axis=1)
    print(n_fold + 1) 
    n_fold_str = str(n_fold + 1)
    pathv ='val_out'+ n_fold_str
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\result\val\\'+pathv+'.csv',encoding='utf-8')
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\result\valtxt\\'+pathv+'.txt',sep='\t',index=False,encoding='utf-8')
    scores2 = model1.predict(x_test, batch_size=batch_size)[:, 0]
    score_indep = pd.DataFrame(scores2)
    test_y = pd.DataFrame(y_test)
    datai = pd.concat([score_indep,test_y],axis=1)
    pathi ='indep_out'+ n_fold_str
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\result\indep\\'+pathi+'.csv',encoding='utf-8')
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\result\indeptxt\\'+pathi+'.txt',sep='\t',index=False,encoding='utf-8')
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# =================================================================
# Total params: 199,680
# Trainable params: 199,680
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 5, 128)            199680
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 64)             0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 205,185
# Non-trainable params: 2,816
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 2s - loss: 0.6762 - accuracy: 0.5695 - val_loss: 0.6890 - val_accuracy: 0.5289
#
# Epoch 00001: val_loss improved from inf to 0.68904, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_0.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.6482 - accuracy: 0.6204 - val_loss: 0.6442 - val_accuracy: 0.6489
#
# Epoch 00002: val_loss improved from 0.68904 to 0.64421, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_0.h5
# Epoch 3/300
# 8/8 - 0s - loss: 0.6395 - accuracy: 0.6337 - val_loss: 0.6590 - val_accuracy: 0.5822
#
# Epoch 00003: val_loss did not improve from 0.64421
# Epoch 4/300
# 8/8 - 0s - loss: 0.6355 - accuracy: 0.6238 - val_loss: 0.6505 - val_accuracy: 0.6044
#
# Epoch 00004: val_loss did not improve from 0.64421
# Epoch 5/300
# 8/8 - 0s - loss: 0.6244 - accuracy: 0.6540 - val_loss: 0.6468 - val_accuracy: 0.6000
#
# Epoch 00005: val_loss did not improve from 0.64421
# Epoch 6/300
# 8/8 - 0s - loss: 0.6212 - accuracy: 0.6525 - val_loss: 0.6408 - val_accuracy: 0.6133
#
# Epoch 00006: val_loss improved from 0.64421 to 0.64082, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_0.h5
# Epoch 7/300
# 8/8 - 0s - loss: 0.6071 - accuracy: 0.6634 - val_loss: 0.6309 - val_accuracy: 0.6622
#
# Epoch 00007: val_loss improved from 0.64082 to 0.63085, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_0.h5
# Epoch 8/300
# 8/8 - 0s - loss: 0.6154 - accuracy: 0.6649 - val_loss: 0.6347 - val_accuracy: 0.6222
#
# Epoch 00008: val_loss did not improve from 0.63085
# Epoch 9/300
# 8/8 - 0s - loss: 0.6108 - accuracy: 0.6584 - val_loss: 0.6325 - val_accuracy: 0.6267
#
# Epoch 00009: val_loss did not improve from 0.63085
# Epoch 10/300
# 8/8 - 0s - loss: 0.6158 - accuracy: 0.6624 - val_loss: 0.6314 - val_accuracy: 0.6800
#
# Epoch 00010: val_loss did not improve from 0.63085
# Epoch 11/300
# 8/8 - 0s - loss: 0.5966 - accuracy: 0.6653 - val_loss: 0.6434 - val_accuracy: 0.6400
#
# Epoch 00011: val_loss did not improve from 0.63085
# Epoch 12/300
# 8/8 - 0s - loss: 0.6167 - accuracy: 0.6629 - val_loss: 0.6459 - val_accuracy: 0.6444
#
# Epoch 00012: val_loss did not improve from 0.63085
# Epoch 13/300
# 8/8 - 0s - loss: 0.5946 - accuracy: 0.6792 - val_loss: 0.6204 - val_accuracy: 0.6489
#
# Epoch 00013: val_loss improved from 0.63085 to 0.62036, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_0.h5
# Epoch 14/300
# 8/8 - 0s - loss: 0.6025 - accuracy: 0.6673 - val_loss: 0.6242 - val_accuracy: 0.6622
#
# Epoch 00014: val_loss did not improve from 0.62036
# Epoch 15/300
# 8/8 - 0s - loss: 0.5803 - accuracy: 0.6841 - val_loss: 0.6165 - val_accuracy: 0.6578
#
# Epoch 00015: val_loss improved from 0.62036 to 0.61655, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_0.h5
# Epoch 16/300
# 8/8 - 0s - loss: 0.5831 - accuracy: 0.7004 - val_loss: 0.6258 - val_accuracy: 0.6667
#
# Epoch 00016: val_loss did not improve from 0.61655
# Epoch 17/300
# 8/8 - 0s - loss: 0.5746 - accuracy: 0.7014 - val_loss: 0.6297 - val_accuracy: 0.5911
#
# Epoch 00017: val_loss did not improve from 0.61655
# Epoch 18/300
# 8/8 - 0s - loss: 0.5815 - accuracy: 0.6925 - val_loss: 0.6343 - val_accuracy: 0.6622
#
# Epoch 00018: val_loss did not improve from 0.61655
# Epoch 19/300
# 8/8 - 0s - loss: 0.5743 - accuracy: 0.6990 - val_loss: 0.6437 - val_accuracy: 0.6444
#
# Epoch 00019: val_loss did not improve from 0.61655
# Epoch 20/300
# 8/8 - 0s - loss: 0.5919 - accuracy: 0.6876 - val_loss: 0.6266 - val_accuracy: 0.6756
#
# Epoch 00020: val_loss did not improve from 0.61655
# Epoch 21/300
# 8/8 - 0s - loss: 0.5743 - accuracy: 0.7084 - val_loss: 0.6237 - val_accuracy: 0.5822
#
# Epoch 00021: val_loss did not improve from 0.61655
# Epoch 22/300
# 8/8 - 0s - loss: 0.5660 - accuracy: 0.7074 - val_loss: 0.6174 - val_accuracy: 0.6756
#
# Epoch 00022: val_loss did not improve from 0.61655
# Epoch 23/300
# 8/8 - 0s - loss: 0.5781 - accuracy: 0.6915 - val_loss: 0.6196 - val_accuracy: 0.6711
#
# Epoch 00023: val_loss did not improve from 0.61655
# Epoch 24/300
# 8/8 - 0s - loss: 0.5707 - accuracy: 0.6970 - val_loss: 0.6404 - val_accuracy: 0.6489
#
# Epoch 00024: val_loss did not improve from 0.61655
# Epoch 25/300
# 8/8 - 0s - loss: 0.5645 - accuracy: 0.7192 - val_loss: 0.6159 - val_accuracy: 0.6711
#
# Epoch 00025: val_loss improved from 0.61655 to 0.61594, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_0.h5
# Epoch 26/300
# 8/8 - 0s - loss: 0.5537 - accuracy: 0.7207 - val_loss: 0.6313 - val_accuracy: 0.6622
#
# Epoch 00026: val_loss did not improve from 0.61594
# Epoch 27/300
# 8/8 - 0s - loss: 0.5677 - accuracy: 0.6975 - val_loss: 0.6229 - val_accuracy: 0.6667
#
# Epoch 00027: val_loss did not improve from 0.61594
# Epoch 28/300
# 8/8 - 0s - loss: 0.5520 - accuracy: 0.7143 - val_loss: 0.6157 - val_accuracy: 0.6800
#
# Epoch 00028: val_loss improved from 0.61594 to 0.61574, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_0.h5
# Epoch 29/300
# 8/8 - 0s - loss: 0.5503 - accuracy: 0.7286 - val_loss: 0.6124 - val_accuracy: 0.6933
#
# Epoch 00029: val_loss improved from 0.61574 to 0.61239, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_0.h5
# Epoch 30/300
# 8/8 - 0s - loss: 0.5501 - accuracy: 0.7084 - val_loss: 0.6244 - val_accuracy: 0.6444
#
# Epoch 00030: val_loss did not improve from 0.61239
# Epoch 31/300
# 8/8 - 0s - loss: 0.5260 - accuracy: 0.7336 - val_loss: 0.6357 - val_accuracy: 0.6800
#
# Epoch 00031: val_loss did not improve from 0.61239
# Epoch 32/300
# 8/8 - 0s - loss: 0.5379 - accuracy: 0.7247 - val_loss: 0.6313 - val_accuracy: 0.6622
#
# Epoch 00032: val_loss did not improve from 0.61239
# Epoch 33/300
# 8/8 - 0s - loss: 0.5402 - accuracy: 0.7168 - val_loss: 0.6338 - val_accuracy: 0.6756
#
# Epoch 00033: val_loss did not improve from 0.61239
# Epoch 34/300
# 8/8 - 0s - loss: 0.5295 - accuracy: 0.7222 - val_loss: 0.6206 - val_accuracy: 0.6756
#
# Epoch 00034: val_loss did not improve from 0.61239
# Epoch 35/300
# 8/8 - 0s - loss: 0.5233 - accuracy: 0.7360 - val_loss: 0.6563 - val_accuracy: 0.6578
#
# Epoch 00035: val_loss did not improve from 0.61239
# Epoch 36/300
# 8/8 - 0s - loss: 0.5266 - accuracy: 0.7291 - val_loss: 0.6212 - val_accuracy: 0.6622
#
# Epoch 00036: val_loss did not improve from 0.61239
# Epoch 37/300
# 8/8 - 0s - loss: 0.5152 - accuracy: 0.7523 - val_loss: 0.6242 - val_accuracy: 0.6222
#
# Epoch 00037: val_loss did not improve from 0.61239
# Epoch 38/300
# 8/8 - 0s - loss: 0.5436 - accuracy: 0.7182 - val_loss: 0.6175 - val_accuracy: 0.6756
#
# Epoch 00038: val_loss did not improve from 0.61239
# Epoch 39/300
# 8/8 - 0s - loss: 0.5104 - accuracy: 0.7435 - val_loss: 0.6180 - val_accuracy: 0.6622
#
# Epoch 00039: val_loss did not improve from 0.61239
# Epoch 40/300
# 8/8 - 0s - loss: 0.5123 - accuracy: 0.7430 - val_loss: 0.6254 - val_accuracy: 0.6800
#
# Epoch 00040: val_loss did not improve from 0.61239
# Epoch 41/300
# 8/8 - 0s - loss: 0.5425 - accuracy: 0.7271 - val_loss: 0.6280 - val_accuracy: 0.6533
#
# Epoch 00041: val_loss did not improve from 0.61239
# Epoch 42/300
# 8/8 - 0s - loss: 0.5094 - accuracy: 0.7420 - val_loss: 0.6281 - val_accuracy: 0.5778
#
# Epoch 00042: val_loss did not improve from 0.61239
# Epoch 43/300
# 8/8 - 0s - loss: 0.4938 - accuracy: 0.7563 - val_loss: 0.6180 - val_accuracy: 0.6800
#
# Epoch 00043: val_loss did not improve from 0.61239
# Epoch 44/300
# 8/8 - 0s - loss: 0.5081 - accuracy: 0.7464 - val_loss: 0.6151 - val_accuracy: 0.6756
#
# Epoch 00044: val_loss did not improve from 0.61239
# Epoch 45/300
# 8/8 - 0s - loss: 0.5315 - accuracy: 0.7227 - val_loss: 0.6320 - val_accuracy: 0.6711
#
# Epoch 00045: val_loss did not improve from 0.61239
# Epoch 46/300
# 8/8 - 0s - loss: 0.5010 - accuracy: 0.7435 - val_loss: 0.6202 - val_accuracy: 0.6667
#
# Epoch 00046: val_loss did not improve from 0.61239
# Epoch 47/300
# 8/8 - 0s - loss: 0.4941 - accuracy: 0.7514 - val_loss: 0.6251 - val_accuracy: 0.6178
#
# Epoch 00047: val_loss did not improve from 0.61239
# Epoch 48/300
# 8/8 - 0s - loss: 0.4856 - accuracy: 0.7558 - val_loss: 0.6203 - val_accuracy: 0.6489
#
# Epoch 00048: val_loss did not improve from 0.61239
# Epoch 49/300
# 8/8 - 0s - loss: 0.5129 - accuracy: 0.7519 - val_loss: 0.6485 - val_accuracy: 0.5689
#
# Epoch 00049: val_loss did not improve from 0.61239
# Epoch 50/300
# 8/8 - 0s - loss: 0.4814 - accuracy: 0.7840 - val_loss: 0.6379 - val_accuracy: 0.6756
#
# Epoch 00050: val_loss did not improve from 0.61239
# Epoch 51/300
# 8/8 - 0s - loss: 0.4800 - accuracy: 0.7603 - val_loss: 0.6279 - val_accuracy: 0.6756
#
# Epoch 00051: val_loss did not improve from 0.61239
# Epoch 52/300
# 8/8 - 0s - loss: 0.4873 - accuracy: 0.7642 - val_loss: 0.6170 - val_accuracy: 0.6844
#
# Epoch 00052: val_loss did not improve from 0.61239
# Epoch 53/300
# 8/8 - 0s - loss: 0.4596 - accuracy: 0.7766 - val_loss: 0.6248 - val_accuracy: 0.6400
#
# Epoch 00053: val_loss did not improve from 0.61239
# Epoch 54/300
# 8/8 - 0s - loss: 0.4681 - accuracy: 0.7766 - val_loss: 0.6214 - val_accuracy: 0.6578
#
# Epoch 00054: val_loss did not improve from 0.61239
# Epoch 55/300
# 8/8 - 0s - loss: 0.4955 - accuracy: 0.7627 - val_loss: 0.6508 - val_accuracy: 0.5822
#
# Epoch 00055: val_loss did not improve from 0.61239
# Epoch 56/300
# 8/8 - 0s - loss: 0.4575 - accuracy: 0.7781 - val_loss: 0.6263 - val_accuracy: 0.6578
#
# Epoch 00056: val_loss did not improve from 0.61239
# Epoch 57/300
# 8/8 - 0s - loss: 0.4705 - accuracy: 0.7741 - val_loss: 0.6412 - val_accuracy: 0.6844
#
# Epoch 00057: val_loss did not improve from 0.61239
# Epoch 58/300
# 8/8 - 0s - loss: 0.4621 - accuracy: 0.7790 - val_loss: 0.6435 - val_accuracy: 0.6889
#
# Epoch 00058: val_loss did not improve from 0.61239
# Epoch 59/300
# 8/8 - 0s - loss: 0.4567 - accuracy: 0.7929 - val_loss: 0.6457 - val_accuracy: 0.6756
#
# Epoch 00059: val_loss did not improve from 0.61239
# Epoch 60/300
# 8/8 - 0s - loss: 0.4701 - accuracy: 0.7696 - val_loss: 0.6635 - val_accuracy: 0.6533
#
# Epoch 00060: val_loss did not improve from 0.61239
# Epoch 61/300
# 8/8 - 0s - loss: 0.4663 - accuracy: 0.7785 - val_loss: 0.6277 - val_accuracy: 0.6667
#
# Epoch 00061: val_loss did not improve from 0.61239
# Epoch 62/300
# 8/8 - 0s - loss: 0.4248 - accuracy: 0.8067 - val_loss: 0.6316 - val_accuracy: 0.6844
#
# Epoch 00062: val_loss did not improve from 0.61239
# Epoch 63/300
# 8/8 - 0s - loss: 0.4556 - accuracy: 0.7805 - val_loss: 0.6265 - val_accuracy: 0.6578
#
# Epoch 00063: val_loss did not improve from 0.61239
# Epoch 64/300
# 8/8 - 0s - loss: 0.4592 - accuracy: 0.7785 - val_loss: 0.6225 - val_accuracy: 0.6667
#
# Epoch 00064: val_loss did not improve from 0.61239
# Epoch 65/300
# 8/8 - 0s - loss: 0.4349 - accuracy: 0.7830 - val_loss: 0.6262 - val_accuracy: 0.6622
#
# Epoch 00065: val_loss did not improve from 0.61239
# Epoch 66/300
# 8/8 - 0s - loss: 0.4613 - accuracy: 0.7761 - val_loss: 0.6267 - val_accuracy: 0.6889
#
# Epoch 00066: val_loss did not improve from 0.61239
# Epoch 67/300
# 8/8 - 0s - loss: 0.4302 - accuracy: 0.8003 - val_loss: 0.6413 - val_accuracy: 0.6800
#
# Epoch 00067: val_loss did not improve from 0.61239
# Epoch 68/300
# 8/8 - 0s - loss: 0.4343 - accuracy: 0.7978 - val_loss: 0.6320 - val_accuracy: 0.6800
#
# Epoch 00068: val_loss did not improve from 0.61239
# Epoch 69/300
# 8/8 - 0s - loss: 0.4454 - accuracy: 0.7860 - val_loss: 0.6263 - val_accuracy: 0.6578
#
# Epoch 00069: val_loss did not improve from 0.61239
# Epoch 70/300
# 8/8 - 0s - loss: 0.4171 - accuracy: 0.8082 - val_loss: 0.6533 - val_accuracy: 0.6756
#
# Epoch 00070: val_loss did not improve from 0.61239
# Epoch 71/300
# 8/8 - 0s - loss: 0.4075 - accuracy: 0.8062 - val_loss: 0.6496 - val_accuracy: 0.6578
#
# Epoch 00071: val_loss did not improve from 0.61239
# Epoch 72/300
# 8/8 - 0s - loss: 0.4523 - accuracy: 0.7790 - val_loss: 0.6389 - val_accuracy: 0.6889
#
# Epoch 00072: val_loss did not improve from 0.61239
# Epoch 73/300
# 8/8 - 0s - loss: 0.3839 - accuracy: 0.8230 - val_loss: 0.6546 - val_accuracy: 0.6400
#
# Epoch 00073: val_loss did not improve from 0.61239
# Epoch 74/300
# 8/8 - 0s - loss: 0.4150 - accuracy: 0.8018 - val_loss: 0.6535 - val_accuracy: 0.6489
#
# Epoch 00074: val_loss did not improve from 0.61239
# Epoch 75/300
# 8/8 - 0s - loss: 0.4264 - accuracy: 0.7988 - val_loss: 0.6639 - val_accuracy: 0.6622
#
# Epoch 00075: val_loss did not improve from 0.61239
# Epoch 76/300
# 8/8 - 0s - loss: 0.4324 - accuracy: 0.7909 - val_loss: 0.6437 - val_accuracy: 0.6667
#
# Epoch 00076: val_loss did not improve from 0.61239
# Epoch 77/300
# 8/8 - 0s - loss: 0.3946 - accuracy: 0.8201 - val_loss: 0.6810 - val_accuracy: 0.6622
#
# Epoch 00077: val_loss did not improve from 0.61239
# Epoch 78/300
# 8/8 - 0s - loss: 0.3948 - accuracy: 0.8245 - val_loss: 0.6953 - val_accuracy: 0.6489
#
# Epoch 00078: val_loss did not improve from 0.61239
# Epoch 79/300
# 8/8 - 0s - loss: 0.4200 - accuracy: 0.7988 - val_loss: 0.6412 - val_accuracy: 0.6889
#
# Epoch 00079: val_loss did not improve from 0.61239
# 1
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# =================================================================
# Total params: 199,680
# Trainable params: 199,680
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Functional)         (None, 5, 128)            199680
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 64)             0
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 205,185
# Non-trainable params: 2,816
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 1s - loss: 0.6857 - accuracy: 0.5477 - val_loss: 0.6636 - val_accuracy: 0.6444
#
# Epoch 00001: val_loss improved from inf to 0.66360, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.6606 - accuracy: 0.6036 - val_loss: 0.6456 - val_accuracy: 0.6311
#
# Epoch 00002: val_loss improved from 0.66360 to 0.64563, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 3/300
# 8/8 - 0s - loss: 0.6459 - accuracy: 0.6045 - val_loss: 0.6382 - val_accuracy: 0.6667
#
# Epoch 00003: val_loss improved from 0.64563 to 0.63823, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 4/300
# 8/8 - 0s - loss: 0.6303 - accuracy: 0.6461 - val_loss: 0.6307 - val_accuracy: 0.6622
#
# Epoch 00004: val_loss improved from 0.63823 to 0.63074, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 5/300
# 8/8 - 0s - loss: 0.6204 - accuracy: 0.6555 - val_loss: 0.6216 - val_accuracy: 0.6578
#
# Epoch 00005: val_loss improved from 0.63074 to 0.62158, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 6/300
# 8/8 - 0s - loss: 0.6231 - accuracy: 0.6476 - val_loss: 0.6179 - val_accuracy: 0.6444
#
# Epoch 00006: val_loss improved from 0.62158 to 0.61790, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 7/300
# 8/8 - 0s - loss: 0.6277 - accuracy: 0.6480 - val_loss: 0.6273 - val_accuracy: 0.6578
#
# Epoch 00007: val_loss did not improve from 0.61790
# Epoch 8/300
# 8/8 - 0s - loss: 0.6117 - accuracy: 0.6614 - val_loss: 0.6146 - val_accuracy: 0.6311
#
# Epoch 00008: val_loss improved from 0.61790 to 0.61455, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 9/300
# 8/8 - 0s - loss: 0.6181 - accuracy: 0.6604 - val_loss: 0.6246 - val_accuracy: 0.6444
#
# Epoch 00009: val_loss did not improve from 0.61455
# Epoch 10/300
# 8/8 - 0s - loss: 0.6061 - accuracy: 0.6708 - val_loss: 0.6080 - val_accuracy: 0.6622
#
# Epoch 00010: val_loss improved from 0.61455 to 0.60800, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 11/300
# 8/8 - 0s - loss: 0.6038 - accuracy: 0.6762 - val_loss: 0.6119 - val_accuracy: 0.6400
#
# Epoch 00011: val_loss did not improve from 0.60800
# Epoch 12/300
# 8/8 - 0s - loss: 0.5970 - accuracy: 0.6871 - val_loss: 0.6023 - val_accuracy: 0.6489
#
# Epoch 00012: val_loss improved from 0.60800 to 0.60232, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 13/300
# 8/8 - 0s - loss: 0.5980 - accuracy: 0.6742 - val_loss: 0.6077 - val_accuracy: 0.6800
#
# Epoch 00013: val_loss did not improve from 0.60232
# Epoch 14/300
# 8/8 - 0s - loss: 0.5935 - accuracy: 0.6747 - val_loss: 0.6187 - val_accuracy: 0.6311
#
# Epoch 00014: val_loss did not improve from 0.60232
# Epoch 15/300
# 8/8 - 0s - loss: 0.5853 - accuracy: 0.6846 - val_loss: 0.5995 - val_accuracy: 0.6711
#
# Epoch 00015: val_loss improved from 0.60232 to 0.59946, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 16/300
# 8/8 - 0s - loss: 0.5790 - accuracy: 0.6846 - val_loss: 0.6223 - val_accuracy: 0.6400
#
# Epoch 00016: val_loss did not improve from 0.59946
# Epoch 17/300
# 8/8 - 0s - loss: 0.5841 - accuracy: 0.7054 - val_loss: 0.6033 - val_accuracy: 0.6267
#
# Epoch 00017: val_loss did not improve from 0.59946
# Epoch 18/300
# 8/8 - 0s - loss: 0.5815 - accuracy: 0.6812 - val_loss: 0.6018 - val_accuracy: 0.6578
#
# Epoch 00018: val_loss did not improve from 0.59946
# Epoch 19/300
# 8/8 - 0s - loss: 0.5735 - accuracy: 0.6866 - val_loss: 0.6194 - val_accuracy: 0.6356
#
# Epoch 00019: val_loss did not improve from 0.59946
# Epoch 20/300
# 8/8 - 0s - loss: 0.5692 - accuracy: 0.7128 - val_loss: 0.6082 - val_accuracy: 0.6489
#
# Epoch 00020: val_loss did not improve from 0.59946
# Epoch 21/300
# 8/8 - 0s - loss: 0.5704 - accuracy: 0.6970 - val_loss: 0.6041 - val_accuracy: 0.6622
#
# Epoch 00021: val_loss did not improve from 0.59946
# Epoch 22/300
# 8/8 - 0s - loss: 0.5945 - accuracy: 0.6703 - val_loss: 0.6117 - val_accuracy: 0.6444
#
# Epoch 00022: val_loss did not improve from 0.59946
# Epoch 23/300
# 8/8 - 0s - loss: 0.5608 - accuracy: 0.7237 - val_loss: 0.6215 - val_accuracy: 0.6311
#
# Epoch 00023: val_loss did not improve from 0.59946
# Epoch 24/300
# 8/8 - 0s - loss: 0.5694 - accuracy: 0.7084 - val_loss: 0.6101 - val_accuracy: 0.6356
#
# Epoch 00024: val_loss did not improve from 0.59946
# Epoch 25/300
# 8/8 - 0s - loss: 0.5575 - accuracy: 0.7103 - val_loss: 0.6014 - val_accuracy: 0.6400
#
# Epoch 00025: val_loss did not improve from 0.59946
# Epoch 26/300
# 8/8 - 0s - loss: 0.5678 - accuracy: 0.7024 - val_loss: 0.5992 - val_accuracy: 0.6578
#
# Epoch 00026: val_loss improved from 0.59946 to 0.59920, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\_1.h5
# Epoch 27/300
# 8/8 - 0s - loss: 0.5678 - accuracy: 0.6995 - val_loss: 0.6056 - val_accuracy: 0.6622
#
# Epoch 00027: val_loss did not improve from 0.59920
# Epoch 28/300
# 8/8 - 0s - loss: 0.5381 - accuracy: 0.7360 - val_loss: 0.5993 - val_accuracy: 0.6667

# %%
#遍历表格求初始里程
#交叉验证
import os
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1')
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\result\val'
filenames=os.listdir(path)#得到字符串列表
scores_val=[]
lables_val=[]
fpr_list_val = []
tpr_list_val = []
roc_auc_list_val=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_val=data.iloc[:,1]
        scores_val.append(score_val)
        lable_val = data.iloc[:,2]
        lables_val.append(lable_val)
        fpr_val,tpr_val,thresholds_val= roc_curve(lables_val[i],scores_val[i])   #y_true,y_score
        fpr_list_val.append(fpr_val)
        tpr_list_val.append(tpr_val)
        roc_auc_val = auc(fpr_val,tpr_val)
        roc_auc_list_val.append(roc_auc_val)
        i+=1

# %%
roc_auc_list_val
# Out:
# [0.7461283185840709,
#  0.7687340561224489,
#  0.6855246523388115,
#  0.7499209860935524,
#  0.6872629582806574,
#  0.7070954487989886,
#  0.7818426042983565,
#  0.7298514538558786,
#  0.6962705436156763,
#  0.7241709183673469]

# %%
i=1
tprs_val = []
mean_fpr_val = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Validation ROC')
for fpr_val,tpr_val,roc_auc_val in zip(fpr_list_val,tpr_list_val,roc_auc_list_val):
    tprs_val.append(np.interp(mean_fpr_val, fpr_val, tpr_val))
    tprs_val[-1][0] = 0.0
    plt.plot(fpr_val, tpr_val, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_val)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_val.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_val = np.mean(tprs_val, axis=0)
mean_tpr_val[-1] = 1.0
mean_auc_val = auc(mean_fpr_val, mean_tpr_val)
std_auc_val = np.std(roc_auc_list_val)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_val, std_auc_val),lw=2, alpha=.8)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_val),lw=2, alpha=.8)
std_tpr_val = np.std(tprs_val, axis=0)
tprs_upper_val = np.minimum(mean_tpr_val + std_tpr_val, 1)
tprs_lower_val = np.maximum(mean_tpr_val - std_tpr_val, 0)
plt.fill_between(mean_fpr_val, tprs_lower_val, tprs_upper_val, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Cross-Validation ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_val_mean.png')
plt.show()

# %%
def calculate_metrics_val(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_val = []
for score_val,lable_val in zip(scores_val,lables_val):
    val_my_calculate_metrics = calculate_metrics_val(lable_val,score_val)
    my_calculate_metrics_list_val.append(val_my_calculate_metrics)

# %%
my_calculate_metrics_list_val
# Out:
# [{'SN': 0.911504424778761,
#   'SP': 0.35714285714285715,
#   'ACC': 0.6355555555555555,
#   'MCC': 0.3230923368297591,
#   'Recall': 0.911504424778761,
#   'Precision': 0.5885714285714285,
#   'F1-score': 0.7152777777777778,
#   'Cutoff': 0.5},
#  {'SN': 0.7857142857142857,
#   'SP': 0.5982142857142857,
#   'ACC': 0.6919642857142857,
#   'MCC': 0.39086064011369204,
#   'Recall': 0.7857142857142857,
#   'Precision': 0.6616541353383458,
#   'F1-score': 0.7183673469387755,
#   'Cutoff': 0.5},
#  {'SN': 0.6637168141592921,
#   'SP': 0.625,
#   'ACC': 0.6444444444444445,
#   'MCC': 0.2889452113266928,
#   'Recall': 0.6637168141592921,
#   'Precision': 0.6410256410256411,
#   'F1-score': 0.6521739130434783,
#   'Cutoff': 0.5},
#  {'SN': 0.8407079646017699,
#   'SP': 0.5,
#   'ACC': 0.6711111111111111,
#   'MCC': 0.3625986523042244,
#   'Recall': 0.8407079646017699,
#   'Precision': 0.6291390728476821,
#   'F1-score': 0.7196969696969697,
#   'Cutoff': 0.5},
#  {'SN': 0.8230088495575221,
#   'SP': 0.35714285714285715,
#   'ACC': 0.5911111111111111,
#   'MCC': 0.2036896756523513,
#   'Recall': 0.8230088495575221,
#   'Precision': 0.5636363636363636,
#   'F1-score': 0.6690647482014388,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.5752212389380531,
#   'ACC': 0.6622222222222223,
#   'MCC': 0.3302164415878894,
#   'Recall': 0.75,
#   'Precision': 0.6363636363636364,
#   'F1-score': 0.6885245901639344,
#   'Cutoff': 0.5},
#  {'SN': 0.7053571428571429,
#   'SP': 0.6991150442477876,
#   'ACC': 0.7022222222222222,
#   'MCC': 0.4044721871049305,
#   'Recall': 0.7053571428571429,
#   'Precision': 0.6991150442477876,
#   'F1-score': 0.7022222222222222,
#   'Cutoff': 0.5},
#  {'SN': 0.7857142857142857,
#   'SP': 0.5132743362831859,
#   'ACC': 0.6488888888888888,
#   'MCC': 0.3106189517357569,
#   'Recall': 0.7857142857142857,
#   'Precision': 0.6153846153846154,
#   'F1-score': 0.6901960784313725,
#   'Cutoff': 0.5},
#  {'SN': 0.6964285714285714,
#   'SP': 0.6548672566371682,
#   'ACC': 0.6755555555555556,
#   'MCC': 0.35157373003789716,
#   'Recall': 0.6964285714285714,
#   'Precision': 0.6666666666666666,
#   'F1-score': 0.6812227074235808,
#   'Cutoff': 0.5},
#  {'SN': 0.8571428571428571,
#   'SP': 0.35714285714285715,
#   'ACC': 0.6071428571428571,
#   'MCC': 0.24743582965269673,
#   'Recall': 0.8571428571428571,
#   'Precision': 0.5714285714285714,
#   'F1-score': 0.6857142857142857,
#   'Cutoff': 0.5}]

# %%
performance_val=pd.DataFrame(my_calculate_metrics_list_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.911504  0.357143  0.635556  0.323092  0.911504   0.588571  0.715278
# 1  0.785714  0.598214  0.691964  0.390861  0.785714   0.661654  0.718367
# 2  0.663717  0.625000  0.644444  0.288945  0.663717   0.641026  0.652174
# 3  0.840708  0.500000  0.671111  0.362599  0.840708   0.629139  0.719697
# 4  0.823009  0.357143  0.591111  0.203690  0.823009   0.563636  0.669065
# 5  0.750000  0.575221  0.662222  0.330216  0.750000   0.636364  0.688525
# 6  0.705357  0.699115  0.702222  0.404472  0.705357   0.699115  0.702222
# 7  0.785714  0.513274  0.648889  0.310619  0.785714   0.615385  0.690196
# 8  0.696429  0.654867  0.675556  0.351574  0.696429   0.666667  0.681223
# 9  0.857143  0.357143  0.607143  0.247436  0.857143   0.571429  0.685714
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_val = performance_val.std(axis = 0,ddof=1)
mean_val = performance_val.mean(axis = 0)
data_mean_val = pd.DataFrame(mean_val)
data_mean_val = data_mean_val.T
data_std_val = pd.DataFrame(std_val)
data_std_val = data_std_val.T
performance_val = performance_val.append(data_mean_val)
performance_val = performance_val.append(data_std_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.911504  0.357143  0.635556  0.323092  0.911504   0.588571  0.715278
# 1  0.785714  0.598214  0.691964  0.390861  0.785714   0.661654  0.718367
# 2  0.663717  0.625000  0.644444  0.288945  0.663717   0.641026  0.652174
# 3  0.840708  0.500000  0.671111  0.362599  0.840708   0.629139  0.719697
# 4  0.823009  0.357143  0.591111  0.203690  0.823009   0.563636  0.669065
# 5  0.750000  0.575221  0.662222  0.330216  0.750000   0.636364  0.688525
# 6  0.705357  0.699115  0.702222  0.404472  0.705357   0.699115  0.702222
# 7  0.785714  0.513274  0.648889  0.310619  0.785714   0.615385  0.690196
# 8  0.696429  0.654867  0.675556  0.351574  0.696429   0.666667  0.681223
# 9  0.857143  0.357143  0.607143  0.247436  0.857143   0.571429  0.685714
# 0  0.781930  0.523712  0.653022  0.321350  0.781930   0.627299  0.692246
# 0  0.078730  0.129245  0.035262  0.062281  0.078730   0.043433  0.022089
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_val.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\result\CNN_OH_performance_val.csv',encoding='utf-8')

# %% [markdown]
# 独立测试

# %%
#遍历表格求初始里程
#独立测试
import os
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\result\indep'
filenames=os.listdir(path)#得到字符串列表
scores_indep=[]
lables_indep=[]
fpr_list_indep = []
tpr_list_indep = []
roc_auc_list_indep=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_indep=data.iloc[:,1]
        scores_indep.append(score_indep)
        lable_indep = data.iloc[:,2]
        lables_indep.append(lable_indep)
        fpr_indep,tpr_indep,thresholds_indep= roc_curve(lables_indep[i],scores_indep[i])   #y_true,y_score
        fpr_list_indep.append(fpr_indep)
        tpr_list_indep.append(tpr_indep)
        roc_auc_indep = auc(fpr_indep,tpr_indep)
        roc_auc_list_indep.append(roc_auc_indep)
        i+=1

# %%
roc_auc_list_indep
# Out:
# [0.757015306122449,
#  0.7613998724489797,
#  0.7322225765306124,
#  0.7433832908163266,
#  0.746014030612245,
#  0.7560586734693878,
#  0.7574139030612245,
#  0.7275191326530613,
#  0.7618781887755102,
#  0.7369260204081632]

# %%
i=1
tprs_indep = []
mean_fpr_indep = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Independent ROC')
for fpr_indep,tpr_indep,roc_auc_indep in zip(fpr_list_indep,tpr_list_indep,roc_auc_list_indep):
    tprs_indep.append(np.interp(mean_fpr_indep, fpr_indep, tpr_indep))
    tprs_indep[-1][0] = 0.0
    plt.plot(fpr_indep, tpr_indep, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_indep)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_indep.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_indep = np.mean(tprs_indep, axis=0)
mean_tpr_indep[-1] = 1.0
mean_auc_indep = auc(mean_fpr_indep, mean_tpr_indep)
std_auc_indep = np.std(roc_auc_list_indep)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_indep, std_auc_indep),lw=2, alpha=.8)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_indep),lw=2, alpha=.8)
std_tpr_indep = np.std(tprs_indep, axis=0)
tprs_upper_indep = np.minimum(mean_tpr_indep + std_tpr_indep, 1)
tprs_lower_indep = np.maximum(mean_tpr_indep - std_tpr_indep, 0)
plt.fill_between(mean_fpr_indep, tprs_lower_indep, tprs_upper_indep, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Independent ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_indep_mean.png')
plt.show()

# %%
def calculate_metrics_indep(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_indep = []
for score_indep,lable_indep in zip(scores_indep,lables_indep):
    indep_my_calculate_metrics = calculate_metrics_indep(lable_indep,score_indep)
    my_calculate_metrics_list_indep.append(indep_my_calculate_metrics)

# %%
my_calculate_metrics_list_indep
# Out:
# [{'SN': 0.875,
#   'SP': 0.48214285714285715,
#   'ACC': 0.6785714285714286,
#   'MCC': 0.38836781869030873,
#   'Recall': 0.875,
#   'Precision': 0.6282051282051282,
#   'F1-score': 0.7313432835820896,
#   'Cutoff': 0.5},
#  {'SN': 0.75,
#   'SP': 0.5892857142857143,
#   'ACC': 0.6696428571428571,
#   'MCC': 0.3437541846196715,
#   'Recall': 0.75,
#   'Precision': 0.6461538461538462,
#   'F1-score': 0.6942148760330579,
#   'Cutoff': 0.5},
#  {'SN': 0.7142857142857143,
#   'SP': 0.6428571428571429,
#   'ACC': 0.6785714285714286,
#   'MCC': 0.35805743701971643,
#   'Recall': 0.7142857142857143,
#   'Precision': 0.6666666666666666,
#   'F1-score': 0.6896551724137931,
#   'Cutoff': 0.5},
#  {'SN': 0.7678571428571429,
#   'SP': 0.5625,
#   'ACC': 0.6651785714285714,
#   'MCC': 0.3375513400941169,
#   'Recall': 0.7678571428571429,
#   'Precision': 0.6370370370370371,
#   'F1-score': 0.6963562753036437,
#   'Cutoff': 0.5},
#  {'SN': 0.8482142857142857,
#   'SP': 0.5089285714285714,
#   'ACC': 0.6785714285714286,
#   'MCC': 0.3796631983009996,
#   'Recall': 0.8482142857142857,
#   'Precision': 0.6333333333333333,
#   'F1-score': 0.7251908396946565,
#   'Cutoff': 0.5},
#  {'SN': 0.7053571428571429,
#   'SP': 0.6517857142857143,
#   'ACC': 0.6785714285714286,
#   'MCC': 0.3576564446438328,
#   'Recall': 0.7053571428571429,
#   'Precision': 0.6694915254237288,
#   'F1-score': 0.6869565217391305,
#   'Cutoff': 0.5},
#  {'SN': 0.5446428571428571,
#   'SP': 0.7232142857142857,
#   'ACC': 0.6339285714285714,
#   'MCC': 0.2722327532402354,
#   'Recall': 0.5446428571428571,
#   'Precision': 0.6630434782608695,
#   'F1-score': 0.5980392156862745,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.5178571428571429,
#   'ACC': 0.65625,
#   'MCC': 0.3252052261138686,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.6223776223776224,
#   'F1-score': 0.6980392156862745,
#   'Cutoff': 0.5},
#  {'SN': 0.6428571428571429,
#   'SP': 0.7410714285714286,
#   'ACC': 0.6919642857142857,
#   'MCC': 0.3857937725041742,
#   'Recall': 0.6428571428571429,
#   'Precision': 0.7128712871287128,
#   'F1-score': 0.676056338028169,
#   'Cutoff': 0.5},
#  {'SN': 0.8303571428571429,
#   'SP': 0.5089285714285714,
#   'ACC': 0.6696428571428571,
#   'MCC': 0.3582992860422392,
#   'Recall': 0.8303571428571429,
#   'Precision': 0.6283783783783784,
#   'F1-score': 0.7153846153846154,
#   'Cutoff': 0.5}]

# %%
performance_indep=pd.DataFrame(my_calculate_metrics_list_indep)
performance_indep
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.875000  0.482143  0.678571  0.388368  0.875000   0.628205  0.731343
# 1  0.750000  0.589286  0.669643  0.343754  0.750000   0.646154  0.694215
# 2  0.714286  0.642857  0.678571  0.358057  0.714286   0.666667  0.689655
# 3  0.767857  0.562500  0.665179  0.337551  0.767857   0.637037  0.696356
# 4  0.848214  0.508929  0.678571  0.379663  0.848214   0.633333  0.725191
# 5  0.705357  0.651786  0.678571  0.357656  0.705357   0.669492  0.686957
# 6  0.544643  0.723214  0.633929  0.272233  0.544643   0.663043  0.598039
# 7  0.794643  0.517857  0.656250  0.325205  0.794643   0.622378  0.698039
# 8  0.642857  0.741071  0.691964  0.385794  0.642857   0.712871  0.676056
# 9  0.830357  0.508929  0.669643  0.358299  0.830357   0.628378  0.715385
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_indep = performance_indep.std(axis = 0,ddof=1)
mean_indep = performance_indep.mean(axis = 0)
data_mean_indep = pd.DataFrame(mean_indep)
data_mean_indep = data_mean_indep.T
data_std_indep = pd.DataFrame(std_indep)
data_std_indep = data_std_indep.T
performance_indep = performance_indep.append(data_mean_indep)
performance_indep = performance_indep.append(data_std_indep)
performance_indep
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.875000  0.482143  0.678571  0.388368  0.875000   0.628205  0.731343
# 1  0.750000  0.589286  0.669643  0.343754  0.750000   0.646154  0.694215
# 2  0.714286  0.642857  0.678571  0.358057  0.714286   0.666667  0.689655
# 3  0.767857  0.562500  0.665179  0.337551  0.767857   0.637037  0.696356
# 4  0.848214  0.508929  0.678571  0.379663  0.848214   0.633333  0.725191
# 5  0.705357  0.651786  0.678571  0.357656  0.705357   0.669492  0.686957
# 6  0.544643  0.723214  0.633929  0.272233  0.544643   0.663043  0.598039
# 7  0.794643  0.517857  0.656250  0.325205  0.794643   0.622378  0.698039
# 8  0.642857  0.741071  0.691964  0.385794  0.642857   0.712871  0.676056
# 9  0.830357  0.508929  0.669643  0.358299  0.830357   0.628378  0.715385
# 0  0.747321  0.592857  0.670089  0.350658  0.747321   0.650756  0.691124
# 0  0.100492  0.092998  0.015951  0.034444  0.100492   0.027771  0.037063
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_indep.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\freeze_1\result\CNN_OH_performance_indep.csv',encoding='utf-8')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
