# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from sklearn.model_selection import KFold,StratifiedKFold

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def build_network():
    os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\based_model\原数据\K_CNN_OH')
    cnn = load_model('dataoh.h5')
    cnn.trainable = True #固定所有预训练模型层的参数
    base_model = Model(inputs=cnn.layers[0].input,outputs=cnn.layers[8].output)
    base_model.summary()
    base_model.trainable = True
    for layer in base_model.layers[:0]:
        layer.trainable = False
    Dense = tf.keras.layers.Dense(64,activation=tf.nn.relu)
    global_average_layer = tf.keras.layers.GlobalAveragePooling1D()
    prediction_layer = tf.keras.layers.Dense(1,activation=tf.nn.sigmoid)
    model1 = tf.keras.Sequential([
        base_model,
        #layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        #layers.Dropout(0.5),
        Dense,
        layers.Dropout(0.5),
        global_average_layer,
        prediction_layer
    ])
    base_learning_rate = 0.001
    model1.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #model1.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),metrics=['accuracy'])
    model1.summary()
    return model1

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
batch_size=256

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\data\NEDD\不自然数据\1正2345负')
epochs = 300
x_train,y_train = One_hot_raw('train.txt')#十折交叉验证10
x_test,y_test = One_hot_raw('test.txt')#独立测试1

# %%
classes = sorted(list(set(y_train)))
x_train = one_hot(x_train)
x_test = one_hot(x_test)
x_train.shape = (x_train.shape[0],x_train.shape[2],x_train.shape[3])
x_test.shape = (x_test.shape[0],x_test.shape[2],x_test.shape[3])

# %%
# 构建独立测试集对象，预处理，批量化
test_db = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_db = test_db.map(preprocess).batch(batch_size)

# %%
prediction_result_cv = []
prediction_result_ind = []

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze')

# %%
out = os.getcwd() + '\\'

# %%
from sklearn.model_selection import KFold,StratifiedKFold
kf = StratifiedKFold(n_splits=10,shuffle=True)
for n_fold,(tr_idx,val_idx)in enumerate(kf.split(x_train,y_train)):
    tr_x,tr_y,val_x,val_y = x_train[tr_idx],y_train[tr_idx],x_train[val_idx],y_train[val_idx]
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((tr_x, tr_y))
    train_db = train_db.shuffle(len(tr_x)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    valid_db = tf.data.Dataset.from_tensor_slices((val_x, val_y))
    valid_db = valid_db.map(preprocess).batch(batch_size)
    #if not os.path.exists('%s_%d.h5' % (out, n_fold)):
    model1 = build_network()
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath='%s_%d.h5' % (out, n_fold), monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = model1.fit(train_db, epochs=epochs, validation_data=valid_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)
    #network.load_weights('%s_%d.h5' % (out, n_fold))
    #history = network.fit(train_db, epochs=50, validation_data=valid_db, verbose=2)
    scores1 = model1.predict(val_x, batch_size=batch_size)[:, 0]
    score_val = pd.DataFrame(scores1)
    y_val = pd.DataFrame(val_y)
    datav=pd.concat([score_val,y_val],axis=1)
    print(n_fold + 1) 
    n_fold_str = str(n_fold + 1)
    pathv ='val_out'+ n_fold_str
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\result\val\\'+pathv+'.csv',encoding='utf-8')
    datav.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\result\valtxt\\'+pathv+'.txt',sep='\t',index=False,encoding='utf-8')
    scores2 = model1.predict(x_test, batch_size=batch_size)[:, 0]
    score_indep = pd.DataFrame(scores2)
    test_y = pd.DataFrame(y_test)
    datai = pd.concat([score_indep,test_y],axis=1)
    pathi ='indep_out'+ n_fold_str
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\result\indep\\'+pathi+'.csv',encoding='utf-8')
    datai.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\result\indeptxt\\'+pathi+'.txt',sep='\t',index=False,encoding='utf-8')
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# =================================================================
# Total params: 199,680
# Trainable params: 199,680
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 5, 128)            199680
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 64)             0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 5s - loss: 0.6838 - accuracy: 0.5487 - val_loss: 0.6768 - val_accuracy: 0.5733
#
# Epoch 00001: val_loss improved from inf to 0.67681, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.6639 - accuracy: 0.6016 - val_loss: 0.6658 - val_accuracy: 0.5911
#
# Epoch 00002: val_loss improved from 0.67681 to 0.66581, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 3/300
# 8/8 - 0s - loss: 0.6603 - accuracy: 0.6060 - val_loss: 0.6547 - val_accuracy: 0.6311
#
# Epoch 00003: val_loss improved from 0.66581 to 0.65473, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 4/300
# 8/8 - 0s - loss: 0.6374 - accuracy: 0.6406 - val_loss: 0.6482 - val_accuracy: 0.6178
#
# Epoch 00004: val_loss improved from 0.65473 to 0.64816, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 5/300
# 8/8 - 0s - loss: 0.6202 - accuracy: 0.6614 - val_loss: 0.6395 - val_accuracy: 0.6489
#
# Epoch 00005: val_loss improved from 0.64816 to 0.63955, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 6/300
# 8/8 - 0s - loss: 0.6297 - accuracy: 0.6520 - val_loss: 0.6466 - val_accuracy: 0.6178
#
# Epoch 00006: val_loss did not improve from 0.63955
# Epoch 7/300
# 8/8 - 0s - loss: 0.6176 - accuracy: 0.6594 - val_loss: 0.6392 - val_accuracy: 0.6444
#
# Epoch 00007: val_loss improved from 0.63955 to 0.63915, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 8/300
# 8/8 - 0s - loss: 0.6157 - accuracy: 0.6698 - val_loss: 0.6372 - val_accuracy: 0.6222
#
# Epoch 00008: val_loss improved from 0.63915 to 0.63724, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 9/300
# 8/8 - 0s - loss: 0.6012 - accuracy: 0.6747 - val_loss: 0.6441 - val_accuracy: 0.6178
#
# Epoch 00009: val_loss did not improve from 0.63724
# Epoch 10/300
# 8/8 - 0s - loss: 0.6088 - accuracy: 0.6693 - val_loss: 0.6293 - val_accuracy: 0.6311
#
# Epoch 00010: val_loss improved from 0.63724 to 0.62928, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 11/300
# 8/8 - 0s - loss: 0.5932 - accuracy: 0.6688 - val_loss: 0.6360 - val_accuracy: 0.6000
#
# Epoch 00011: val_loss did not improve from 0.62928
# Epoch 12/300
# 8/8 - 0s - loss: 0.6012 - accuracy: 0.6792 - val_loss: 0.6246 - val_accuracy: 0.6356
#
# Epoch 00012: val_loss improved from 0.62928 to 0.62461, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 13/300
# 8/8 - 0s - loss: 0.6041 - accuracy: 0.6822 - val_loss: 0.6393 - val_accuracy: 0.6222
#
# Epoch 00013: val_loss did not improve from 0.62461
# Epoch 14/300
# 8/8 - 0s - loss: 0.5886 - accuracy: 0.6891 - val_loss: 0.6283 - val_accuracy: 0.6133
#
# Epoch 00014: val_loss did not improve from 0.62461
# Epoch 15/300
# 8/8 - 0s - loss: 0.5789 - accuracy: 0.6871 - val_loss: 0.6290 - val_accuracy: 0.6133
#
# Epoch 00015: val_loss did not improve from 0.62461
# Epoch 16/300
# 8/8 - 0s - loss: 0.5917 - accuracy: 0.6713 - val_loss: 0.6244 - val_accuracy: 0.6311
#
# Epoch 00016: val_loss improved from 0.62461 to 0.62444, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 17/300
# 8/8 - 0s - loss: 0.5851 - accuracy: 0.6876 - val_loss: 0.6191 - val_accuracy: 0.6267
#
# Epoch 00017: val_loss improved from 0.62444 to 0.61906, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 18/300
# 8/8 - 0s - loss: 0.5873 - accuracy: 0.6975 - val_loss: 0.6216 - val_accuracy: 0.6356
#
# Epoch 00018: val_loss did not improve from 0.61906
# Epoch 19/300
# 8/8 - 0s - loss: 0.5672 - accuracy: 0.7084 - val_loss: 0.6209 - val_accuracy: 0.6444
#
# Epoch 00019: val_loss did not improve from 0.61906
# Epoch 20/300
# 8/8 - 0s - loss: 0.5656 - accuracy: 0.7064 - val_loss: 0.6273 - val_accuracy: 0.6578
#
# Epoch 00020: val_loss did not improve from 0.61906
# Epoch 21/300
# 8/8 - 0s - loss: 0.5774 - accuracy: 0.6940 - val_loss: 0.6214 - val_accuracy: 0.6400
#
# Epoch 00021: val_loss did not improve from 0.61906
# Epoch 22/300
# 8/8 - 0s - loss: 0.5504 - accuracy: 0.7187 - val_loss: 0.6143 - val_accuracy: 0.6133
#
# Epoch 00022: val_loss improved from 0.61906 to 0.61427, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 23/300
# 8/8 - 0s - loss: 0.5704 - accuracy: 0.6995 - val_loss: 0.6175 - val_accuracy: 0.6133
#
# Epoch 00023: val_loss did not improve from 0.61427
# Epoch 24/300
# 8/8 - 0s - loss: 0.5523 - accuracy: 0.7207 - val_loss: 0.6259 - val_accuracy: 0.6267
#
# Epoch 00024: val_loss did not improve from 0.61427
# Epoch 25/300
# 8/8 - 0s - loss: 0.5442 - accuracy: 0.7222 - val_loss: 0.6140 - val_accuracy: 0.6311
#
# Epoch 00025: val_loss improved from 0.61427 to 0.61403, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 26/300
# 8/8 - 0s - loss: 0.5649 - accuracy: 0.7143 - val_loss: 0.6156 - val_accuracy: 0.6444
#
# Epoch 00026: val_loss did not improve from 0.61403
# Epoch 27/300
# 8/8 - 0s - loss: 0.5529 - accuracy: 0.7153 - val_loss: 0.6109 - val_accuracy: 0.6444
#
# Epoch 00027: val_loss improved from 0.61403 to 0.61093, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 28/300
# 8/8 - 0s - loss: 0.5518 - accuracy: 0.7261 - val_loss: 0.6120 - val_accuracy: 0.6400
#
# Epoch 00028: val_loss did not improve from 0.61093
# Epoch 29/300
# 8/8 - 0s - loss: 0.5531 - accuracy: 0.7148 - val_loss: 0.6466 - val_accuracy: 0.6311
#
# Epoch 00029: val_loss did not improve from 0.61093
# Epoch 30/300
# 8/8 - 0s - loss: 0.5245 - accuracy: 0.7454 - val_loss: 0.6177 - val_accuracy: 0.6533
#
# Epoch 00030: val_loss did not improve from 0.61093
# Epoch 31/300
# 8/8 - 0s - loss: 0.5476 - accuracy: 0.7207 - val_loss: 0.6114 - val_accuracy: 0.6578
#
# Epoch 00031: val_loss did not improve from 0.61093
# Epoch 32/300
# 8/8 - 0s - loss: 0.5295 - accuracy: 0.7331 - val_loss: 0.6085 - val_accuracy: 0.6400
#
# Epoch 00032: val_loss improved from 0.61093 to 0.60848, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 33/300
# 8/8 - 0s - loss: 0.5422 - accuracy: 0.7341 - val_loss: 0.6198 - val_accuracy: 0.6356
#
# Epoch 00033: val_loss did not improve from 0.60848
# Epoch 34/300
# 8/8 - 0s - loss: 0.5126 - accuracy: 0.7563 - val_loss: 0.6082 - val_accuracy: 0.6311
#
# Epoch 00034: val_loss improved from 0.60848 to 0.60818, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 35/300
# 8/8 - 0s - loss: 0.5205 - accuracy: 0.7449 - val_loss: 0.6292 - val_accuracy: 0.6533
#
# Epoch 00035: val_loss did not improve from 0.60818
# Epoch 36/300
# 8/8 - 0s - loss: 0.5266 - accuracy: 0.7385 - val_loss: 0.6183 - val_accuracy: 0.6400
#
# Epoch 00036: val_loss did not improve from 0.60818
# Epoch 37/300
# 8/8 - 0s - loss: 0.5098 - accuracy: 0.7504 - val_loss: 0.6052 - val_accuracy: 0.6444
#
# Epoch 00037: val_loss improved from 0.60818 to 0.60515, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_0.h5
# Epoch 38/300
# 8/8 - 0s - loss: 0.5226 - accuracy: 0.7365 - val_loss: 0.6200 - val_accuracy: 0.6578
#
# Epoch 00038: val_loss did not improve from 0.60515
# Epoch 39/300
# 8/8 - 0s - loss: 0.4950 - accuracy: 0.7598 - val_loss: 0.6208 - val_accuracy: 0.6489
#
# Epoch 00039: val_loss did not improve from 0.60515
# Epoch 40/300
# 8/8 - 0s - loss: 0.5179 - accuracy: 0.7341 - val_loss: 0.6150 - val_accuracy: 0.6622
#
# Epoch 00040: val_loss did not improve from 0.60515
# Epoch 41/300
# 8/8 - 0s - loss: 0.4981 - accuracy: 0.7519 - val_loss: 0.6163 - val_accuracy: 0.6267
#
# Epoch 00041: val_loss did not improve from 0.60515
# Epoch 42/300
# 8/8 - 0s - loss: 0.5040 - accuracy: 0.7568 - val_loss: 0.6134 - val_accuracy: 0.6356
#
# Epoch 00042: val_loss did not improve from 0.60515
# Epoch 43/300
# 8/8 - 0s - loss: 0.5109 - accuracy: 0.7469 - val_loss: 0.6127 - val_accuracy: 0.6489
#
# Epoch 00043: val_loss did not improve from 0.60515
# Epoch 44/300
# 8/8 - 0s - loss: 0.4798 - accuracy: 0.7696 - val_loss: 0.6143 - val_accuracy: 0.6356
#
# Epoch 00044: val_loss did not improve from 0.60515
# Epoch 45/300
# 8/8 - 0s - loss: 0.4977 - accuracy: 0.7662 - val_loss: 0.6398 - val_accuracy: 0.6356
#
# Epoch 00045: val_loss did not improve from 0.60515
# Epoch 46/300
# 8/8 - 0s - loss: 0.4733 - accuracy: 0.7687 - val_loss: 0.6452 - val_accuracy: 0.6489
#
# Epoch 00046: val_loss did not improve from 0.60515
# Epoch 47/300
# 8/8 - 0s - loss: 0.4935 - accuracy: 0.7553 - val_loss: 0.6159 - val_accuracy: 0.6222
#
# Epoch 00047: val_loss did not improve from 0.60515
# Epoch 48/300
# 8/8 - 0s - loss: 0.4905 - accuracy: 0.7504 - val_loss: 0.6132 - val_accuracy: 0.6400
#
# Epoch 00048: val_loss did not improve from 0.60515
# Epoch 49/300
# 8/8 - 0s - loss: 0.4723 - accuracy: 0.7805 - val_loss: 0.6517 - val_accuracy: 0.6356
#
# Epoch 00049: val_loss did not improve from 0.60515
# Epoch 50/300
# 8/8 - 0s - loss: 0.4853 - accuracy: 0.7805 - val_loss: 0.6241 - val_accuracy: 0.6667
#
# Epoch 00050: val_loss did not improve from 0.60515
# Epoch 51/300
# 8/8 - 0s - loss: 0.4532 - accuracy: 0.7904 - val_loss: 0.6157 - val_accuracy: 0.6533
#
# Epoch 00051: val_loss did not improve from 0.60515
# Epoch 52/300
# 8/8 - 0s - loss: 0.4850 - accuracy: 0.7612 - val_loss: 0.6973 - val_accuracy: 0.6178
#
# Epoch 00052: val_loss did not improve from 0.60515
# Epoch 53/300
# 8/8 - 0s - loss: 0.4783 - accuracy: 0.7731 - val_loss: 0.6166 - val_accuracy: 0.6578
#
# Epoch 00053: val_loss did not improve from 0.60515
# Epoch 54/300
# 8/8 - 0s - loss: 0.4680 - accuracy: 0.7736 - val_loss: 0.6295 - val_accuracy: 0.6578
#
# Epoch 00054: val_loss did not improve from 0.60515
# Epoch 55/300
# 8/8 - 0s - loss: 0.4601 - accuracy: 0.7756 - val_loss: 0.6433 - val_accuracy: 0.6400
#
# Epoch 00055: val_loss did not improve from 0.60515
# Epoch 56/300
# 8/8 - 0s - loss: 0.4705 - accuracy: 0.7736 - val_loss: 0.6164 - val_accuracy: 0.6667
#
# Epoch 00056: val_loss did not improve from 0.60515
# Epoch 57/300
# 8/8 - 0s - loss: 0.4451 - accuracy: 0.7954 - val_loss: 0.6210 - val_accuracy: 0.6622
#
# Epoch 00057: val_loss did not improve from 0.60515
# Epoch 58/300
# 8/8 - 0s - loss: 0.4484 - accuracy: 0.7850 - val_loss: 0.6924 - val_accuracy: 0.5956
#
# Epoch 00058: val_loss did not improve from 0.60515
# Epoch 59/300
# 8/8 - 0s - loss: 0.4695 - accuracy: 0.7692 - val_loss: 0.6377 - val_accuracy: 0.6400
#
# Epoch 00059: val_loss did not improve from 0.60515
# Epoch 60/300
# 8/8 - 0s - loss: 0.4299 - accuracy: 0.8082 - val_loss: 0.6341 - val_accuracy: 0.6667
#
# Epoch 00060: val_loss did not improve from 0.60515
# Epoch 61/300
# 8/8 - 0s - loss: 0.4634 - accuracy: 0.7800 - val_loss: 0.6190 - val_accuracy: 0.6533
#
# Epoch 00061: val_loss did not improve from 0.60515
# Epoch 62/300
# 8/8 - 0s - loss: 0.4378 - accuracy: 0.8013 - val_loss: 0.6794 - val_accuracy: 0.6356
#
# Epoch 00062: val_loss did not improve from 0.60515
# Epoch 63/300
# 8/8 - 0s - loss: 0.4205 - accuracy: 0.8122 - val_loss: 0.6333 - val_accuracy: 0.6578
#
# Epoch 00063: val_loss did not improve from 0.60515
# Epoch 64/300
# 8/8 - 0s - loss: 0.4423 - accuracy: 0.7924 - val_loss: 0.6292 - val_accuracy: 0.6622
#
# Epoch 00064: val_loss did not improve from 0.60515
# Epoch 65/300
# 8/8 - 0s - loss: 0.4124 - accuracy: 0.8127 - val_loss: 0.6657 - val_accuracy: 0.6311
#
# Epoch 00065: val_loss did not improve from 0.60515
# Epoch 66/300
# 8/8 - 0s - loss: 0.4238 - accuracy: 0.8043 - val_loss: 0.6571 - val_accuracy: 0.6444
#
# Epoch 00066: val_loss did not improve from 0.60515
# Epoch 67/300
# 8/8 - 0s - loss: 0.4248 - accuracy: 0.8087 - val_loss: 0.6512 - val_accuracy: 0.6444
#
# Epoch 00067: val_loss did not improve from 0.60515
# Epoch 68/300
# 8/8 - 0s - loss: 0.4191 - accuracy: 0.8013 - val_loss: 0.6327 - val_accuracy: 0.6711
#
# Epoch 00068: val_loss did not improve from 0.60515
# Epoch 69/300
# 8/8 - 0s - loss: 0.4461 - accuracy: 0.7963 - val_loss: 0.6336 - val_accuracy: 0.6622
#
# Epoch 00069: val_loss did not improve from 0.60515
# Epoch 70/300
# 8/8 - 0s - loss: 0.4040 - accuracy: 0.8275 - val_loss: 0.7047 - val_accuracy: 0.6133
#
# Epoch 00070: val_loss did not improve from 0.60515
# Epoch 71/300
# 8/8 - 0s - loss: 0.4233 - accuracy: 0.8062 - val_loss: 0.6350 - val_accuracy: 0.6533
#
# Epoch 00071: val_loss did not improve from 0.60515
# Epoch 72/300
# 8/8 - 0s - loss: 0.4099 - accuracy: 0.8102 - val_loss: 0.6463 - val_accuracy: 0.6622
#
# Epoch 00072: val_loss did not improve from 0.60515
# Epoch 73/300
# 8/8 - 0s - loss: 0.3975 - accuracy: 0.8265 - val_loss: 0.6510 - val_accuracy: 0.6622
#
# Epoch 00073: val_loss did not improve from 0.60515
# Epoch 74/300
# 8/8 - 0s - loss: 0.4060 - accuracy: 0.8245 - val_loss: 0.6507 - val_accuracy: 0.6311
#
# Epoch 00074: val_loss did not improve from 0.60515
# Epoch 75/300
# 8/8 - 0s - loss: 0.4174 - accuracy: 0.7973 - val_loss: 0.6429 - val_accuracy: 0.6489
#
# Epoch 00075: val_loss did not improve from 0.60515
# Epoch 76/300
# 8/8 - 0s - loss: 0.3887 - accuracy: 0.8245 - val_loss: 0.6401 - val_accuracy: 0.6533
#
# Epoch 00076: val_loss did not improve from 0.60515
# Epoch 77/300
# 8/8 - 0s - loss: 0.4202 - accuracy: 0.8062 - val_loss: 0.6548 - val_accuracy: 0.6356
#
# Epoch 00077: val_loss did not improve from 0.60515
# Epoch 78/300
# 8/8 - 0s - loss: 0.3757 - accuracy: 0.8344 - val_loss: 0.6763 - val_accuracy: 0.6400
#
# Epoch 00078: val_loss did not improve from 0.60515
# Epoch 79/300
# 8/8 - 0s - loss: 0.3711 - accuracy: 0.8364 - val_loss: 0.6540 - val_accuracy: 0.6533
#
# Epoch 00079: val_loss did not improve from 0.60515
# Epoch 80/300
# 8/8 - 0s - loss: 0.3736 - accuracy: 0.8300 - val_loss: 0.6684 - val_accuracy: 0.6444
#
# Epoch 00080: val_loss did not improve from 0.60515
# Epoch 81/300
# 8/8 - 0s - loss: 0.3574 - accuracy: 0.8418 - val_loss: 0.6556 - val_accuracy: 0.6489
#
# Epoch 00081: val_loss did not improve from 0.60515
# Epoch 82/300
# 8/8 - 0s - loss: 0.3671 - accuracy: 0.8403 - val_loss: 0.6797 - val_accuracy: 0.6311
#
# Epoch 00082: val_loss did not improve from 0.60515
# Epoch 83/300
# 8/8 - 0s - loss: 0.3631 - accuracy: 0.8443 - val_loss: 0.6432 - val_accuracy: 0.6711
#
# Epoch 00083: val_loss did not improve from 0.60515
# Epoch 84/300
# 8/8 - 0s - loss: 0.3307 - accuracy: 0.8596 - val_loss: 0.6720 - val_accuracy: 0.6444
#
# Epoch 00084: val_loss did not improve from 0.60515
# Epoch 85/300
# 8/8 - 0s - loss: 0.3975 - accuracy: 0.8250 - val_loss: 0.6462 - val_accuracy: 0.6578
#
# Epoch 00085: val_loss did not improve from 0.60515
# Epoch 86/300
# 8/8 - 0s - loss: 0.3496 - accuracy: 0.8492 - val_loss: 0.6569 - val_accuracy: 0.6444
#
# Epoch 00086: val_loss did not improve from 0.60515
# Epoch 87/300
# 8/8 - 0s - loss: 0.3718 - accuracy: 0.8295 - val_loss: 0.6629 - val_accuracy: 0.6578
#
# Epoch 00087: val_loss did not improve from 0.60515
# 1
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# =================================================================
# Total params: 199,680
# Trainable params: 199,680
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Functional)         (None, 5, 128)            199680
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 64)             0
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 1s - loss: 0.6822 - accuracy: 0.5556 - val_loss: 0.6597 - val_accuracy: 0.6844
#
# Epoch 00001: val_loss improved from inf to 0.65971, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.6506 - accuracy: 0.6159 - val_loss: 0.6499 - val_accuracy: 0.6133
#
# Epoch 00002: val_loss improved from 0.65971 to 0.64987, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 3/300
# 8/8 - 0s - loss: 0.6494 - accuracy: 0.6209 - val_loss: 0.6162 - val_accuracy: 0.7156
#
# Epoch 00003: val_loss improved from 0.64987 to 0.61619, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 4/300
# 8/8 - 0s - loss: 0.6463 - accuracy: 0.6322 - val_loss: 0.6219 - val_accuracy: 0.7244
#
# Epoch 00004: val_loss did not improve from 0.61619
# Epoch 5/300
# 8/8 - 0s - loss: 0.6209 - accuracy: 0.6594 - val_loss: 0.5939 - val_accuracy: 0.7244
#
# Epoch 00005: val_loss improved from 0.61619 to 0.59390, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 6/300
# 8/8 - 0s - loss: 0.6287 - accuracy: 0.6431 - val_loss: 0.6014 - val_accuracy: 0.7111
#
# Epoch 00006: val_loss did not improve from 0.59390
# Epoch 7/300
# 8/8 - 0s - loss: 0.6201 - accuracy: 0.6540 - val_loss: 0.5982 - val_accuracy: 0.7111
#
# Epoch 00007: val_loss did not improve from 0.59390
# Epoch 8/300
# 8/8 - 0s - loss: 0.6182 - accuracy: 0.6579 - val_loss: 0.5952 - val_accuracy: 0.7200
#
# Epoch 00008: val_loss did not improve from 0.59390
# Epoch 9/300
# 8/8 - 0s - loss: 0.6062 - accuracy: 0.6668 - val_loss: 0.5802 - val_accuracy: 0.7067
#
# Epoch 00009: val_loss improved from 0.59390 to 0.58021, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 10/300
# 8/8 - 0s - loss: 0.6138 - accuracy: 0.6614 - val_loss: 0.5891 - val_accuracy: 0.7111
#
# Epoch 00010: val_loss did not improve from 0.58021
# Epoch 11/300
# 8/8 - 0s - loss: 0.6008 - accuracy: 0.6584 - val_loss: 0.5938 - val_accuracy: 0.7289
#
# Epoch 00011: val_loss did not improve from 0.58021
# Epoch 12/300
# 8/8 - 0s - loss: 0.5972 - accuracy: 0.6663 - val_loss: 0.5797 - val_accuracy: 0.7111
#
# Epoch 00012: val_loss improved from 0.58021 to 0.57974, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 13/300
# 8/8 - 0s - loss: 0.5979 - accuracy: 0.6757 - val_loss: 0.5858 - val_accuracy: 0.7244
#
# Epoch 00013: val_loss did not improve from 0.57974
# Epoch 14/300
# 8/8 - 0s - loss: 0.5872 - accuracy: 0.6797 - val_loss: 0.5850 - val_accuracy: 0.7200
#
# Epoch 00014: val_loss did not improve from 0.57974
# Epoch 15/300
# 8/8 - 0s - loss: 0.5912 - accuracy: 0.6738 - val_loss: 0.5813 - val_accuracy: 0.7244
#
# Epoch 00015: val_loss did not improve from 0.57974
# Epoch 16/300
# 8/8 - 0s - loss: 0.5831 - accuracy: 0.6891 - val_loss: 0.5889 - val_accuracy: 0.7467
#
# Epoch 00016: val_loss did not improve from 0.57974
# Epoch 17/300
# 8/8 - 0s - loss: 0.5868 - accuracy: 0.6861 - val_loss: 0.5929 - val_accuracy: 0.6800
#
# Epoch 00017: val_loss did not improve from 0.57974
# Epoch 18/300
# 8/8 - 0s - loss: 0.5749 - accuracy: 0.7079 - val_loss: 0.5979 - val_accuracy: 0.6356
#
# Epoch 00018: val_loss did not improve from 0.57974
# Epoch 19/300
# 8/8 - 0s - loss: 0.5783 - accuracy: 0.7000 - val_loss: 0.5806 - val_accuracy: 0.7289
#
# Epoch 00019: val_loss did not improve from 0.57974
# Epoch 20/300
# 8/8 - 0s - loss: 0.5715 - accuracy: 0.6980 - val_loss: 0.5796 - val_accuracy: 0.7378
#
# Epoch 00020: val_loss improved from 0.57974 to 0.57964, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 21/300
# 8/8 - 0s - loss: 0.5635 - accuracy: 0.7034 - val_loss: 0.5679 - val_accuracy: 0.7289
#
# Epoch 00021: val_loss improved from 0.57964 to 0.56789, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 22/300
# 8/8 - 0s - loss: 0.5792 - accuracy: 0.6911 - val_loss: 0.5801 - val_accuracy: 0.7422
#
# Epoch 00022: val_loss did not improve from 0.56789
# Epoch 23/300
# 8/8 - 0s - loss: 0.5528 - accuracy: 0.7014 - val_loss: 0.5751 - val_accuracy: 0.6933
#
# Epoch 00023: val_loss did not improve from 0.56789
# Epoch 24/300
# 8/8 - 0s - loss: 0.5728 - accuracy: 0.6920 - val_loss: 0.5612 - val_accuracy: 0.7467
#
# Epoch 00024: val_loss improved from 0.56789 to 0.56122, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 25/300
# 8/8 - 0s - loss: 0.5584 - accuracy: 0.7069 - val_loss: 0.5703 - val_accuracy: 0.7067
#
# Epoch 00025: val_loss did not improve from 0.56122
# Epoch 26/300
# 8/8 - 0s - loss: 0.5665 - accuracy: 0.7014 - val_loss: 0.5725 - val_accuracy: 0.7244
#
# Epoch 00026: val_loss did not improve from 0.56122
# Epoch 27/300
# 8/8 - 0s - loss: 0.5531 - accuracy: 0.7143 - val_loss: 0.5978 - val_accuracy: 0.7067
#
# Epoch 00027: val_loss did not improve from 0.56122
# Epoch 28/300
# 8/8 - 0s - loss: 0.5541 - accuracy: 0.7069 - val_loss: 0.5779 - val_accuracy: 0.7200
#
# Epoch 00028: val_loss did not improve from 0.56122
# Epoch 29/300
# 8/8 - 0s - loss: 0.5409 - accuracy: 0.7177 - val_loss: 0.5702 - val_accuracy: 0.7067
#
# Epoch 00029: val_loss did not improve from 0.56122
# Epoch 30/300
# 8/8 - 0s - loss: 0.5483 - accuracy: 0.7163 - val_loss: 0.5967 - val_accuracy: 0.6800
#
# Epoch 00030: val_loss did not improve from 0.56122
# Epoch 31/300
# 8/8 - 0s - loss: 0.5640 - accuracy: 0.7123 - val_loss: 0.6027 - val_accuracy: 0.6756
#
# Epoch 00031: val_loss did not improve from 0.56122
# Epoch 32/300
# 8/8 - 0s - loss: 0.5460 - accuracy: 0.7197 - val_loss: 0.5775 - val_accuracy: 0.7111
#
# Epoch 00032: val_loss did not improve from 0.56122
# Epoch 33/300
# 8/8 - 0s - loss: 0.5405 - accuracy: 0.7227 - val_loss: 0.6114 - val_accuracy: 0.6756
#
# Epoch 00033: val_loss did not improve from 0.56122
# Epoch 34/300
# 8/8 - 0s - loss: 0.5336 - accuracy: 0.7237 - val_loss: 0.5612 - val_accuracy: 0.7200
#
# Epoch 00034: val_loss did not improve from 0.56122
# Epoch 35/300
# 8/8 - 0s - loss: 0.5163 - accuracy: 0.7464 - val_loss: 0.5591 - val_accuracy: 0.7200
#
# Epoch 00035: val_loss improved from 0.56122 to 0.55907, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 36/300
# 8/8 - 0s - loss: 0.5315 - accuracy: 0.7306 - val_loss: 0.5629 - val_accuracy: 0.7244
#
# Epoch 00036: val_loss did not improve from 0.55907
# Epoch 37/300
# 8/8 - 0s - loss: 0.5116 - accuracy: 0.7583 - val_loss: 0.5654 - val_accuracy: 0.7156
#
# Epoch 00037: val_loss did not improve from 0.55907
# Epoch 38/300
# 8/8 - 0s - loss: 0.5052 - accuracy: 0.7558 - val_loss: 0.5846 - val_accuracy: 0.6933
#
# Epoch 00038: val_loss did not improve from 0.55907
# Epoch 39/300
# 8/8 - 0s - loss: 0.5316 - accuracy: 0.7395 - val_loss: 0.5670 - val_accuracy: 0.7200
#
# Epoch 00039: val_loss did not improve from 0.55907
# Epoch 40/300
# 8/8 - 0s - loss: 0.5261 - accuracy: 0.7375 - val_loss: 0.5670 - val_accuracy: 0.7244
#
# Epoch 00040: val_loss did not improve from 0.55907
# Epoch 41/300
# 8/8 - 0s - loss: 0.5260 - accuracy: 0.7341 - val_loss: 0.5815 - val_accuracy: 0.7111
#
# Epoch 00041: val_loss did not improve from 0.55907
# Epoch 42/300
# 8/8 - 0s - loss: 0.5133 - accuracy: 0.7519 - val_loss: 0.5701 - val_accuracy: 0.7022
#
# Epoch 00042: val_loss did not improve from 0.55907
# Epoch 43/300
# 8/8 - 0s - loss: 0.5082 - accuracy: 0.7523 - val_loss: 0.5751 - val_accuracy: 0.6844
#
# Epoch 00043: val_loss did not improve from 0.55907
# Epoch 44/300
# 8/8 - 0s - loss: 0.5125 - accuracy: 0.7454 - val_loss: 0.5851 - val_accuracy: 0.6978
#
# Epoch 00044: val_loss did not improve from 0.55907
# Epoch 45/300
# 8/8 - 0s - loss: 0.5001 - accuracy: 0.7593 - val_loss: 0.5636 - val_accuracy: 0.7467
#
# Epoch 00045: val_loss did not improve from 0.55907
# Epoch 46/300
# 8/8 - 0s - loss: 0.4957 - accuracy: 0.7523 - val_loss: 0.5609 - val_accuracy: 0.7333
#
# Epoch 00046: val_loss did not improve from 0.55907
# Epoch 47/300
# 8/8 - 0s - loss: 0.4960 - accuracy: 0.7533 - val_loss: 0.5596 - val_accuracy: 0.7200
#
# Epoch 00047: val_loss did not improve from 0.55907
# Epoch 48/300
# 8/8 - 0s - loss: 0.4675 - accuracy: 0.7672 - val_loss: 0.5585 - val_accuracy: 0.7289
#
# Epoch 00048: val_loss improved from 0.55907 to 0.55851, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 49/300
# 8/8 - 0s - loss: 0.5046 - accuracy: 0.7474 - val_loss: 0.5586 - val_accuracy: 0.7111
#
# Epoch 00049: val_loss did not improve from 0.55851
# Epoch 50/300
# 8/8 - 0s - loss: 0.4866 - accuracy: 0.7612 - val_loss: 0.5592 - val_accuracy: 0.7067
#
# Epoch 00050: val_loss did not improve from 0.55851
# Epoch 51/300
# 8/8 - 0s - loss: 0.4961 - accuracy: 0.7504 - val_loss: 0.5612 - val_accuracy: 0.7378
#
# Epoch 00051: val_loss did not improve from 0.55851
# Epoch 52/300
# 8/8 - 0s - loss: 0.4758 - accuracy: 0.7721 - val_loss: 0.5924 - val_accuracy: 0.6622
#
# Epoch 00052: val_loss did not improve from 0.55851
# Epoch 53/300
# 8/8 - 0s - loss: 0.4898 - accuracy: 0.7652 - val_loss: 0.5665 - val_accuracy: 0.7067
#
# Epoch 00053: val_loss did not improve from 0.55851
# Epoch 54/300
# 8/8 - 0s - loss: 0.4710 - accuracy: 0.7835 - val_loss: 0.5863 - val_accuracy: 0.7022
#
# Epoch 00054: val_loss did not improve from 0.55851
# Epoch 55/300
# 8/8 - 0s - loss: 0.4865 - accuracy: 0.7716 - val_loss: 0.5525 - val_accuracy: 0.7244
#
# Epoch 00055: val_loss improved from 0.55851 to 0.55248, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_1.h5
# Epoch 56/300
# 8/8 - 0s - loss: 0.4666 - accuracy: 0.7800 - val_loss: 0.5863 - val_accuracy: 0.6933
#
# Epoch 00056: val_loss did not improve from 0.55248
# Epoch 57/300
# 8/8 - 0s - loss: 0.4695 - accuracy: 0.7741 - val_loss: 0.5695 - val_accuracy: 0.7022
#
# Epoch 00057: val_loss did not improve from 0.55248
# Epoch 58/300
# 8/8 - 0s - loss: 0.4771 - accuracy: 0.7830 - val_loss: 0.5678 - val_accuracy: 0.7022
#
# Epoch 00058: val_loss did not improve from 0.55248
# Epoch 59/300
# 8/8 - 0s - loss: 0.4522 - accuracy: 0.7855 - val_loss: 0.5544 - val_accuracy: 0.7333
#
# Epoch 00059: val_loss did not improve from 0.55248
# Epoch 60/300
# 8/8 - 0s - loss: 0.4672 - accuracy: 0.7672 - val_loss: 0.5638 - val_accuracy: 0.7156
#
# Epoch 00060: val_loss did not improve from 0.55248
# Epoch 61/300
# 8/8 - 0s - loss: 0.4686 - accuracy: 0.7736 - val_loss: 0.5567 - val_accuracy: 0.7200
#
# Epoch 00061: val_loss did not improve from 0.55248
# Epoch 62/300
# 8/8 - 0s - loss: 0.4393 - accuracy: 0.7954 - val_loss: 0.5633 - val_accuracy: 0.7289
#
# Epoch 00062: val_loss did not improve from 0.55248
# Epoch 63/300
# 8/8 - 0s - loss: 0.4420 - accuracy: 0.7909 - val_loss: 0.5721 - val_accuracy: 0.6889
#
# Epoch 00063: val_loss did not improve from 0.55248
# Epoch 64/300
# 8/8 - 0s - loss: 0.4602 - accuracy: 0.7815 - val_loss: 0.5742 - val_accuracy: 0.7022
#
# Epoch 00064: val_loss did not improve from 0.55248
# Epoch 65/300
# 8/8 - 0s - loss: 0.4477 - accuracy: 0.7934 - val_loss: 0.5752 - val_accuracy: 0.7111
#
# Epoch 00065: val_loss did not improve from 0.55248
# Epoch 66/300
# 8/8 - 0s - loss: 0.4338 - accuracy: 0.7899 - val_loss: 0.5804 - val_accuracy: 0.6844
#
# Epoch 00066: val_loss did not improve from 0.55248
# Epoch 67/300
# 8/8 - 0s - loss: 0.4346 - accuracy: 0.7934 - val_loss: 0.5921 - val_accuracy: 0.6889
#
# Epoch 00067: val_loss did not improve from 0.55248
# Epoch 68/300
# 8/8 - 0s - loss: 0.4274 - accuracy: 0.8067 - val_loss: 0.5647 - val_accuracy: 0.7200
#
# Epoch 00068: val_loss did not improve from 0.55248
# Epoch 69/300
# 8/8 - 0s - loss: 0.4443 - accuracy: 0.7939 - val_loss: 0.5664 - val_accuracy: 0.7111
#
# Epoch 00069: val_loss did not improve from 0.55248
# Epoch 70/300
# 8/8 - 0s - loss: 0.4014 - accuracy: 0.8171 - val_loss: 0.6189 - val_accuracy: 0.6622
#
# Epoch 00070: val_loss did not improve from 0.55248
# Epoch 71/300
# 8/8 - 0s - loss: 0.4414 - accuracy: 0.7958 - val_loss: 0.5620 - val_accuracy: 0.7156
# Epoch 00071: val_loss did not improve from 0.55248
# Epoch 72/300
# 8/8 - 0s - loss: 0.4186 - accuracy: 0.7988 - val_loss: 0.5731 - val_accuracy: 0.6889
#
# Epoch 00072: val_loss did not improve from 0.55248
# Epoch 73/300
# 8/8 - 0s - loss: 0.4309 - accuracy: 0.7963 - val_loss: 0.5714 - val_accuracy: 0.6978
#
# Epoch 00073: val_loss did not improve from 0.55248
# Epoch 74/300
# 8/8 - 0s - loss: 0.4010 - accuracy: 0.8146 - val_loss: 0.5611 - val_accuracy: 0.6933
#
# Epoch 00074: val_loss did not improve from 0.55248
# Epoch 75/300
# 8/8 - 0s - loss: 0.3959 - accuracy: 0.8344 - val_loss: 0.6634 - val_accuracy: 0.6622
#
# Epoch 00075: val_loss did not improve from 0.55248
# Epoch 76/300
# 8/8 - 0s - loss: 0.4063 - accuracy: 0.8092 - val_loss: 0.5912 - val_accuracy: 0.6933
#
# Epoch 00076: val_loss did not improve from 0.55248
# Epoch 77/300
# 8/8 - 0s - loss: 0.4051 - accuracy: 0.8122 - val_loss: 0.6128 - val_accuracy: 0.6667
#
# Epoch 00077: val_loss did not improve from 0.55248
# Epoch 78/300
# 8/8 - 0s - loss: 0.3991 - accuracy: 0.8161 - val_loss: 0.5804 - val_accuracy: 0.7022
#
# Epoch 00078: val_loss did not improve from 0.55248
# Epoch 79/300
# 8/8 - 0s - loss: 0.4136 - accuracy: 0.8062 - val_loss: 0.5705 - val_accuracy: 0.7022
#
# Epoch 00079: val_loss did not improve from 0.55248
# Epoch 80/300
# 8/8 - 0s - loss: 0.4069 - accuracy: 0.8156 - val_loss: 0.5954 - val_accuracy: 0.6844
#
# Epoch 00080: val_loss did not improve from 0.55248
# Epoch 81/300
# 8/8 - 0s - loss: 0.4058 - accuracy: 0.8151 - val_loss: 0.5770 - val_accuracy: 0.6800
#
# Epoch 00081: val_loss did not improve from 0.55248
# Epoch 82/300
# 8/8 - 0s - loss: 0.4282 - accuracy: 0.8028 - val_loss: 0.5914 - val_accuracy: 0.6578
#
# Epoch 00082: val_loss did not improve from 0.55248
# Epoch 83/300
# 8/8 - 0s - loss: 0.3732 - accuracy: 0.8428 - val_loss: 0.5907 - val_accuracy: 0.6800
#
# Epoch 00083: val_loss did not improve from 0.55248
# Epoch 84/300
# 8/8 - 0s - loss: 0.3991 - accuracy: 0.8176 - val_loss: 0.5728 - val_accuracy: 0.6889
#
# Epoch 00084: val_loss did not improve from 0.55248
# Epoch 85/300
# 8/8 - 0s - loss: 0.3837 - accuracy: 0.8349 - val_loss: 0.5784 - val_accuracy: 0.6756
#
# Epoch 00085: val_loss did not improve from 0.55248
# Epoch 86/300
# 8/8 - 0s - loss: 0.3853 - accuracy: 0.8280 - val_loss: 0.5769 - val_accuracy: 0.7111
#
# Epoch 00086: val_loss did not improve from 0.55248
# Epoch 87/300
# 8/8 - 0s - loss: 0.3880 - accuracy: 0.8260 - val_loss: 0.5820 - val_accuracy: 0.6978
#
# Epoch 00087: val_loss did not improve from 0.55248
# Epoch 88/300
# 8/8 - 0s - loss: 0.3785 - accuracy: 0.8364 - val_loss: 0.6006 - val_accuracy: 0.6667
#
# Epoch 00088: val_loss did not improve from 0.55248
# Epoch 89/300
# 8/8 - 0s - loss: 0.3522 - accuracy: 0.8433 - val_loss: 0.5754 - val_accuracy: 0.6933
#
# Epoch 00089: val_loss did not improve from 0.55248
# Epoch 90/300
# 8/8 - 0s - loss: 0.3510 - accuracy: 0.8497 - val_loss: 0.5897 - val_accuracy: 0.6933
#
# Epoch 00090: val_loss did not improve from 0.55248
# Epoch 91/300
# 8/8 - 0s - loss: 0.3586 - accuracy: 0.8487 - val_loss: 0.5869 - val_accuracy: 0.7067
#
# Epoch 00091: val_loss did not improve from 0.55248
# Epoch 92/300
# 8/8 - 0s - loss: 0.3820 - accuracy: 0.8230 - val_loss: 0.6031 - val_accuracy: 0.6578
#
# Epoch 00092: val_loss did not improve from 0.55248
# Epoch 93/300
# 8/8 - 0s - loss: 0.3527 - accuracy: 0.8473 - val_loss: 0.6049 - val_accuracy: 0.6800
#
# Epoch 00093: val_loss did not improve from 0.55248
# Epoch 94/300
# 8/8 - 0s - loss: 0.3613 - accuracy: 0.8275 - val_loss: 0.5863 - val_accuracy: 0.6933
#
# Epoch 00094: val_loss did not improve from 0.55248
# Epoch 95/300
# 8/8 - 0s - loss: 0.3563 - accuracy: 0.8423 - val_loss: 0.6348 - val_accuracy: 0.6489
#
# Epoch 00095: val_loss did not improve from 0.55248
# Epoch 96/300
# 8/8 - 0s - loss: 0.3730 - accuracy: 0.8285 - val_loss: 0.5840 - val_accuracy: 0.6756
#
# Epoch 00096: val_loss did not improve from 0.55248
# Epoch 97/300
# 8/8 - 0s - loss: 0.3258 - accuracy: 0.8626 - val_loss: 0.5806 - val_accuracy: 0.7111
#
# Epoch 00097: val_loss did not improve from 0.55248
# Epoch 98/300
# 8/8 - 0s - loss: 0.3552 - accuracy: 0.8433 - val_loss: 0.5906 - val_accuracy: 0.7067
#
# Epoch 00098: val_loss did not improve from 0.55248
# Epoch 99/300
# 8/8 - 0s - loss: 0.3128 - accuracy: 0.8670 - val_loss: 0.5955 - val_accuracy: 0.6756
#
# Epoch 00099: val_loss did not improve from 0.55248
# Epoch 100/300
# 8/8 - 0s - loss: 0.3995 - accuracy: 0.8171 - val_loss: 0.5854 - val_accuracy: 0.6756
#
# Epoch 00100: val_loss did not improve from 0.55248
# Epoch 101/300
# 8/8 - 0s - loss: 0.3239 - accuracy: 0.8562 - val_loss: 0.5901 - val_accuracy: 0.6844
#
# Epoch 00101: val_loss did not improve from 0.55248
# Epoch 102/300
# 8/8 - 0s - loss: 0.3530 - accuracy: 0.8398 - val_loss: 0.6074 - val_accuracy: 0.6578
#
# Epoch 00102: val_loss did not improve from 0.55248
# Epoch 103/300
# 8/8 - 0s - loss: 0.3138 - accuracy: 0.8700 - val_loss: 0.6215 - val_accuracy: 0.6756
#
# Epoch 00103: val_loss did not improve from 0.55248
# Epoch 104/300
# 8/8 - 0s - loss: 0.3580 - accuracy: 0.8389 - val_loss: 0.5816 - val_accuracy: 0.7067
#
# Epoch 00104: val_loss did not improve from 0.55248
# Epoch 105/300
# 8/8 - 0s - loss: 0.2984 - accuracy: 0.8720 - val_loss: 0.5922 - val_accuracy: 0.6844
#
# Epoch 00105: val_loss did not improve from 0.55248
# 2
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_input (InputLayer)    [(None, 41, 21)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# =================================================================
# Total params: 199,680
# Trainable params: 199,680
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_2 (Functional)         (None, 5, 128)            199680
# _________________________________________________________________
# dense_4 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 64)             0
# _________________________________________________________________
# global_average_pooling1d_2 ( (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 8/8 - 1s - loss: 0.6852 - accuracy: 0.5531 - val_loss: 0.6656 - val_accuracy: 0.5822
#
# Epoch 00001: val_loss improved from inf to 0.66562, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 2/300
# 8/8 - 0s - loss: 0.6481 - accuracy: 0.6273 - val_loss: 0.6252 - val_accuracy: 0.6889
# Epoch 00002: val_loss improved from 0.66562 to 0.62520, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 3/300
# 8/8 - 0s - loss: 0.6510 - accuracy: 0.6174 - val_loss: 0.6272 - val_accuracy: 0.6711
#
# Epoch 00003: val_loss did not improve from 0.62520
# Epoch 4/300
# 8/8 - 0s - loss: 0.6304 - accuracy: 0.6411 - val_loss: 0.6163 - val_accuracy: 0.6933
#
# Epoch 00004: val_loss improved from 0.62520 to 0.61630, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 5/300
# 8/8 - 0s - loss: 0.6246 - accuracy: 0.6490 - val_loss: 0.6152 - val_accuracy: 0.6711
#
# Epoch 00005: val_loss improved from 0.61630 to 0.61523, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 6/300
# 8/8 - 0s - loss: 0.6288 - accuracy: 0.6456 - val_loss: 0.6131 - val_accuracy: 0.6844
#
# Epoch 00006: val_loss improved from 0.61523 to 0.61311, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 7/300
# 8/8 - 0s - loss: 0.6124 - accuracy: 0.6658 - val_loss: 0.6024 - val_accuracy: 0.6889
#
# Epoch 00007: val_loss improved from 0.61311 to 0.60242, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 8/300
# 8/8 - 0s - loss: 0.6184 - accuracy: 0.6698 - val_loss: 0.6128 - val_accuracy: 0.7111
#
# Epoch 00008: val_loss did not improve from 0.60242
# Epoch 9/300
# 8/8 - 0s - loss: 0.6079 - accuracy: 0.6644 - val_loss: 0.5994 - val_accuracy: 0.6889
#
# Epoch 00009: val_loss improved from 0.60242 to 0.59942, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 10/300
# 8/8 - 0s - loss: 0.5850 - accuracy: 0.6881 - val_loss: 0.5956 - val_accuracy: 0.7022
#
# Epoch 00010: val_loss improved from 0.59942 to 0.59563, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 11/300
# 8/8 - 0s - loss: 0.5922 - accuracy: 0.6822 - val_loss: 0.5905 - val_accuracy: 0.6978
#
# Epoch 00011: val_loss improved from 0.59563 to 0.59051, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 12/300
# 8/8 - 0s - loss: 0.5958 - accuracy: 0.6807 - val_loss: 0.5914 - val_accuracy: 0.6933
#
# Epoch 00012: val_loss did not improve from 0.59051
# Epoch 13/300
# 8/8 - 0s - loss: 0.6087 - accuracy: 0.6594 - val_loss: 0.6057 - val_accuracy: 0.6844
#
# Epoch 00013: val_loss did not improve from 0.59051
# Epoch 14/300
# 8/8 - 0s - loss: 0.5845 - accuracy: 0.6881 - val_loss: 0.5787 - val_accuracy: 0.6889
#
# Epoch 00014: val_loss improved from 0.59051 to 0.57872, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 15/300
# 8/8 - 0s - loss: 0.5832 - accuracy: 0.6841 - val_loss: 0.5771 - val_accuracy: 0.6800
#
# Epoch 00015: val_loss improved from 0.57872 to 0.57707, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 16/300
# 8/8 - 0s - loss: 0.5947 - accuracy: 0.6728 - val_loss: 0.5934 - val_accuracy: 0.6978
#
# Epoch 00016: val_loss did not improve from 0.57707
# Epoch 17/300
# 8/8 - 0s - loss: 0.5782 - accuracy: 0.6920 - val_loss: 0.6002 - val_accuracy: 0.6889
#
# Epoch 00017: val_loss did not improve from 0.57707
# Epoch 18/300
# 8/8 - 0s - loss: 0.5802 - accuracy: 0.7000 - val_loss: 0.5845 - val_accuracy: 0.6844
#
# Epoch 00018: val_loss did not improve from 0.57707
# Epoch 19/300
# 8/8 - 0s - loss: 0.5844 - accuracy: 0.6836 - val_loss: 0.5943 - val_accuracy: 0.6711
#
# Epoch 00019: val_loss did not improve from 0.57707
# Epoch 20/300
# 8/8 - 0s - loss: 0.5644 - accuracy: 0.6970 - val_loss: 0.5966 - val_accuracy: 0.6889
#
# Epoch 00020: val_loss did not improve from 0.57707
# Epoch 21/300
# 8/8 - 0s - loss: 0.5605 - accuracy: 0.7019 - val_loss: 0.5884 - val_accuracy: 0.6933
#
# Epoch 00021: val_loss did not improve from 0.57707
# Epoch 22/300
# 8/8 - 0s - loss: 0.5730 - accuracy: 0.6896 - val_loss: 0.5993 - val_accuracy: 0.6756
#
# Epoch 00022: val_loss did not improve from 0.57707
# Epoch 23/300
# 8/8 - 0s - loss: 0.5626 - accuracy: 0.7054 - val_loss: 0.5995 - val_accuracy: 0.6844
#
# Epoch 00023: val_loss did not improve from 0.57707
# Epoch 24/300
# 8/8 - 0s - loss: 0.5644 - accuracy: 0.7158 - val_loss: 0.5759 - val_accuracy: 0.6933
#
# Epoch 00024: val_loss improved from 0.57707 to 0.57594, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 25/300
# 8/8 - 0s - loss: 0.5500 - accuracy: 0.7158 - val_loss: 0.5958 - val_accuracy: 0.6844
#
# Epoch 00025: val_loss did not improve from 0.57594
# Epoch 26/300
# 8/8 - 0s - loss: 0.5596 - accuracy: 0.6980 - val_loss: 0.5908 - val_accuracy: 0.6933
#
# Epoch 00026: val_loss did not improve from 0.57594
# Epoch 27/300
# 8/8 - 0s - loss: 0.5384 - accuracy: 0.7192 - val_loss: 0.5902 - val_accuracy: 0.6756
#
# Epoch 00027: val_loss did not improve from 0.57594
# Epoch 28/300
# 8/8 - 0s - loss: 0.5529 - accuracy: 0.7232 - val_loss: 0.6099 - val_accuracy: 0.6667
#
# Epoch 00028: val_loss did not improve from 0.57594
# Epoch 29/300
# 8/8 - 0s - loss: 0.5411 - accuracy: 0.7266 - val_loss: 0.5864 - val_accuracy: 0.6756
#
# Epoch 00029: val_loss did not improve from 0.57594
# Epoch 30/300
# 8/8 - 0s - loss: 0.5413 - accuracy: 0.7266 - val_loss: 0.6136 - val_accuracy: 0.6356
#
# Epoch 00030: val_loss did not improve from 0.57594
# Epoch 31/300
# 8/8 - 0s - loss: 0.5491 - accuracy: 0.7133 - val_loss: 0.5821 - val_accuracy: 0.7067
#
# Epoch 00031: val_loss did not improve from 0.57594
# Epoch 32/300
# 8/8 - 0s - loss: 0.5395 - accuracy: 0.7271 - val_loss: 0.5910 - val_accuracy: 0.6933
#
# Epoch 00032: val_loss did not improve from 0.57594
# Epoch 33/300
# 8/8 - 0s - loss: 0.5274 - accuracy: 0.7449 - val_loss: 0.5837 - val_accuracy: 0.7022
#
# Epoch 00033: val_loss did not improve from 0.57594
# Epoch 34/300
# 8/8 - 0s - loss: 0.5242 - accuracy: 0.7355 - val_loss: 0.5753 - val_accuracy: 0.6889
#
# Epoch 00034: val_loss improved from 0.57594 to 0.57529, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_2.h5
# Epoch 35/300
# 8/8 - 0s - loss: 0.5358 - accuracy: 0.7261 - val_loss: 0.6041 - val_accuracy: 0.6622
#
# Epoch 00035: val_loss did not improve from 0.57529
# Epoch 36/300
# 8/8 - 0s - loss: 0.5266 - accuracy: 0.7326 - val_loss: 0.5784 - val_accuracy: 0.6756
#
# ...
# Epoch 6/300
# 8/8 - 0s - loss: 0.6204 - accuracy: 0.6591 - val_loss: 0.6376 - val_accuracy: 0.6161
#
# Epoch 00006: val_loss did not improve from 0.61797
# Epoch 7/300
# 8/8 - 0s - loss: 0.6229 - accuracy: 0.6576 - val_loss: 0.6154 - val_accuracy: 0.6696
#
# Epoch 00007: val_loss improved from 0.61797 to 0.61544, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 8/300
# 8/8 - 0s - loss: 0.6197 - accuracy: 0.6532 - val_loss: 0.6125 - val_accuracy: 0.6786
#
# Epoch 00008: val_loss improved from 0.61544 to 0.61254, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 9/300
# 8/8 - 0s - loss: 0.6058 - accuracy: 0.6714 - val_loss: 0.6097 - val_accuracy: 0.6696
#
# Epoch 00009: val_loss improved from 0.61254 to 0.60970, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 10/300
# 8/8 - 0s - loss: 0.6095 - accuracy: 0.6714 - val_loss: 0.6032 - val_accuracy: 0.6607
#
# Epoch 00010: val_loss improved from 0.60970 to 0.60319, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 11/300
# 8/8 - 0s - loss: 0.5954 - accuracy: 0.6793 - val_loss: 0.6058 - val_accuracy: 0.6786
#
# Epoch 00011: val_loss did not improve from 0.60319
# Epoch 12/300
# 8/8 - 0s - loss: 0.6027 - accuracy: 0.6660 - val_loss: 0.6157 - val_accuracy: 0.6473
#
# Epoch 00012: val_loss did not improve from 0.60319
# Epoch 13/300
# 8/8 - 0s - loss: 0.6014 - accuracy: 0.6724 - val_loss: 0.6101 - val_accuracy: 0.6652
#
# Epoch 00013: val_loss did not improve from 0.60319
# Epoch 14/300
# 8/8 - 0s - loss: 0.5973 - accuracy: 0.6729 - val_loss: 0.6029 - val_accuracy: 0.6875
#
# Epoch 00014: val_loss improved from 0.60319 to 0.60294, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 15/300
# 8/8 - 0s - loss: 0.5912 - accuracy: 0.6724 - val_loss: 0.6050 - val_accuracy: 0.6875
#
# Epoch 00015: val_loss did not improve from 0.60294
# Epoch 16/300
# 8/8 - 0s - loss: 0.5868 - accuracy: 0.6947 - val_loss: 0.5927 - val_accuracy: 0.6786
#
# Epoch 00016: val_loss improved from 0.60294 to 0.59266, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 17/300
# 8/8 - 0s - loss: 0.5728 - accuracy: 0.7115 - val_loss: 0.6440 - val_accuracy: 0.6384
#
# Epoch 00017: val_loss did not improve from 0.59266
# Epoch 18/300
# 8/8 - 0s - loss: 0.5836 - accuracy: 0.6902 - val_loss: 0.5940 - val_accuracy: 0.6830
#
# Epoch 00018: val_loss did not improve from 0.59266
# Epoch 19/300
# 8/8 - 0s - loss: 0.5845 - accuracy: 0.6882 - val_loss: 0.5940 - val_accuracy: 0.6786
#
# Epoch 00019: val_loss did not improve from 0.59266
# Epoch 20/300
# 8/8 - 0s - loss: 0.5680 - accuracy: 0.6981 - val_loss: 0.5888 - val_accuracy: 0.6964
#
# Epoch 00020: val_loss improved from 0.59266 to 0.58878, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 21/300
# 8/8 - 0s - loss: 0.5532 - accuracy: 0.7159 - val_loss: 0.6202 - val_accuracy: 0.6295
# Epoch 00021: val_loss did not improve from 0.58878
# Epoch 22/300
# 8/8 - 0s - loss: 0.5839 - accuracy: 0.6828 - val_loss: 0.5859 - val_accuracy: 0.6830
#
# Epoch 00022: val_loss improved from 0.58878 to 0.58594, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 23/300
# 8/8 - 0s - loss: 0.5626 - accuracy: 0.7021 - val_loss: 0.5909 - val_accuracy: 0.6964
#
# Epoch 00023: val_loss did not improve from 0.58594
# Epoch 24/300
# 8/8 - 0s - loss: 0.5616 - accuracy: 0.7021 - val_loss: 0.5807 - val_accuracy: 0.7098
#
# Epoch 00024: val_loss improved from 0.58594 to 0.58074, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 25/300
# 8/8 - 0s - loss: 0.5694 - accuracy: 0.6942 - val_loss: 0.6163 - val_accuracy: 0.6696
#
# Epoch 00025: val_loss did not improve from 0.58074
# Epoch 26/300
# 8/8 - 0s - loss: 0.5577 - accuracy: 0.7134 - val_loss: 0.5818 - val_accuracy: 0.7143
#
# Epoch 00026: val_loss did not improve from 0.58074
# Epoch 27/300
# 8/8 - 0s - loss: 0.5577 - accuracy: 0.7139 - val_loss: 0.5837 - val_accuracy: 0.7232
#
# Epoch 00027: val_loss did not improve from 0.58074
# Epoch 28/300
# 8/8 - 0s - loss: 0.5406 - accuracy: 0.7273 - val_loss: 0.5837 - val_accuracy: 0.7054
#
# Epoch 00028: val_loss did not improve from 0.58074
# Epoch 29/300
# 8/8 - 0s - loss: 0.5623 - accuracy: 0.7080 - val_loss: 0.5816 - val_accuracy: 0.7143
#
# Epoch 00029: val_loss did not improve from 0.58074
# Epoch 30/300
# 8/8 - 0s - loss: 0.5381 - accuracy: 0.7297 - val_loss: 0.5854 - val_accuracy: 0.7143
#
# Epoch 00030: val_loss did not improve from 0.58074
# Epoch 31/300
# 8/8 - 0s - loss: 0.5601 - accuracy: 0.7060 - val_loss: 0.5870 - val_accuracy: 0.7143
#
# Epoch 00031: val_loss did not improve from 0.58074
# Epoch 32/300
# 8/8 - 0s - loss: 0.5436 - accuracy: 0.7164 - val_loss: 0.5806 - val_accuracy: 0.7098
#
# Epoch 00032: val_loss improved from 0.58074 to 0.58060, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 33/300
# 8/8 - 0s - loss: 0.5455 - accuracy: 0.7179 - val_loss: 0.5979 - val_accuracy: 0.7054
#
# Epoch 00033: val_loss did not improve from 0.58060
# Epoch 34/300
# 8/8 - 0s - loss: 0.5323 - accuracy: 0.7288 - val_loss: 0.5781 - val_accuracy: 0.7009
#
# Epoch 00034: val_loss improved from 0.58060 to 0.57811, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 35/300
# 8/8 - 0s - loss: 0.5469 - accuracy: 0.7129 - val_loss: 0.5952 - val_accuracy: 0.6607
#
# Epoch 00035: val_loss did not improve from 0.57811
# Epoch 36/300
# 8/8 - 0s - loss: 0.5260 - accuracy: 0.7436 - val_loss: 0.5830 - val_accuracy: 0.7277
#
# Epoch 00036: val_loss did not improve from 0.57811
# Epoch 37/300
# 8/8 - 0s - loss: 0.5440 - accuracy: 0.7288 - val_loss: 0.5953 - val_accuracy: 0.7098
#
# Epoch 00037: val_loss did not improve from 0.57811
# Epoch 38/300
# 8/8 - 0s - loss: 0.5258 - accuracy: 0.7386 - val_loss: 0.5716 - val_accuracy: 0.7143
#
# Epoch 00038: val_loss improved from 0.57811 to 0.57163, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 39/300
# 8/8 - 0s - loss: 0.5099 - accuracy: 0.7426 - val_loss: 0.6511 - val_accuracy: 0.6205
#
# Epoch 00039: val_loss did not improve from 0.57163
# Epoch 40/300
# 8/8 - 0s - loss: 0.5390 - accuracy: 0.7367 - val_loss: 0.5753 - val_accuracy: 0.7098
#
# Epoch 00040: val_loss did not improve from 0.57163
# Epoch 41/300
# 8/8 - 0s - loss: 0.5259 - accuracy: 0.7421 - val_loss: 0.6091 - val_accuracy: 0.6384
#
# Epoch 00041: val_loss did not improve from 0.57163
# Epoch 42/300
# 8/8 - 0s - loss: 0.5041 - accuracy: 0.7535 - val_loss: 0.5980 - val_accuracy: 0.6786
#
# Epoch 00042: val_loss did not improve from 0.57163
# Epoch 43/300
# 8/8 - 0s - loss: 0.5304 - accuracy: 0.7327 - val_loss: 0.5855 - val_accuracy: 0.7321
#
# Epoch 00043: val_loss did not improve from 0.57163
# Epoch 44/300
# 8/8 - 0s - loss: 0.4945 - accuracy: 0.7465 - val_loss: 0.5709 - val_accuracy: 0.7098
#
# Epoch 00044: val_loss improved from 0.57163 to 0.57090, saving model to D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\_9.h5
# Epoch 45/300
# 8/8 - 0s - loss: 0.5041 - accuracy: 0.7574 - val_loss: 0.5906 - val_accuracy: 0.6384
#
# Epoch 00045: val_loss did not improve from 0.57090
# Epoch 46/300
# 8/8 - 0s - loss: 0.5142 - accuracy: 0.7544 - val_loss: 0.5849 - val_accuracy: 0.7188
#
# Epoch 00046: val_loss did not improve from 0.57090
# Epoch 47/300
# 8/8 - 0s - loss: 0.4948 - accuracy: 0.7485 - val_loss: 0.5802 - val_accuracy: 0.7188
#
# Epoch 00047: val_loss did not improve from 0.57090
# Epoch 48/300
# 8/8 - 0s - loss: 0.5096 - accuracy: 0.7549 - val_loss: 0.6018 - val_accuracy: 0.6875
#
# Epoch 00048: val_loss did not improve from 0.57090
# Epoch 49/300
# 8/8 - 0s - loss: 0.4928 - accuracy: 0.7628 - val_loss: 0.5837 - val_accuracy: 0.7321
#
# Epoch 00049: val_loss did not improve from 0.57090
# Epoch 50/300
# 8/8 - 0s - loss: 0.4764 - accuracy: 0.7698 - val_loss: 0.6918 - val_accuracy: 0.6161
#
# Epoch 00050: val_loss did not improve from 0.57090
# Epoch 51/300
# 8/8 - 0s - loss: 0.5081 - accuracy: 0.7535 - val_loss: 0.6140 - val_accuracy: 0.6875
#
# Epoch 00051: val_loss did not improve from 0.57090
# Epoch 52/300
# 8/8 - 0s - loss: 0.4920 - accuracy: 0.7540 - val_loss: 0.5869 - val_accuracy: 0.7143
#
# Epoch 00052: val_loss did not improve from 0.57090
# Epoch 53/300
# 8/8 - 0s - loss: 0.5064 - accuracy: 0.7431 - val_loss: 0.5877 - val_accuracy: 0.7277
#
# Epoch 00053: val_loss did not improve from 0.57090
# Epoch 54/300
# 8/8 - 0s - loss: 0.4691 - accuracy: 0.7841 - val_loss: 0.5750 - val_accuracy: 0.6875
#
# Epoch 00054: val_loss did not improve from 0.57090
# Epoch 55/300
# 8/8 - 0s - loss: 0.4872 - accuracy: 0.7633 - val_loss: 0.5794 - val_accuracy: 0.7098
#
# Epoch 00055: val_loss did not improve from 0.57090
# Epoch 56/300
# 8/8 - 0s - loss: 0.4811 - accuracy: 0.7535 - val_loss: 0.5781 - val_accuracy: 0.7411
#
# Epoch 00056: val_loss did not improve from 0.57090
# Epoch 57/300
# 8/8 - 0s - loss: 0.4747 - accuracy: 0.7698 - val_loss: 0.5781 - val_accuracy: 0.6830
#
# Epoch 00057: val_loss did not improve from 0.57090
# Epoch 58/300
# 8/8 - 0s - loss: 0.4615 - accuracy: 0.7905 - val_loss: 0.5757 - val_accuracy: 0.7188
#
# Epoch 00058: val_loss did not improve from 0.57090
# Epoch 59/300
# 8/8 - 0s - loss: 0.4789 - accuracy: 0.7688 - val_loss: 0.5837 - val_accuracy: 0.7098
#
# Epoch 00059: val_loss did not improve from 0.57090
# Epoch 60/300
# 8/8 - 0s - loss: 0.4591 - accuracy: 0.7777 - val_loss: 0.5798 - val_accuracy: 0.6875
#
# Epoch 00060: val_loss did not improve from 0.57090
# Epoch 61/300
# 8/8 - 0s - loss: 0.4699 - accuracy: 0.7683 - val_loss: 0.6013 - val_accuracy: 0.6562
#
# Epoch 00061: val_loss did not improve from 0.57090
# Epoch 62/300
# 8/8 - 0s - loss: 0.4502 - accuracy: 0.7885 - val_loss: 0.5836 - val_accuracy: 0.7098
#
# Epoch 00062: val_loss did not improve from 0.57090
# Epoch 63/300
# 8/8 - 0s - loss: 0.4306 - accuracy: 0.8098 - val_loss: 0.6006 - val_accuracy: 0.6652
#
# Epoch 00063: val_loss did not improve from 0.57090
# Epoch 64/300
# 8/8 - 0s - loss: 0.4806 - accuracy: 0.7712 - val_loss: 0.5832 - val_accuracy: 0.7098
#
# Epoch 00064: val_loss did not improve from 0.57090
# Epoch 65/300
# 8/8 - 0s - loss: 0.4402 - accuracy: 0.7890 - val_loss: 0.5879 - val_accuracy: 0.7143
#
# Epoch 00065: val_loss did not improve from 0.57090
# Epoch 66/300
# 8/8 - 0s - loss: 0.4438 - accuracy: 0.7955 - val_loss: 0.5801 - val_accuracy: 0.6964
#
# Epoch 00066: val_loss did not improve from 0.57090
# Epoch 67/300
# 8/8 - 0s - loss: 0.4673 - accuracy: 0.7841 - val_loss: 0.5972 - val_accuracy: 0.6607
#
# Epoch 00067: val_loss did not improve from 0.57090
# Epoch 68/300
# 8/8 - 0s - loss: 0.4248 - accuracy: 0.8147 - val_loss: 0.5912 - val_accuracy: 0.7188
#
# Epoch 00068: val_loss did not improve from 0.57090
# Epoch 69/300
# 8/8 - 0s - loss: 0.4258 - accuracy: 0.8142 - val_loss: 0.6045 - val_accuracy: 0.7098
#
# Epoch 00069: val_loss did not improve from 0.57090
# Epoch 70/300
# 8/8 - 0s - loss: 0.4198 - accuracy: 0.8014 - val_loss: 0.6238 - val_accuracy: 0.6830
#
# Epoch 00070: val_loss did not improve from 0.57090
# Epoch 71/300
# 8/8 - 0s - loss: 0.4559 - accuracy: 0.7831 - val_loss: 0.5957 - val_accuracy: 0.6920
#
# Epoch 00071: val_loss did not improve from 0.57090
# Epoch 72/300
# 8/8 - 0s - loss: 0.4188 - accuracy: 0.8137 - val_loss: 0.6114 - val_accuracy: 0.6652
#
# Epoch 00072: val_loss did not improve from 0.57090
# Epoch 73/300
# 8/8 - 0s - loss: 0.4366 - accuracy: 0.7910 - val_loss: 0.5905 - val_accuracy: 0.6875
#
# Epoch 00073: val_loss did not improve from 0.57090
# Epoch 74/300
# 8/8 - 0s - loss: 0.3998 - accuracy: 0.8167 - val_loss: 0.5990 - val_accuracy: 0.6696
#
# Epoch 00074: val_loss did not improve from 0.57090
# Epoch 75/300
# 8/8 - 0s - loss: 0.4306 - accuracy: 0.7979 - val_loss: 0.6044 - val_accuracy: 0.7098
#
# Epoch 00075: val_loss did not improve from 0.57090
# Epoch 76/300
# 8/8 - 0s - loss: 0.4172 - accuracy: 0.8024 - val_loss: 0.6044 - val_accuracy: 0.7232
#
# Epoch 00076: val_loss did not improve from 0.57090
# Epoch 77/300
# 8/8 - 0s - loss: 0.4132 - accuracy: 0.8147 - val_loss: 0.6124 - val_accuracy: 0.6607
#
# Epoch 00077: val_loss did not improve from 0.57090
# Epoch 78/300
# 8/8 - 0s - loss: 0.3966 - accuracy: 0.8207 - val_loss: 0.6001 - val_accuracy: 0.7188
#
# Epoch 00078: val_loss did not improve from 0.57090
# Epoch 79/300
# 8/8 - 0s - loss: 0.3873 - accuracy: 0.8177 - val_loss: 0.6073 - val_accuracy: 0.6920
#
# Epoch 00079: val_loss did not improve from 0.57090
# Epoch 80/300
# 8/8 - 0s - loss: 0.3749 - accuracy: 0.8394 - val_loss: 0.6997 - val_accuracy: 0.6429
#
# Epoch 00080: val_loss did not improve from 0.57090
# Epoch 81/300
# 8/8 - 0s - loss: 0.3874 - accuracy: 0.8157 - val_loss: 0.5910 - val_accuracy: 0.6920
#
# Epoch 00081: val_loss did not improve from 0.57090
# Epoch 82/300
# 8/8 - 0s - loss: 0.3647 - accuracy: 0.8434 - val_loss: 0.7077 - val_accuracy: 0.6518
#
# Epoch 00082: val_loss did not improve from 0.57090
# Epoch 83/300
# 8/8 - 0s - loss: 0.4342 - accuracy: 0.7846 - val_loss: 0.6119 - val_accuracy: 0.6875
#
# Epoch 00083: val_loss did not improve from 0.57090
# Epoch 84/300
# 8/8 - 0s - loss: 0.3688 - accuracy: 0.8256 - val_loss: 0.5918 - val_accuracy: 0.7098
#
# Epoch 00084: val_loss did not improve from 0.57090
# Epoch 85/300
# 8/8 - 0s - loss: 0.3812 - accuracy: 0.8291 - val_loss: 0.6275 - val_accuracy: 0.6696
#
# Epoch 00085: val_loss did not improve from 0.57090
# Epoch 86/300
# 8/8 - 0s - loss: 0.3719 - accuracy: 0.8335 - val_loss: 0.6441 - val_accuracy: 0.6741
#
# Epoch 00086: val_loss did not improve from 0.57090
# Epoch 87/300
# 8/8 - 0s - loss: 0.4202 - accuracy: 0.8004 - val_loss: 0.5971 - val_accuracy: 0.6786
#
# Epoch 00087: val_loss did not improve from 0.57090
# Epoch 88/300
# 8/8 - 0s - loss: 0.3606 - accuracy: 0.8404 - val_loss: 0.5964 - val_accuracy: 0.6741
#
# Epoch 00088: val_loss did not improve from 0.57090
# Epoch 89/300
# 8/8 - 0s - loss: 0.3658 - accuracy: 0.8444 - val_loss: 0.6205 - val_accuracy: 0.6964
#
# Epoch 00089: val_loss did not improve from 0.57090
# Epoch 90/300
# 8/8 - 0s - loss: 0.3804 - accuracy: 0.8261 - val_loss: 0.6101 - val_accuracy: 0.7009
#
# Epoch 00090: val_loss did not improve from 0.57090
# Epoch 91/300
# 8/8 - 0s - loss: 0.3348 - accuracy: 0.8651 - val_loss: 0.6128 - val_accuracy: 0.6920
#
# Epoch 00091: val_loss did not improve from 0.57090
# Epoch 92/300
# 8/8 - 0s - loss: 0.4020 - accuracy: 0.8310 - val_loss: 0.6277 - val_accuracy: 0.6429
#
# Epoch 00092: val_loss did not improve from 0.57090
# Epoch 93/300
# 8/8 - 0s - loss: 0.3308 - accuracy: 0.8617 - val_loss: 0.6396 - val_accuracy: 0.6786
#
# Epoch 00093: val_loss did not improve from 0.57090
# Epoch 94/300
# 8/8 - 0s - loss: 0.3304 - accuracy: 0.8572 - val_loss: 0.7151 - val_accuracy: 0.6696
#
# Epoch 00094: val_loss did not improve from 0.57090
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001859E20BB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10

# %%
#遍历表格求初始里程
#交叉验证
import os
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze')
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\result\val'
filenames=os.listdir(path)#得到字符串列表
scores_val=[]
lables_val=[]
fpr_list_val = []
tpr_list_val = []
roc_auc_list_val=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_val=data.iloc[:,1]
        scores_val.append(score_val)
        lable_val = data.iloc[:,2]
        lables_val.append(lable_val)
        fpr_val,tpr_val,thresholds_val= roc_curve(lables_val[i],scores_val[i])   #y_true,y_score
        fpr_list_val.append(fpr_val)
        tpr_list_val.append(tpr_val)
        roc_auc_val = auc(fpr_val,tpr_val)
        roc_auc_list_val.append(roc_auc_val)
        i+=1

# %%
roc_auc_list_val
# Out:
# [0.7133375474083439,
#  0.7265625,
#  0.7670670037926675,
#  0.7410714285714286,
#  0.7456542351453854,
#  0.7213969658659926,
#  0.7339601769911505,
#  0.7384639696586599,
#  0.7234513274336283,
#  0.7691326530612244]

# %%
i=1
tprs_val = []
mean_fpr_val = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Validation ROC')
for fpr_val,tpr_val,roc_auc_val in zip(fpr_list_val,tpr_list_val,roc_auc_list_val):
    tprs_val.append(np.interp(mean_fpr_val, fpr_val, tpr_val))
    tprs_val[-1][0] = 0.0
    plt.plot(fpr_val, tpr_val, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_val)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_val.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_val = np.mean(tprs_val, axis=0)
mean_tpr_val[-1] = 1.0
mean_auc_val = auc(mean_fpr_val, mean_tpr_val)
std_auc_val = np.std(roc_auc_list_val)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_val, std_auc_val),lw=2, alpha=.8)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_val),lw=2, alpha=.8)
std_tpr_val = np.std(tprs_val, axis=0)
tprs_upper_val = np.minimum(mean_tpr_val + std_tpr_val, 1)
tprs_lower_val = np.maximum(mean_tpr_val - std_tpr_val, 0)
plt.fill_between(mean_fpr_val, tprs_lower_val, tprs_upper_val, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Cross-Validation ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_val_mean.png')
plt.show()

# %%
def calculate_metrics_val(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_val = []
for score_val,lable_val in zip(scores_val,lables_val):
    val_my_calculate_metrics = calculate_metrics_val(lable_val,score_val)
    my_calculate_metrics_list_val.append(val_my_calculate_metrics)

# %%
my_calculate_metrics_list_val
# Out:
# [{'SN': 0.5398230088495575,
#   'SP': 0.7767857142857143,
#   'ACC': 0.6577777777777778,
#   'MCC': 0.3257725472139103,
#   'Recall': 0.5398230088495575,
#   'Precision': 0.7093023255813954,
#   'F1-score': 0.6130653266331658,
#   'Cutoff': 0.5},
#  {'SN': 0.9285714285714286,
#   'SP': 0.4107142857142857,
#   'ACC': 0.6696428571428571,
#   'MCC': 0.3966087176872613,
#   'Recall': 0.9285714285714286,
#   'Precision': 0.611764705882353,
#   'F1-score': 0.7375886524822695,
#   'Cutoff': 0.5},
#  {'SN': 0.6902654867256637,
#   'SP': 0.6785714285714286,
#   'ACC': 0.6844444444444444,
#   'MCC': 0.36886606199714944,
#   'Recall': 0.6902654867256637,
#   'Precision': 0.6842105263157895,
#   'F1-score': 0.6872246696035242,
#   'Cutoff': 0.5},
#  {'SN': 0.7699115044247787,
#   'SP': 0.5267857142857143,
#   'ACC': 0.6488888888888888,
#   'MCC': 0.30597660923643105,
#   'Recall': 0.7699115044247787,
#   'Precision': 0.6214285714285714,
#   'F1-score': 0.6877470355731226,
#   'Cutoff': 0.5},
#  {'SN': 0.7787610619469026,
#   'SP': 0.5446428571428571,
#   'ACC': 0.6622222222222223,
#   'MCC': 0.33276442119953453,
#   'Recall': 0.7787610619469026,
#   'Precision': 0.6330935251798561,
#   'F1-score': 0.6984126984126984,
#   'Cutoff': 0.5},
#  {'SN': 0.7410714285714286,
#   'SP': 0.5929203539823009,
#   'ACC': 0.6666666666666666,
#   'MCC': 0.3376397290490517,
#   'Recall': 0.7410714285714286,
#   'Precision': 0.6434108527131783,
#   'F1-score': 0.6887966804979253,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.5221238938053098,
#   'ACC': 0.6577777777777778,
#   'MCC': 0.32908863041983333,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.6223776223776224,
#   'F1-score': 0.6980392156862745,
#   'Cutoff': 0.5},
#  {'SN': 0.7678571428571429,
#   'SP': 0.5221238938053098,
#   'ACC': 0.6444444444444445,
#   'MCC': 0.29905037440684473,
#   'Recall': 0.7678571428571429,
#   'Precision': 0.6142857142857143,
#   'F1-score': 0.6825396825396826,
#   'Cutoff': 0.5},
#  {'SN': 0.6160714285714286,
#   'SP': 0.6460176991150443,
#   'ACC': 0.6311111111111111,
#   'MCC': 0.262213468230047,
#   'Recall': 0.6160714285714286,
#   'Precision': 0.6330275229357798,
#   'F1-score': 0.6244343891402715,
#   'Cutoff': 0.5},
#  {'SN': 0.7767857142857143,
#   'SP': 0.6160714285714286,
#   'ACC': 0.6964285714285714,
#   'MCC': 0.398031161138567,
#   'Recall': 0.7767857142857143,
#   'Precision': 0.6692307692307692,
#   'F1-score': 0.71900826446281,
#   'Cutoff': 0.5}]

# %%
performance_val=pd.DataFrame(my_calculate_metrics_list_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.539823  0.776786  0.657778  0.325773  0.539823   0.709302  0.613065
# 1  0.928571  0.410714  0.669643  0.396609  0.928571   0.611765  0.737589
# 2  0.690265  0.678571  0.684444  0.368866  0.690265   0.684211  0.687225
# 3  0.769912  0.526786  0.648889  0.305977  0.769912   0.621429  0.687747
# 4  0.778761  0.544643  0.662222  0.332764  0.778761   0.633094  0.698413
# 5  0.741071  0.592920  0.666667  0.337640  0.741071   0.643411  0.688797
# 6  0.794643  0.522124  0.657778  0.329089  0.794643   0.622378  0.698039
# 7  0.767857  0.522124  0.644444  0.299050  0.767857   0.614286  0.682540
# 8  0.616071  0.646018  0.631111  0.262213  0.616071   0.633028  0.624434
# 9  0.776786  0.616071  0.696429  0.398031  0.776786   0.669231  0.719008
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_val = performance_val.std(axis = 0,ddof=1)
mean_val = performance_val.mean(axis = 0)
data_mean_val = pd.DataFrame(mean_val)
data_mean_val = data_mean_val.T
data_std_val = pd.DataFrame(std_val)
data_std_val = data_std_val.T
performance_val = performance_val.append(data_mean_val)
performance_val = performance_val.append(data_std_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.539823  0.776786  0.657778  0.325773  0.539823   0.709302  0.613065
# 1  0.928571  0.410714  0.669643  0.396609  0.928571   0.611765  0.737589
# 2  0.690265  0.678571  0.684444  0.368866  0.690265   0.684211  0.687225
# 3  0.769912  0.526786  0.648889  0.305977  0.769912   0.621429  0.687747
# 4  0.778761  0.544643  0.662222  0.332764  0.778761   0.633094  0.698413
# 5  0.741071  0.592920  0.666667  0.337640  0.741071   0.643411  0.688797
# 6  0.794643  0.522124  0.657778  0.329089  0.794643   0.622378  0.698039
# 7  0.767857  0.522124  0.644444  0.299050  0.767857   0.614286  0.682540
# 8  0.616071  0.646018  0.631111  0.262213  0.616071   0.633028  0.624434
# 9  0.776786  0.616071  0.696429  0.398031  0.776786   0.669231  0.719008
# 0  0.740376  0.583676  0.661940  0.335601  0.740376   0.644213  0.683686
# 0  0.105921  0.101965  0.018971  0.042787  0.105921   0.032755  0.038196
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_val.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\result\CNN_OH_performance_val.csv',encoding='utf-8')

# %% [markdown]
# 独立测试

# %%
#遍历表格求初始里程
#独立测试
import os
path = r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\result\indep'
filenames=os.listdir(path)#得到字符串列表
scores_indep=[]
lables_indep=[]
fpr_list_indep = []
tpr_list_indep = []
roc_auc_list_indep=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_indep=data.iloc[:,1]
        scores_indep.append(score_indep)
        lable_indep = data.iloc[:,2]
        lables_indep.append(lable_indep)
        fpr_indep,tpr_indep,thresholds_indep= roc_curve(lables_indep[i],scores_indep[i])   #y_true,y_score
        fpr_list_indep.append(fpr_indep)
        tpr_list_indep.append(tpr_indep)
        roc_auc_indep = auc(fpr_indep,tpr_indep)
        roc_auc_list_indep.append(roc_auc_indep)
        i+=1

# %%
roc_auc_list_indep
# Out:
# [0.71875,
#  0.7090242346938775,
#  0.7136479591836734,
#  0.6890943877551021,
#  0.7362882653061223,
#  0.6949936224489797,
#  0.7263233418367346,
#  0.7128507653061225,
#  0.7387595663265305,
#  0.7231345663265307]

# %%
i=1
tprs_indep = []
mean_fpr_indep = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Independent ROC')
for fpr_indep,tpr_indep,roc_auc_indep in zip(fpr_list_indep,tpr_list_indep,roc_auc_list_indep):
    tprs_indep.append(np.interp(mean_fpr_indep, fpr_indep, tpr_indep))
    tprs_indep[-1][0] = 0.0
    plt.plot(fpr_indep, tpr_indep, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_indep)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_indep.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_indep = np.mean(tprs_indep, axis=0)
mean_tpr_indep[-1] = 1.0
mean_auc_indep = auc(mean_fpr_indep, mean_tpr_indep)
std_auc_indep = np.std(roc_auc_list_indep)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_indep, std_auc_indep),lw=2, alpha=.8)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_indep),lw=2, alpha=.8)
std_tpr_indep = np.std(tprs_indep, axis=0)
tprs_upper_indep = np.minimum(mean_tpr_indep + std_tpr_indep, 1)
tprs_lower_indep = np.maximum(mean_tpr_indep - std_tpr_indep, 0)
plt.fill_between(mean_fpr_indep, tprs_lower_indep, tprs_upper_indep, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Independent ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_indep_mean.png')
plt.show()

# %%
def calculate_metrics_indep(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_indep = []
for score_indep,lable_indep in zip(scores_indep,lables_indep):
    indep_my_calculate_metrics = calculate_metrics_indep(lable_indep,score_indep)
    my_calculate_metrics_list_indep.append(indep_my_calculate_metrics)

# %%
my_calculate_metrics_list_indep
# Out:
# [{'SN': 0.5267857142857143,
#   'SP': 0.75,
#   'ACC': 0.6383928571428571,
#   'MCC': 0.28394994176256727,
#   'Recall': 0.5267857142857143,
#   'Precision': 0.6781609195402298,
#   'F1-score': 0.592964824120603,
#   'Cutoff': 0.5},
#  {'SN': 0.8392857142857143,
#   'SP': 0.41964285714285715,
#   'ACC': 0.6294642857142857,
#   'MCC': 0.2852612345552926,
#   'Recall': 0.8392857142857143,
#   'Precision': 0.5911949685534591,
#   'F1-score': 0.6937269372693727,
#   'Cutoff': 0.5},
#  {'SN': 0.6696428571428571,
#   'SP': 0.625,
#   'ACC': 0.6473214285714286,
#   'MCC': 0.29493690609444523,
#   'Recall': 0.6696428571428571,
#   'Precision': 0.6410256410256411,
#   'F1-score': 0.6550218340611353,
#   'Cutoff': 0.5},
#  {'SN': 0.7678571428571429,
#   'SP': 0.4732142857142857,
#   'ACC': 0.6205357142857143,
#   'MCC': 0.2522703544471045,
#   'Recall': 0.7678571428571429,
#   'Precision': 0.593103448275862,
#   'F1-score': 0.669260700389105,
#   'Cutoff': 0.5},
#  {'SN': 0.7857142857142857,
#   'SP': 0.5267857142857143,
#   'ACC': 0.65625,
#   'MCC': 0.323533638451669,
#   'Recall': 0.7857142857142857,
#   'Precision': 0.624113475177305,
#   'F1-score': 0.6956521739130435,
#   'Cutoff': 0.5},
#  {'SN': 0.7053571428571429,
#   'SP': 0.5535714285714286,
#   'ACC': 0.6294642857142857,
#   'MCC': 0.2619638352895147,
#   'Recall': 0.7053571428571429,
#   'Precision': 0.6124031007751938,
#   'F1-score': 0.6556016597510373,
#   'Cutoff': 0.5},
#  {'SN': 0.8125,
#   'SP': 0.5089285714285714,
#   'ACC': 0.6607142857142857,
#   'MCC': 0.33734849075542506,
#   'Recall': 0.8125,
#   'Precision': 0.6232876712328768,
#   'F1-score': 0.7054263565891473,
#   'Cutoff': 0.5},
#  {'SN': 0.8035714285714286,
#   'SP': 0.5,
#   'ACC': 0.6517857142857143,
#   'MCC': 0.31860690793567925,
#   'Recall': 0.8035714285714286,
#   'Precision': 0.6164383561643836,
#   'F1-score': 0.6976744186046512,
#   'Cutoff': 0.5},
#  {'SN': 0.5535714285714286,
#   'SP': 0.7142857142857143,
#   'ACC': 0.6339285714285714,
#   'MCC': 0.2713848825944775,
#   'Recall': 0.5535714285714286,
#   'Precision': 0.6595744680851063,
#   'F1-score': 0.6019417475728155,
#   'Cutoff': 0.5},
#  {'SN': 0.7678571428571429,
#   'SP': 0.5178571428571429,
#   'ACC': 0.6428571428571429,
#   'MCC': 0.29508444542532697,
#   'Recall': 0.7678571428571429,
#   'Precision': 0.6142857142857143,
#   'F1-score': 0.6825396825396826,
#   'Cutoff': 0.5}]

# %%
performance_indep=pd.DataFrame(my_calculate_metrics_list_indep)
performance_indep
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.526786  0.750000  0.638393  0.283950  0.526786   0.678161  0.592965
# 1  0.839286  0.419643  0.629464  0.285261  0.839286   0.591195  0.693727
# 2  0.669643  0.625000  0.647321  0.294937  0.669643   0.641026  0.655022
# 3  0.767857  0.473214  0.620536  0.252270  0.767857   0.593103  0.669261
# 4  0.785714  0.526786  0.656250  0.323534  0.785714   0.624113  0.695652
# 5  0.705357  0.553571  0.629464  0.261964  0.705357   0.612403  0.655602
# 6  0.812500  0.508929  0.660714  0.337348  0.812500   0.623288  0.705426
# 7  0.803571  0.500000  0.651786  0.318607  0.803571   0.616438  0.697674
# 8  0.553571  0.714286  0.633929  0.271385  0.553571   0.659574  0.601942
# 9  0.767857  0.517857  0.642857  0.295084  0.767857   0.614286  0.682540
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_indep = performance_indep.std(axis = 0,ddof=1)
mean_indep = performance_indep.mean(axis = 0)
data_mean_indep = pd.DataFrame(mean_indep)
data_mean_indep = data_mean_indep.T
data_std_indep = pd.DataFrame(std_indep)
data_std_indep = data_std_indep.T
performance_indep = performance_indep.append(data_mean_indep)
performance_indep = performance_indep.append(data_std_indep)
performance_indep
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.526786  0.750000  0.638393  0.283950  0.526786   0.678161  0.592965
# 1  0.839286  0.419643  0.629464  0.285261  0.839286   0.591195  0.693727
# 2  0.669643  0.625000  0.647321  0.294937  0.669643   0.641026  0.655022
# 3  0.767857  0.473214  0.620536  0.252270  0.767857   0.593103  0.669261
# 4  0.785714  0.526786  0.656250  0.323534  0.785714   0.624113  0.695652
# 5  0.705357  0.553571  0.629464  0.261964  0.705357   0.612403  0.655602
# 6  0.812500  0.508929  0.660714  0.337348  0.812500   0.623288  0.705426
# 7  0.803571  0.500000  0.651786  0.318607  0.803571   0.616438  0.697674
# 8  0.553571  0.714286  0.633929  0.271385  0.553571   0.659574  0.601942
# 9  0.767857  0.517857  0.642857  0.295084  0.767857   0.614286  0.682540
# 0  0.723214  0.558929  0.641071  0.292434  0.723214   0.625359  0.664981
# 0  0.108702  0.105661  0.013007  0.027469  0.108702   0.027462  0.039645
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_indep.to_csv(r'D:\PycharmProjects\pythonProject\Papernew_datachangetry\model\target_model\NEDD_K\layer_NEDD_K_不自然数据集\unfreeze\result\CNN_OH_performance_indep.csv',encoding='utf-8')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
