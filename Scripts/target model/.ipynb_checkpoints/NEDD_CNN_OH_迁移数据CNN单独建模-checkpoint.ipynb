# %%
import matplotlib as mpl
from numpy import *
from itertools import cycle
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score, precision_recall_curve
from sklearn.model_selection import KFold, train_test_split, cross_val_score, StratifiedKFold
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, losses, optimizers
import pandas as pd
import matplotlib.pyplot as plt

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
def One_hot_raw(path):
    seqs = open(path).readlines()

    X1 = [seq.split()[1] for seq in seqs if seq.strip() != '']
    y = [int(seq.split()[0]) for seq in seqs if seq.strip() != '']
    One = []
    for i in range(0, len(X1)):
        One.append(list(X1[i]))
    X = pd.DataFrame(One)
    return np.array(X), np.array(y)


def one_hot(rawDataFrame, codingMode=0):  # rawDataFrame is numpy.ndarray

    sampleSeq3DArr = rawDataFrame[:, :]

    if codingMode == 0:
        probMatr = convertSampleToProbMatr(sampleSeq3DArr)

    return probMatr


def convertSampleToProbMatr(sampleSeq3DArr):  # changed add one column for '1'

    letterDict = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
                  "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "V": 17, "W": 18, "Y": 19, "X": 20}
    AACategoryLen = 21  # add -

    probMatr = np.zeros((len(sampleSeq3DArr), 1, len(sampleSeq3DArr[0]), AACategoryLen))

    sampleNo = 0
    for sequence in sampleSeq3DArr:

        AANo = 0
        for AA in sequence:

            if not AA in letterDict:
                probMatr[sampleNo][0][AANo] = np.full((1, AACategoryLen), 1.0 / AACategoryLen)

            else:
                index = letterDict[AA]
                probMatr[sampleNo][0][AANo][index] = 1

            AANo += 1
        sampleNo += 1

    return probMatr

# %%
def build_network():
    # 先创建包含多网络层的列表
    conv_layers = [
        layers.Conv1D(filters=128, kernel_size=1, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=3, padding='same', activation=tf.nn.relu),
        layers.Dropout(0.5),
        layers.MaxPooling1D(2),
        layers.Conv1D(filters=128, kernel_size=9, padding='same', activation=tf.nn.relu),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5)
    ]

    fc_layers = [
        layers.Dense(64, activation=tf.nn.relu),  # 全连接层， 64 个节点
        layers.GlobalAveragePooling1D(),
        layers.Dense(1, activation=tf.nn.sigmoid)  # 全连接层， 1 个节点
    ]

    conv_layers.extend(fc_layers)
    network = Sequential(conv_layers)
    network.build(input_shape=[None, 41, 21])#[None, 41, 21]
    base_learning_rate = 0.001
    network.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate), loss='binary_crossentropy',metrics=['accuracy'])#编译模型
    #network.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    network.summary()
    return network

# %%
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32)
    y = tf.cast(y, dtype=tf.int32)
    return x, y

# %%
batch_size=128

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\Papernew\data\NEDD\迁移数据\训练集')
epochs = 300
x_train,y_train = One_hot_raw('train.txt')#十折交叉验证10
x_test,y_test = One_hot_raw('test.txt')#独立测试1

# %%
classes = sorted(list(set(y_train)))
x_train = one_hot(x_train)
x_test = one_hot(x_test)
x_train.shape = (x_train.shape[0],x_train.shape[2],x_train.shape[3])
x_test.shape = (x_test.shape[0],x_test.shape[2],x_test.shape[3])

# %%
# 构建独立测试集对象，预处理，批量化
test_db = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_db = test_db.map(preprocess).batch(batch_size)

# %%
prediction_result_cv = []
prediction_result_ind = []

# %%
os.chdir(r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new')

# %%
out = os.getcwd() + '\\'

# %%
from sklearn.model_selection import KFold,StratifiedKFold
kf = StratifiedKFold(n_splits=10,shuffle=True)
for n_fold,(tr_idx,val_idx)in enumerate(kf.split(x_train,y_train)):
    tr_x,tr_y,val_x,val_y = x_train[tr_idx],y_train[tr_idx],x_train[val_idx],y_train[val_idx]
    # 构建训练集对象，随机打乱，预处理，批量化
    train_db = tf.data.Dataset.from_tensor_slices((tr_x, tr_y))
    train_db = train_db.shuffle(len(tr_x)).map(preprocess).batch(batch_size)
    # 构建测试集对象，预处理，批量化
    valid_db = tf.data.Dataset.from_tensor_slices((val_x, val_y))
    valid_db = valid_db.map(preprocess).batch(batch_size)
    network = build_network()
    #if not os.path.exists('%s_%d.h5' % (out, n_fold)):
    best_saving = tf.keras.callbacks.ModelCheckpoint(filepath='%s_%d.h5' % (out, n_fold), monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=False)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    history = network.fit(train_db, epochs=epochs, validation_data=valid_db, verbose=2,callbacks=[best_saving, early_stopping], batch_size=batch_size)
    #network.load_weights('%s_%d.h5' % (out, n_fold))
    #history = network.fit(train_db, epochs=50, validation_data=valid_db, verbose=2)
    scores1 = network.predict(val_x, batch_size=batch_size)[:, 0]
    score_val = pd.DataFrame(scores1)
    y_val = pd.DataFrame(val_y)
    datav=pd.concat([score_val,y_val],axis=1)
    print(n_fold + 1) 
    n_fold_str = str(n_fold + 1)
    pathv ='val_out'+ n_fold_str
    datav.to_csv(r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\result\val\\'+pathv+'.csv',encoding='utf-8')
    datav.to_csv(r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\result\valtxt\\'+pathv+'.txt',sep='\t',index=False,encoding='utf-8')
    scores2 = network.predict(x_test, batch_size=batch_size)[:, 0]
    score_indep = pd.DataFrame(scores2)
    test_y = pd.DataFrame(y_test)
    datai = pd.concat([score_indep,test_y],axis=1)
    pathi ='indep_out'+ n_fold_str
    datai.to_csv(r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\result\indep\\'+pathi+'.csv',encoding='utf-8')
    datai.to_csv(r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\result\indeptxt\\'+pathi+'.txt',sep='\t',index=False,encoding='utf-8')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 41, 128)           2816
# _________________________________________________________________
# dropout (Dropout)            (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense (Dense)                (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 16/16 - 6s - loss: 0.6963 - accuracy: 0.5240 - val_loss: 0.6916 - val_accuracy: 0.5022
#
# Epoch 00001: val_loss improved from inf to 0.69156, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 2/300
# 16/16 - 0s - loss: 0.6896 - accuracy: 0.5294 - val_loss: 0.6833 - val_accuracy: 0.5200
#
# Epoch 00002: val_loss improved from 0.69156 to 0.68326, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 3/300
# 16/16 - 0s - loss: 0.6833 - accuracy: 0.5388 - val_loss: 0.6775 - val_accuracy: 0.5067
#
# Epoch 00003: val_loss improved from 0.68326 to 0.67746, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 4/300
# 16/16 - 0s - loss: 0.6790 - accuracy: 0.5670 - val_loss: 0.6774 - val_accuracy: 0.5956
#
# Epoch 00004: val_loss improved from 0.67746 to 0.67742, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 5/300
# 16/16 - 0s - loss: 0.6727 - accuracy: 0.5868 - val_loss: 0.6749 - val_accuracy: 0.5244
#
# Epoch 00005: val_loss improved from 0.67742 to 0.67489, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 6/300
# 16/16 - 0s - loss: 0.6677 - accuracy: 0.5947 - val_loss: 0.6663 - val_accuracy: 0.5867
#
# Epoch 00006: val_loss improved from 0.67489 to 0.66633, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 7/300
# 16/16 - 0s - loss: 0.6681 - accuracy: 0.6016 - val_loss: 0.6724 - val_accuracy: 0.5911
#
# Epoch 00007: val_loss did not improve from 0.66633
# Epoch 8/300
# 16/16 - 0s - loss: 0.6532 - accuracy: 0.6169 - val_loss: 0.6633 - val_accuracy: 0.5822
#
# Epoch 00008: val_loss improved from 0.66633 to 0.66327, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 9/300
# 16/16 - 0s - loss: 0.6665 - accuracy: 0.5996 - val_loss: 0.6615 - val_accuracy: 0.6222
#
# Epoch 00009: val_loss improved from 0.66327 to 0.66151, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 10/300
# 16/16 - 0s - loss: 0.6552 - accuracy: 0.6164 - val_loss: 0.6658 - val_accuracy: 0.6222
#
# Epoch 00010: val_loss did not improve from 0.66151
# Epoch 11/300
# 16/16 - 0s - loss: 0.6542 - accuracy: 0.6204 - val_loss: 0.6842 - val_accuracy: 0.5378
#
# Epoch 00011: val_loss did not improve from 0.66151
# Epoch 12/300
# 16/16 - 0s - loss: 0.6464 - accuracy: 0.6273 - val_loss: 0.6574 - val_accuracy: 0.6133
#
# Epoch 00012: val_loss improved from 0.66151 to 0.65741, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 13/300
# 16/16 - 0s - loss: 0.6560 - accuracy: 0.6075 - val_loss: 0.6629 - val_accuracy: 0.6356
#
# Epoch 00013: val_loss did not improve from 0.65741
# Epoch 14/300
# 16/16 - 0s - loss: 0.6460 - accuracy: 0.6204 - val_loss: 0.6596 - val_accuracy: 0.6444
#
# Epoch 00014: val_loss did not improve from 0.65741
# Epoch 15/300
# 16/16 - 0s - loss: 0.6405 - accuracy: 0.6303 - val_loss: 0.6646 - val_accuracy: 0.5733
#
# Epoch 00015: val_loss did not improve from 0.65741
# Epoch 16/300
# 16/16 - 0s - loss: 0.6414 - accuracy: 0.6174 - val_loss: 0.6503 - val_accuracy: 0.6444
#
# Epoch 00016: val_loss improved from 0.65741 to 0.65030, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 17/300
# 16/16 - 0s - loss: 0.6402 - accuracy: 0.6278 - val_loss: 0.6583 - val_accuracy: 0.6444
#
# Epoch 00017: val_loss did not improve from 0.65030
# Epoch 18/300
# 16/16 - 0s - loss: 0.6332 - accuracy: 0.6485 - val_loss: 0.6501 - val_accuracy: 0.6267
#
# Epoch 00018: val_loss improved from 0.65030 to 0.65007, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 19/300
# 16/16 - 0s - loss: 0.6360 - accuracy: 0.6337 - val_loss: 0.6538 - val_accuracy: 0.6356
#
# Epoch 00019: val_loss did not improve from 0.65007
# Epoch 20/300
# 16/16 - 0s - loss: 0.6253 - accuracy: 0.6387 - val_loss: 0.6522 - val_accuracy: 0.6267
#
# Epoch 00020: val_loss did not improve from 0.65007
# Epoch 21/300
# 16/16 - 0s - loss: 0.6207 - accuracy: 0.6535 - val_loss: 0.6417 - val_accuracy: 0.6533
#
# Epoch 00021: val_loss improved from 0.65007 to 0.64168, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 22/300
# 16/16 - 0s - loss: 0.6187 - accuracy: 0.6495 - val_loss: 0.6630 - val_accuracy: 0.5822
#
# Epoch 00022: val_loss did not improve from 0.64168
# Epoch 23/300
# 16/16 - 0s - loss: 0.6210 - accuracy: 0.6520 - val_loss: 0.6403 - val_accuracy: 0.6222
#
# Epoch 00023: val_loss improved from 0.64168 to 0.64032, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 24/300
# 16/16 - 0s - loss: 0.6076 - accuracy: 0.6653 - val_loss: 0.6396 - val_accuracy: 0.6267
#
# Epoch 00024: val_loss improved from 0.64032 to 0.63960, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 25/300
# 16/16 - 0s - loss: 0.6151 - accuracy: 0.6357 - val_loss: 0.6435 - val_accuracy: 0.6311
#
# Epoch 00025: val_loss did not improve from 0.63960
# Epoch 26/300
# 16/16 - 0s - loss: 0.6053 - accuracy: 0.6639 - val_loss: 0.6460 - val_accuracy: 0.6400
#
# Epoch 00026: val_loss did not improve from 0.63960
# Epoch 27/300
# 16/16 - 0s - loss: 0.6078 - accuracy: 0.6693 - val_loss: 0.6376 - val_accuracy: 0.6356
#
# Epoch 00027: val_loss improved from 0.63960 to 0.63759, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 28/300
# 16/16 - 0s - loss: 0.5991 - accuracy: 0.6698 - val_loss: 0.6394 - val_accuracy: 0.6311
#
# Epoch 00028: val_loss did not improve from 0.63759
# Epoch 29/300
# 16/16 - 0s - loss: 0.6052 - accuracy: 0.6599 - val_loss: 0.6340 - val_accuracy: 0.6622
#
# Epoch 00029: val_loss improved from 0.63759 to 0.63399, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 30/300
# 16/16 - 0s - loss: 0.5950 - accuracy: 0.6817 - val_loss: 0.6339 - val_accuracy: 0.6222
#
# Epoch 00030: val_loss improved from 0.63399 to 0.63385, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 31/300
# 16/16 - 0s - loss: 0.5831 - accuracy: 0.6817 - val_loss: 0.6206 - val_accuracy: 0.6400
#
# Epoch 00031: val_loss improved from 0.63385 to 0.62058, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 32/300
# 16/16 - 0s - loss: 0.5995 - accuracy: 0.6708 - val_loss: 0.6255 - val_accuracy: 0.6533
# Epoch 00032: val_loss did not improve from 0.62058
# Epoch 33/300
# 16/16 - 0s - loss: 0.5783 - accuracy: 0.6856 - val_loss: 0.6340 - val_accuracy: 0.6622
#
# Epoch 00033: val_loss did not improve from 0.62058
# Epoch 34/300
# 16/16 - 0s - loss: 0.5782 - accuracy: 0.6915 - val_loss: 0.6314 - val_accuracy: 0.6844
#
# Epoch 00034: val_loss did not improve from 0.62058
# Epoch 35/300
# 16/16 - 0s - loss: 0.5874 - accuracy: 0.6871 - val_loss: 0.6246 - val_accuracy: 0.6622
#
# Epoch 00035: val_loss did not improve from 0.62058
# Epoch 36/300
# 16/16 - 0s - loss: 0.5858 - accuracy: 0.6807 - val_loss: 0.6166 - val_accuracy: 0.6667
#
# Epoch 00036: val_loss improved from 0.62058 to 0.61660, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 37/300
# 16/16 - 0s - loss: 0.5664 - accuracy: 0.7004 - val_loss: 0.6373 - val_accuracy: 0.6578
#
# Epoch 00037: val_loss did not improve from 0.61660
# Epoch 38/300
# 16/16 - 0s - loss: 0.5706 - accuracy: 0.6955 - val_loss: 0.6132 - val_accuracy: 0.6711
#
# Epoch 00038: val_loss improved from 0.61660 to 0.61322, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 39/300
# 16/16 - 0s - loss: 0.5691 - accuracy: 0.7004 - val_loss: 0.6200 - val_accuracy: 0.6622
#
# Epoch 00039: val_loss did not improve from 0.61322
# Epoch 40/300
# 16/16 - 0s - loss: 0.5599 - accuracy: 0.6970 - val_loss: 0.6308 - val_accuracy: 0.6356
#
# Epoch 00040: val_loss did not improve from 0.61322
# Epoch 41/300
# 16/16 - 0s - loss: 0.5580 - accuracy: 0.7009 - val_loss: 0.6115 - val_accuracy: 0.6711
#
# Epoch 00041: val_loss improved from 0.61322 to 0.61148, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 42/300
# 16/16 - 0s - loss: 0.5529 - accuracy: 0.7059 - val_loss: 0.6103 - val_accuracy: 0.6578
#
# Epoch 00042: val_loss improved from 0.61148 to 0.61030, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 43/300
# 16/16 - 0s - loss: 0.5552 - accuracy: 0.7187 - val_loss: 0.6560 - val_accuracy: 0.6222
#
# Epoch 00043: val_loss did not improve from 0.61030
# Epoch 44/300
# 16/16 - 0s - loss: 0.5587 - accuracy: 0.6985 - val_loss: 0.6060 - val_accuracy: 0.6756
#
# Epoch 00044: val_loss improved from 0.61030 to 0.60602, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 45/300
# 16/16 - 0s - loss: 0.5602 - accuracy: 0.7019 - val_loss: 0.6000 - val_accuracy: 0.6889
#
# Epoch 00045: val_loss improved from 0.60602 to 0.59999, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 46/300
# 16/16 - 0s - loss: 0.5326 - accuracy: 0.7321 - val_loss: 0.5990 - val_accuracy: 0.6933
#
# Epoch 00046: val_loss improved from 0.59999 to 0.59901, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 47/300
# 16/16 - 0s - loss: 0.5279 - accuracy: 0.7192 - val_loss: 0.6128 - val_accuracy: 0.6889
#
# Epoch 00047: val_loss did not improve from 0.59901
# Epoch 48/300
# 16/16 - 0s - loss: 0.5314 - accuracy: 0.7326 - val_loss: 0.5956 - val_accuracy: 0.6889
#
# Epoch 00048: val_loss improved from 0.59901 to 0.59561, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 49/300
# 16/16 - 0s - loss: 0.5365 - accuracy: 0.7207 - val_loss: 0.5954 - val_accuracy: 0.7067
#
# Epoch 00049: val_loss improved from 0.59561 to 0.59538, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 50/300
# 16/16 - 0s - loss: 0.5302 - accuracy: 0.7316 - val_loss: 0.6341 - val_accuracy: 0.6400
#
# Epoch 00050: val_loss did not improve from 0.59538
# Epoch 51/300
# 16/16 - 0s - loss: 0.5391 - accuracy: 0.7182 - val_loss: 0.6556 - val_accuracy: 0.6311
#
# Epoch 00051: val_loss did not improve from 0.59538
# Epoch 52/300
# 16/16 - 0s - loss: 0.5203 - accuracy: 0.7375 - val_loss: 0.5933 - val_accuracy: 0.6978
#
# Epoch 00052: val_loss improved from 0.59538 to 0.59332, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 53/300
# 16/16 - 0s - loss: 0.5095 - accuracy: 0.7484 - val_loss: 0.5937 - val_accuracy: 0.6889
#
# Epoch 00053: val_loss did not improve from 0.59332
# Epoch 54/300
# 16/16 - 0s - loss: 0.5353 - accuracy: 0.7321 - val_loss: 0.5952 - val_accuracy: 0.6711
#
# Epoch 00054: val_loss did not improve from 0.59332
# Epoch 55/300
# 16/16 - 0s - loss: 0.5135 - accuracy: 0.7360 - val_loss: 0.5957 - val_accuracy: 0.6756
#
# Epoch 00055: val_loss did not improve from 0.59332
# Epoch 56/300
# 16/16 - 0s - loss: 0.5118 - accuracy: 0.7346 - val_loss: 0.6049 - val_accuracy: 0.6444
#
# Epoch 00056: val_loss did not improve from 0.59332
# Epoch 57/300
# 16/16 - 0s - loss: 0.5061 - accuracy: 0.7439 - val_loss: 0.5833 - val_accuracy: 0.6889
#
# Epoch 00057: val_loss improved from 0.59332 to 0.58332, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 58/300
# 16/16 - 0s - loss: 0.4994 - accuracy: 0.7336 - val_loss: 0.6144 - val_accuracy: 0.6933
#
# Epoch 00058: val_loss did not improve from 0.58332
# Epoch 59/300
# 16/16 - 0s - loss: 0.4969 - accuracy: 0.7533 - val_loss: 0.5846 - val_accuracy: 0.7156
#
# Epoch 00059: val_loss did not improve from 0.58332
# Epoch 60/300
# 16/16 - 0s - loss: 0.5069 - accuracy: 0.7588 - val_loss: 0.6212 - val_accuracy: 0.6311
#
# Epoch 00060: val_loss did not improve from 0.58332
# Epoch 61/300
# 16/16 - 0s - loss: 0.4801 - accuracy: 0.7682 - val_loss: 0.5898 - val_accuracy: 0.6978
#
# Epoch 00061: val_loss did not improve from 0.58332
# Epoch 62/300
# 16/16 - 0s - loss: 0.4875 - accuracy: 0.7603 - val_loss: 0.5809 - val_accuracy: 0.6933
#
# Epoch 00062: val_loss improved from 0.58332 to 0.58090, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 63/300
# 16/16 - 0s - loss: 0.4775 - accuracy: 0.7593 - val_loss: 0.6130 - val_accuracy: 0.6667
#
# Epoch 00063: val_loss did not improve from 0.58090
# Epoch 64/300
# 16/16 - 0s - loss: 0.4861 - accuracy: 0.7598 - val_loss: 0.5865 - val_accuracy: 0.6978
#
# Epoch 00064: val_loss did not improve from 0.58090
# Epoch 65/300
# 16/16 - 0s - loss: 0.4810 - accuracy: 0.7573 - val_loss: 0.5776 - val_accuracy: 0.6711
#
# Epoch 00065: val_loss improved from 0.58090 to 0.57759, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 66/300
# 16/16 - 0s - loss: 0.4780 - accuracy: 0.7632 - val_loss: 0.5790 - val_accuracy: 0.6933
#
# Epoch 00066: val_loss did not improve from 0.57759
# Epoch 67/300
# 16/16 - 0s - loss: 0.4645 - accuracy: 0.7647 - val_loss: 0.5905 - val_accuracy: 0.6844
#
# Epoch 00067: val_loss did not improve from 0.57759
# Epoch 68/300
# 16/16 - 0s - loss: 0.4642 - accuracy: 0.7761 - val_loss: 0.5715 - val_accuracy: 0.6933
#
# Epoch 00068: val_loss improved from 0.57759 to 0.57145, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 69/300
# 16/16 - 0s - loss: 0.4614 - accuracy: 0.7721 - val_loss: 0.5718 - val_accuracy: 0.6978
#
# Epoch 00069: val_loss did not improve from 0.57145
# Epoch 70/300
# 16/16 - 0s - loss: 0.4616 - accuracy: 0.7677 - val_loss: 0.5761 - val_accuracy: 0.6844
#
# Epoch 00070: val_loss did not improve from 0.57145
# Epoch 71/300
# 16/16 - 0s - loss: 0.4536 - accuracy: 0.7840 - val_loss: 0.5834 - val_accuracy: 0.6756
#
# Epoch 00071: val_loss did not improve from 0.57145
# Epoch 72/300
# 16/16 - 0s - loss: 0.4458 - accuracy: 0.7835 - val_loss: 0.5790 - val_accuracy: 0.6933
#
# Epoch 00072: val_loss did not improve from 0.57145
# Epoch 73/300
# 16/16 - 0s - loss: 0.4306 - accuracy: 0.7939 - val_loss: 0.5765 - val_accuracy: 0.6889
#
# Epoch 00073: val_loss did not improve from 0.57145
# Epoch 74/300
# 16/16 - 0s - loss: 0.4438 - accuracy: 0.7894 - val_loss: 0.5722 - val_accuracy: 0.7067
#
# Epoch 00074: val_loss did not improve from 0.57145
# Epoch 75/300
# 16/16 - 0s - loss: 0.4195 - accuracy: 0.8062 - val_loss: 0.5774 - val_accuracy: 0.6933
#
# Epoch 00075: val_loss did not improve from 0.57145
# Epoch 76/300
# 16/16 - 0s - loss: 0.4468 - accuracy: 0.7810 - val_loss: 0.5727 - val_accuracy: 0.6978
#
# Epoch 00076: val_loss did not improve from 0.57145
# Epoch 77/300
# 16/16 - 0s - loss: 0.4176 - accuracy: 0.8028 - val_loss: 0.6123 - val_accuracy: 0.6889
#
# Epoch 00077: val_loss did not improve from 0.57145
# Epoch 78/300
# 16/16 - 0s - loss: 0.4117 - accuracy: 0.8176 - val_loss: 0.5846 - val_accuracy: 0.6711
# Epoch 00078: val_loss did not improve from 0.57145
# Epoch 79/300
# 16/16 - 0s - loss: 0.4422 - accuracy: 0.7909 - val_loss: 0.5713 - val_accuracy: 0.7022
#
# Epoch 00079: val_loss improved from 0.57145 to 0.57126, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 80/300
# 16/16 - 0s - loss: 0.4186 - accuracy: 0.8013 - val_loss: 0.5867 - val_accuracy: 0.6844
#
# Epoch 00080: val_loss did not improve from 0.57126
# Epoch 81/300
# 16/16 - 0s - loss: 0.4231 - accuracy: 0.7993 - val_loss: 0.5701 - val_accuracy: 0.6978
#
# Epoch 00081: val_loss improved from 0.57126 to 0.57008, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 82/300
# 16/16 - 0s - loss: 0.4028 - accuracy: 0.8161 - val_loss: 0.5677 - val_accuracy: 0.6933
#
# Epoch 00082: val_loss improved from 0.57008 to 0.56767, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 83/300
# 16/16 - 0s - loss: 0.4098 - accuracy: 0.7958 - val_loss: 0.6055 - val_accuracy: 0.6622
#
# Epoch 00083: val_loss did not improve from 0.56767
# Epoch 84/300
# 16/16 - 0s - loss: 0.3911 - accuracy: 0.8191 - val_loss: 0.5619 - val_accuracy: 0.7111
#
# Epoch 00084: val_loss improved from 0.56767 to 0.56188, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 85/300
# 16/16 - 0s - loss: 0.3819 - accuracy: 0.8201 - val_loss: 0.5648 - val_accuracy: 0.6978
#
# Epoch 00085: val_loss did not improve from 0.56188
# Epoch 86/300
# 16/16 - 0s - loss: 0.4038 - accuracy: 0.8112 - val_loss: 0.5691 - val_accuracy: 0.6978
#
# Epoch 00086: val_loss did not improve from 0.56188
# Epoch 87/300
# 16/16 - 0s - loss: 0.3912 - accuracy: 0.8225 - val_loss: 0.5613 - val_accuracy: 0.7067
#
# Epoch 00087: val_loss improved from 0.56188 to 0.56134, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 88/300
# 16/16 - 0s - loss: 0.3789 - accuracy: 0.8260 - val_loss: 0.5824 - val_accuracy: 0.6978
#
# Epoch 00088: val_loss did not improve from 0.56134
# Epoch 89/300
# 16/16 - 0s - loss: 0.3898 - accuracy: 0.8176 - val_loss: 0.5698 - val_accuracy: 0.6889
#
# Epoch 00089: val_loss did not improve from 0.56134
# Epoch 90/300
# 16/16 - 0s - loss: 0.3752 - accuracy: 0.8290 - val_loss: 0.5671 - val_accuracy: 0.7111
#
# Epoch 00090: val_loss did not improve from 0.56134
# Epoch 91/300
# 16/16 - 0s - loss: 0.3816 - accuracy: 0.8211 - val_loss: 0.5639 - val_accuracy: 0.6978
#
# Epoch 00091: val_loss did not improve from 0.56134
# Epoch 92/300
# 16/16 - 0s - loss: 0.3738 - accuracy: 0.8359 - val_loss: 0.5705 - val_accuracy: 0.7200
#
# Epoch 00092: val_loss did not improve from 0.56134
# Epoch 93/300
# 16/16 - 0s - loss: 0.3524 - accuracy: 0.8473 - val_loss: 0.5898 - val_accuracy: 0.6844
#
# Epoch 00093: val_loss did not improve from 0.56134
# Epoch 94/300
# 16/16 - 0s - loss: 0.3699 - accuracy: 0.8206 - val_loss: 0.5705 - val_accuracy: 0.7067
#
# Epoch 00094: val_loss did not improve from 0.56134
# Epoch 95/300
# 16/16 - 0s - loss: 0.3808 - accuracy: 0.8240 - val_loss: 0.5594 - val_accuracy: 0.6933
#
# Epoch 00095: val_loss improved from 0.56134 to 0.55943, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 96/300
# 16/16 - 0s - loss: 0.3427 - accuracy: 0.8512 - val_loss: 0.5731 - val_accuracy: 0.7022
#
# Epoch 00096: val_loss did not improve from 0.55943
# Epoch 97/300
# 16/16 - 0s - loss: 0.3587 - accuracy: 0.8324 - val_loss: 0.5616 - val_accuracy: 0.7067
#
# Epoch 00097: val_loss did not improve from 0.55943
# Epoch 98/300
# 16/16 - 0s - loss: 0.3595 - accuracy: 0.8408 - val_loss: 0.5696 - val_accuracy: 0.6800
#
# Epoch 00098: val_loss did not improve from 0.55943
# Epoch 99/300
# 16/16 - 0s - loss: 0.3479 - accuracy: 0.8408 - val_loss: 0.5657 - val_accuracy: 0.6844
#
# Epoch 00099: val_loss did not improve from 0.55943
# Epoch 100/300
# 16/16 - 0s - loss: 0.3637 - accuracy: 0.8453 - val_loss: 0.5619 - val_accuracy: 0.7067
#
# Epoch 00100: val_loss did not improve from 0.55943
# Epoch 101/300
# 16/16 - 0s - loss: 0.3460 - accuracy: 0.8562 - val_loss: 0.5591 - val_accuracy: 0.7067
#
# Epoch 00101: val_loss improved from 0.55943 to 0.55908, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_0.h5
# Epoch 102/300
# 16/16 - 0s - loss: 0.3370 - accuracy: 0.8517 - val_loss: 0.5941 - val_accuracy: 0.6844
#
# Epoch 00102: val_loss did not improve from 0.55908
# Epoch 103/300
# 16/16 - 0s - loss: 0.3516 - accuracy: 0.8433 - val_loss: 0.5713 - val_accuracy: 0.6756
#
# Epoch 00103: val_loss did not improve from 0.55908
# Epoch 104/300
# 16/16 - 0s - loss: 0.3517 - accuracy: 0.8334 - val_loss: 0.5619 - val_accuracy: 0.6978
#
# Epoch 00104: val_loss did not improve from 0.55908
# Epoch 105/300
# 16/16 - 0s - loss: 0.3324 - accuracy: 0.8473 - val_loss: 0.5800 - val_accuracy: 0.6978
#
# Epoch 00105: val_loss did not improve from 0.55908
# Epoch 106/300
# 16/16 - 0s - loss: 0.3324 - accuracy: 0.8527 - val_loss: 0.5721 - val_accuracy: 0.7156
#
# Epoch 00106: val_loss did not improve from 0.55908
# Epoch 107/300
# 16/16 - 0s - loss: 0.3451 - accuracy: 0.8433 - val_loss: 0.5646 - val_accuracy: 0.7111
#
# Epoch 00107: val_loss did not improve from 0.55908
# Epoch 108/300
# 16/16 - 0s - loss: 0.3140 - accuracy: 0.8641 - val_loss: 0.5688 - val_accuracy: 0.7022
#
# Epoch 00108: val_loss did not improve from 0.55908
# Epoch 109/300
# 16/16 - 0s - loss: 0.3360 - accuracy: 0.8487 - val_loss: 0.6124 - val_accuracy: 0.6756
#
# Epoch 00109: val_loss did not improve from 0.55908
# Epoch 110/300
# 16/16 - 0s - loss: 0.3209 - accuracy: 0.8591 - val_loss: 0.5766 - val_accuracy: 0.7156
#
# Epoch 00110: val_loss did not improve from 0.55908
# Epoch 111/300
# 16/16 - 0s - loss: 0.3138 - accuracy: 0.8720 - val_loss: 0.5715 - val_accuracy: 0.6933
#
# Epoch 00111: val_loss did not improve from 0.55908
# Epoch 112/300
# 16/16 - 0s - loss: 0.2929 - accuracy: 0.8774 - val_loss: 0.5741 - val_accuracy: 0.6978
#
# Epoch 00112: val_loss did not improve from 0.55908
# Epoch 113/300
# 16/16 - 0s - loss: 0.3051 - accuracy: 0.8720 - val_loss: 0.5846 - val_accuracy: 0.6844
#
# Epoch 00113: val_loss did not improve from 0.55908
# Epoch 114/300
# 16/16 - 0s - loss: 0.3132 - accuracy: 0.8636 - val_loss: 0.5801 - val_accuracy: 0.6933
#
# Epoch 00114: val_loss did not improve from 0.55908
# Epoch 115/300
# 16/16 - 0s - loss: 0.3331 - accuracy: 0.8596 - val_loss: 0.6343 - val_accuracy: 0.6800
#
# Epoch 00115: val_loss did not improve from 0.55908
# Epoch 116/300
# 16/16 - 0s - loss: 0.2991 - accuracy: 0.8754 - val_loss: 0.5703 - val_accuracy: 0.6844
#
# Epoch 00116: val_loss did not improve from 0.55908
# Epoch 117/300
# 16/16 - 0s - loss: 0.2980 - accuracy: 0.8744 - val_loss: 0.5936 - val_accuracy: 0.6800
#
# Epoch 00117: val_loss did not improve from 0.55908
# Epoch 118/300
# 16/16 - 0s - loss: 0.3003 - accuracy: 0.8730 - val_loss: 0.5733 - val_accuracy: 0.7022
#
# Epoch 00118: val_loss did not improve from 0.55908
# Epoch 119/300
# 16/16 - 0s - loss: 0.2824 - accuracy: 0.8739 - val_loss: 0.6010 - val_accuracy: 0.6978
#
# Epoch 00119: val_loss did not improve from 0.55908
# Epoch 120/300
# 16/16 - 0s - loss: 0.3128 - accuracy: 0.8591 - val_loss: 0.6701 - val_accuracy: 0.6756
#
# Epoch 00120: val_loss did not improve from 0.55908
# Epoch 121/300
# 16/16 - 0s - loss: 0.2901 - accuracy: 0.8680 - val_loss: 0.5874 - val_accuracy: 0.6889
#
# Epoch 00121: val_loss did not improve from 0.55908
# Epoch 122/300
# 16/16 - 0s - loss: 0.2842 - accuracy: 0.8784 - val_loss: 0.5936 - val_accuracy: 0.6800
#
# Epoch 00122: val_loss did not improve from 0.55908
# Epoch 123/300
# 16/16 - 0s - loss: 0.2892 - accuracy: 0.8769 - val_loss: 0.5867 - val_accuracy: 0.6889
#
# Epoch 00123: val_loss did not improve from 0.55908
# Epoch 124/300
# 16/16 - 0s - loss: 0.2977 - accuracy: 0.8626 - val_loss: 0.6623 - val_accuracy: 0.6800
#
# Epoch 00124: val_loss did not improve from 0.55908
# Epoch 125/300
# 16/16 - 0s - loss: 0.2577 - accuracy: 0.8878 - val_loss: 0.6456 - val_accuracy: 0.7022
#
# Epoch 00125: val_loss did not improve from 0.55908
# Epoch 126/300
# 16/16 - 0s - loss: 0.2801 - accuracy: 0.8858 - val_loss: 0.6635 - val_accuracy: 0.6667
#
# Epoch 00126: val_loss did not improve from 0.55908
# Epoch 127/300
# 16/16 - 0s - loss: 0.2873 - accuracy: 0.8779 - val_loss: 0.6367 - val_accuracy: 0.6444
#
# Epoch 00127: val_loss did not improve from 0.55908
# Epoch 128/300
# 16/16 - 0s - loss: 0.2498 - accuracy: 0.8942 - val_loss: 0.6048 - val_accuracy: 0.6889
# Epoch 00128: val_loss did not improve from 0.55908
# Epoch 129/300
# 16/16 - 0s - loss: 0.2830 - accuracy: 0.8749 - val_loss: 0.6745 - val_accuracy: 0.6667
#
# Epoch 00129: val_loss did not improve from 0.55908
# Epoch 130/300
# 16/16 - 0s - loss: 0.2313 - accuracy: 0.9086 - val_loss: 0.6589 - val_accuracy: 0.7067
#
# Epoch 00130: val_loss did not improve from 0.55908
# Epoch 131/300
# 16/16 - 0s - loss: 0.2541 - accuracy: 0.8913 - val_loss: 0.5919 - val_accuracy: 0.6800
#
# Epoch 00131: val_loss did not improve from 0.55908
# Epoch 132/300
# 16/16 - 0s - loss: 0.2241 - accuracy: 0.9071 - val_loss: 0.5978 - val_accuracy: 0.6844
#
# Epoch 00132: val_loss did not improve from 0.55908
# Epoch 133/300
# 16/16 - 0s - loss: 0.2615 - accuracy: 0.8888 - val_loss: 0.6254 - val_accuracy: 0.6800
#
# Epoch 00133: val_loss did not improve from 0.55908
# Epoch 134/300
# 16/16 - 0s - loss: 0.2432 - accuracy: 0.8992 - val_loss: 0.5852 - val_accuracy: 0.7067
#
# Epoch 00134: val_loss did not improve from 0.55908
# Epoch 135/300
# 16/16 - 0s - loss: 0.2451 - accuracy: 0.8947 - val_loss: 0.6767 - val_accuracy: 0.6756
#
# Epoch 00135: val_loss did not improve from 0.55908
# Epoch 136/300
# 16/16 - 0s - loss: 0.2408 - accuracy: 0.8992 - val_loss: 0.5940 - val_accuracy: 0.6933
#
# Epoch 00136: val_loss did not improve from 0.55908
# Epoch 137/300
# 16/16 - 0s - loss: 0.2472 - accuracy: 0.8937 - val_loss: 0.6369 - val_accuracy: 0.7111
#
# Epoch 00137: val_loss did not improve from 0.55908
# Epoch 138/300
# 16/16 - 0s - loss: 0.2846 - accuracy: 0.8769 - val_loss: 0.6459 - val_accuracy: 0.6622
#
# Epoch 00138: val_loss did not improve from 0.55908
# Epoch 139/300
# 16/16 - 0s - loss: 0.2285 - accuracy: 0.9105 - val_loss: 0.5977 - val_accuracy: 0.7111
#
# Epoch 00139: val_loss did not improve from 0.55908
# Epoch 140/300
# 16/16 - 0s - loss: 0.2414 - accuracy: 0.9016 - val_loss: 0.6549 - val_accuracy: 0.6622
#
# Epoch 00140: val_loss did not improve from 0.55908
# Epoch 141/300
# 16/16 - 0s - loss: 0.2506 - accuracy: 0.8982 - val_loss: 0.5954 - val_accuracy: 0.7022
#
# Epoch 00141: val_loss did not improve from 0.55908
# Epoch 142/300
# 16/16 - 0s - loss: 0.2610 - accuracy: 0.8873 - val_loss: 0.5766 - val_accuracy: 0.6933
#
# Epoch 00142: val_loss did not improve from 0.55908
# Epoch 143/300
# 16/16 - 0s - loss: 0.2251 - accuracy: 0.9100 - val_loss: 0.6129 - val_accuracy: 0.7067
#
# Epoch 00143: val_loss did not improve from 0.55908
# Epoch 144/300
# 16/16 - 0s - loss: 0.2727 - accuracy: 0.8917 - val_loss: 0.5802 - val_accuracy: 0.7067
#
# Epoch 00144: val_loss did not improve from 0.55908
# Epoch 145/300
# 16/16 - 0s - loss: 0.2290 - accuracy: 0.9081 - val_loss: 0.6165 - val_accuracy: 0.7067
#
# Epoch 00145: val_loss did not improve from 0.55908
# Epoch 146/300
# 16/16 - 0s - loss: 0.2381 - accuracy: 0.9036 - val_loss: 0.6000 - val_accuracy: 0.6933
#
# Epoch 00146: val_loss did not improve from 0.55908
# Epoch 147/300
# 16/16 - 0s - loss: 0.2250 - accuracy: 0.8992 - val_loss: 0.6159 - val_accuracy: 0.6844
#
# Epoch 00147: val_loss did not improve from 0.55908
# Epoch 148/300
# 16/16 - 0s - loss: 0.2249 - accuracy: 0.9086 - val_loss: 0.6196 - val_accuracy: 0.6889
#
# Epoch 00148: val_loss did not improve from 0.55908
# Epoch 149/300
# 16/16 - 0s - loss: 0.2138 - accuracy: 0.9174 - val_loss: 0.6459 - val_accuracy: 0.6711
#
# Epoch 00149: val_loss did not improve from 0.55908
# Epoch 150/300
# 16/16 - 0s - loss: 0.2340 - accuracy: 0.9011 - val_loss: 0.6044 - val_accuracy: 0.7022
#
# Epoch 00150: val_loss did not improve from 0.55908
# Epoch 151/300
# 16/16 - 0s - loss: 0.2284 - accuracy: 0.9076 - val_loss: 0.6366 - val_accuracy: 0.6800
#
# Epoch 00151: val_loss did not improve from 0.55908
# 1
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 41, 128)           2816
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 41, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 128)           147584
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 64)             8256
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 208,001
# Trainable params: 208,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 16/16 - 1s - loss: 0.6976 - accuracy: 0.5230 - val_loss: 0.6933 - val_accuracy: 0.4933
#
# Epoch 00001: val_loss improved from inf to 0.69328, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 2/300
# 16/16 - 0s - loss: 0.6864 - accuracy: 0.5442 - val_loss: 0.6888 - val_accuracy: 0.5333
#
# Epoch 00002: val_loss improved from 0.69328 to 0.68879, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 3/300
# 16/16 - 0s - loss: 0.6823 - accuracy: 0.5467 - val_loss: 0.6884 - val_accuracy: 0.5422
#
# Epoch 00003: val_loss improved from 0.68879 to 0.68842, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 4/300
# 16/16 - 0s - loss: 0.6784 - accuracy: 0.5665 - val_loss: 0.6873 - val_accuracy: 0.5422
#
# Epoch 00004: val_loss improved from 0.68842 to 0.68725, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 5/300
# 16/16 - 0s - loss: 0.6696 - accuracy: 0.5863 - val_loss: 0.6826 - val_accuracy: 0.5556
#
# Epoch 00005: val_loss improved from 0.68725 to 0.68265, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 6/300
# 16/16 - 0s - loss: 0.6668 - accuracy: 0.5828 - val_loss: 0.6795 - val_accuracy: 0.5556
#
# Epoch 00006: val_loss improved from 0.68265 to 0.67946, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 7/300
# 16/16 - 0s - loss: 0.6598 - accuracy: 0.6036 - val_loss: 0.6895 - val_accuracy: 0.5556
#
# Epoch 00007: val_loss did not improve from 0.67946
# Epoch 8/300
# 16/16 - 0s - loss: 0.6593 - accuracy: 0.6115 - val_loss: 0.6778 - val_accuracy: 0.5733
#
# Epoch 00008: val_loss improved from 0.67946 to 0.67779, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 9/300
# 16/16 - 0s - loss: 0.6616 - accuracy: 0.6021 - val_loss: 0.6771 - val_accuracy: 0.5689
#
# Epoch 00009: val_loss improved from 0.67779 to 0.67709, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 10/300
# 16/16 - 0s - loss: 0.6516 - accuracy: 0.6144 - val_loss: 0.6759 - val_accuracy: 0.5733
#
# Epoch 00010: val_loss improved from 0.67709 to 0.67594, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 11/300
# 16/16 - 0s - loss: 0.6494 - accuracy: 0.6204 - val_loss: 0.6735 - val_accuracy: 0.5644
#
# Epoch 00011: val_loss improved from 0.67594 to 0.67346, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 12/300
# 16/16 - 0s - loss: 0.6484 - accuracy: 0.6258 - val_loss: 0.6735 - val_accuracy: 0.5689
#
# Epoch 00012: val_loss did not improve from 0.67346
# Epoch 13/300
# 16/16 - 0s - loss: 0.6453 - accuracy: 0.6263 - val_loss: 0.6770 - val_accuracy: 0.5733
# Epoch 00013: val_loss did not improve from 0.67346
# Epoch 14/300
# 16/16 - 0s - loss: 0.6468 - accuracy: 0.6144 - val_loss: 0.6740 - val_accuracy: 0.5644
#
# Epoch 00014: val_loss did not improve from 0.67346
# Epoch 15/300
# 16/16 - 0s - loss: 0.6370 - accuracy: 0.6431 - val_loss: 0.6668 - val_accuracy: 0.5644
#
# Epoch 00015: val_loss improved from 0.67346 to 0.66683, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 16/300
# 16/16 - 0s - loss: 0.6406 - accuracy: 0.6233 - val_loss: 0.6672 - val_accuracy: 0.5778
#
# Epoch 00016: val_loss did not improve from 0.66683
# Epoch 17/300
# 16/16 - 0s - loss: 0.6416 - accuracy: 0.6298 - val_loss: 0.6680 - val_accuracy: 0.5733
#
# Epoch 00017: val_loss did not improve from 0.66683
# Epoch 18/300
# 16/16 - 0s - loss: 0.6323 - accuracy: 0.6293 - val_loss: 0.6676 - val_accuracy: 0.6000
#
# Epoch 00018: val_loss did not improve from 0.66683
# Epoch 19/300
# 16/16 - 0s - loss: 0.6333 - accuracy: 0.6307 - val_loss: 0.6625 - val_accuracy: 0.5778
#
# Epoch 00019: val_loss improved from 0.66683 to 0.66249, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 20/300
# 16/16 - 0s - loss: 0.6256 - accuracy: 0.6466 - val_loss: 0.6577 - val_accuracy: 0.5733
#
# Epoch 00020: val_loss improved from 0.66249 to 0.65768, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 21/300
# 16/16 - 0s - loss: 0.6295 - accuracy: 0.6382 - val_loss: 0.6603 - val_accuracy: 0.5867
#
# Epoch 00021: val_loss did not improve from 0.65768
# Epoch 22/300
# 16/16 - 0s - loss: 0.6245 - accuracy: 0.6560 - val_loss: 0.6568 - val_accuracy: 0.5956
#
# Epoch 00022: val_loss improved from 0.65768 to 0.65683, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 23/300
# 16/16 - 0s - loss: 0.6194 - accuracy: 0.6510 - val_loss: 0.6520 - val_accuracy: 0.5911
#
# Epoch 00023: val_loss improved from 0.65683 to 0.65197, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 24/300
# 16/16 - 0s - loss: 0.6185 - accuracy: 0.6624 - val_loss: 0.6540 - val_accuracy: 0.5822
#
# Epoch 00024: val_loss did not improve from 0.65197
# Epoch 25/300
# 16/16 - 0s - loss: 0.6155 - accuracy: 0.6589 - val_loss: 0.6489 - val_accuracy: 0.5822
#
# Epoch 00025: val_loss improved from 0.65197 to 0.64892, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 26/300
# 16/16 - 0s - loss: 0.6109 - accuracy: 0.6525 - val_loss: 0.6463 - val_accuracy: 0.5733
#
# Epoch 00026: val_loss improved from 0.64892 to 0.64625, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 27/300
# 16/16 - 0s - loss: 0.6028 - accuracy: 0.6708 - val_loss: 0.6552 - val_accuracy: 0.6222
#
# Epoch 00027: val_loss did not improve from 0.64625
# Epoch 28/300
# 16/16 - 0s - loss: 0.5932 - accuracy: 0.6624 - val_loss: 0.6440 - val_accuracy: 0.5689
#
# Epoch 00028: val_loss improved from 0.64625 to 0.64400, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 29/300
# 16/16 - 0s - loss: 0.5963 - accuracy: 0.6797 - val_loss: 0.6458 - val_accuracy: 0.5956
#
# Epoch 00029: val_loss did not improve from 0.64400
# Epoch 30/300
# 16/16 - 0s - loss: 0.5981 - accuracy: 0.6718 - val_loss: 0.6503 - val_accuracy: 0.6356
#
# Epoch 00030: val_loss did not improve from 0.64400
# Epoch 31/300
# 16/16 - 0s - loss: 0.5882 - accuracy: 0.6876 - val_loss: 0.6528 - val_accuracy: 0.6356
#
# Epoch 00031: val_loss did not improve from 0.64400
# Epoch 32/300
# 16/16 - 0s - loss: 0.5755 - accuracy: 0.6995 - val_loss: 0.6389 - val_accuracy: 0.6089
#
# Epoch 00032: val_loss improved from 0.64400 to 0.63891, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 33/300
# 16/16 - 0s - loss: 0.5734 - accuracy: 0.6965 - val_loss: 0.6553 - val_accuracy: 0.6489
#
# Epoch 00033: val_loss did not improve from 0.63891
# Epoch 34/300
# 16/16 - 0s - loss: 0.5842 - accuracy: 0.6817 - val_loss: 0.6320 - val_accuracy: 0.5911
#
# Epoch 00034: val_loss improved from 0.63891 to 0.63202, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 35/300
# 16/16 - 0s - loss: 0.5772 - accuracy: 0.6896 - val_loss: 0.6307 - val_accuracy: 0.6267
#
# Epoch 00035: val_loss improved from 0.63202 to 0.63073, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 36/300
# 16/16 - 0s - loss: 0.5608 - accuracy: 0.7133 - val_loss: 0.6427 - val_accuracy: 0.6667
#
# Epoch 00036: val_loss did not improve from 0.63073
# Epoch 37/300
# 16/16 - 0s - loss: 0.5632 - accuracy: 0.6945 - val_loss: 0.6336 - val_accuracy: 0.6533
#
# Epoch 00037: val_loss did not improve from 0.63073
# Epoch 38/300
# 16/16 - 0s - loss: 0.5588 - accuracy: 0.7098 - val_loss: 0.6546 - val_accuracy: 0.5556
#
# Epoch 00038: val_loss did not improve from 0.63073
# Epoch 39/300
# 16/16 - 0s - loss: 0.5615 - accuracy: 0.7064 - val_loss: 0.6219 - val_accuracy: 0.6622
#
# Epoch 00039: val_loss improved from 0.63073 to 0.62190, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 40/300
# 16/16 - 0s - loss: 0.5676 - accuracy: 0.7064 - val_loss: 0.6302 - val_accuracy: 0.6800
#
# Epoch 00040: val_loss did not improve from 0.62190
# Epoch 41/300
# 16/16 - 0s - loss: 0.5353 - accuracy: 0.7291 - val_loss: 0.6644 - val_accuracy: 0.6222
#
# Epoch 00041: val_loss did not improve from 0.62190
# Epoch 42/300
# 16/16 - 0s - loss: 0.5474 - accuracy: 0.7123 - val_loss: 0.6264 - val_accuracy: 0.6800
#
# Epoch 00042: val_loss did not improve from 0.62190
# Epoch 43/300
# 16/16 - 0s - loss: 0.5349 - accuracy: 0.7257 - val_loss: 0.6251 - val_accuracy: 0.6533
#
# Epoch 00043: val_loss did not improve from 0.62190
# Epoch 44/300
# 16/16 - 0s - loss: 0.5340 - accuracy: 0.7311 - val_loss: 0.6227 - val_accuracy: 0.6889
#
# Epoch 00044: val_loss did not improve from 0.62190
# Epoch 45/300
# 16/16 - 0s - loss: 0.5216 - accuracy: 0.7390 - val_loss: 0.6232 - val_accuracy: 0.6000
#
# Epoch 00045: val_loss did not improve from 0.62190
# Epoch 46/300
# 16/16 - 0s - loss: 0.5441 - accuracy: 0.7257 - val_loss: 0.6566 - val_accuracy: 0.6400
#
# Epoch 00046: val_loss did not improve from 0.62190
# Epoch 47/300
# 16/16 - 0s - loss: 0.5426 - accuracy: 0.7301 - val_loss: 0.6186 - val_accuracy: 0.6044
#
# Epoch 00047: val_loss improved from 0.62190 to 0.61860, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 48/300
# 16/16 - 0s - loss: 0.5269 - accuracy: 0.7296 - val_loss: 0.6325 - val_accuracy: 0.6622
#
# Epoch 00048: val_loss did not improve from 0.61860
# Epoch 49/300
# 16/16 - 0s - loss: 0.5072 - accuracy: 0.7420 - val_loss: 0.6138 - val_accuracy: 0.6667
#
# Epoch 00049: val_loss improved from 0.61860 to 0.61382, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 50/300
# 16/16 - 0s - loss: 0.5246 - accuracy: 0.7405 - val_loss: 0.6102 - val_accuracy: 0.6178
#
# Epoch 00050: val_loss improved from 0.61382 to 0.61020, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 51/300
# 16/16 - 0s - loss: 0.5067 - accuracy: 0.7410 - val_loss: 0.6066 - val_accuracy: 0.6489
#
# Epoch 00051: val_loss improved from 0.61020 to 0.60664, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_1.h5
# Epoch 52/300
# 16/16 - 0s - loss: 0.5128 - accuracy: 0.7504 - val_loss: 0.6326 - val_accuracy: 0.6711
#
# Epoch 00052: val_loss did not improve from 0.60664
# Epoch 53/300
# 16/16 - 0s - loss: 0.4970 - accuracy: 0.7622 - val_loss: 0.6100 - val_accuracy: 0.6000
#
# Epoch 00053: val_loss did not improve from 0.60664
# Epoch 54/300
# 16/16 - 0s - loss: 0.4981 - accuracy: 0.7504 - val_loss: 0.6103 - val_accuracy: 0.6489
#
# Epoch 00054: val_loss did not improve from 0.60664
# Epoch 55/300
# 16/16 - 0s - loss: 0.4972 - accuracy: 0.7622 - val_loss: 0.6161 - val_accuracy: 0.6267
#
# Epoch 00055: val_loss did not improve from 0.60664
# Epoch 56/300
# 16/16 - 0s - loss: 0.4969 - accuracy: 0.7479 - val_loss: 0.6225 - val_accuracy: 0.6400
#
# Epoch 00056: val_loss did not improve from 0.60664
# Epoch 57/300
# 16/16 - 0s - loss: 0.4904 - accuracy: 0.7598 - val_loss: 0.6255 - val_accuracy: 0.6489
#
# Epoch 00057: val_loss did not improve from 0.60664
# Epoch 58/300
# 16/16 - 0s - loss: 0.4921 - accuracy: 0.7484 - val_loss: 0.6443 - val_accuracy: 0.6578
# Epoch 00058: val_loss did not improve from 0.60664
# Epoch 59/300
# 16/16 - 0s - loss: 0.4775 - accuracy: 0.7672 - val_loss: 0.6445 - val_accuracy: 0.6489
#
# Epoch 00059: val_loss did not improve from 0.60664
# Epoch 60/300
# 16/16 - 0s - loss: 0.4896 - accuracy: 0.7538 - val_loss: 0.6458 - val_accuracy: 0.6400
#
# Epoch 00060: val_loss did not improve from 0.60664
# Epoch 61/300
# 16/16 - 0s - loss: 0.4824 - accuracy: 0.7632 - val_loss: 0.6167 - val_accuracy: 0.6178
#
# Epoch 00061: val_loss did not improve from 0.60664
# Epoch 62/300
# 16/16 - 0s - loss: 0.4828 - accuracy: 0.7603 - val_loss: 0.6234 - val_accuracy: 0.6400
#
# Epoch 00062: val_loss did not improve from 0.60664
# Epoch 63/300
# 16/16 - 0s - loss: 0.4768 - accuracy: 0.7647 - val_loss: 0.6134 - val_accuracy: 0.6444
#
# Epoch 00063: val_loss did not improve from 0.60664
# Epoch 64/300
# 16/16 - 0s - loss: 0.4767 - accuracy: 0.7701 - val_loss: 0.6126 - val_accuracy: 0.6622
#
# Epoch 00064: val_loss did not improve from 0.60664
# Epoch 65/300
# 16/16 - 0s - loss: 0.4676 - accuracy: 0.7701 - val_loss: 0.6137 - val_accuracy: 0.6400
#
# Epoch 00065: val_loss did not improve from 0.60664
# Epoch 66/300
# 16/16 - 0s - loss: 0.4591 - accuracy: 0.7647 - val_loss: 0.6246 - val_accuracy: 0.6178
#
# Epoch 00066: val_loss did not improve from 0.60664
# Epoch 67/300
# 16/16 - 0s - loss: 0.4427 - accuracy: 0.7820 - val_loss: 0.6263 - val_accuracy: 0.6533
#
# Epoch 00067: val_loss did not improve from 0.60664
# Epoch 68/300
# 16/16 - 0s - loss: 0.4509 - accuracy: 0.7820 - val_loss: 0.6356 - val_accuracy: 0.6489
#
# Epoch 00068: val_loss did not improve from 0.60664
# Epoch 69/300
# 16/16 - 0s - loss: 0.4737 - accuracy: 0.7637 - val_loss: 0.6139 - val_accuracy: 0.6444
#
# Epoch 00069: val_loss did not improve from 0.60664
# Epoch 70/300
# 16/16 - 0s - loss: 0.4498 - accuracy: 0.7850 - val_loss: 0.6281 - val_accuracy: 0.6044
#
# Epoch 00070: val_loss did not improve from 0.60664
# Epoch 71/300
# 16/16 - 0s - loss: 0.4250 - accuracy: 0.8043 - val_loss: 0.6341 - val_accuracy: 0.5956
#
# Epoch 00071: val_loss did not improve from 0.60664
# Epoch 72/300
# 16/16 - 0s - loss: 0.4382 - accuracy: 0.7939 - val_loss: 0.6529 - val_accuracy: 0.6533
#
# Epoch 00072: val_loss did not improve from 0.60664
# Epoch 73/300
# 16/16 - 0s - loss: 0.4346 - accuracy: 0.7973 - val_loss: 0.6676 - val_accuracy: 0.6444
#
# Epoch 00073: val_loss did not improve from 0.60664
# Epoch 74/300
# 16/16 - 0s - loss: 0.4210 - accuracy: 0.8028 - val_loss: 0.6122 - val_accuracy: 0.6489
#
# Epoch 00074: val_loss did not improve from 0.60664
# Epoch 75/300
# 16/16 - 0s - loss: 0.4504 - accuracy: 0.7761 - val_loss: 0.6122 - val_accuracy: 0.6622
#
# Epoch 00075: val_loss did not improve from 0.60664
# Epoch 76/300
# 16/16 - 0s - loss: 0.4307 - accuracy: 0.7914 - val_loss: 0.6089 - val_accuracy: 0.6356
#
# Epoch 00076: val_loss did not improve from 0.60664
# Epoch 77/300
# 16/16 - 0s - loss: 0.4140 - accuracy: 0.7973 - val_loss: 0.6169 - val_accuracy: 0.6267
#
# Epoch 00077: val_loss did not improve from 0.60664
# Epoch 78/300
# 16/16 - 0s - loss: 0.4227 - accuracy: 0.7978 - val_loss: 0.6376 - val_accuracy: 0.6356
#
# Epoch 00078: val_loss did not improve from 0.60664
# Epoch 79/300
# 16/16 - 0s - loss: 0.4164 - accuracy: 0.8072 - val_loss: 0.6218 - val_accuracy: 0.6222
#
# Epoch 00079: val_loss did not improve from 0.60664
# Epoch 80/300
# 16/16 - 0s - loss: 0.4097 - accuracy: 0.8087 - val_loss: 0.6567 - val_accuracy: 0.6533
#
# Epoch 00080: val_loss did not improve from 0.60664
# Epoch 81/300
# 16/16 - 0s - loss: 0.4029 - accuracy: 0.8146 - val_loss: 0.6761 - val_accuracy: 0.6267
#
# Epoch 00081: val_loss did not improve from 0.60664
# Epoch 82/300
# 16/16 - 0s - loss: 0.4121 - accuracy: 0.8008 - val_loss: 0.6596 - val_accuracy: 0.5956
#
# Epoch 00082: val_loss did not improve from 0.60664
# Epoch 83/300
# 16/16 - 0s - loss: 0.3915 - accuracy: 0.8146 - val_loss: 0.6402 - val_accuracy: 0.6311
#
# Epoch 00083: val_loss did not improve from 0.60664
# Epoch 84/300
# 16/16 - 0s - loss: 0.3879 - accuracy: 0.8176 - val_loss: 0.6642 - val_accuracy: 0.6044
#
# Epoch 00084: val_loss did not improve from 0.60664
# Epoch 85/300
# 16/16 - 0s - loss: 0.3816 - accuracy: 0.8216 - val_loss: 0.6457 - val_accuracy: 0.6089
#
# Epoch 00085: val_loss did not improve from 0.60664
# Epoch 86/300
# 16/16 - 0s - loss: 0.4068 - accuracy: 0.8196 - val_loss: 0.6137 - val_accuracy: 0.6578
#
# Epoch 00086: val_loss did not improve from 0.60664
# Epoch 87/300
# 16/16 - 0s - loss: 0.4042 - accuracy: 0.8102 - val_loss: 0.6245 - val_accuracy: 0.6356
#
# Epoch 00087: val_loss did not improve from 0.60664
# Epoch 88/300
# 16/16 - 0s - loss: 0.3864 - accuracy: 0.8216 - val_loss: 0.6266 - val_accuracy: 0.6356
#
# Epoch 00088: val_loss did not improve from 0.60664
# Epoch 89/300
# 16/16 - 0s - loss: 0.3882 - accuracy: 0.8260 - val_loss: 0.6485 - val_accuracy: 0.6356
#
# Epoch 00089: val_loss did not improve from 0.60664
# Epoch 90/300
# 16/16 - 0s - loss: 0.3769 - accuracy: 0.8309 - val_loss: 0.6435 - val_accuracy: 0.6356
#
# Epoch 00090: val_loss did not improve from 0.60664
# Epoch 91/300
# 16/16 - 0s - loss: 0.3594 - accuracy: 0.8359 - val_loss: 0.6179 - val_accuracy: 0.6356
#
# Epoch 00091: val_loss did not improve from 0.60664
# Epoch 92/300
# 16/16 - 0s - loss: 0.3894 - accuracy: 0.8112 - val_loss: 0.6274 - val_accuracy: 0.6489
#
# Epoch 00092: val_loss did not improve from 0.60664
# Epoch 93/300
# 16/16 - 0s - loss: 0.3574 - accuracy: 0.8473 - val_loss: 0.6134 - val_accuracy: 0.6356
#
# Epoch 00093: val_loss did not improve from 0.60664
# Epoch 94/300
# 16/16 - 0s - loss: 0.3693 - accuracy: 0.8280 - val_loss: 0.6175 - val_accuracy: 0.6356
#
# Epoch 00094: val_loss did not improve from 0.60664
# Epoch 95/300
# 16/16 - 0s - loss: 0.3625 - accuracy: 0.8403 - val_loss: 0.6184 - val_accuracy: 0.6222
#
# Epoch 00095: val_loss did not improve from 0.60664
# Epoch 96/300
# 16/16 - 0s - loss: 0.3418 - accuracy: 0.8453 - val_loss: 0.6284 - val_accuracy: 0.6222
#
# Epoch 00096: val_loss did not improve from 0.60664
# Epoch 97/300
# 16/16 - 0s - loss: 0.3750 - accuracy: 0.8339 - val_loss: 0.6300 - val_accuracy: 0.6311
#
# Epoch 00097: val_loss did not improve from 0.60664
# Epoch 98/300
# 16/16 - 0s - loss: 0.3454 - accuracy: 0.8418 - val_loss: 0.6286 - val_accuracy: 0.6400
#
# Epoch 00098: val_loss did not improve from 0.60664
# Epoch 99/300
# 16/16 - 0s - loss: 0.3665 - accuracy: 0.8349 - val_loss: 0.6353 - val_accuracy: 0.6444
#
# Epoch 00099: val_loss did not improve from 0.60664
# Epoch 100/300
# 16/16 - 0s - loss: 0.3387 - accuracy: 0.8581 - val_loss: 0.6416 - val_accuracy: 0.6311
#
# Epoch 00100: val_loss did not improve from 0.60664
# Epoch 101/300
# 16/16 - 0s - loss: 0.3252 - accuracy: 0.8621 - val_loss: 0.6229 - val_accuracy: 0.6578
#
# Epoch 00101: val_loss did not improve from 0.60664
# 2
# Model: "sequential_2"
# _________________________________________________________________
# ...
#
# Epoch 00003: val_loss improved from 0.69195 to 0.68625, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 4/300
# 16/16 - 0s - loss: 0.6845 - accuracy: 0.5420 - val_loss: 0.6822 - val_accuracy: 0.5580
#
# Epoch 00004: val_loss improved from 0.68625 to 0.68223, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 5/300
# 16/16 - 0s - loss: 0.6739 - accuracy: 0.5879 - val_loss: 0.6854 - val_accuracy: 0.5223
#
# Epoch 00005: val_loss did not improve from 0.68223
# Epoch 6/300
# 16/16 - 0s - loss: 0.6732 - accuracy: 0.5810 - val_loss: 0.6691 - val_accuracy: 0.6161
#
# Epoch 00006: val_loss improved from 0.68223 to 0.66908, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 7/300
# 16/16 - 0s - loss: 0.6755 - accuracy: 0.5909 - val_loss: 0.6698 - val_accuracy: 0.5893
#
# Epoch 00007: val_loss did not improve from 0.66908
# Epoch 8/300
# 16/16 - 0s - loss: 0.6702 - accuracy: 0.5692 - val_loss: 0.6674 - val_accuracy: 0.6161
#
# Epoch 00008: val_loss improved from 0.66908 to 0.66740, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 9/300
# 16/16 - 0s - loss: 0.6594 - accuracy: 0.6092 - val_loss: 0.6689 - val_accuracy: 0.5848
#
# Epoch 00009: val_loss did not improve from 0.66740
# Epoch 10/300
# 16/16 - 0s - loss: 0.6664 - accuracy: 0.6052 - val_loss: 0.6589 - val_accuracy: 0.5982
#
# Epoch 00010: val_loss improved from 0.66740 to 0.65886, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 11/300
# 16/16 - 0s - loss: 0.6550 - accuracy: 0.6087 - val_loss: 0.6559 - val_accuracy: 0.6027
#
# Epoch 00011: val_loss improved from 0.65886 to 0.65590, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 12/300
# 16/16 - 0s - loss: 0.6642 - accuracy: 0.5983 - val_loss: 0.6525 - val_accuracy: 0.6205
#
# Epoch 00012: val_loss improved from 0.65590 to 0.65246, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 13/300
# 16/16 - 0s - loss: 0.6509 - accuracy: 0.6181 - val_loss: 0.6495 - val_accuracy: 0.6116
#
# Epoch 00013: val_loss improved from 0.65246 to 0.64951, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 14/300
# 16/16 - 0s - loss: 0.6586 - accuracy: 0.6107 - val_loss: 0.6486 - val_accuracy: 0.6250
#
# Epoch 00014: val_loss improved from 0.64951 to 0.64859, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 15/300
# 16/16 - 0s - loss: 0.6474 - accuracy: 0.6186 - val_loss: 0.6554 - val_accuracy: 0.6205
#
# Epoch 00015: val_loss did not improve from 0.64859
# Epoch 16/300
# 16/16 - 0s - loss: 0.6509 - accuracy: 0.6102 - val_loss: 0.6470 - val_accuracy: 0.6473
#
# Epoch 00016: val_loss improved from 0.64859 to 0.64701, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 17/300
# 16/16 - 0s - loss: 0.6544 - accuracy: 0.6151 - val_loss: 0.6529 - val_accuracy: 0.6429
#
# Epoch 00017: val_loss did not improve from 0.64701
# Epoch 18/300
# 16/16 - 0s - loss: 0.6497 - accuracy: 0.6220 - val_loss: 0.6501 - val_accuracy: 0.6429
#
# Epoch 00018: val_loss did not improve from 0.64701
# Epoch 19/300
# 16/16 - 0s - loss: 0.6372 - accuracy: 0.6280 - val_loss: 0.6489 - val_accuracy: 0.6161
#
# Epoch 00019: val_loss did not improve from 0.64701
# Epoch 20/300
# 16/16 - 0s - loss: 0.6467 - accuracy: 0.6181 - val_loss: 0.6425 - val_accuracy: 0.6473
#
# Epoch 00020: val_loss improved from 0.64701 to 0.64251, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 21/300
# 16/16 - 0s - loss: 0.6397 - accuracy: 0.6250 - val_loss: 0.6352 - val_accuracy: 0.6473
#
# Epoch 00021: val_loss improved from 0.64251 to 0.63517, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 22/300
# 16/16 - 0s - loss: 0.6374 - accuracy: 0.6344 - val_loss: 0.6593 - val_accuracy: 0.5759
#
# Epoch 00022: val_loss did not improve from 0.63517
# Epoch 23/300
# 16/16 - 0s - loss: 0.6263 - accuracy: 0.6566 - val_loss: 0.6301 - val_accuracy: 0.6607
#
# Epoch 00023: val_loss improved from 0.63517 to 0.63010, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 24/300
# 16/16 - 0s - loss: 0.6164 - accuracy: 0.6586 - val_loss: 0.6288 - val_accuracy: 0.6607
# Epoch 00024: val_loss improved from 0.63010 to 0.62876, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 25/300
# 16/16 - 0s - loss: 0.6160 - accuracy: 0.6680 - val_loss: 0.6261 - val_accuracy: 0.6384
#
# Epoch 00025: val_loss improved from 0.62876 to 0.62607, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 26/300
# 16/16 - 0s - loss: 0.6170 - accuracy: 0.6576 - val_loss: 0.6241 - val_accuracy: 0.6607
#
# Epoch 00026: val_loss improved from 0.62607 to 0.62409, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 27/300
# 16/16 - 0s - loss: 0.6114 - accuracy: 0.6709 - val_loss: 0.6228 - val_accuracy: 0.6562
#
# Epoch 00027: val_loss improved from 0.62409 to 0.62283, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 28/300
# 16/16 - 0s - loss: 0.6167 - accuracy: 0.6477 - val_loss: 0.6294 - val_accuracy: 0.6473
#
# Epoch 00028: val_loss did not improve from 0.62283
# Epoch 29/300
# 16/16 - 0s - loss: 0.6142 - accuracy: 0.6670 - val_loss: 0.6105 - val_accuracy: 0.7188
#
# Epoch 00029: val_loss improved from 0.62283 to 0.61049, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 30/300
# 16/16 - 0s - loss: 0.6082 - accuracy: 0.6532 - val_loss: 0.6129 - val_accuracy: 0.6920
#
# Epoch 00030: val_loss did not improve from 0.61049
# Epoch 31/300
# 16/16 - 0s - loss: 0.6024 - accuracy: 0.6640 - val_loss: 0.6251 - val_accuracy: 0.6562
#
# Epoch 00031: val_loss did not improve from 0.61049
# Epoch 32/300
# 16/16 - 0s - loss: 0.5926 - accuracy: 0.6749 - val_loss: 0.6072 - val_accuracy: 0.6875
#
# Epoch 00032: val_loss improved from 0.61049 to 0.60721, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 33/300
# 16/16 - 0s - loss: 0.6002 - accuracy: 0.6724 - val_loss: 0.6012 - val_accuracy: 0.7143
#
# Epoch 00033: val_loss improved from 0.60721 to 0.60120, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 34/300
# 16/16 - 0s - loss: 0.5776 - accuracy: 0.6813 - val_loss: 0.5856 - val_accuracy: 0.7321
#
# Epoch 00034: val_loss improved from 0.60120 to 0.58565, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 35/300
# 16/16 - 0s - loss: 0.5863 - accuracy: 0.6952 - val_loss: 0.6026 - val_accuracy: 0.6786
#
# Epoch 00035: val_loss did not improve from 0.58565
# Epoch 36/300
# 16/16 - 0s - loss: 0.5797 - accuracy: 0.6942 - val_loss: 0.5833 - val_accuracy: 0.7188
#
# Epoch 00036: val_loss improved from 0.58565 to 0.58334, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 37/300
# 16/16 - 0s - loss: 0.5798 - accuracy: 0.6863 - val_loss: 0.6034 - val_accuracy: 0.7098
#
# Epoch 00037: val_loss did not improve from 0.58334
# Epoch 38/300
# 16/16 - 0s - loss: 0.5759 - accuracy: 0.6991 - val_loss: 0.6230 - val_accuracy: 0.6473
#
# Epoch 00038: val_loss did not improve from 0.58334
# Epoch 39/300
# 16/16 - 0s - loss: 0.5579 - accuracy: 0.7075 - val_loss: 0.5861 - val_accuracy: 0.7054
#
# Epoch 00039: val_loss did not improve from 0.58334
# Epoch 40/300
# 16/16 - 0s - loss: 0.5483 - accuracy: 0.7164 - val_loss: 0.5845 - val_accuracy: 0.7143
#
# Epoch 00040: val_loss did not improve from 0.58334
# Epoch 41/300
# 16/16 - 0s - loss: 0.5669 - accuracy: 0.7041 - val_loss: 0.5945 - val_accuracy: 0.6696
#
# Epoch 00041: val_loss did not improve from 0.58334
# Epoch 42/300
# 16/16 - 0s - loss: 0.5512 - accuracy: 0.7159 - val_loss: 0.6088 - val_accuracy: 0.6429
#
# Epoch 00042: val_loss did not improve from 0.58334
# Epoch 43/300
# 16/16 - 0s - loss: 0.5558 - accuracy: 0.7055 - val_loss: 0.5802 - val_accuracy: 0.7143
#
# Epoch 00043: val_loss improved from 0.58334 to 0.58022, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 44/300
# 16/16 - 0s - loss: 0.5489 - accuracy: 0.7169 - val_loss: 0.5758 - val_accuracy: 0.6964
#
# Epoch 00044: val_loss improved from 0.58022 to 0.57581, saving model to D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\_9.h5
# Epoch 45/300
# 16/16 - 0s - loss: 0.5611 - accuracy: 0.6927 - val_loss: 0.5974 - val_accuracy: 0.6964
#
# Epoch 00045: val_loss did not improve from 0.57581
# Epoch 46/300
# 16/16 - 0s - loss: 0.5422 - accuracy: 0.7045 - val_loss: 0.5872 - val_accuracy: 0.7188
#
# Epoch 00046: val_loss did not improve from 0.57581
# Epoch 47/300
# 16/16 - 0s - loss: 0.5338 - accuracy: 0.7248 - val_loss: 0.6327 - val_accuracy: 0.6339
#
# Epoch 00047: val_loss did not improve from 0.57581
# Epoch 48/300
# 16/16 - 0s - loss: 0.5304 - accuracy: 0.7322 - val_loss: 0.5818 - val_accuracy: 0.7321
#
# Epoch 00048: val_loss did not improve from 0.57581
# Epoch 49/300
# 16/16 - 0s - loss: 0.5344 - accuracy: 0.7179 - val_loss: 0.5815 - val_accuracy: 0.7143
#
# Epoch 00049: val_loss did not improve from 0.57581
# Epoch 50/300
# 16/16 - 0s - loss: 0.5174 - accuracy: 0.7406 - val_loss: 0.6028 - val_accuracy: 0.6741
#
# Epoch 00050: val_loss did not improve from 0.57581
# Epoch 51/300
# 16/16 - 0s - loss: 0.5353 - accuracy: 0.7204 - val_loss: 0.5769 - val_accuracy: 0.7098
#
# Epoch 00051: val_loss did not improve from 0.57581
# Epoch 52/300
# 16/16 - 0s - loss: 0.5147 - accuracy: 0.7406 - val_loss: 0.6015 - val_accuracy: 0.6607
#
# Epoch 00052: val_loss did not improve from 0.57581
# Epoch 53/300
# 16/16 - 0s - loss: 0.5203 - accuracy: 0.7396 - val_loss: 0.5866 - val_accuracy: 0.7143
#
# Epoch 00053: val_loss did not improve from 0.57581
# Epoch 54/300
# 16/16 - 0s - loss: 0.5068 - accuracy: 0.7480 - val_loss: 0.5922 - val_accuracy: 0.6786
#
# Epoch 00054: val_loss did not improve from 0.57581
# Epoch 55/300
# 16/16 - 0s - loss: 0.5219 - accuracy: 0.7337 - val_loss: 0.5963 - val_accuracy: 0.7009
#
# Epoch 00055: val_loss did not improve from 0.57581
# Epoch 56/300
# 16/16 - 0s - loss: 0.5113 - accuracy: 0.7495 - val_loss: 0.5788 - val_accuracy: 0.6964
#
# Epoch 00056: val_loss did not improve from 0.57581
# Epoch 57/300
# 16/16 - 0s - loss: 0.4927 - accuracy: 0.7460 - val_loss: 0.6409 - val_accuracy: 0.6250
#
# Epoch 00057: val_loss did not improve from 0.57581
# Epoch 58/300
# 16/16 - 0s - loss: 0.4962 - accuracy: 0.7609 - val_loss: 0.5917 - val_accuracy: 0.7098
#
# Epoch 00058: val_loss did not improve from 0.57581
# Epoch 59/300
# 16/16 - 0s - loss: 0.5024 - accuracy: 0.7451 - val_loss: 0.5881 - val_accuracy: 0.7143
#
# Epoch 00059: val_loss did not improve from 0.57581
# Epoch 60/300
# 16/16 - 0s - loss: 0.4727 - accuracy: 0.7683 - val_loss: 0.5874 - val_accuracy: 0.7098
#
# Epoch 00060: val_loss did not improve from 0.57581
# Epoch 61/300
# 16/16 - 0s - loss: 0.5090 - accuracy: 0.7530 - val_loss: 0.5780 - val_accuracy: 0.6786
#
# Epoch 00061: val_loss did not improve from 0.57581
# Epoch 62/300
# 16/16 - 0s - loss: 0.4706 - accuracy: 0.7777 - val_loss: 0.5765 - val_accuracy: 0.6875
#
# Epoch 00062: val_loss did not improve from 0.57581
# Epoch 63/300
# 16/16 - 0s - loss: 0.4700 - accuracy: 0.7693 - val_loss: 0.5960 - val_accuracy: 0.6786
#
# Epoch 00063: val_loss did not improve from 0.57581
# Epoch 64/300
# 16/16 - 0s - loss: 0.4901 - accuracy: 0.7594 - val_loss: 0.5805 - val_accuracy: 0.7009
#
# Epoch 00064: val_loss did not improve from 0.57581
# Epoch 65/300
# 16/16 - 0s - loss: 0.4607 - accuracy: 0.7796 - val_loss: 0.5948 - val_accuracy: 0.7143
#
# Epoch 00065: val_loss did not improve from 0.57581
# Epoch 66/300
# 16/16 - 0s - loss: 0.4652 - accuracy: 0.7678 - val_loss: 0.5789 - val_accuracy: 0.7009
#
# Epoch 00066: val_loss did not improve from 0.57581
# Epoch 67/300
# 16/16 - 0s - loss: 0.4721 - accuracy: 0.7693 - val_loss: 0.6158 - val_accuracy: 0.6562
#
# Epoch 00067: val_loss did not improve from 0.57581
# Epoch 68/300
# 16/16 - 0s - loss: 0.4666 - accuracy: 0.7678 - val_loss: 0.5899 - val_accuracy: 0.6830
#
# Epoch 00068: val_loss did not improve from 0.57581
# Epoch 69/300
# 16/16 - 0s - loss: 0.4546 - accuracy: 0.7836 - val_loss: 0.6119 - val_accuracy: 0.6429
#
# Epoch 00069: val_loss did not improve from 0.57581
# Epoch 70/300
# 16/16 - 0s - loss: 0.4593 - accuracy: 0.7796 - val_loss: 0.6365 - val_accuracy: 0.6696
#
# Epoch 00070: val_loss did not improve from 0.57581
# Epoch 71/300
# 16/16 - 0s - loss: 0.4465 - accuracy: 0.7846 - val_loss: 0.5980 - val_accuracy: 0.6830
#
# Epoch 00071: val_loss did not improve from 0.57581
# Epoch 72/300
# 16/16 - 0s - loss: 0.4529 - accuracy: 0.7841 - val_loss: 0.5938 - val_accuracy: 0.6652
# Epoch 00072: val_loss did not improve from 0.57581
# Epoch 73/300
# 16/16 - 0s - loss: 0.4400 - accuracy: 0.7974 - val_loss: 0.5941 - val_accuracy: 0.6652
#
# Epoch 00073: val_loss did not improve from 0.57581
# Epoch 74/300
# 16/16 - 0s - loss: 0.4502 - accuracy: 0.7905 - val_loss: 0.5917 - val_accuracy: 0.7143
#
# Epoch 00074: val_loss did not improve from 0.57581
# Epoch 75/300
# 16/16 - 0s - loss: 0.4413 - accuracy: 0.7851 - val_loss: 0.6087 - val_accuracy: 0.6518
#
# Epoch 00075: val_loss did not improve from 0.57581
# Epoch 76/300
# 16/16 - 0s - loss: 0.4460 - accuracy: 0.7816 - val_loss: 0.5965 - val_accuracy: 0.6741
#
# Epoch 00076: val_loss did not improve from 0.57581
# Epoch 77/300
# 16/16 - 0s - loss: 0.4072 - accuracy: 0.8132 - val_loss: 0.6070 - val_accuracy: 0.7098
#
# Epoch 00077: val_loss did not improve from 0.57581
# Epoch 78/300
# 16/16 - 0s - loss: 0.4291 - accuracy: 0.8083 - val_loss: 0.6544 - val_accuracy: 0.6384
#
# Epoch 00078: val_loss did not improve from 0.57581
# Epoch 79/300
# 16/16 - 0s - loss: 0.4351 - accuracy: 0.7836 - val_loss: 0.6027 - val_accuracy: 0.7009
#
# Epoch 00079: val_loss did not improve from 0.57581
# Epoch 80/300
# 16/16 - 0s - loss: 0.4180 - accuracy: 0.8058 - val_loss: 0.6001 - val_accuracy: 0.6607
#
# Epoch 00080: val_loss did not improve from 0.57581
# Epoch 81/300
# 16/16 - 0s - loss: 0.4152 - accuracy: 0.8004 - val_loss: 0.5998 - val_accuracy: 0.6473
#
# Epoch 00081: val_loss did not improve from 0.57581
# Epoch 82/300
# 16/16 - 0s - loss: 0.4012 - accuracy: 0.8098 - val_loss: 0.5966 - val_accuracy: 0.6964
#
# Epoch 00082: val_loss did not improve from 0.57581
# Epoch 83/300
# 16/16 - 0s - loss: 0.4072 - accuracy: 0.8093 - val_loss: 0.5952 - val_accuracy: 0.6964
#
# Epoch 00083: val_loss did not improve from 0.57581
# Epoch 84/300
# 16/16 - 0s - loss: 0.4269 - accuracy: 0.7925 - val_loss: 0.5967 - val_accuracy: 0.7009
#
# Epoch 00084: val_loss did not improve from 0.57581
# Epoch 85/300
# 16/16 - 0s - loss: 0.4016 - accuracy: 0.8137 - val_loss: 0.6324 - val_accuracy: 0.6696
#
# Epoch 00085: val_loss did not improve from 0.57581
# Epoch 86/300
# 16/16 - 0s - loss: 0.4119 - accuracy: 0.8039 - val_loss: 0.6050 - val_accuracy: 0.6652
#
# Epoch 00086: val_loss did not improve from 0.57581
# Epoch 87/300
# 16/16 - 0s - loss: 0.3888 - accuracy: 0.8207 - val_loss: 0.6321 - val_accuracy: 0.6652
#
# Epoch 00087: val_loss did not improve from 0.57581
# Epoch 88/300
# 16/16 - 0s - loss: 0.4026 - accuracy: 0.8073 - val_loss: 0.6274 - val_accuracy: 0.6518
#
# Epoch 00088: val_loss did not improve from 0.57581
# Epoch 89/300
# 16/16 - 0s - loss: 0.3760 - accuracy: 0.8384 - val_loss: 0.6007 - val_accuracy: 0.6786
#
# Epoch 00089: val_loss did not improve from 0.57581
# Epoch 90/300
# 16/16 - 0s - loss: 0.3812 - accuracy: 0.8266 - val_loss: 0.6248 - val_accuracy: 0.6875
#
# Epoch 00090: val_loss did not improve from 0.57581
# Epoch 91/300
# 16/16 - 0s - loss: 0.3835 - accuracy: 0.8167 - val_loss: 0.6017 - val_accuracy: 0.6830
#
# Epoch 00091: val_loss did not improve from 0.57581
# Epoch 92/300
# 16/16 - 0s - loss: 0.4109 - accuracy: 0.8063 - val_loss: 0.5986 - val_accuracy: 0.6875
#
# Epoch 00092: val_loss did not improve from 0.57581
# Epoch 93/300
# 16/16 - 0s - loss: 0.3720 - accuracy: 0.8355 - val_loss: 0.6026 - val_accuracy: 0.6696
#
# Epoch 00093: val_loss did not improve from 0.57581
# Epoch 94/300
# 16/16 - 0s - loss: 0.3618 - accuracy: 0.8424 - val_loss: 0.6162 - val_accuracy: 0.6786
#
# Epoch 00094: val_loss did not improve from 0.57581
# 10

# %%
#遍历表格求初始里程
#交叉验证
import os
os.chdir(r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new')
path = r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\result\val'
filenames=os.listdir(path)#得到字符串列表
scores_val=[]
lables_val=[]
fpr_list_val = []
tpr_list_val = []
roc_auc_list_val=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_val=data.iloc[:,1]
        scores_val.append(score_val)
        lable_val = data.iloc[:,2]
        lables_val.append(lable_val)
        fpr_val,tpr_val,thresholds_val= roc_curve(lables_val[i],scores_val[i])   #y_true,y_score
        fpr_list_val.append(fpr_val)
        tpr_list_val.append(tpr_val)
        roc_auc_val = auc(fpr_val,tpr_val)
        roc_auc_list_val.append(roc_auc_val)
        i+=1

# %%
roc_auc_list_val
# Out:
# [0.773625158027813,
#  0.7354113520408164,
#  0.7234513274336283,
#  0.7392541087231352,
#  0.7393331226295828,
#  0.779393173198483,
#  0.7246365360303414,
#  0.7628002528445006,
#  0.7679361567635904,
#  0.739078443877551]

# %%
i=1
tprs_val = []
mean_fpr_val = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Validation ROC')
for fpr_val,tpr_val,roc_auc_val in zip(fpr_list_val,tpr_list_val,roc_auc_list_val):
    tprs_val.append(np.interp(mean_fpr_val, fpr_val, tpr_val))
    tprs_val[-1][0] = 0.0
    plt.plot(fpr_val, tpr_val, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_val)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_val.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_val = np.mean(tprs_val, axis=0)
mean_tpr_val[-1] = 1.0
mean_auc_val = auc(mean_fpr_val, mean_tpr_val)
std_auc_val = np.std(roc_auc_list_val)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_val, std_auc_val),lw=2, alpha=.8)
plt.plot(mean_fpr_val, mean_tpr_val, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_val),lw=2, alpha=.8)
std_tpr_val = np.std(tprs_val, axis=0)
tprs_upper_val = np.minimum(mean_tpr_val + std_tpr_val, 1)
tprs_lower_val = np.maximum(mean_tpr_val - std_tpr_val, 0)
plt.fill_between(mean_fpr_val, tprs_lower_val, tprs_upper_val, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Cross-Validation ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_val_mean.png')
plt.show()

# %%
def calculate_metrics_val(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_val = []
for score_val,lable_val in zip(scores_val,lables_val):
    val_my_calculate_metrics = calculate_metrics_val(lable_val,score_val)
    my_calculate_metrics_list_val.append(val_my_calculate_metrics)

# %%
my_calculate_metrics_list_val
# Out:
# [{'SN': 0.7964601769911505,
#   'SP': 0.5625,
#   'ACC': 0.68,
#   'MCC': 0.3693498083336148,
#   'Recall': 0.7964601769911505,
#   'Precision': 0.6474820143884892,
#   'F1-score': 0.7142857142857143,
#   'Cutoff': 0.5},
#  {'SN': 0.6964285714285714,
#   'SP': 0.6607142857142857,
#   'ACC': 0.6785714285714286,
#   'MCC': 0.35737084494593163,
#   'Recall': 0.6964285714285714,
#   'Precision': 0.6724137931034483,
#   'F1-score': 0.6842105263157895,
#   'Cutoff': 0.5},
#  {'SN': 0.6637168141592921,
#   'SP': 0.6517857142857143,
#   'ACC': 0.6577777777777778,
#   'MCC': 0.31552746048727887,
#   'Recall': 0.6637168141592921,
#   'Precision': 0.6578947368421053,
#   'F1-score': 0.6607929515418502,
#   'Cutoff': 0.5},
#  {'SN': 0.6548672566371682,
#   'SP': 0.7053571428571429,
#   'ACC': 0.68,
#   'MCC': 0.3606521010730979,
#   'Recall': 0.6548672566371682,
#   'Precision': 0.6915887850467289,
#   'F1-score': 0.6727272727272727,
#   'Cutoff': 0.5},
#  {'SN': 0.7345132743362832,
#   'SP': 0.5625,
#   'ACC': 0.6488888888888888,
#   'MCC': 0.3015752196134296,
#   'Recall': 0.7345132743362832,
#   'Precision': 0.6287878787878788,
#   'F1-score': 0.6775510204081633,
#   'Cutoff': 0.5},
#  {'SN': 0.6428571428571429,
#   'SP': 0.7610619469026548,
#   'ACC': 0.7022222222222222,
#   'MCC': 0.40685507928953984,
#   'Recall': 0.6428571428571429,
#   'Precision': 0.7272727272727273,
#   'F1-score': 0.6824644549763034,
#   'Cutoff': 0.5},
#  {'SN': 0.7142857142857143,
#   'SP': 0.5486725663716814,
#   'ACC': 0.6311111111111111,
#   'MCC': 0.26658487766103417,
#   'Recall': 0.7142857142857143,
#   'Precision': 0.6106870229007634,
#   'F1-score': 0.6584362139917695,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.584070796460177,
#   'ACC': 0.6888888888888889,
#   'MCC': 0.3872529532211876,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.6544117647058824,
#   'F1-score': 0.717741935483871,
#   'Cutoff': 0.5},
#  {'SN': 0.5982142857142857,
#   'SP': 0.7699115044247787,
#   'ACC': 0.6844444444444444,
#   'MCC': 0.37377998089358033,
#   'Recall': 0.5982142857142857,
#   'Precision': 0.7204301075268817,
#   'F1-score': 0.6536585365853659,
#   'Cutoff': 0.5},
#  {'SN': 0.6607142857142857,
#   'SP': 0.6607142857142857,
#   'ACC': 0.6607142857142857,
#   'MCC': 0.32142857142857145,
#   'Recall': 0.6607142857142857,
#   'Precision': 0.6607142857142857,
#   'F1-score': 0.6607142857142857,
#   'Cutoff': 0.5}]

# %%
performance_val=pd.DataFrame(my_calculate_metrics_list_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.796460  0.562500  0.680000  0.369350  0.796460   0.647482  0.714286
# 1  0.696429  0.660714  0.678571  0.357371  0.696429   0.672414  0.684211
# 2  0.663717  0.651786  0.657778  0.315527  0.663717   0.657895  0.660793
# 3  0.654867  0.705357  0.680000  0.360652  0.654867   0.691589  0.672727
# 4  0.734513  0.562500  0.648889  0.301575  0.734513   0.628788  0.677551
# 5  0.642857  0.761062  0.702222  0.406855  0.642857   0.727273  0.682464
# 6  0.714286  0.548673  0.631111  0.266585  0.714286   0.610687  0.658436
# 7  0.794643  0.584071  0.688889  0.387253  0.794643   0.654412  0.717742
# 8  0.598214  0.769912  0.684444  0.373780  0.598214   0.720430  0.653659
# 9  0.660714  0.660714  0.660714  0.321429  0.660714   0.660714  0.660714
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_val = performance_val.std(axis = 0,ddof=1)
mean_val = performance_val.mean(axis = 0)
data_mean_val = pd.DataFrame(mean_val)
data_mean_val = data_mean_val.T
data_std_val = pd.DataFrame(std_val)
data_std_val = data_std_val.T
performance_val = performance_val.append(data_mean_val)
performance_val = performance_val.append(data_std_val)
performance_val
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.796460  0.562500  0.680000  0.369350  0.796460   0.647482  0.714286
# 1  0.696429  0.660714  0.678571  0.357371  0.696429   0.672414  0.684211
# 2  0.663717  0.651786  0.657778  0.315527  0.663717   0.657895  0.660793
# 3  0.654867  0.705357  0.680000  0.360652  0.654867   0.691589  0.672727
# 4  0.734513  0.562500  0.648889  0.301575  0.734513   0.628788  0.677551
# 5  0.642857  0.761062  0.702222  0.406855  0.642857   0.727273  0.682464
# 6  0.714286  0.548673  0.631111  0.266585  0.714286   0.610687  0.658436
# 7  0.794643  0.584071  0.688889  0.387253  0.794643   0.654412  0.717742
# 8  0.598214  0.769912  0.684444  0.373780  0.598214   0.720430  0.653659
# 9  0.660714  0.660714  0.660714  0.321429  0.660714   0.660714  0.660714
# 0  0.695670  0.646729  0.671262  0.346038  0.695670   0.667168  0.678258
# 0  0.064983  0.081534  0.021226  0.043306  0.064983   0.037140  0.022490
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_val.to_csv(r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\result\CNN_OH_performance_val.csv',encoding='utf-8')

# %% [markdown]
# 独立测试

# %%
#遍历表格求初始里程
#独立测试
import os
path = r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\result\indep'
filenames=os.listdir(path)#得到字符串列表
scores_indep=[]
lables_indep=[]
fpr_list_indep = []
tpr_list_indep = []
roc_auc_list_indep=[]
i=0
for filename in filenames:
        true_path=path+r'\\'+filename
        data=pd.read_csv(true_path,engine='python')
        score_indep=data.iloc[:,1]
        scores_indep.append(score_indep)
        lable_indep = data.iloc[:,2]
        lables_indep.append(lable_indep)
        fpr_indep,tpr_indep,thresholds_indep= roc_curve(lables_indep[i],scores_indep[i])   #y_true,y_score
        fpr_list_indep.append(fpr_indep)
        tpr_list_indep.append(tpr_indep)
        roc_auc_indep = auc(fpr_indep,tpr_indep)
        roc_auc_list_indep.append(roc_auc_indep)
        i+=1

# %%
roc_auc_list_indep
# Out:
# [0.7043207908163265,
#  0.7325414540816326,
#  0.7165975765306123,
#  0.7615593112244897,
#  0.7455357142857143,
#  0.7287149234693877,
#  0.7507174744897959,
#  0.7277582908163265,
#  0.7385204081632654,
#  0.7379623724489797]

# %%
i=1
tprs_indep = []
mean_fpr_indep = np.linspace(0, 1, 100)
plt.figure(figsize=(6,6))
plt.title('Independent ROC')
for fpr_indep,tpr_indep,roc_auc_indep in zip(fpr_list_indep,tpr_list_indep,roc_auc_list_indep):
    tprs_indep.append(np.interp(mean_fpr_indep, fpr_indep, tpr_indep))
    tprs_indep[-1][0] = 0.0
    plt.plot(fpr_indep, tpr_indep, label = 'Val ' + str(i) + ' AUC = %0.3f' % roc_auc_indep)
    i+=1
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig('CNN_OH_indep.png')
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8)
mean_tpr_indep = np.mean(tprs_indep, axis=0)
mean_tpr_indep[-1] = 1.0
mean_auc_indep = auc(mean_fpr_indep, mean_tpr_indep)
std_auc_indep = np.std(roc_auc_list_indep)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.3f $\pm$ %0.3f)' % (mean_auc_indep, std_auc_indep),lw=2, alpha=.8)
plt.plot(mean_fpr_indep, mean_tpr_indep, color='b',label=r'Mean ROC (AUC = %0.4f)' % (mean_auc_indep),lw=2, alpha=.8)
std_tpr_indep = np.std(tprs_indep, axis=0)
tprs_upper_indep = np.minimum(mean_tpr_indep + std_tpr_indep, 1)
tprs_lower_indep = np.maximum(mean_tpr_indep - std_tpr_indep, 0)
plt.fill_between(mean_fpr_indep, tprs_lower_indep, tprs_upper_indep, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate',fontsize=10)
plt.ylabel('True Positive Rate',fontsize=10)
plt.title('Independent ROC',fontsize=10)
plt.legend(loc="lower right", prop={'size': 8})
plt.savefig('CNN_OH_indep_mean.png')
plt.show()

# %%
def calculate_metrics_indep(labels, scores, cutoff=0.5, po_label=1):  # 计算阈值为0.5时的各性能指数
    my_metrics = {  # 先声明建立一个字典，对应KEY值
        'SN': 'NA',
        'SP': 'NA',
        'ACC': 'NA',
        'MCC': 'NA',
        'Recall': 'NA',
        'Precision': 'NA',
        'F1-score': 'NA',
        'Cutoff': cutoff,
    }
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(scores)):
        if labels[i] == po_label:  # 如果为正样本
            if scores[i] >= cutoff:  # 阈值为0.5，如果打分大于0.5
                tp = tp + 1  # tp+1  预测为真，实际为真的
            else:
                fn = fn + 1  # 预测为真，实际为负
        else:  # 如果为负样本
            if scores[i] < cutoff:  # 打分小于阈值，说明实际为负，预测也为负
                tn = tn + 1  # tn+1
            else:
                fp = fp + 1  # 打分大于阈值，说明实际为负，预测为正
    my_metrics['SN'] = tp / (tp + fn) if (tp + fn) != 0 else 'NA'  # sn 灵敏度
    my_metrics['SP'] = tn / (fp + tn) if (fp + tn) != 0 else 'NA'  # sp 特异性
    my_metrics['ACC'] = (tp + tn) / (tp + fn + tn + fp)  # acc正确度
    my_metrics['MCC'] = (tp * tn - fp * fn) / np.math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) if ( tp + fp) * ( tp + fn) * ( tn + fp) * ( tn + fn) != 0 else 'NA'
    my_metrics['Precision'] = tp / (tp + fp) if (tp + fp) != 0 else 'NA'  # 查准率
    my_metrics['Recall'] = my_metrics['SN']  # 召回率
    my_metrics['F1-score'] = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) != 0 else 'NA'
    return my_metrics

# %%
my_calculate_metrics_list_indep = []
for score_indep,lable_indep in zip(scores_indep,lables_indep):
    indep_my_calculate_metrics = calculate_metrics_indep(lable_indep,score_indep)
    my_calculate_metrics_list_indep.append(indep_my_calculate_metrics)

# %%
my_calculate_metrics_list_indep
# Out:
# [{'SN': 0.7678571428571429,
#   'SP': 0.49107142857142855,
#   'ACC': 0.6294642857142857,
#   'MCC': 0.26945575878006256,
#   'Recall': 0.7678571428571429,
#   'Precision': 0.6013986013986014,
#   'F1-score': 0.6745098039215687,
#   'Cutoff': 0.5},
#  {'SN': 0.7142857142857143,
#   'SP': 0.6339285714285714,
#   'ACC': 0.6741071428571429,
#   'MCC': 0.3493440168037039,
#   'Recall': 0.7142857142857143,
#   'Precision': 0.6611570247933884,
#   'F1-score': 0.6866952789699571,
#   'Cutoff': 0.5},
#  {'SN': 0.6428571428571429,
#   'SP': 0.6875,
#   'ACC': 0.6651785714285714,
#   'MCC': 0.33068683410589317,
#   'Recall': 0.6428571428571429,
#   'Precision': 0.6728971962616822,
#   'F1-score': 0.6575342465753424,
#   'Cutoff': 0.5},
#  {'SN': 0.7142857142857143,
#   'SP': 0.6964285714285714,
#   'ACC': 0.7053571428571429,
#   'MCC': 0.4107797851622286,
#   'Recall': 0.7142857142857143,
#   'Precision': 0.7017543859649122,
#   'F1-score': 0.7079646017699115,
#   'Cutoff': 0.5},
#  {'SN': 0.7946428571428571,
#   'SP': 0.5803571428571429,
#   'ACC': 0.6875,
#   'MCC': 0.38391802266674363,
#   'Recall': 0.7946428571428571,
#   'Precision': 0.6544117647058824,
#   'F1-score': 0.717741935483871,
#   'Cutoff': 0.5},
#  {'SN': 0.6339285714285714,
#   'SP': 0.7232142857142857,
#   'ACC': 0.6785714285714286,
#   'MCC': 0.3585749859822395,
#   'Recall': 0.6339285714285714,
#   'Precision': 0.696078431372549,
#   'F1-score': 0.6635514018691588,
#   'Cutoff': 0.5},
#  {'SN': 0.7053571428571429,
#   'SP': 0.6428571428571429,
#   'ACC': 0.6741071428571429,
#   'MCC': 0.34889639074744044,
#   'Recall': 0.7053571428571429,
#   'Precision': 0.6638655462184874,
#   'F1-score': 0.683982683982684,
#   'Cutoff': 0.5},
#  {'SN': 0.7678571428571429,
#   'SP': 0.6071428571428571,
#   'ACC': 0.6875,
#   'MCC': 0.3799388356322685,
#   'Recall': 0.7678571428571429,
#   'Precision': 0.6615384615384615,
#   'F1-score': 0.7107438016528925,
#   'Cutoff': 0.5},
#  {'SN': 0.5982142857142857,
#   'SP': 0.7946428571428571,
#   'ACC': 0.6964285714285714,
#   'MCC': 0.40066280078597893,
#   'Recall': 0.5982142857142857,
#   'Precision': 0.7444444444444445,
#   'F1-score': 0.6633663366336634,
#   'Cutoff': 0.5},
#  {'SN': 0.6607142857142857,
#   'SP': 0.6875,
#   'ACC': 0.6741071428571429,
#   'MCC': 0.3483392704067959,
#   'Recall': 0.6607142857142857,
#   'Precision': 0.6788990825688074,
#   'F1-score': 0.669683257918552,
#   'Cutoff': 0.5}]

# %%
performance_indep=pd.DataFrame(my_calculate_metrics_list_indep)
performance_indep
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.767857  0.491071  0.629464  0.269456  0.767857   0.601399  0.674510
# 1  0.714286  0.633929  0.674107  0.349344  0.714286   0.661157  0.686695
# 2  0.642857  0.687500  0.665179  0.330687  0.642857   0.672897  0.657534
# 3  0.714286  0.696429  0.705357  0.410780  0.714286   0.701754  0.707965
# 4  0.794643  0.580357  0.687500  0.383918  0.794643   0.654412  0.717742
# 5  0.633929  0.723214  0.678571  0.358575  0.633929   0.696078  0.663551
# 6  0.705357  0.642857  0.674107  0.348896  0.705357   0.663866  0.683983
# 7  0.767857  0.607143  0.687500  0.379939  0.767857   0.661538  0.710744
# 8  0.598214  0.794643  0.696429  0.400663  0.598214   0.744444  0.663366
# 9  0.660714  0.687500  0.674107  0.348339  0.660714   0.678899  0.669683
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5

# %%
std_indep = performance_indep.std(axis = 0,ddof=1)
mean_indep = performance_indep.mean(axis = 0)
data_mean_indep = pd.DataFrame(mean_indep)
data_mean_indep = data_mean_indep.T
data_std_indep = pd.DataFrame(std_indep)
data_std_indep = data_std_indep.T
performance_indep = performance_indep.append(data_mean_indep)
performance_indep = performance_indep.append(data_std_indep)
performance_indep
# Out:
#          SN        SP       ACC       MCC    Recall  Precision  F1-score  \
# 0  0.767857  0.491071  0.629464  0.269456  0.767857   0.601399  0.674510
# 1  0.714286  0.633929  0.674107  0.349344  0.714286   0.661157  0.686695
# 2  0.642857  0.687500  0.665179  0.330687  0.642857   0.672897  0.657534
# 3  0.714286  0.696429  0.705357  0.410780  0.714286   0.701754  0.707965
# 4  0.794643  0.580357  0.687500  0.383918  0.794643   0.654412  0.717742
# 5  0.633929  0.723214  0.678571  0.358575  0.633929   0.696078  0.663551
# 6  0.705357  0.642857  0.674107  0.348896  0.705357   0.663866  0.683983
# 7  0.767857  0.607143  0.687500  0.379939  0.767857   0.661538  0.710744
# 8  0.598214  0.794643  0.696429  0.400663  0.598214   0.744444  0.663366
# 9  0.660714  0.687500  0.674107  0.348339  0.660714   0.678899  0.669683
# 0  0.700000  0.654464  0.677232  0.358060  0.700000   0.673644  0.683577
# 0  0.065096  0.083868  0.020625  0.040272  0.065096   0.037001  0.021789
#
#    Cutoff
# 0     0.5
# 1     0.5
# 2     0.5
# 3     0.5
# 4     0.5
# 5     0.5
# 6     0.5
# 7     0.5
# 8     0.5
# 9     0.5
# 0     0.5
# 0     0.0

# %%
performance_val.to_csv(r'D:\PycharmProjects\pythonProject\最后2\41window\DL\CNN_OH_new\result\CNN_OH_performance_indep.csv',encoding='utf-8')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
